# %%
import os
import re
import spacy
import pandas as pd

# %% [markdown]
# # Preprocess Text

# %%
FILE_PATH = "../assets/NER_assets/Ancient_Words.csv"
# read csv file
df = pd.read_csv(FILE_PATH)

# %%
# rename columns to fit code
df.rename(columns = {'Word':'Keyword', 'Category Types':'Label'}, inplace = True)
# If a cell is empty (NaN), Fill it with the value in its parallel "Early" column
for row in df:
    df['Quote'].fillna(df['Early Quote'], inplace=True)
    df['Word Before'].fillna(df['Early Word Before'], inplace=True)
    df['Word After'].fillna(df['Early Word After'], inplace=True)
    df['Label'].fillna(df['Early Category Type'], inplace=True)
# remove rows with no Keyword
df = df.dropna(subset=['Keyword'])
# Remove any row that isn't Greek
pat = '[ء-ي]+'
#df.Keyword.str.contains(pat)
df = df[~df.Keyword.str.contains(pat, na=False)]
#replace new line in df column
df['Keyword'].replace('\n', '', regex=True, inplace=True)
#replace numbers in df
df.replace('\d+', '', regex=True, inplace=True)
#replace hyphens in df column
df.replace('-', '', regex=True, inplace=True)
# replace comma in df column
df['Keyword'].replace(',', '', regex=True, inplace=True)
#replace period in df column
df['Keyword'].replace('\.', '', regex=True, inplace=True)
#replace interpunkt in df column
df['Keyword'].replace('\·', '', regex=True, inplace=True)
# replace multiple spaces in df column
df.replace(' +', ' ', regex=True, inplace=True)
# replace end punctuation in df column
df['Keyword'].replace('\s+$', '', regex=True, inplace=True)

df.fillna(0)
df.reset_index(drop=True, inplace=True)

# %%
df.head(10)
# Out:
#      Keyword Word Before Word After  \
# 0  ἐγκέφαλος          ὁ    ἐστὶ τοῦ
# 1    διπλόος   ἀνθρώπου      ὥσπερ
# 2      μέσον          δὲ      αὐτοῦ
# 3   διείργει       αὐτοῦ     μῆνιγξ
# 4     μῆνιγξ   διείργει       λεπτή
# 5      λεπτή      μῆνιγξ          .
# 6    κεφαλὴς        τῆς       ἀλγεῖ
# 7      ἀλγεῖ    κεφαλὴς       ἀλλ'
# 8      μέρει          ἐν   ἑκάτερον
# 9     ἅπασαν         δὲ       . καὶ
#
#                                                Quote                 Label  \
# 0  ὁ ἐγκέφαλος ἐστὶ τοῦ ἀνθρώπου διπλόος ὥσπερ κα...             Body Part
# 1  ὁ ἐγκέφαλος ἐστὶ τοῦ ἀνθρώπου διπλόος ὥσπερ κα...  Adjectives/Qualities
# 2            τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή            Topography
# 3            τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή            Topography
# 4            τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή             Body Part
# 5            τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή  Adjectives/Qualities
# 6  διότι οὐκ αἰεὶ κατὰ τωὐτὸ τῆς κεφαλὴς ἀλγεῖ, ἀ...             Body Part
# 7  διότι οὐκ αἰεὶ κατὰ τωὐτὸ τῆς κεφαλὴς ἀλγεῖ, ἀ...             Pathology
# 8  διότι οὐκ αἰεὶ κατὰ τωὐτὸ τῆς κεφαλὴς ἀλγεῖ, ἀ...            Topography
# 9  διότι οὐκ αἰεὶ κατὰ τωὐτὸ τῆς κεφαλὴς ἀλγεῖ, ἀ...            Topography
#
#        Lemma Early Category Type Early Word Early Word Before  \
# 0  ἐγκέφαλος                 NaN        NaN                 ο
# 1    διπλόος                 NaN        NaN              εστι
# 2      μέσος                 NaN        NaN               NaN
# 3    διείργω                 NaN        NaN             αυτου
# 4     μῆνιγξ                 NaN        NaN          διείργει
# 5     λεπτός                 NaN        NaN            μῆνιγξ
# 6     κεφαλή                 NaN        NaN               NaN
# 7      ἀλγέω                 NaN        NaN               NaN
# 8      μέρος                 NaN        NaN               NaN
# 9       ἅπας                 NaN        NaN               NaN
#
#   Early Word After Early Quote  Lemma arabic
# 0              του         NaN           NaN
# 1            ωσπερ         NaN           NaN
# 2              NaN         NaN           NaN
# 3           μηνιγξ         NaN           NaN
# 4            λεπτή         NaN           NaN
# 5                .         NaN           NaN
# 6              NaN         NaN           NaN
# 7              NaN         NaN           NaN
# 8              NaN         NaN           NaN
# 9              NaN         NaN           NaN

# %%
# if any of the fields "KeyWord", "Quote", "Word Before", "Word After" are "0", drop the row
for w in ['Keyword', 'Quote', 'Word Before', 'Word After']:
    df = df[df[w] != 0]

# %%
# import requirements for converting the dataframe to Spacy Docs
from collections import defaultdict
from typing import List
from spacy.language import Language
from spacy.tokens import Doc, DocBin, Span
from spacy.util import filter_spans
from unicodedata import normalize
import regex
import random

# %%
d = {ord('\N{COMBINING ACUTE ACCENT}'):None, ord('\N{COMBINING COMMA ABOVE}'):None, ord('\N{COMBINING REVERSED COMMA ABOVE}'):None}

def find_word_index(sentence, word, word_before, word_after):
    """Find the index of a word in a sentence, it can appear multiple times but we return by word_before and word_after"""


    # find the index of the word in the sentence (return index of beginning of word)
    word_index = sentence.find(word)

    # return all chars of word before: [),.,·] (meaning none of these chars will be included) so we get only data contained within the sentence
    for char in [")", ".", "·"]:
        if word_before.find(char) != -1:
            word_before = word_before[word_before.find(char)+1:]
        if word_after.find(char) != -1:
            word_after = word_after[:word_after.find(char)]



    pattern = fr"{re.escape(word_before)}({(word)}){re.escape(word_after)}"
    # add fuzzy matching with up to 3 mistakes
    pattern = fr"(?:{pattern}){{e<=3}}"



    match = regex.search(pattern, sentence)
    try:
        print ("match:", match.span(1))
        return match.span(1)
    except:

        return None

# %%
# normalize table
FORMAT = 'NFKD'
for col in ['Keyword', 'Quote', 'Word Before', 'Word After']:
    df[col] = df[col].apply(lambda x: normalize(FORMAT, x))

# %%
# using word before and word after, we want to bring our data into the following format:
# TRAIN_DATA = [ (TEXT AS A STRING, {“entities”: [(START, END, LABEL)]}) ]

TRAIN_DATA = []
train_data_df = pd.DataFrame(columns=['text', 'keyword', 'index', 'label', 'lemma'])
no_found = 0

for i,row in df.iterrows():
    # fill train_data_df with index from find_word_index
    index = find_word_index(row['Quote'], row['Keyword'], row['Word Before'], row['Word After'])
    if index:
        row_to_add = [row['Quote'], row['Keyword'], index, row['Label'], row['Lemma']]
        train_data_df = pd.concat([train_data_df, pd.DataFrame([row_to_add], columns=['text', 'keyword', 'index', 'label', 'lemma'])], ignore_index=True)
    else:
        print ("No index found for", row['Keyword'], "in", row['Quote'])
        no_found += 1

print ("No index found for", no_found, "words")
# Out:
# match: (3, 14)
# match: (38, 46)
# match: (7, 14)
# match: (22, 32)
# match: (33, 40)
# match: (40, 47)
# match: (38, 46)
# match: (47, 54)
# match: (65, 72)
# match: (95, 103)
# match: (4, 12)
# match: (27, 38)
# match: (66, 74)
# match: (79, 87)
# match: (87, 93)
# match: (97, 106)
# match: (115, 121)
# match: (126, 135)
# match: (143, 149)
# No index found for σπληνός in Καὶ φλέβες δ' ἐς αὐτὸν τείνουσιν ἐξ ἅπαντος τοῦ σώματος πολλαὶ καὶ λεπταί, δύο δὲ παχεῖαι, ἡ μὲν ἀπὸ τοῦ ἥπατος, ἡ δὲ ἀπὸ τοῦ σπληνός
# match: (12, 18)
# match: (23, 32)
# match: (38, 45)
# match: (16, 24)
# match: (24, 30)
# match: (30, 38)
# match: (38, 43)
# match: (48, 54)
# match: (54, 61)
# match: (61, 66)
# match: (67, 74)
# match: (79, 87)
# match: (98, 103)
# match: (104, 107)
# match: (112, 119)
# match: (125, 131)
# match: (137, 145)
# match: (146, 149)
# match: (155, 160)
# match: (176, 182)
# match: (183, 188)
# match: (14, 19)
# match: (20, 27)
# match: (28, 32)
# match: (38, 45)
# match: (56, 66)
# match: (67, 71)
# match: (71, 79)
# match: (79, 93)
# match: (103, 106)
# match: (112, 120)
# match: (103, 106)
# match: (134, 144)
# match: (149, 157)
# match: (180, 185)
# match: (186, 192)
# match: (193, 197)
# match: (202, 212)
# match: (216, 227)
# match: (233, 242)
# match: (242, 247)
# match: (259, 265)
# match: (272, 283)
# match: (319, 329)
# match: (334, 344)
# match: (345, 354)
# match: (14, 24)
# match: (30, 39)
# match: (45, 56)
# match: (66, 77)
# match: (78, 87)
# No index found for δεξιὸν in καὶ τὸ μὲν παχύτατον καὶ μέγιστον καὶ κοιλότατον ἐς τὸν ἐγκέφαλον τελευτᾷ, τὸ δὲ ἐς τὸ οὖς τὸ δεξιὸν, τὸ δὲ ἐς τὸν ὀφθαλμὸν τὸν δεξιόν, τὸ δὲ ἐς τὸν μυκτῆρα
# match: (141, 151)
# No index found for δεξιόν in καὶ τὸ μὲν παχύτατον καὶ μέγιστον καὶ κοιλότατον ἐς τὸν ἐγκέφαλον τελευτᾷ, τὸ δὲ ἐς τὸ οὖς τὸ δεξιὸν, τὸ δὲ ἐς τὸν ὀφθαλμὸν τὸν δεξιόν, τὸ δὲ ἐς τὸν μυκτῆρα
# match: (182, 191)
# match: (0, 5)
# match: (15, 24)
# match: (24, 32)
# match: (32, 39)
# No index found for φλεβῶν in Ἀπὸ μὲν τοῦ ἥπατος οὕτως ἔχει τῶν φλεβῶν
# match: (0, 11)
# match: (20, 26)
# No index found for σπληνὸς in διατέταται δὲ καὶ ἀπὸ τοῦ σπληνὸς φλὲψ ἐς τὰ ἀριστερὰ καὶ κάτω καὶ ἄνω, ὥσπερ καὶ ἀπὸ τοῦ ἥπατος, λεπτοτέρη δὲ καὶ ἀσθενεστέρη
# match: (41, 46)
# No index found for ἀριστερὰ in διατέταται δὲ καὶ ἀπὸ τοῦ σπληνὸς φλὲψ ἐς τὰ ἀριστερὰ καὶ κάτω καὶ ἄνω, ὥσπερ καὶ ἀπὸ τοῦ ἥπατος, λεπτοτέρη δὲ καὶ ἀσθενεστέρη
# match: (71, 76)
# match: (82, 87)
# match: (101, 107)
# No index found for ἥπατος in διατέταται δὲ καὶ ἀπὸ τοῦ σπληνὸς φλὲψ ἐς τὰ ἀριστερὰ καὶ κάτω καὶ ἄνω, ὥσπερ καὶ ἀπὸ τοῦ ἥπατος, λεπτοτέρη δὲ καὶ ἀσθενεστέρη
# match: (121, 133)
# match: (142, 156)
# match: (9, 16)
# match: (17, 23)
# match: (31, 43)
# match: (31, 43)
# match: (49, 56)
# match: (101, 109)
# match: (33, 43)
# match: (48, 55)
# match: (60, 65)
# match: (84, 92)
# match: (19, 27)
# match: (33, 40)
# match: (44, 52)
# match: (35, 41)
# match: (63, 71)
# match: (70, 77)
# match: (12, 20)
# match: (28, 35)
# match: (41, 50)
# match: (50, 58)
# No index found for θερμοῦ in αἵ τε γὰρ φλέβες εἰσὶ κοῖλαι καὶ αἵματος μεσταὶ θερμοῦ
# match: (187, 195)
# match: (127, 135)
# match: (130, 141)
# match: (11, 18)
# match: (48, 59)
# match: (70, 78)
# match: (78, 95)
# match: (107, 116)
# No index found for ἀριστεροῖσιν in ἐς δὲ τὰ δεξιὰ μᾶλλον καταρρεῖ ἢ ἐς τὰ ἀριστερά, ὅτι αἱ φλέβες ἐπικοιλότεραί εἰσὶ καὶ πλέονες ἢ ἐν τοῖσιν ἀριστεροῖσιν
# No index found for ἀπὸ in ἀπὸ γὰρ τοῦ ἥπατος τείνουσι καὶ ἀπὸ τοῦ σπληνός
# match: (15, 24)
# match: (15, 24)
# match: (24, 34)
# No index found for σπληνός in ἀπὸ γὰρ τοῦ ἥπατος τείνουσι καὶ ἀπὸ τοῦ σπληνός
# No index found for σπληνός in ἀπὸ γὰρ τοῦ ἥπατος τείνουσι καὶ ἀπὸ τοῦ σπληνός
# match: (98, 106)
# match: (186, 198)
# match: (65, 77)
# match: (78, 92)
# match: (97, 109)
# match: (50, 59)
# match: (69, 81)
# match: (75, 83)
# match: (8, 16)
# match: (16, 24)
# match: (32, 41)
# match: (50, 62)
# match: (18, 29)
# match: (8, 15)
# match: (221, 234)
# match: (5, 13)
# match: (19, 28)
# match: (44, 52)
# match: (61, 68)
# match: (32, 40)
# match: (44, 52)
# match: (53, 62)
# match: (69, 81)
# match: (82, 88)
# match: (59, 72)
# match: (10, 17)
# match: (52, 60)
# match: (84, 96)
# match: (172, 177)
# match: (172, 177)
# No index found for σπλάγχνων in Δοκεῖ δὲ τῶν σπλάγχνων τὰ μὲν εἶναι μονοφυῆ, καθάπερ καρδία καὶ πλεύμων, τὰ δὲ διφυῆ, καθάπερ νεφροί, τὰ δ' ἀπορεῖται ποτέρως ἔχει.
# match: (43, 52)
# match: (62, 70)
# match: (75, 84)
# match: (93, 100)
# match: (111, 118)
# match: (47, 54)
# match: (62, 69)
# match: (13, 23)
# No index found for διφυῆ in Ἔστι δὲ πάντα διφυῆ
# match: (13, 19)
# match: (25, 30)
# match: (38, 50)
# match: (55, 65)
# match: (73, 81)
# match: (86, 98)
# match: (15, 27)
# match: (37, 46)
# match: (70, 84)
# match: (32, 40)
# match: (46, 56)
# match: (6, 15)
# match: (51, 62)
# match: (97, 108)
# match: (8, 16)
# match: (13, 20)
# match: (30, 38)
# match: (63, 71)
# match: (92, 99)
# match: (107, 114)
# match: (117, 124)
# match: (175, 186)
# match: (194, 203)
# match: (221, 230)
# match: (234, 242)
# match: (273, 280)
# match: (288, 298)
# match: (304, 315)
# match: (17, 24)
# match: (145, 156)
# match: (214, 222)
# match: (17, 24)
# match: (36, 43)
# match: (53, 62)
# match: (78, 87)
# match: (95, 102)
# match: (15, 22)
# match: (26, 34)
# match: (47, 58)
# match: (108, 116)
# match: (12, 21)
# match: (27, 30)
# match: (54, 62)
# match: (70, 78)
# match: (78, 82)
# match: (30, 38)
# match: (0, 3)
# match: (25, 32)
# match: (37, 46)
# No index found for λεπτότατον in ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δ’ ἐστὶ τὸ ἐν τῇ μέσῃ.
# match: (73, 77)
# match: (83, 89)
# match: (0, 5)
# match: (14, 24)
# match: (35, 44)
# match: (53, 62)
# match: (79, 87)
# No index found for πρός in Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρ τημέναι, ἐν μέσῳ δ’ ἔχει τὰ λεπτὰ καὶ ὑμενώδη
# match: (103, 111)
# match: (120, 133)
# match: (143, 151)
# match: (151, 166)
# match: (167, 171)
# match: (171, 178)
# match: (192, 199)
# match: (205, 214)
# match: (10, 15)
# match: (14, 22)
# match: (27, 35)
# match: (35, 46)
# match: (28, 36)
# match: (36, 45)
# match: (23, 31)
# match: (36, 47)
# match: (47, 59)
# No index found for χονδρώδεσι in Συνήρτηται δὲ καὶ ἡ καρδία τῇ ἀρτηρίᾳ πιμελώδεσι καὶ χονδρώδεσι καὶ ἰνώδεσι δεσμοῖς
# match: (81, 91)
# match: (91, 100)
# match: (0, 4)
# No index found for συνήρτηται in ᾗ δὲ συνήρτηται κοῖλόν ἐστιν
# No index found for κοῖλον in ᾗ δὲ συνήρτηται κοῖλόν ἐστιν
# match: (19, 30)
# match: (120, 132)
# match: (136, 144)
# match: (144, 149)
# match: (149, 157)
# match: (13, 23)
# match: (57, 66)
# No index found for πνεῦμα in Ἡ μὲν οὖν ἀρτηρία τοῦτον ἔχει τὸν τρόπον, καὶ δέχεται μόνον τὸ πνεῦμα καὶ ἀφίησιν ἄλλο δ’ οὐθὲν οὔτε ξηρὸν οὔθ’ ὑγρόν, ἢ πόνον παρέχει, ἕως ἂν ἐκβήξῃ τὸ κατελθόν.
# match: (90, 100)
# match: (125, 132)
# match: (138, 147)
# match: (152, 159)
# match: (180, 190)
# match: (19, 28)
# match: (32, 40)
# match: (20, 32)
# match: (49, 60)
# match: (60, 68)
# match: (68, 78)
# match: (14, 25)
# match: (61, 72)
# match: (80, 87)
# No index found for ἀνωμαλίαν in Ἔστι δ’ οὐ πολυσχιδὴς ὁ τοῦ ἀνθρώπου, ὥσπερ ἐνίων ζῳοτόκων, οὐδὲ λεῖος, ἀλλ’ ἔχει ἀνωμαλίαν
# match: (13, 25)
# match: (70, 80)
# match: (91, 98)
# match: (115, 124)
# match: (152, 156)
# match: (5, 10)
# match: (10, 16)
# match: (40, 51)
# match: (51, 57)
# match: (57, 68)
# match: (72, 79)
# match: (79, 89)
# No index found for πλεύμονος in καὶ ἀπὸ μιᾶς δύο ἐστὶ μόρια τῆς ἀρτηρίας, εἰς ἑκάτερον τὸ μέρος τείνοντα τοῦ πλεύμονος
# No index found for μεγάλῃ φλεβὶ in Συνήρτηται δὲ καὶ τῇ μεγάλῃ φλεβὶ καὶ τῇ ἀορτῇ καλουμένῃ
# match: (51, 60)
# match: (19, 30)
# match: (30, 42)
# match: (42, 47)
# match: (51, 58)
# match: (58, 64)
# match: (69, 80)
# No index found for πνεῦμα in Φυσωμένης δὲ τῆς ἀρτηρίας διαδίδωσιν εἰς τὰ κοῖλα μέρη τοῦ πλεύμονος τὸ πνεῦμα
# match: (10, 21)
# match: (29, 40)
# No index found for εἰς in Ταῦτα δὲ διαφύσεις ἔχει χονδρώδεις εἰς ὀξὺ συνηκούσας
# match: (45, 51)
# No index found for συνηκούσας in Ταῦτα δὲ διαφύσεις ἔχει χονδρώδεις εἰς ὀξὺ συνηκούσας
# match: (75, 78)
# match: (13, 23)
# match: (23, 32)
# match: (32, 37)
# match: (37, 45)
# match: (56, 67)
# match: (78, 88)
# match: (93, 102)
# match: (0, 7)
# match: (16, 26)
# match: (34, 45)
# No index found for ἀρτηρία in Ἐντὸς δὲ τοῦ αὐχένος ὅ τε οἰσοφάγος καλούμενός ἐστιν, ἔχων τὴν ἐπωνυμίαν ἀπὸ τοῦ μήκους καὶ τῆς στενότητος, καὶ ἡ ἀρτηρία
# match: (0, 9)
# match: (19, 25)
# match: (29, 38)
# match: (39, 46)
# match: (52, 63)
# match: (35, 44)
# match: (18, 27)
# match: (28, 38)
# match: (44, 50)
# match: (56, 67)
# match: (68, 77)
# match: (78, 86)
# match: (86, 96)
# match: (97, 109)
# match: (110, 118)
# match: (122, 127)
# match: (136, 142)
# match: (142, 148)
# match: (152, 159)
# match: (159, 165)
# match: (170, 174)
# match: (179, 189)
# match: (190, 200)
# match: (209, 216)
# match: (234, 244)
# match: (245, 258)
# match: (273, 281)
# match: (281, 285)
# match: (291, 300)
# match: (300, 305)
# match: (310, 320)
# match: (320, 326)
# match: (15, 22)
# match: (23, 34)
# match: (39, 48)
# match: (1, 5)
# match: (10, 17)
# match: (18, 26)
# match: (27, 31)
# match: (35, 43)
# match: (49, 59)
# match: (67, 73)
# match: (97, 107)
# match: (125, 135)
# match: (50, 58)
# match: (74, 83)
# match: (50, 58)
# match: (95, 101)
# match: (122, 128)
# match: (133, 142)
# match: (20, 27)
# match: (36, 44)
# match: (67, 72)
# match: (77, 86)
# match: (86, 94)
# match: (3, 8)
# match: (28, 37)
# match: (71, 79)
# match: (26, 35)
# match: (35, 42)
# match: (47, 56)
# match: (56, 64)
# match: (92, 105)
# match: (137, 146)
# match: (162, 170)
# match: (170, 178)
# match: (43, 52)
# match: (52, 58)
# match: (127, 134)
# match: (28, 37)
# match: (37, 45)
# match: (45, 58)
# match: (75, 80)
# match: (89, 99)
# No index found for φρένας in Δύο δ’ ἀπὸ τῆς διὰ τοῦ ἥπατος φλεβὸς ἀποσχίσεις εἰσίν, ὧν ἡ μὲν εἰς τὸ ὑπόζωμα τελευτᾷ καὶ τὰς καλουμένας φρένας, ἡ δὲ πάλιν ἐπανελθοῦσα διὰ τῆς μασχάλης εἰς τὸν βραχίονα τὸν δεξιὸν συμβάλλει ταῖς ἑτέραις φλεψὶ κατὰ τὴν ἐντὸς καμπήν
# match: (143, 147)
# match: (178, 188)
# match: (198, 208)
# match: (248, 255)
# match: (274, 282)
# match: (33, 41)
# match: (78, 85)
# match: (7, 12)
# match: (56, 62)
# match: (80, 88)
# match: (124, 132)
# match: (12, 19)
# match: (47, 56)
# match: (56, 64)
# match: (132, 142)
# match: (5, 14)
# match: (32, 42)
# match: (50, 57)
# match: (83, 91)
# match: (9, 16)
# match: (27, 36)
# match: (36, 44)
# match: (63, 68)
# match: (78, 89)
# match: (90, 93)
# match: (118, 128)
# match: (9, 17)
# match: (25, 33)
# match: (43, 56)
# match: (9, 17)
# match: (28, 35)
# match: (72, 82)
# match: (92, 101)
# match: (113, 123)
# match: (21, 28)
# match: (60, 68)
# match: (38, 50)
# match: (5, 16)
# match: (178, 190)
# match: (195, 205)
# match: (23, 28)
# match: (59, 68)
# match: (73, 82)
# match: (97, 105)
# match: (110, 118)
# match: (0, 4)
# match: (213, 221)
# match: (266, 274)
# match: (12, 24)
# match: (32, 39)
# match: (44, 52)
# match: (30, 42)
# match: (120, 132)
# No index found for ἄλλαι in Ἔτι δ’ ἄλλαι ἀπὸ τῆς μεγάλης φλεβὸς ἀποσχίζονται, ἡ μὲν ἐπὶ τὸ ἐπίπλοον, ἡ δ’ ἐπὶ τὸ καλούμενον πάγκρεας
# match: (17, 25)
# match: (0, 6)
# match: (22, 28)
# match: (47, 56)
# match: (63, 68)
# match: (28, 36)
# match: (84, 95)
# match: (102, 122)
# match: (14, 23)
# match: (6, 11)
# match: (15, 21)
# match: (64, 72)
# match: (72, 82)
# match: (82, 87)
# match: (106, 117)
# match: (126, 132)
# match: (151, 157)
# match: (0, 7)
# match: (10, 15)
# match: (33, 38)
# match: (87, 92)
# match: (118, 123)
# match: (134, 149)
# match: (149, 163)
# match: (7, 13)
# match: (18, 23)
# match: (80, 85)
# match: (99, 109)
# match: (154, 168)
# match: (168, 173)
# match: (188, 193)
# match: (221, 232)
# match: (255, 261)
# match: (68, 74)
# match: (0, 3)
# match: (62, 70)
# match: (70, 75)
# match: (94, 107)
# match: (111, 116)
# match: (132, 137)
# match: (19, 25)
# match: (64, 77)
# match: (98, 110)
# match: (110, 115)
# match: (22, 27)
# match: (73, 78)
# match: (91, 102)
# match: (16, 22)
# match: (44, 59)
# match: (68, 74)
# match: (96, 102)
# match: (0, 5)
# match: (33, 38)
# match: (56, 67)
# match: (17, 22)
# match: (35, 47)
# match: (57, 63)
# match: (101, 108)
# match: (123, 134)
# match: (36, 41)
# match: (49, 60)
# match: (0, 3)
# match: (72, 75)
# match: (140, 143)
# match: (14, 19)
# match: (57, 60)
# match: (63, 68)
# match: (93, 96)
# match: (59, 71)
# match: (74, 83)
# match: (119, 131)
# match: (131, 139)
# match: (106, 118)
# No index found for πάγκρεας in Ἔτι δ’ ἄλλαι ἀπὸ τῆς μεγάλης φλεβὸς ἀποσχίζονται, ἡ μὲν ἐπὶ τὸ ἐπίπλοον, ἡ δ’ ἐπὶ τὸ καλούμενον πάγκρεας
# match: (13, 27)
# match: (56, 65)
# match: (118, 126)
# match: (154, 160)
# match: (178, 187)
# match: (187, 195)
# match: (200, 208)
# match: (231, 238)
# match: (5, 13)
# match: (19, 24)
# match: (43, 52)
# match: (12, 18)
# match: (28, 37)
# match: (52, 61)
# match: (72, 81)
# match: (20, 34)
# match: (69, 77)
# match: (40, 49)
# match: (70, 77)
# match: (41, 50)
# match: (55, 72)
# match: (91, 101)
# match: (125, 134)
# match: (166, 172)
# match: (26, 33)
# match: (59, 69)
# match: (88, 96)
# match: (121, 131)
# match: (131, 142)
# match: (36, 46)
# match: (131, 138)
# match: (24, 31)
# match: (31, 43)
# match: (34, 45)
# match: (50, 62)
# match: (77, 88)
# match: (114, 124)
# match: (77, 84)
# match: (101, 111)
# match: (135, 146)
# match: (151, 159)
# match: (33, 38)
# match: (27, 31)
# match: (46, 56)
# match: (70, 76)
# match: (81, 85)
# match: (91, 100)
# match: (108, 113)
# match: (138, 147)
# match: (147, 154)
# match: (208, 212)
# match: (212, 217)
# match: (18, 23)
# match: (38, 43)
# match: (61, 67)
# match: (81, 89)
# match: (4, 19)
# match: (26, 32)
# match: (54, 60)
# match: (64, 70)
# match: (0, 7)
# match: (24, 30)
# match: (30, 36)
# match: (80, 86)
# match: (111, 120)
# match: (0, 9)
# match: (12, 18)
# match: (48, 54)
# match: (78, 83)
# match: (106, 116)
# match: (12, 15)
# match: (15, 20)
# match: (63, 66)
# match: (66, 69)
# match: (39, 43)
# match: (43, 48)
# match: (70, 74)
# match: (74, 76)
# match: (26, 35)
# match: (45, 54)
# match: (54, 62)
# match: (73, 85)
# match: (90, 98)
# match: (99, 103)
# match: (120, 130)
# match: (180, 188)
# match: (0, 6)
# match: (17, 28)
# match: (11, 21)
# match: (31, 41)
# match: (51, 58)
# match: (79, 82)
# match: (125, 128)
# match: (27, 36)
# match: (52, 60)
# match: (37, 45)
# match: (73, 81)
# match: (73, 81)
# match: (101, 109)
# match: (28, 36)
# match: (82, 88)
# match: (18, 25)
# match: (123, 130)
# match: (137, 145)
# match: (6, 14)
# match: (14, 20)
# match: (90, 98)
# match: (138, 147)
# match: (152, 160)
# match: (11, 21)
# match: (42, 52)
# match: (91, 101)
# match: (25, 39)
# match: (101, 110)
# match: (39, 49)
# match: (0, 9)
# match: (12, 18)
# match: (62, 68)
# match: (108, 114)
# match: (170, 175)
# match: (188, 200)
# match: (200, 205)
# match: (21, 26)
# match: (58, 68)
# match: (68, 78)
# match: (87, 91)
# match: (96, 108)
# match: (108, 113)
# match: (117, 124)
# match: (132, 136)
# match: (140, 151)
# match: (151, 155)
# match: (160, 168)
# match: (4, 16)
# match: (16, 22)
# match: (15, 23)
# match: (23, 33)
# match: (50, 57)
# match: (57, 68)
# match: (62, 68)
# match: (51, 58)
# match: (101, 109)
# match: (109, 119)
# match: (103, 108)
# match: (128, 131)
# match: (39, 50)
# match: (240, 252)
# match: (257, 268)
# match: (14, 23)
# match: (32, 44)
# match: (53, 60)
# match: (69, 78)
# match: (61, 70)
# match: (22, 30)
# match: (69, 77)
# match: (85, 93)
# match: (93, 99)
# match: (27, 35)
# match: (155, 163)
# match: (163, 169)
# match: (174, 183)
# match: (17, 25)
# match: (39, 47)
# match: (58, 67)
# match: (6, 18)
# match: (24, 34)
# match: (12, 20)
# match: (36, 45)
# match: (29, 38)
# match: (47, 60)
# match: (60, 68)
# match: (91, 108)
# match: (53, 63)
# match: (12, 19)
# match: (29, 37)
# match: (66, 75)
# match: (75, 81)
# match: (7, 16)
# match: (32, 40)
# match: (60, 69)
# match: (108, 117)
# match: (28, 37)
# match: (51, 60)
# match: (60, 68)
# match: (78, 87)
# match: (87, 95)
# match: (70, 78)
# match: (21, 30)
# match: (43, 50)
# match: (70, 78)
# match: (140, 148)
# match: (176, 185)
# match: (185, 192)
# match: (19, 27)
# match: (38, 44)
# match: (107, 115)
# match: (125, 133)
# match: (26, 35)
# match: (125, 134)
# match: (26, 34)
# match: (43, 53)
# match: (57, 65)
# match: (65, 73)
# match: (127, 137)
# match: (26, 35)
# match: (35, 43)
# match: (63, 73)
# match: (89, 98)
# match: (30, 35)
# match: (42, 52)
# match: (102, 112)
# match: (34, 45)
# match: (50, 59)
# match: (0, 6)
# match: (21, 36)
# match: (41, 55)
# match: (123, 135)
# match: (0, 7)
# match: (23, 33)
# match: (0, 8)
# match: (18, 27)
# match: (32, 42)
# match: (37, 47)
# match: (16, 27)
# match: (69, 80)
# match: (117, 129)
# match: (38, 43)
# match: (79, 89)
# match: (94, 104)
# match: (27, 38)
# match: (44, 51)
# match: (56, 66)
# match: (94, 102)
# match: (11, 22)
# match: (48, 58)
# match: (76, 83)
# match: (43, 53)
# match: (98, 106)
# match: (111, 119)
# match: (0, 6)
# match: (42, 52)
# match: (52, 60)
# match: (0, 9)
# match: (13, 19)
# match: (43, 57)
# match: (63, 74)
# match: (74, 79)
# match: (79, 84)
# match: (127, 132)
# match: (135, 144)
# match: (0, 11)
# match: (47, 53)
# match: (20, 26)
# match: (45, 55)
# match: (7, 18)
# match: (0, 9)
# match: (18, 24)
# match: (38, 43)
# match: (80, 86)
# match: (42, 53)
# match: (0, 4)
# match: (47, 55)
# match: (55, 61)
# match: (40, 51)
# match: (51, 56)
# match: (86, 99)
# match: (99, 104)
# match: (0, 8)
# match: (17, 22)
# match: (37, 43)
# match: (10, 15)
# match: (33, 38)
# match: (48, 65)
# match: (0, 5)
# match: (50, 60)
# match: (60, 65)
# match: (118, 122)
# match: (127, 135)
# match: (157, 171)
# match: (0, 3)
# match: (3, 10)
# match: (66, 78)
# match: (79, 89)
# match: (89, 94)
# match: (115, 120)
# match: (6, 11)
# match: (35, 48)
# match: (101, 115)
# match: (115, 121)
# match: (0, 11)
# match: (15, 21)
# match: (116, 122)
# match: (0, 7)
# match: (10, 16)
# match: (74, 80)
# match: (5, 15)
# match: (58, 64)
# match: (59, 67)
# match: (97, 108)
# match: (156, 165)
# match: (215, 227)
# match: (246, 255)
# match: (17, 25)
# match: (48, 54)
# match: (14, 22)
# match: (22, 30)
# match: (57, 64)
# match: (15, 22)
# match: (93, 102)
# match: (43, 51)
# match: (0, 11)
# match: (54, 65)
# match: (0, 6)
# match: (37, 46)
# match: (65, 72)
# match: (22, 33)
# match: (39, 47)
# match: (52, 62)
# match: (51, 58)
# match: (33, 41)
# match: (59, 64)
# match: (72, 81)
# match: (41, 50)
# match: (50, 55)
# match: (84, 91)
# match: (91, 97)
# match: (138, 143)
# match: (147, 151)
# match: (204, 210)
# match: (237, 241)
# match: (16, 25)
# match: (25, 30)
# match: (26, 37)
# match: (55, 65)
# match: (48, 53)
# match: (17, 21)
# match: (47, 51)
# match: (5, 16)
# match: (41, 51)
# match: (9, 19)
# match: (24, 33)
# match: (102, 111)
# match: (11, 24)
# match: (29, 41)
# match: (108, 121)
# match: (125, 137)
# match: (178, 189)
# match: (194, 204)
# match: (42, 47)
# match: (5, 16)
# match: (20, 31)
# match: (92, 99)
# match: (0, 12)
# match: (25, 35)
# match: (64, 77)
# match: (50, 59)
# match: (31, 39)
# match: (101, 109)
# match: (119, 126)
# match: (9, 19)
# match: (21, 30)
# match: (49, 56)
# match: (38, 47)
# match: (14, 21)
# match: (21, 28)
# match: (14, 21)
# match: (21, 31)
# match: (36, 44)
# match: (22, 32)
# match: (40, 48)
# match: (26, 34)
# match: (36, 42)
# match: (12, 20)
# match: (17, 30)
# match: (26, 36)
# match: (36, 48)
# match: (67, 75)
# match: (10, 20)
# match: (16, 24)
# match: (19, 24)
# match: (11, 21)
# match: (38, 49)
# match: (32, 38)
# match: (28, 33)
# match: (34, 40)
# match: (40, 52)
# match: (7, 13)
# match: (19, 26)
# match: (38, 46)
# match: (29, 36)
# match: (58, 67)
# match: (67, 75)
# match: (80, 88)
# match: (123, 130)
# match: (13, 22)
# match: (26, 33)
# match: (37, 43)
# match: (2, 8)
# match: (12, 22)
# match: (27, 38)
# match: (8, 18)
# match: (22, 36)
# match: (20, 26)
# match: (26, 32)
# match: (37, 44)
# match: (10, 17)
# match: (13, 21)
# match: (57, 67)
# match: (0, 8)
# match: (20, 31)
# match: (24, 38)
# match: (39, 45)
# match: (45, 57)
# match: (16, 22)
# match: (0, 5)
# match: (6, 14)
# match: (16, 20)
# match: (25, 33)
# match: (9, 15)
# match: (19, 26)
# match: (26, 37)
# match: (88, 93)
# match: (93, 102)
# match: (102, 109)
# match: (0, 7)
# match: (0, 6)
# match: (7, 11)
# match: (31, 35)
# match: (13, 17)
# match: (17, 22)
# match: (32, 36)
# match: (36, 40)
# match: (0, 3)
# match: (3, 6)
# match: (4, 8)
# match: (8, 13)
# match: (49, 53)
# match: (53, 57)
# match: (36, 45)
# match: (0, 6)
# match: (5, 16)
# match: (0, 12)
# match: (6, 19)
# match: (23, 31)
# match: (36, 47)
# match: (91, 100)
# match: (20, 29)
# match: (19, 30)
# match: (136, 144)
# match: (149, 157)
# match: (77, 85)
# match: (47, 59)
# match: (64, 76)
# match: (81, 91)
# match: (125, 132)
# match: (139, 147)
# match: (0, 11)
# match: (0, 4)
# match: (8, 20)
# match: (119, 132)
# match: (144, 149)
# match: (0, 10)
# match: (57, 66)
# match: (90, 100)
# match: (180, 190)
# match: (16, 26)
# match: (33, 45)
# match: (140, 150)
# match: (28, 38)
# match: (51, 63)
# match: (34, 44)
# match: (17, 27)
# match: (86, 96)
# match: (152, 159)
# match: (179, 189)
# match: (189, 200)
# match: (209, 216)
# match: (290, 300)
# match: (310, 320)
# match: (22, 31)
# match: (36, 50)
# match: (105, 116)
# match: (116, 123)
# match: (136, 143)
# match: (11, 22)
# match: (39, 48)
# match: (48, 59)
# match: (112, 119)
# No index found for πλεύμονος in Ἐπὶ δὲ θάτερα καθήκει εἰς τὸ μεταξὺ τοῦ πλεύμονος, εἶτ’ ἀπὸ τούτου σχίζεται εἰς ἑκάτερον τῶν μερῶν τοῦ πλεύμονος
# match: (27, 38)
# match: (55, 67)
# match: (68, 77)
# match: (77, 86)
# match: (0, 7)
# match: (0, 9)
# match: (18, 25)
# match: (38, 46)
# match: (96, 109)
# match: (110, 118)
# match: (121, 127)
# match: (136, 142)
# match: (142, 148)
# match: (159, 165)
# match: (170, 174)
# match: (274, 281)
# match: (281, 285)
# match: (300, 305)
# match: (320, 326)
# match: (0, 7)
# match: (90, 96)
# match: (123, 132)
# match: (143, 151)
# match: (22, 34)
# match: (0, 5)
# match: (9, 17)
# match: (17, 26)
# match: (26, 31)
# match: (35, 43)
# match: (67, 73)
# match: (73, 81)
# match: (81, 91)
# match: (91, 96)
# match: (96, 107)
# match: (34, 45)
# match: (37, 50)
# match: (234, 244)
# match: (244, 258)
# match: (63, 79)
# match: (43, 50)
# match: (0, 6)
# match: (28, 37)
# match: (67, 75)
# match: (94, 104)
# match: (55, 64)
# match: (64, 71)
# match: (85, 94)
# match: (94, 102)
# match: (149, 156)
# match: (15, 26)
# match: (29, 37)
# match: (51, 58)
# match: (12, 21)
# match: (54, 62)
# match: (70, 78)
# match: (25, 32)
# match: (37, 46)
# match: (10, 20)
# match: (22, 30)
# match: (36, 46)
# match: (156, 165)
# match: (7, 15)
# match: (37, 44)
# match: (47, 59)
# match: (82, 89)
# match: (0, 6)
# match: (31, 36)
# match: (71, 80)
# match: (83, 87)
# match: (26, 30)
# match: (44, 48)
# match: (78, 82)
# match: (0, 3)
# match: (3, 13)
# match: (73, 77)
# match: (50, 62)
# match: (68, 83)
# match: (92, 106)
# match: (30, 38)
# match: (82, 90)
# match: (102, 110)
# match: (38, 47)
# match: (57, 69)
# match: (39, 47)
# match: (4, 12)
# match: (29, 37)
# match: (48, 56)
# match: (274, 283)
# match: (350, 358)
# match: (0, 7)
# match: (43, 52)
# match: (27, 38)
# match: (123, 131)
# match: (139, 147)
# match: (163, 171)
# match: (259, 267)
# match: (311, 320)
# match: (0, 4)
# match: (101, 109)
# match: (136, 145)
# match: (101, 109)
# match: (220, 229)
# match: (332, 342)
# match: (19, 27)
# match: (68, 75)
# match: (99, 110)
# match: (155, 163)
# match: (214, 224)
# match: (13, 21)
# match: (29, 33)
# match: (37, 43)
# match: (62, 70)
# match: (74, 84)
# match: (109, 113)
# match: (119, 128)
# match: (145, 155)
# match: (185, 189)
# match: (195, 204)
# match: (229, 233)
# match: (239, 252)
# match: (24, 32)
# match: (0, 4)
# match: (39, 44)
# match: (56, 67)
# match: (75, 79)
# match: (87, 99)
# match: (196, 209)
# match: (232, 238)
# match: (248, 254)
# match: (267, 275)
# match: (284, 288)
# match: (288, 295)
# match: (93, 96)
# match: (96, 101)
# match: (129, 132)
# match: (132, 135)
# match: (169, 172)
# match: (172, 177)
# match: (213, 216)
# match: (216, 219)
# match: (258, 268)
# match: (274, 283)
# match: (44, 53)
# match: (71, 89)
# match: (101, 118)
# match: (292, 303)
# match: (308, 312)
# match: (318, 328)
# match: (47, 54)
# match: (41, 50)
# match: (68, 71)
# match: (97, 105)
# match: (0, 3)
# match: (32, 40)
# match: (50, 59)
# match: (80, 90)
# match: (124, 135)
# match: (176, 183)
# No index found for πτέρυγας in Αἱ μὲν γὰρ φέρουσιν εἰς τὰ πλάγια καὶ τὰς κλεῖδας, κἄπειτα διὰ τῶν μασχαλῶν τοῖς μὲν ἀνθρώποις εἰς τοὺς βραχίονας, τοῖς δὲ τετράποσιν εἰς τὰ πρόσθια σκέλη τείνουσι, τοῖς δ’ ὄρνισιν εἰς τὰς πτέρυ γας, τοῖς δ’ ἰχθύσιν εἰς τὰ πτερύγια τὰ πρανῆ
# match: (263, 273)
# match: (0, 3)
# match: (6, 14)
# match: (27, 35)
# match: (76, 88)
# match: (29, 38)
# match: (49, 66)
# match: (78, 89)
# match: (109, 120)
# match: (110, 119)
# match: (4, 15)
# match: (37, 44)
# match: (68, 76)
# match: (81, 90)
# match: (46, 54)
# match: (55, 60)
# match: (107, 117)
# match: (127, 134)
# match: (166, 178)
# match: (183, 191)
# match: (207, 218)
# match: (243, 251)
# match: (261, 268)
# match: (289, 300)
# match: (58, 64)
# match: (75, 87)
# match: (135, 143)
# match: (165, 174)
# match: (75, 87)
# match: (13, 25)
# match: (84, 93)
# match: (32, 40)
# match: (60, 68)
# match: (68, 72)
# match: (82, 91)
# match: (117, 121)
# match: (172, 182)
# No index found for φλεβίοις in Τῶν δὲ λοιπῶν τῶν ἀπὸ τῆς φλεβὸς ταύτης σχισθεισῶν φλεβῶν αἱ μὲν τὴν κεφαλὴν κύκλῳ περιλαμβάνουσιν, αἱ δ’ εἰς τὰ αἰσθητήρια ἀποτελευτῶσι καὶ τοὺς ὀδόντας λεπτοῖς πάμπαν φλεβίοις
# match: (71, 77)
# match: (92, 97)
# match: (167, 176)
# match: (277, 284)
# match: (119, 134)
# match: (25, 35)
# match: (60, 65)
# match: (0, 4)
# match: (7, 15)
# match: (20, 31)
# match: (116, 123)
# match: (128, 135)
# match: (25, 35)
# match: (63, 69)
# match: (76, 84)
# match: (8, 16)
# match: (182, 191)
# match: (0, 9)
# match: (21, 27)
# match: (32, 36)
# match: (50, 61)
# match: (77, 87)
# match: (87, 92)
# match: (13, 23)
# match: (23, 28)
# match: (70, 75)
# match: (113, 118)
# match: (183, 193)
# match: (213, 218)
# match: (254, 259)
# match: (36, 41)
# match: (41, 52)
# match: (0, 4)
# match: (8, 19)
# match: (19, 24)
# match: (67, 73)
# match: (89, 99)
# match: (10, 21)
# match: (27, 35)
# match: (35, 48)
# match: (16, 25)
# match: (25, 32)
# match: (45, 50)
# match: (50, 64)
# match: (9, 20)
# match: (35, 46)
# match: (70, 85)
# match: (85, 97)
# match: (97, 102)
# match: (140, 151)
# match: (191, 197)
# match: (218, 226)
# match: (251, 256)
# match: (268, 278)
# match: (15, 20)
# match: (36, 43)
# match: (48, 54)
# match: (64, 70)
# match: (87, 95)
# match: (101, 111)
# match: (111, 116)
# match: (143, 148)
# match: (179, 185)
# match: (0, 7)
# match: (93, 103)
# match: (103, 108)
# match: (21, 27)
# match: (48, 60)
# match: (99, 116)
# match: (124, 129)
# match: (146, 161)
# match: (3, 8)
# match: (3, 6)
# match: (72, 77)
# match: (121, 124)
# match: (65, 76)
# No index found for σφαγίτιδες in Αἱ δ’ ἀρχαὶ τούτων τῶν φλεβῶν, ᾗ σχίζονται τὸ πρῶτον, καλοῦνται σφαγίτιδες
# match: (153, 165)
# match: (165, 174)
# match: (47, 56)
# match: (56, 71)
# match: (91, 105)
# match: (133, 146)
# match: (164, 175)
# match: (28, 35)
# match: (40, 51)
# match: (94, 105)
# match: (19, 30)
# match: (58, 64)
# match: (69, 80)
# match: (10, 21)
# match: (12, 23)
# match: (23, 32)
# match: (56, 67)
# match: (91, 98)
# match: (151, 156)
# match: (10, 16)
# match: (57, 68)
# match: (72, 79)
# match: (51, 58)
# match: (28, 40)
# match: (37, 45)
# match: (78, 88)
# match: (93, 102)
# match: (98, 109)
# match: (109, 114)
# match: (114, 124)
# match: (124, 135)
# match: (4, 10)
# match: (52, 57)
# match: (79, 89)
# match: (0, 11)
# match: (42, 47)
# match: (40, 45)
# match: (45, 51)
# match: (51, 63)
# match: (0, 3)
# match: (32, 37)
# match: (102, 115)
# match: (25, 34)
# match: (34, 41)
# match: (51, 60)
# match: (0, 10)
# match: (30, 42)
# match: (20, 32)
# match: (61, 72)
# match: (84, 92)
# No index found for κοιλία in δὲ κοιλία ἡ τοῦ ἀνθρώπου ὁμοία τῇ κυνείᾳ ἐστίν
# match: (6, 16)
# match: (19, 30)
# match: (30, 38)
# match: (43, 52)
# match: (22, 32)
# match: (32, 40)
# match: (47, 57)
# match: (66, 76)
# match: (82, 90)
# match: (0, 7)
# match: (7, 17)
# match: (17, 26)
# match: (27, 40)
# match: (52, 59)
# match: (7, 21)
# match: (7, 21)
# match: (21, 29)
# match: (34, 42)
# match: (0, 10)
# match: (29, 66)
# match: (33, 39)
# match: (47, 53)
# match: (58, 66)
# match: (66, 72)
# match: (77, 84)
# match: (6, 17)
# match: (17, 23)
# match: (23, 30)
# match: (35, 44)
# match: (44, 54)
# match: (70, 77)
# match: (77, 84)
# match: (84, 95)
# match: (130, 144)
# match: (149, 162)
# match: (0, 6)
# match: (15, 25)
# match: (29, 43)
# match: (0, 10)
# match: (37, 44)
# match: (50, 56)
# match: (0, 11)
# match: (14, 18)
# match: (23, 40)
# match: (23, 40)
# match: (50, 59)
# match: (65, 69)
# match: (77, 85)
# match: (0, 5)
# match: (85, 93)
# match: (98, 106)
# match: (107, 122)
# match: (122, 128)
# match: (138, 148)
# match: (148, 155)
# match: (156, 165)
# match: (165, 177)
# match: (177, 184)
# match: (184, 190)
# match: (26, 36)
# match: (46, 57)
# match: (93, 102)
# match: (13, 23)
# match: (20, 28)
# match: (34, 42)
# match: (45, 53)
# match: (63, 68)
# match: (78, 90)
# match: (95, 105)
# match: (116, 124)
# match: (131, 135)
# match: (149, 157)
# match: (149, 157)
# match: (157, 163)
# match: (168, 177)
# match: (8, 17)
# match: (17, 28)
# match: (17, 28)
# match: (44, 54)
# match: (44, 54)
# match: (11, 20)
# match: (38, 45)
# match: (50, 57)
# match: (9, 19)
# match: (24, 38)
# match: (38, 46)
# match: (83, 94)
# match: (139, 149)
# match: (159, 173)
# match: (0, 5)
# match: (204, 208)
# match: (213, 225)
# No index found for κοιλίαν in μετὰ γὰρ τὴν κοιλίαν ἡ τῶν ἐντέρων ἔγκειται φύσις πᾶσι τοῖς ζῴοις
# match: (32, 42)
# match: (39, 50)
# match: (50, 57)
# match: (69, 77)
# match: (11, 21)
# match: (42, 50)
# match: (15, 24)
# match: (35, 44)
# match: (44, 58)
# match: (44, 58)
# match: (68, 79)
# match: (18, 30)
# match: (18, 30)
# match: (34, 40)
# match: (45, 54)
# match: (55, 81)
# match: (74, 81)
# match: (81, 93)
# match: (126, 138)
# match: (153, 165)
# match: (187, 196)
# match: (196, 208)
# match: (209, 215)
# match: (230, 242)
# match: (0, 6)
# match: (15, 30)
# match: (56, 69)
# match: (86, 94)
# match: (99, 108)
# match: (117, 126)
# match: (136, 146)
# match: (36, 48)
# match: (58, 71)
# match: (19, 34)
# match: (34, 46)
# match: (46, 58)
# match: (92, 115)
# match: (108, 115)
# match: (135, 145)
# match: (145, 153)
# match: (161, 171)
# match: (172, 178)
# match: (179, 183)
# match: (198, 210)
# match: (215, 228)
# No index found for τό στενώτερον καὶ εἱλιγμένον in Πᾶσι δὲ τοῖς μὴ εὐθυεντέροις προϊοῦσιν εὐρύτερον γίνεται τὸ μόριον τοῦτο, καὶ τὸ καλούμενον κόλον ἔχουσι, καὶ τοῦ ἐντέρου τυφλόν τι καὶ ὀγκῶδες, εἶτ' ἐκ τούτου πάλιν στενώτερον καὶ εἱλιγμένον
# match: (0, 20)
# match: (7, 13)
# match: (20, 27)
# match: (27, 33)
# match: (38, 47)
# match: (47, 58)
# match: (129, 137)
# match: (129, 137)
# match: (138, 149)
# match: (166, 177)
# match: (67, 78)
# match: (0, 10)
# match: (20, 34)
# match: (52, 64)
# match: (88, 101)
# match: (101, 113)
# match: (190, 199)
# match: (208, 219)
# match: (0, 5)
# match: (6, 17)
# match: (33, 39)
# match: (44, 59)
# match: (59, 68)
# match: (68, 80)
# match: (80, 90)
# match: (99, 103)
# match: (108, 115)
# match: (125, 138)
# match: (138, 142)
# No index found for κάτω κοιλίᾳ in Εἶτ' ἐντεῦθεν πάλιν, ὥσπερ ἀπὸ τῆς ἄνω κοιλίας δέχεται στενώτερον ἔντερον, οὕτως ἐκ τοῦ κώλου καὶ τῆς εὐρυχωρίας ἐν τῇ κάτω κοιλίᾳ πάλιν εἰς στενώτερον ἔρχεται καὶ εἰς τὴν ἕλικα τὸ περίττωμα ἐξικμασμένον πάμπαν, ὅπως ταμιεύηται ἡ φύσις καὶ μὴ ἀθρόος ᾖ ἡ ἔξοδος τοῦ περιττώματος
# No index found for κάτω κοιλίᾳ in Εἶτ' ἐντεῦθεν πάλιν, ὥσπερ ἀπὸ τῆς ἄνω κοιλίας δέχεται στενώτερον ἔντερον, οὕτως ἐκ τοῦ κώλου καὶ τῆς εὐρυχωρίας ἐν τῇ κάτω κοιλίᾳ πάλιν εἰς στενώτερον ἔρχεται καὶ εἰς τὴν ἕλικα τὸ περίττωμα ἐξικμασμένον πάμπαν, ὅπως ταμιεύηται ἡ φύσις καὶ μὴ ἀθρόος ᾖ ἡ ἔξοδος τοῦ περιττώματος
# match: (169, 174)
# match: (174, 186)
# match: (186, 196)
# match: (211, 219)
# match: (265, 277)
# match: (9, 13)
# match: (18, 38)
# match: (18, 38)
# match: (24, 29)
# match: (57, 67)
# match: (122, 128)
# match: (128, 132)
# match: (132, 144)
# match: (207, 215)
# match: (216, 220)
# match: (225, 237)
# match: (61, 69)
# match: (61, 69)
# match: (74, 78)
# match: (83, 89)
# match: (94, 103)
# match: (103, 113)
# match: (118, 126)
# match: (11, 19)
# match: (27, 33)
# match: (34, 38)
# match: (68, 74)
# match: (75, 79)
# match: (16, 28)
# match: (103, 114)
# match: (34, 41)
# match: (57, 63)
# match: (63, 73)
# match: (76, 84)
# match: (25, 30)
# match: (35, 43)
# No index found for κάτω κοιλίας in οἱ δ' ἄρρενες ἔχουσι πρὸ τοῦ τυφλοῦ καὶ τῆς κάτω κοιλίας
# No index found for 40 words

# %%
# compare text[index] with keyword
test_data_df = pd.DataFrame(columns=['text', 'real_keyword', 'function_found'])
# count nulls in train_data_df
nulls = train_data_df.isnull().sum()
# drop nulls in train_data_df
train_data_df = train_data_df.dropna()
# iterate over all rows in train_data_df
for index, row in train_data_df.iterrows():
    test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# Out:
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)
# /tmp/ipykernel_9643/523546791.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data_df = test_data_df.append({'text': row['text'], 'real_keyword': row['keyword'], 'function_found': row['text'][row['index'][0]:row['index'][1]]}, ignore_index=True)

# %%
# print nulls in train_data_df
print ("Nulls", nulls)
# print shape of train_data_df
print ("\nShape", train_data_df.shape)
# Out:
# Nulls text       0
# keyword    0
# index      0
# label      2
# lemma      0
# dtype: int64
#
# Shape (1492, 5)

# %%
# sample test_data_df where real_keyword != function_found
test_data_df[test_data_df['real_keyword'] != test_data_df['function_found']].sample(10)
# Out:
#                                                    text real_keyword  \
# 846        Τὸ δ’ ἐντὸς στόμα σιαγόνων καὶ χειλῶν       στόμα
# 563   Τείνουσι δ’ ἀπὸ τε τῆς ἀορτῆς καὶ τῆς ...      ἄλλαι
# 904   Αἰσθάνεται δὲ καὶ ὧν ἡ ἄλλη σὰρξ πά...       μέρος
# 788   Ἔτι προσώπου μέρος τὸ μὲν ὂν τῷ πνευ...       μέρος
# 1483  τοῦτο γὰρ μεταξὺ τῆς τ' ἄνω, ἐν ᾗ το...          ἐν
# 992   Ταύτῃ δὲ τὸ πέρας συνήρτηται τῆς γλώττης   συνήρτηται
# 634   Μέχρι μὲν οὖν τῶν νεφρῶν μία οὖσα ἑκ...      νεφρῶν
# 595   Ἡ δὲ μεγάλη φλὲψ ἐν πᾶσι μάλιστα διάδη...    διάδηλος
# 1085  Δύο φλέβες εἰσὶν ἐν τῷ θώρακι κατὰ τη...          ἐν
# 640   ἐνταῦθα δὲ πρός τε τὴν ῥάχιν μᾶλλον πρ...        φλὲψ
#
#      function_found
# 846          στόμα
# 563         ἄλλαι
# 904          μέρος
# 788          μέρος
# 1483            ἐν
# 992     συνήρτηται
# 634         νεφρῶν
# 595       διάδηλος
# 1085            ἐν
# 640           φλὲψ

# %% [markdown]
# # Create dictionaries from dendrosearch and conllu files (supplied by Jackobo)

# %%
PUNCTUATION = ['.', ")", ".", "·", "(", "[", "]", ":", ";", ",", "?", "!", "،", "_"]
# extract from df a dictionary {word: lemma}
lemma_dict = {}
for index, row in df.iterrows():
    lemma_dict[row['Keyword']] = row['Lemma']

# load dendrosearch lemma dictionary
dendrosearch_lemma_dict = {}
with open('../assets/dendrosearch_lemma_dict.txt', 'r', encoding='utf-8') as f:
    for line in f:
        line = line.split()
        # check if not punctuation
        if len(line) > 1 and line[0] not in PUNCTUATION:
            dendrosearch_lemma_dict[line[0]] = line[1]

# create dictionary from all conllu files
PATH = "../assets/Lemmatization_training_files/"
conllu_lemma_dict = {}

# iterate over all files in directory
#for f in os.listdir(PATH):
#    if f.endswith(".conllu"):
#        # if file is a conllu file
#        with open(os.path.join(PATH, f), 'r', encoding='utf-8') as f:
#            for line in f:
#                # conll line is: id | keyword | lemma | pos | _
#                # we want only keyword and lemma
#                line = line.split()
#                if len(line) > 2 and line[1] not in PUNCTUATION:
#                    conllu_lemma_dict[line[1]] = line[2]

# %% [markdown]
# 1. Error fix: I added above the line:\
# <code>if f.endswith(".conllu")</code>\
# Without it it gets an error because it tries to read folders and other files as well.\ :)
# 2. Why do you add the conllu to dictionary? ANSWER: I thought they might be useful for lemmatization, anyways they can't hurt, and if you don't want them you can just ignore them.

# %% [markdown]
# ## Create dictionary from INCEpTION files

# %%
from cassis import *
import zipfile
import tempfile

inception_dict = {}
inception_sentences = []

# %%
# extract all files in inception folder to temp folder
with tempfile.TemporaryDirectory() as tempdir:
    for f in os.listdir("../assets/NER_assets/INCEpTION_files/"):
        if f.endswith(".zip"):
            with zipfile.ZipFile(os.path.join("../assets/NER_assets/INCEpTION_files/", f), 'r') as zip_ref:
                zip_ref.extractall(tempdir)
    print (tempdir)
    # open typesystem and print content
    with open('{0}/{1}'.format(tempdir, "TypeSystem.xml"), 'rb') as f:
        typesystem = load_typesystem(f)

    # iterate over all files in temp folder
    for f in os.listdir(tempdir):
        # if file is a xmi file
        print (typesystem)
        if f.endswith(".xmi"):
            # load xmi file
            with open(os.path.join(tempdir, f), 'rb') as f:
                # load typesystem from temp folder
                cas = load_cas_from_xmi(f, typesystem=typesystem)
                for token in cas.select('de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Lemma'):
                    inception_dict[token.get_covered_text()] = token.value
                for sentence in cas.select("de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Sentence"):
                    inception_sentences.append(sentence.get_covered_text())
# Out:
# /tmp/tmpleujz7ve
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>
# <cassis.typesystem.TypeSystem object at 0x7fade6442210>

# %%
# add to big dictionary and sample
big_dict = {**lemma_dict, **dendrosearch_lemma_dict, **conllu_lemma_dict, **inception_dict}

random.sample(list(big_dict.items()), 10)
# Out:
# [('προτέρη', 'πρότερος'),
#  ('πολιορκοῦσι', 'πολιορκέω'),
#  ('λα-ῃ', 'λα-ος'),
#  ('γράσωνα', 'γράσων'),
#  ('κρινῶ', 'κρίνω'),
#  ('ὅττευ', 'ὅστις'),
#  ('ἐνέβαλον', 'ἐμβάλλω'),
#  ('ἐξαφίησι', 'ἐξαφίημι'),
#  ('κατατήκομαι', 'κατατήκω'),
#  ('ἐγγενέσθαι', 'ἐγγίγνομαι')]

# %%
# create two copies of dictionary, one in NFKD, other in NFKC
FIRST_FORMAT = 'NFKD'
SECOND_FORMAT = 'NFKC'

big_dict_nfkd = {}
big_dict_nfkc = {}

# remove all nan values from big_dict
big_dict = {k: v for k, v in big_dict.items() if pd.notnull(v)}

for key, value in big_dict.items():
    big_dict_nfkd[normalize(FIRST_FORMAT, key)] = normalize(FIRST_FORMAT, value)
    big_dict_nfkc[normalize(SECOND_FORMAT, key)] = normalize(SECOND_FORMAT, value)

# %%
# check delta between two dictionaries
delta = {k: big_dict_nfkd[k] for k in set(big_dict_nfkd) - set(big_dict_nfkc)}
# delta size estimation
print ("delta size:", len(delta))
# Out:
# delta size: 141592

# %% [markdown]
# # Run NLP pipeline on INCEpTION and Coda files

# %%
# merge sentences from inception and coda

sentences = df['Quote'].tolist() + inception_sentences
sentences = list(set(sentences))
random.sample(sentences, 10)
# Out:
# ['καὶ διὰ τοῦτο διὰ πλείονος ἀκούει ἢ ὀσφραίνεται·',
#  "Καὶ ἡ μὲν ἀπὸ τοῦ ἥπατος ὧδ' ἔχει",
#  'Ἔστι δ’ ἡ τοῦ ἀνθρώπου κύστις ἐπιεικῶς \r\nἔχουσα μέγεθος.',
#  'τὰ γὰρ φλέβια λεπτὰ ἐόντα οὐ δύναται παραδέχεσθαι τὸ φλέγμα ὑπὸ πάχεος καὶ πλήθεος, ἀλλὰ ἀποψύχεται καὶ πήγνυται τὸ αἷμα, καὶ οὕτως ἀποθνήσκει',
#  'ἰσχύουσι δὲ μάλιστα ἐν ἐκείνοισι τοῦ σώματος καὶ αἰεὶ παχύτατά \r\nἐστιν, ἐν οἷσι τοῦ σώματος αἱ σάρκες ἐλάχισταί εἰσι.',
#  'Ἐκ δὲ πλευρῆς νόθης, λέγω δὲ ἀριστερῆς, σπλὴν ἀρξάμενος ἐκτέταται ὁμοιορυσμὸς ἴχνει ποδός.',
#  'αἱ μὲν \r\nτέσσερας έχουσαι, κατὰ τὰ ὦτα ἑκατέρωθεν ραφή, άλλη έμπροσθεν, \r\nἄλλη ἐξόπισθεν τῆς κεφαλῆς, οὕτω μὲν ἡ τὰς τέσσερας ἔχουσα·',
#  'Ὀστέα χειρὸς εἰκοσιεπτὰ καὶ ποδὸς εἰκοσιτέσσαρα·',
#  'ἐς δὲ τὰ δεξιὰ μᾶλλον καταρρεῖ ἢ ἐς τὰ ἀριστερά, ὅτι αἱ φλέβες ἐπικοιλότεραί εἰσὶ καὶ πλέονες ἢ ἐν τοῖσιν ἀριστεροῖσιν',
#  'αἱ κεφαλαὶ ῥαφὰς ἔχουσιν, αἱ μὲν τρεῖς, αἱ δὲ τέσσερας·']

# %%
# run nlp pipeline on sentences
# install spacy grc model if not already installed
nlp = spacy.load("grc_proiel_trf") # I use small model for speed but you should use trf (transformer) model for better accuracy

# create list of Doc objects
docs: List[Doc] = []

# create df to record corrections
corrections_df = pd.DataFrame(columns=['sentence', 'token', 'lemma', 'lemma_corrected', 'dictionary'])
corrected_sentences = 0
for sentence in sentences:
    doc = nlp(sentence)
    # we use our dictionary to replace lemmas which the model didn't recognize correctly
    for token in doc:
        # if token text is a lexical value in our dictionary
        if token.text in big_dict_nfkd:
            if token.lemma_ != big_dict_nfkd[token.text]:
                corrections_df = pd.concat([corrections_df, pd.DataFrame({'sentence': sentence,  'token': token.text, 'lemma': token.lemma_, 'lemma_corrected': big_dict_nfkd[token.text], 'dictionary': 'big_dict_nfkd'}, index=[0])], ignore_index=True)
                token.lemma_ = big_dict_nfkd[token.text]

        elif token.text in big_dict_nfkc:
            if token.lemma_ != big_dict_nfkc[token.text]:
                corrections_df = pd.concat([corrections_df, pd.DataFrame({'sentence': sentence,  'token': token.text, 'lemma': token.lemma_, 'lemma_corrected': big_dict_nfkc[token.text], 'dictionary': 'big_dict_nfkc'}, index=[0])], ignore_index=True)
                token.lemma_ = big_dict_nfkc[token.text]
    docs.append(doc)

# %%
print ("corrections_df size:", corrections_df.shape)
# Out:
# corrections_df size: (3312, 5)

# %%
corrections_df.sample(10)
# Out:
#                                                sentence     token       lemma  \
# 1145  Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τ...       τὸ         τὸ
# 1778  προσάγεταί τε γὰρ καὶ λαμβάνει τούτῳ κα...      καὶ        καὶ
# 660   πλὴν οὐκ εἰς τὸ κοῖλον ἀλλ’ εἰς τὸ σῶ...      τῶν        τῶν
# 963   καὶ ἀποτεινομένη πόρρω πρός τε τὴν κεφαλ...     πρὸς       πρὸς
# 950   τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τω...  καθήκει  καθήκομαι
# 1007  καὶ τὸ μὲν παχύτατον καὶ μέγιστον καὶ κ...       ἐς         ἐς
# 2971  ἐς δὲ τὰ δεξιὰ μᾶλλον καταρρεῖ ἢ ἐς τ...      καὶ        καὶ
# 222   Ὁ δὲ στόμαχος ἤρτηται μὲν ἄνωθεν ἀπὸ...  συνεχὴς    συνεχὴς
# 3117  Εἶτ' ἐντεῦθεν πάλιν, ὥσπερ ἀπὸ τῆς α...  κοιλίας     οιλίας
# 2304  Ποτὸν \r\nδιὰ φάρυγγος καὶ διὰ στομάχου (λάρυγ...       διὰ         διά
#
#      lemma_corrected     dictionary
# 1145              ὁ  big_dict_nfkd
# 1778            καί  big_dict_nfkd
# 660               ὁ  big_dict_nfkd
# 963            πρός  big_dict_nfkd
# 950          καθήκω  big_dict_nfkd
# 1007            εἰς  big_dict_nfkd
# 2971            καί  big_dict_nfkd
# 222         συνεχής  big_dict_nfkd
# 3117         κοιλία  big_dict_nfkd
# 2304             διὰ  big_dict_nfkc

# %%
# find how many corrected by each dictionary
corrections_df.groupby('dictionary').count()
# Out:
#                sentence  token  lemma  lemma_corrected
# dictionary
# big_dict_nfkc       212    212    212              212
# big_dict_nfkd      3100   3100   3100             3100

# %%
corrections_df[corrections_df['dictionary'] == 'big_dict_nfkc'].sample(10)
# Out:
#                                                sentence       token  \
# 920             ἕκαθεν δὲ κύστιος μετοχὴ, εἰς ὃ πέφυκε.           ὃ
# 2518  καὶ ἀπὸ τῶν φλεβὼν ὅ τι ἂν νόσημα γένηται ῥήϊό...           ἢ
# 2304  Ποτὸν \r\nδιὰ φάρυγγος καὶ διὰ στομάχου (λάρυγ...         διὰ
# 378   Ὅσα μὲν οὖν ἐστι ζῳοτόκα καὶ δίποδα ἢ τετράποδ...      δίποδα
# 274   παρὰ δὲ τὸ ὀστέον περόναι δύο παρήκουσιν, ἡ μὲ...     ἔνδοθεν
# 1256  Τὰ μὲν\r\nγὰρ κερατοφόρα καὶ μὴ ἀμφώδοντα ἔχει...  ἀμφωδόντων
# 2695  αὖτις δ᾿ ὅθεν φρένες ἐξεπεφύκεσαν, ἀπὸ τούτου ...        κατὰ
# 873   Ἔτι  \r\nδὲ διαφορὰ καὶ ἥδε πρὸς ἀλλήλας ἐστὶ ...     ὑστερῶν
# 1480  Φέρουσι δὲ εἰς αὐτοὺς πόροι ἔκ τε τῆς μεγάλης\...      κοῖλον
# 2818  Καλεῖται δὲ τούτων τὰ μὲν ὑστέρα καὶ δελφύς (ὅ...    Καλεῖται
#
#            lemma lemma_corrected     dictionary
# 920            ὁ              ὅς  big_dict_nfkc
# 2518           ἤ               ἢ  big_dict_nfkc
# 2304         διά             διὰ  big_dict_nfkc
# 378      διπόδης         δίποδος  big_dict_nfkc
# 274        ἔνδον         ἔνδοθεν  big_dict_nfkc
# 1256  ἀμφωδόντων         ἀμφώδων  big_dict_nfkc
# 2695        κατά            κατὰ  big_dict_nfkc
# 873      ὑστερέω          ὑστέρα  big_dict_nfkc
# 1480      κοῖλος          κοῖλον  big_dict_nfkc
# 2818       Καλέω           καλέω  big_dict_nfkc

# %%
corrections_df[corrections_df['dictionary'] == 'big_dict_nfkd'].sample(10)
# Out:
#                                                sentence       token  \
# 462   ἐπὶ μὲν τοῦ ἐντὸς κεκλιμένου τῶν δικραίων ἐπὶ ...           δ
# 2269  Πάλιν δ’ ἐντεῦθεν εἰς τέτταρας σχίζονται...     φλεβὸς
# 1584  Αἱ μὲν γὰρ φέρουσιν εἰς τὰ πλάγια καὶ ...          δ’
# 1062  τὸ γὰρ ἄλλο πλῆθος τῶν φλεβῶν οὐχ ὡσα...       μέρη
# 2489  τῶν μὲν γὰρ οἱ πόροι συγκεχυμένοι καθάπ...       τινες
# 543   Προϊόντι γὰρ καὶ καταβαίνοντι τῷ περιττ...         τὸ
# 151   Ἡ μὲν οὖν μεγάλη φλὲψ ἐκ τῆς μεγίστης...        τῆς
# 2645  ἐπεὶ αἰσθάνονταί γε οὐδενὸς πρότερον τ...        τὴν
# 1747  Φυσωμένης δὲ τῆς ἀρτηρίας διαδίδωσιν εἰ...  πλεύμονος
# 2406  καὶ πάλιν ἕτε ραι διὰ τῶν βουβώνων καὶ...   βουβώνων
#
#            lemma lemma_corrected     dictionary
# 462            δ             δέ  big_dict_nfkd
# 2269     φλεβὸς           φλέψ  big_dict_nfkd
# 1584          δ’             δέ  big_dict_nfkd
# 1062       μέρη          μέρος  big_dict_nfkd
# 2489         τίς             τις  big_dict_nfkd
# 543          τὸ              ὁ  big_dict_nfkd
# 151         τῆς              ὁ  big_dict_nfkd
# 2645        τὴν              ὁ  big_dict_nfkd
# 1747  πλεύμονος        πνεύμων  big_dict_nfkd
# 2406    βουβώνω         βουβών  big_dict_nfkd

# %%
# print lines in corrections_df where lemma_corrected is "NA"
corrections_df[corrections_df['lemma_corrected'] == 'NA']
# Out:
# Empty DataFrame
# Columns: [sentence, token, lemma, lemma_corrected, dictionary]
# Index: []

# %%
# split docs to train, dev, test randomly
from sklearn.model_selection import train_test_split
from pathlib import Path


train_docs, test_docs = train_test_split(docs, test_size=0.2, random_state=42)
train_docs, dev_docs = train_test_split(train_docs, test_size=0.4, random_state=42)

print ("train_docs size:", len(train_docs))
print ("dev_docs size:", len(dev_docs))
print ("test_docs size:", len(test_docs))

# save each one to DocBin

Path("../corpus/train/lemma_train").mkdir(parents=True, exist_ok=True)
Path("../corpus/dev/lemma_dev").mkdir(parents=True, exist_ok=True)
Path("../corpus/test/lemma_test").mkdir(parents=True, exist_ok=True)


train_bin = DocBin(docs=train_docs)
train_bin.to_disk('../corpus/train/lemma_train/lemma_train.spacy')
test_bin = DocBin(docs=test_docs)
test_bin.to_disk('../corpus/test/lemma_test/lemma_test.spacy')
dev_bin = DocBin(docs=dev_docs)
dev_bin.to_disk('../corpus/dev/lemma_dev/lemma_dev.spacy')
# Out:
# train_docs size: 189
# dev_docs size: 127
# test_docs size: 79

# %% [markdown]
# The spacy dataset should be exported to '../corpus/' folder.\
# More specifically:\
# train to '..corpus/train/lemma_train/'\
# dev to '../corpus/dev/lemma_dev/'\
# test to '../corpus/test/lemma_test/

# %%
import os
from spacy.tokens import DocBin, Doc
# Merge all dataset files in the train folder

Merged_lemma_train_dataset = DocBin().from_disk("../corpus/train/lemma_train/lemma_train.spacy")
print(len(Merged_lemma_train_dataset))
# merge all .spacy files that are in the folder (except self) with base_db.spacy
for file in os.listdir("../corpus/train/lemma_train/"):
    if file.endswith(".spacy") and file != 'lemma_train.spacy':
        print(file)
        Merged_lemma_train_dataset.merge(
            DocBin().from_disk(f"../corpus/train/lemma_train/{file}")
        )
print(len(Merged_lemma_train_dataset))
# write the merged file to disk
Merged_lemma_train_dataset.to_disk("../corpus/train/lemma_train/Merged_lemma_train_dataset.spacy")
# Out:
# 189
# euripides_i_train_NFKD.spacy
# train_lemma_NFKD.spacy
# galen_train_NFKD.spacy
# galen_train_NFKC.spacy
# train_lemma_NFKC.spacy
# grc_perseus-ud-train_NFKD.spacy
# grc_proiel-ud-train_NFKD.spacy
# aeschylus_ii_train_NFKC.spacy
# aeschylus_ii_train_NFKD.spacy
# euripides_i_train_NFKC.spacy
# grc_proiel-ud-train_NKFC.spacy
# grc_perseus-ud-train_NFKC.spacy
# 8189

# %%
import os
from spacy.tokens import DocBin, Doc
# Merge all dataset files in the dev folder

Merged_lemma_dev_dataset = DocBin().from_disk("../corpus/dev/lemma_dev/lemma_dev.spacy")
print(len(Merged_lemma_dev_dataset))
# merge all .spacy files that are in the folder (except self) with base_db.spacy
for file in os.listdir("../corpus/dev/lemma_dev/"):
    if file.endswith(".spacy") and file != 'lemma_dev.spacy':
        print(file)
        Merged_lemma_dev_dataset.merge(
            DocBin().from_disk(f"../corpus/dev/lemma_dev/{file}")
        )
print(len(Merged_lemma_dev_dataset))
# write the merged file to disk
Merged_lemma_dev_dataset.to_disk("../corpus/dev/lemma_dev/Merged_lemma_dev_dataset.spacy")
# Out:
# 127
# galen_dev_NFKC.spacy
# grc_proiel-ud-dev_NKFC.spacy
# grc_perseus-ud-dev_NFKC.spacy
# dev_lemma_NFKD.spacy
# dev_lemma_NFKC.spacy
# aeschylus_ii_dev_NFKC.spacy
# galen_dev_NFKD.spacy
# grc_perseus-ud-dev_NFKD.spacy
# grc_proiel-ud-dev_NFKD.spacy
# aeschylus_ii_dev_NFKD.spacy
# euripides_i_dev_NFKD.spacy
# euripides_i_dev_NFKC.spacy
# 1237

# %%
import os
from spacy.tokens import DocBin, Doc
# Merge all dataset files in the dev folder

Merged_lemma_dev_dataset = DocBin().from_disk("../corpus/test/lemma_test/lemma_test.spacy")
print(len(Merged_lemma_dev_dataset))
# merge all .spacy files that are in the folder (except self) with base_db.spacy
for file in os.listdir("../corpus/test/lemma_test/"):
    if file.endswith(".spacy") and file != 'lemma_test.spacy':
        print(file)
        Merged_lemma_dev_dataset.merge(
            DocBin().from_disk(f"../corpus/test/lemma_test/{file}")
        )
print(len(Merged_lemma_dev_dataset))
# write the merged file to disk
Merged_lemma_dev_dataset.to_disk("../corpus/test/lemma_test/Merged_lemma_test_dataset.spacy")
# Out:
# 79
# grc_proiel-ud-test_NFKD.spacy
# grc_perseus-ud-test_NFKC.spacy
# test_lemma_NFKD.spacy
# grc_proiel-ud-test_NKFC.spacy
# grc_perseus-ud-test_NFKD.spacy
# test_lemma_NFKC.spacy
# 1233

# %%
# !python -m spacy debug data ../configs/transformer-full.cfg  --paths.train ../corpus/train/lemma_train/Merged_lemma_train_dataset.spacy --paths.dev ../corpus/dev/lemma_dev/Merged_lemma_dev_dataset.spacy --nlp.lang=grc
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#
# ============================ Data file validation ============================
# Some weights of the model checkpoint at Jacobo/aristoBERTo were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertModel were not initialized from the model checkpoint at Jacobo/aristoBERTo and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✔ Pipeline can be initialized with data
# ✔ Corpus is loadable
#
# =============================== Training stats ===============================
# Language: grc
# Training pipeline: transformer, morphologizer, tagger, parser,
# trainable_lemmatizer, attribute_ruler
# 8189 training docs
# 1237 evaluation docs
# ⚠ 317 training examples also in evaluation data
#
# ============================== Vocab & Vectors ==============================
# ℹ 925659 total word(s) in the data (128762 unique)
# ⚠ 669 misaligned tokens in the training data
# ⚠ 41 misaligned tokens in the dev data
# ℹ No word vectors present in the package
#
# =========================== Part-of-speech Tagging ===========================
# ℹ 1415 label(s) in train data
#
# ========================= Morphologizer (POS+Morph) =========================
# ℹ 1504 label(s) in train data
#
# ============================= Dependency Parsing =============================
# ℹ Found 230348 sentence(s) with an average length of 4.0 words.
# ℹ Found 6233 nonprojective train sentence(s)
# ℹ 36 label(s) in train data
# ℹ 416 label(s) in projectivized train data
# ⚠ Low number of examples for 214 label(s) in the projectivized
# dependency trees used for training. You may want to projectivize labels such as
# punct before training in order to improve parser performance.
# ⚠ Multiple root labels (ROOT, _) found in training data. spaCy's parser
# uses a single root label ROOT so this distinction will not be available.
#
# ============================ Trainable Lemmatizer ============================
# ℹ 48801 lemmatizer trees generated from training data
# ℹ 13546 lemmatizer trees generated from dev data
# ℹ 4381 lemmatizer trees (32.3% of dev trees) were found exclusively in
# the dev data.
# ✔ All training docs have lemma annotations.
# ✔ All dev docs have lemma annotations.
# ✔ All training docs have complete lemma annotations.
# ✔ All dev docs have complete lemma annotations.
#
# ================================== Summary ==================================
# ✔ 6 checks passed
# ⚠ 8 warnings

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:512"

# %%
# !python -m spacy train ../configs/transformer-full.cfg  --output ../training/transformer/assembled --paths.train ../corpus/train/lemma_train/Merged_lemma_train_dataset.spacy --paths.dev ../corpus/dev/lemma_dev/Merged_lemma_dev_dataset.spacy --gpu-id 0 --nlp.lang=grc

# %%
# !python -m spacy train ../configs/transformer-full.cfg  --output ../training/transformer/assembled --paths.train ../corpus/train/lemma_train/Merged_lemma_train_dataset.spacy --paths.dev ../corpus/dev/lemma_dev/Merged_lemma_dev_dataset.spacy --gpu-id 0 --nlp.lang=grc

# %% [markdown]
# ## Evaluations

# %%
# !python -m spacy benchmark accuracy ../training/transformer/assembled/model-best ../corpus/test/lemma_test/lemma_test.spacy --gpu-id 0

# %%
# NER eval
# !python -m spacy benchmark accuracy ../training/transformer/assembled/model-best ../corpus/test/grc_proiel-ud-test_NFKD.spacy --gpu-id 0

# %%
# NER eval
# !python -m spacy benchmark accuracy ../training/transformer/assembled/model-best ../corpus/test/ner_test/On_Anatomy_test.spacy --gpu-id 0

# %% [markdown]
# Evaluation

# %%
# constant evaluation sentencs
#Gal PHP 1.7
text = "Καὶ τὸ μὲν διφυὲς τοῦ στόματος παρίσθμιον, τὸ δὲ πολυφυὲς οὖλον"
#text = "ὧν πρώτη μέν ἐστι συζυγία τῶν ἐπὶ τὰς ὠμοπλάτας ἀναφερομένων, ἀφ' ὧν οὐκ ὀλίγη μοῖρα καὶ πρὸς τὸν νωτιαῖον εἴσω καταδύεται καὶ τοῖς ἐν τραχήλῳ μυσὶ διασπείρεται, δευτέρα δὲ τῶν εἰς τὰς χεῖρας φερομένων ἀρτηριῶν."
text2 = "ἐκφύεται μὲν γὰρ ἐκ τῆς ἀριστερᾶς  κοιλίας τῆς καρδίας ἀρτηρία μεγίστη, καθάπερ τι πρέμνον ἁπασῶν τῶν κατὰ τὸ ζῷον ἀρτηριῶν. ἀποβλαστάνει δὲ ἀπ' αὐτῆς πρῶτον μὲν ἡ τὴν καρδίαν περιστέφουσα· καὶ δὴ καὶ ὀνομάζουσιν οὕτως αὐτὴν οἷς μέλει τῶν ἀνατομῶν."
text3 = "καὶ φαίνεταί γε καθ' ὅλον τὸν θώρακα καὶ συναποτεινόμενά τε καὶ συγκατασχιζόμενα ταυτὶ τὰ δύο γένη τῶν ἀγγείων, εἴς τε τὸν ὑπεζωκότα τὰς πλευρὰς χιτῶνα καὶ τοὺς μεσοπλευρίους μῦς τρίτου τινὸς αὐτοῖς συναποφυομένου τε καὶ συναποτεινομένου καὶ συγκατασχιζομένου φλεβώδους ἀγγείου."
text4 = "Ταῦτ’ οὖν εἴς τε τὸν παρόντα καὶ τὸν ἑξῆς ἅπαντα λόγον οἷον ὑποθέσεις τινὰς τῶν ἀποδείξεων λαμβάνοντες ἐν ἑκάστῳ τῶν ὀργάνων τὴν ἐξ αὐτῶν ὠφέλειαν ἐροῦμεν ἀπὸ τῶν δακτύλων αὖθις ἀρξάμενοι."
text5 = 'Ἔχει δὲ δι’αὑτοῦ καὶ φλέβας τεταμένας'

# %%
import spacy
spacy.require_gpu()
import unicodedata
import pandas as pd

# %%
nlp1 = spacy.load("grc_proiel_trf")
nlp2 = spacy.load("../training/transformer/lemmatizer/model-best")

# %%
# Infer word lemma in sentence without normalization
text = text
doc = nlp1(text)
for token in doc:
    print(token.text, token.lemma_)
print('............')

# Infer word lemma in sentence with NFKD normalization
text_nfkd = unicodedata.normalize("NFKD", text)
doc = nlp1(text_nfkd)
for token in doc:
    print(token.text, token.lemma_)
print('............')
# Infer word lemma in sentence with NFKC normalization
text_nfkc = unicodedata.normalize("NFKC", text)
doc = nlp1(text_nfkc)
for token in doc:
    print(token.text, token.lemma_)

# %% [markdown]
# Text examples:
# text4 = "Ταῦτ’ οὖν εἴς τε τὸν παρόντα καὶ τὸν ἑξῆς ἅπαντα λόγον οἷον ὑποθέσεις τινὰς τῶν ἀποδείξεων λαμβάνοντες ἐν ἑκάστῳ τῶν ὀργάνων τὴν ἐξ αὐτῶν ὠφέλειαν ἐροῦμεν ἀπὸ τῶν δακτύλων αὖθις ἀρξάμενοι."
# text5 = 'Ἔχει δὲ δι’αὑτοῦ καὶ φλέβας τεταμένας'

# %%
# Infer word lemma in sentence without normalization
import pandas as pd

# check if the normalization is NFKD or NFKC
def line_norm(intext):
    if intext == unicodedata.normalize("NFKD", intext):
        return unicodedata.normalize("NFKD", intext)
    elif intext == unicodedata.normalize("NFKC", intext):
        return unicodedata.normalize("NFKC", intext)
    else:
        print('unknown normalization')
        return 'other'
    
# create a dataframe with the results
df = pd.DataFrame(columns=['text', 'M1 lemma', 'M2 lemma', 'M1 lemma_nfkd', 'M2 lemma_nfkd', 'M1 lemma_nfkc', 'M2 lemma_nfkc'])
# Infer word lemma in sentence without normalization
doc = nlp1(text3) 
# check if the normalization is NFKD or NFKC
if unicodedata.is_normalized('NFKD', doc[0].text):
    doc_norm = 'NFKD'
elif unicodedata.is_normalized('NFKC', doc[0].text):
    doc_norm = 'NFKC'
print(doc_norm)
# Infer word lemma in sentence without normalization
for token in doc:
    df = df.append({'text': token.text, 'M1 lemma': token.lemma_}, ignore_index=True)
doc = nlp2(text3)
for token in doc:
        df.loc[df['text'] == line_norm(token.text), 'M2 lemma'] = token.lemma_

# Infer word lemma in sentence with NFKD normalization
text_nfkd = unicodedata.normalize("NFKD", text3)
doc = nlp1(text_nfkd)
for token in doc:
    df.loc[df['text'] == unicodedata.normalize(doc_norm, token.text), 'M1 lemma_nfkd'] = token.lemma_
doc = nlp2(text_nfkd)
for token in doc:
    df.loc[df['text'] == unicodedata.normalize(doc_norm, token.text), 'M2 lemma_nfkd'] = token.lemma_

# Infer word lemma in sentence with NFKC normalization
text_nfkc = unicodedata.normalize("NFKC", text3)
doc = nlp1(text_nfkc)
for token in doc:
    df.loc[df['text'] == unicodedata.normalize(doc_norm, token.text), 'M1 lemma_nfkc'] = token.lemma_
doc = nlp2(text_nfkc)
for token in doc:
    df.loc[df['text'] == unicodedata.normalize(doc_norm, token.text), 'M2 lemma_nfkc'] = token.lemma_
df

# %%
doc_norm

# %%
doc[0]

# %%
doc = nlp1(text)
if doc[0].text == unicodedata.normalize("NFKD", doc[0].text):
    print('NFKD')

doc = nlp2(text)
if doc[0].text == unicodedata.normalize("NFKD", doc[0].text):
    print('NFKD')

# %%
doc = nlp2(text)
for token in doc:
        df.loc[df['text'] == unicodedata.normalize('NFKC', token.text), 'M2 lemma'] = token.lemma_

# %%
df

# %%
# Loading a spacy test corpus and using that for xplicit evaluations
# load corpus
from spacy.tokens import DocBin, Doc
docs = []
corpus = DocBin().from_disk("../Archive/corpus_latest_no_accents/test/lemma_test/lemma_test.spacy")
# doc = the first document in the corpus
for doc in corpus.get_docs(nlp1.vocab):
    #print(doc.text)
    docs.append(doc)
