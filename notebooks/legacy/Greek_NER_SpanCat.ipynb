# %%
import os
import re
import spacy
import pandas as pd
import logging
from pathlib import Path

# import requirements for converting the dataframe to Spacy Docs
from collections import defaultdict
from unicodedata import normalize
import regex
import random

# Get the root logger
logger = logging.getLogger()

# Remove all handlers from the logger
for handler in logger.handlers[:]:
    logger.removeHandler(handler)

# Add a new handler to the logger
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(name)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

logger.setLevel(logging.DEBUG)

# Define global parameters as lists
INCEPTION_TRAIN_DATA = []
TRAIN_DATA = []
not_found_list = []
MERGED_TRAIN_DATA = []

# %%
# config.py

class Config:
    DEFAULT_FORM = 'NFC'
    REMOVE_ACCENTS = False
    LOWERCASE = False
    STANDARDIZE_APOSTROPHE = True
    REMOVE_BRACKETS = False
    REMOVE_TRAILING_NUMBERS = False
    REMOVE_EXTRA_SPACES = False
    DEBUG = False

# Instantiating the Config class for application-wide access.
app_config = Config()

import re
import unicodedata

# apostrophes and correct_apostrophe are defined as follows:
apostrophes = ["᾽", "᾿", "'", "’", "‘"]
correct_apostrophe = "ʼ"

def clean_and_remove_accents(text: str) -> str:
    """
    Cleans the given text by removing diacritics (accents), except for specific characters,
    and converting it to lowercase.
    """
    allowed_characters = [' ̓', "᾿", "᾽", "'", "’", "‘", 'ʼ', '̓']  # Including the Greek apostrophe
    if not isinstance(text, str):
        raise ValueError("Input must be a string.")
    try:
        non_accent_chars = [c for c in unicodedata.normalize('NFC', text) 
        if unicodedata.category(c) != 'Mn' or c in allowed_characters]
        return ''.join(non_accent_chars)
    
    except Exception as e:
        # A more generic exception handling if unexpected errors occur
        print(f"An error occurred: {e}")
        return text
    

def normalize_text(text: str, 
                   form: str = None, 
                   remove_accents: bool = None, 
                   lowercase: bool = None, 
                   standardize_apostrophe: bool = None, 
                   remove_brackets: bool = None, 
                   remove_trailing_numbers: bool = None, 
                   remove_extra_spaces: bool = None, 
                   debug: bool = None) -> str:
    """
    Applies multiple text normalization and cleaning steps on the input text.

    Parameters:
    - text (str): The text to be normalized.
    - form (str): Unicode normalization form ('NFC', 'NFD', 'NFKC', 'NFKD').
    - remove_accents (bool): If True, removes accents from the text.
    - lowercase (bool): If True, the text is converted to lowercase.
    - standardize_apostrophe (bool): If True, replaces all defined apostrophe characters with a standard one.
    - remove_brackets_only (bool): If True, removes the brackets themselves.
    - remove_trailing_numbers (bool): If True, strips leading or trailing digits from the text.
    - remove_extra_spaces (bool): If True, removes extra spaces and leading/trailing spaces.
    - debug (bool): If True, prints before and after states for each operation.
    
    Returns:
    - str: The processed text.
    """
    
    # Fetch default settings from app_config if not provided
    form = form if form is not None else app_config.DEFAULT_FORM
    remove_accents = remove_accents if remove_accents is not None else app_config.REMOVE_ACCENTS
    lowercase = lowercase if lowercase is not None else app_config.LOWERCASE
    standardize_apostrophe = standardize_apostrophe if standardize_apostrophe is not None else app_config.STANDARDIZE_APOSTROPHE
    remove_brackets = remove_brackets if remove_brackets is not None else app_config.REMOVE_BRACKETS
    remove_trailing_numbers = remove_trailing_numbers if remove_trailing_numbers is not None else app_config.REMOVE_TRAILING_NUMBERS
    remove_extra_spaces = remove_extra_spaces if remove_extra_spaces is not None else app_config.REMOVE_EXTRA_SPACES
    debug = debug if debug is not None else app_config.DEBUG
    
    normalized_text = text  # Initialize normalized_text with the original text

    # Function to print before and after states for each operation during debugging
    def debug_print(operation_name, before, after):
        if debug:
            logger.debug(f"{operation_name} - Before: {before}")
            logger.debug(f"{operation_name} - After: {after}")

    # Standardize apostrophe characters if required
    if standardize_apostrophe:
        before_text = normalized_text
        for apos in apostrophes:
            normalized_text = normalized_text.replace(apos, correct_apostrophe)
        debug_print("Standardizing apostrophes", before_text, normalized_text)
        
    if remove_accents:
        before_text = normalized_text
        try:
            normalized_text = clean_and_remove_accents(normalized_text)
        except Exception as e:
            logger.error(f"An error occurred while removing accents: {e}")
            # Decide what to do here: return the original text, a special value, or stop the process
            return text        
        debug_print("Removing accents", before_text, normalized_text)
        
    # Convert to lowercase if required
    if lowercase:
        before_text = normalized_text
        normalized_text = normalized_text.lower()
        debug_print("Lowercase conversion", before_text, normalized_text)

    # Unicode normalization
    if form:
        before_text = normalized_text
        normalized_text = unicodedata.normalize(form, normalized_text)
        debug_print("Unicode normalization", before_text, normalized_text)
            
    # Remove brackets only if required
    if remove_brackets:
        before_text = normalized_text
        normalized_text = re.sub(r'[\(\)\[\]]', '', normalized_text)
        debug_print("Removing brackets", before_text, normalized_text)
        
    # Remove trailing numbers if required
    if remove_trailing_numbers:
        before_text = normalized_text
        normalized_text = re.sub(r'^\d+|\d+$', '', normalized_text)
        debug_print("Removing trailing numbers", before_text, normalized_text)

    # Remove multiple spaces and leading/trailing spaces
    if remove_extra_spaces:
        before_text = normalized_text
        normalized_text = ' '.join(normalized_text.split()).strip()
        debug_print("Removing extra spaces", before_text, normalized_text)

    return normalized_text

# %% [markdown]
# # Load and process data from csv
# This segment processes a csv from a table of references.
# Spacy needs the index of a word (start and end characters index in the sentence) and the tag it has. Since csv doesn't include the indexes, this cells group processes the csv, cleans it up, pairs words with tags and indexes the words. The output is a dataframe with 'entities': [(start, end, 'LABEL')]}, 'SOURCE'

# %%
# Load the dataset
FILE_PATH = "../assets/NER_assets/Ancient_Words_12_5_22.csv"
df = pd.read_csv(FILE_PATH)

# Renaming columns
df.rename(columns={'Word': 'Keyword', 'Category Types': 'Label'}, inplace=True)

# Filling NaN values more efficiently and appropriately
for early_col, new_col in [('Early Quote', 'Quote'), ('Early Word Before', 'Word Before'), 
                           ('Early Word After', 'Word After'), ('Early Category Type', 'Label')]:
    df[new_col] = df[new_col].fillna(df[early_col])
# Dropping rows with no Keyword and non-Greek Keywords
pat = '[ء-ي]+'
df = df.dropna(subset=['Keyword']).copy()
df = df[~df['Keyword'].str.contains(pat, na=False)]

# Cleaning data with combined regex patterns

# Define a dictionary of patterns and replacements for the entire dataframe
df_replacements = {
    r'\d+': '',  # Numbers
    '-': '',  # Hyphens
    ' +': ' ',  # Multiple spaces
}

# Apply the replacements to the text columns ('Early Quote', 'Quote', 'Early Word Before', 'Word Before', 'Early Word After', 'Word After', 'Keyword')
for col in ['Early Quote', 'Quote', 'Early Word Before', 'Word Before', 'Early Word After', 'Word After', 'Keyword']:
    for pattern, replacement in df_replacements.items():
        df[col] = df[col].replace(pattern, replacement, regex=True)
# Define a dictionary of patterns and replacements for the 'Keyword' column
keyword_replacements = {
    '\n': '',  # New line
    ',': '',  # Comma
    r'\.': '',  # Period
    r'\·': '',  # Interpunkt
    r'\s+$': ''  # End punctuation
}

# Apply the replacements to the 'Keyword' column
for pattern, replacement in keyword_replacements.items():
    df['Keyword'] = df['Keyword'].replace(pattern, replacement, regex=True)
# Resetting the dataframe index
df.reset_index(drop=True, inplace=True)

# Normalizing the text in the columns
columns_to_normalize = ['Early Quote', 'Quote', 'Early Word Before', 'Word Before', 'Early Word After', 'Word After', 'Keyword']

for col in columns_to_normalize:
    if df[col].dtype == 'object':
        df[col] = df[col].apply(lambda x: normalize_text(x) if pd.notna(x) else x)

# %%
len(df)
# Out:
# 1411

# %%
def create_source_description(row):
    formatted_values = []
    for col in ['Modern Edition', 'Book', 'Chapter', 'Section', 'Page', 'Line Number']:
        value = row[col]
        if pd.notna(value) and value != '':
            # Handling special case for Modern Edition
            formatted_value = str(value) if col == 'Modern Edition' else f"{col[0]}({int(value)})" if isinstance(value, (int, float)) else f"{col[0]}({value})"
            formatted_values.append(formatted_value)
    source = ', '.join(formatted_values)
    return f"Coda, {source}"

df['Source'] = df.apply(create_source_description, axis=1)

# %% [markdown]
# ## Fix similar sentences

# %%
def ngrams(sentence, n=2):
    """Returns a list of n-grams from the sentence."""
    # Convert sentence to lowercase and split into tokens/words
    tokens = sentence.lower().split()
    # Generate n-grams
    return set(zip(*[tokens[i:] for i in range(n)]))

def jaccard_similarity(set1, set2):

    debug = app_config.DEBUG

    """Calculate the Jaccard Similarity between two sets, handling empty sets."""
    try:
        intersection = len(set1.intersection(set2))
        print(f"Intersection: {intersection}") if debug else None
        
        union = len(set1.union(set2))
        print(f"Union: {union}") if debug else None
        
        return intersection / union if union != 0 else 0
    except Exception as e:
        print(f"An error occurred: {e}") if debug else None
        return None

# Assuming df_grouped is your DataFrame and 'Quote' is the column with sentences.
threshold = 0.5  # Example threshold, adjust based on your requirements
groups = []
df_grouped = df.copy()
df_grouped["Quote_ngrams"] = df_grouped["Quote"].apply(lambda x: ngrams(x, n=2)) # Create n-grams for each quote

for i, base_row in df_grouped.iterrows():
    similar_found = False
    base_ngrams = base_row["Quote_ngrams"]
    
    for group in groups:
        representative_index = group[0]  # Use the first sentence of each group as the representative
        representative_ngrams = df_grouped.loc[representative_index, "Quote_ngrams"]
        
        if jaccard_similarity(base_ngrams, representative_ngrams) >= threshold:
            group.append(i)
            similar_found = True
            break
            
    if not similar_found:
        groups.append([i])  # Start a new group
        
from collections import Counter

# Initialize a list to hold the data for the new DataFrame
new_data = []

for group_indices in groups:
    # Extract sentences and their corresponding rows for the current group
    group_rows = df_grouped.iloc[group_indices]
    
    # Determine the most frequent sentence in the group
    sentence_counts = Counter(group_rows['Quote'])
    most_freq_sentence, _ = sentence_counts.most_common(1)[0]
    
    # Determine the most complete (longest) sentence in the group after removing whitespace
    most_complete_sentence = group_rows.loc[group_rows['Quote'].str.len().idxmax(), 'Quote']
    
    # Choose the sentence to use based on frequency and completeness
    sentence_to_use = most_freq_sentence if len(most_freq_sentence) >= len(most_complete_sentence) else most_complete_sentence
    
    # Consolidate labels, keywords, words before, and words after into lists
    entities = group_rows[['Label', 'Keyword', 'Word Before', 'Word After']].values.tolist()
    
    source_detail = group_rows.loc[group_rows['Quote'].str.len().idxmax(), 'Source']  # Use source of most complete sentence
    
    # Append to new data list: the chosen sentence, the consolidated entities and the source
    new_data.append({'Quote': sentence_to_use, 'Entities': entities, 'Source': source_detail})

# Create a new DataFrame from the new data
df_final = pd.DataFrame(new_data)

# Print the groups, their sentences with their original index, and the chosen sentence for verification
for i, group_indices in enumerate(groups):
    print(f"Group {i + 1}:")
    for index in group_indices:
        print(f"  - Index {index}: {df_grouped.loc[index, 'Quote']}, Source: {df_grouped.loc[index, 'Source']}")
    print(f"  Chosen sentence: {df_final.loc[i, 'Quote']}, Source: {df_final.loc[i, 'Source']}\n")
    print(f"  Entities: {df_final.loc[i, 'Entities']}\n")
        
# Structure of df_final:
# 'Quote': The representative sentence of the group.
# 'Entities': A list of lists for each sentence, containing label, keyword, word before, and word after.
# Out:
# Group 1:
#   - Index 0: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(9)
#   - Index 288: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(9)
#   - Index 295: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(10)
#   - Index 296: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(10)
#   - Index 304: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(9)
#   - Index 305: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(9)
#   - Index 306: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(10)
#   Chosen sentence: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(9)
#
#   Entities: [['Body Part', 'αἷμα', 'γὰρ ἔχει', 'τῶν κοιλιῶν'], ['Body Part', 'κοιλιῶν', 'αἷμα τῶν', ', λεπτότατον δʼ'], ['Adjectives/Qualities', 'λεπτότατον', 'τῶν κοιλιῶν,', 'δʼ ἐστὶ'], ['Adjectives/Qualities', 'μέσῃ', 'ἐν τῇ', '.'], ['Topography', 'ἐν', 'ἐν αὑτῇ·', 'ἑκάστῃ γὰρ'], ['Topography', 'ἑκάστῃ', 'αὑτῇ· ἐν', 'γὰρ ἔχει'], ['Topography', 'ἐν', 'ἐστὶ τὸ', 'τῇ μέσῃ']]
#
# Group 2:
#   - Index 1: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(10)
#   - Index 2: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(10)
#   - Index 3: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(11)
#   - Index 4: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(11)
#   - Index 5: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(11)
#   - Index 6: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(11)
#   - Index 7: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(12)
#   - Index 8: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(12)
#   - Index 9: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(12)
#   - Index 10: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(12)
#   - Index 11: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(13)
#   - Index 12: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(13)
#   - Index 13: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(13)
#   - Index 14: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(13)
#   Chosen sentence: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(10)
#
#   Entities: [['Topography', 'Ὑπὸ', 'μέσῃ.', 'δὲ τὸν'], ['Body Part', 'πνεύμονά', 'δὲ τὸν', 'ἐστι τὸ'], ['Body Part', 'διάζωμα', 'ἐστι τὸ', 'τὸ τοῦ'], ['Body Part', 'θώρακος', 'τὸ τοῦ', ', αἱ καλούμεναι'], ['Body Part', 'φρένες', ', αἱ καλούμεναι', ', πρός μὲν'], ['Topography', 'πρός', 'καλούμεναι φρένες,', 'μέν τὰ'], ['Body Part', 'πλευρά', 'μὲν τὰ', 'καὶ τὰ'], ['Body Part', 'ὑποχόνδρια', 'καὶ τὰ', 'καὶ τὴν'], ['Body Part', 'ῥάχιν', 'καὶ τὴν', 'συνηρτημέναι, ἐν'], ['Topography', 'συνηρτημέναι', 'τὴν ῥάχιν', ', ἐν μέσῳ'], ['Topography', 'ἐν', 'συνηρ τημέναι,', 'μέσῳ δʼ'], ['Topography', 'μέσῳ', 'τημέναι, ἐν', 'δʼ ἔχει'], ['Adjectives/Qualities', 'λεπτά', 'ἔχει τὰ', 'καὶ ὑμενώδη'], ['Adjectives/Qualities', 'ὑμενώδη', 'λεπτὰ καὶ ', '. Ἔχει']]
#
# Group 3:
#   - Index 15: Ἔχει δὲ διʼ αὑτοῦ καὶ φλέβας τεταμένας, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84)
#   - Index 16: Ἔχει δὲ διʼ αὑτοῦ καὶ φλέβας τεταμένας, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84)
#   - Index 17: Ἔχει δὲ διʼ αὑτοῦ καὶ φλέβας τεταμένας, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84)
#   - Index 18: Ἔχει δὲ διʼ αὑτοῦ καὶ φλέβας τεταμένας, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84)
#   Chosen sentence: Ἔχει δὲ διʼ αὑτοῦ καὶ φλέβας τεταμένας, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84)
#
#   Entities: [['Topography', 'διʼ', 'Ἔχει δὲ', 'αὑτοῦ καὶ'], ['Medical', 'αὑτοῦ', 'δὲ διʼ', 'καὶ φλέβας'], ['Body Part', 'φλέβας', 'αὑτοῦ καὶ', 'τεταμένας· '], ['Topography', 'τεταμένας', 'καὶ φλέβας', '· εἰσί']]
#
# Group 4:
#   - Index 19: εἰσὶ δʼαἱ τοῦ ἀνθρώπου φρένες παχεῖαι ὡς κατὰ λόγον τοῦ σώματος, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84)
#   - Index 20: εἰσὶ δʼαἱ τοῦ ἀνθρώπου φρένες παχεῖαι ὡς κατὰ λόγον τοῦ σώματος, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(
, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(15)
#   - Index 57: Μέρος δʼ αὐτοῦ τὸ μὲν διάφραγμα χόνδρος, τὸ δʼ ὀχέτευμα κενόν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(16)
#   - Index 58: Μέρος δʼ αὐτοῦ τὸ μὲν διάφραγμα χόνδρος, τὸ δʼ ὀχέτευμα κενόν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(16)
#   - Index 76: Μέρος δʼ αὐτοῦ τὸ μὲν διάφραγμα χόνδρος, τὸ δʼ ὀχέτευμα κενόν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(16)
#   - Index 77: Μέρος δʼ αὐτοῦ τὸ μὲν διάφραγμα χόνδρος, τὸ δʼ ὀχέτευμα κενόν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(16)
#   - Index 79: Μέρος δʼ αὐτοῦ τὸ μὲν διάφραγμα χόνδρος, τὸ δʼ ὀχέτευμα κενόν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(15)
#   - Index 80: Μέρος δʼ αὐτοῦ τὸ μὲν διάφραγμα χόνδρος, τὸ δʼ ὀχέτευμα κενόν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(16)
#   Chosen sentence: Μέρος δʼ αὐτοῦ τὸ μὲν διάφραγμα χόνδρος, τὸ δʼ ὀχέτευμα κενόν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(15)
#
#   Entities: [['Adjectives/Qualities', 'Μέρος', 'κατʼ ἰδίαν.', 'δʼ αὐτοῦ'], ['Adjectives/Qualities', 'χόνδρος', 'μὲν διάφραγμα', ', τὸ δ'], ['Adjectives/Qualities', 'κενόν', 'δʼ ὀχέτευμα', '· ἔστι γὰρ'], ['Topography', 'διάφραγμα', 'τὸ μὲν', 'χόνδρος, τὸ'], ['Topography', 'ὀχέτευμα', 'δ ʼ', 'κενόν· ἔστι'], ['Division', 'τὸ', 'δʼ αὐτοῦ', 'μὲν διάφραγμα'], ['Division', 'τὸ', 'διάφραγμα χόνδρος,', 'δʼ ὀχέτευμα']]
#
# Group 21:
#   - Index 92: ἐνδέχεται δὲ καὶ μὴ χρώμενον ταύτῃ ζῆν , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(13)
#   Chosen sentence: ἐνδέχεται δὲ καὶ μὴ χρώμενον ταύτῃ ζῆν , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(13)
#
#   Entities: [['Physiology', 'ζῆν', 'χρώμενον ταύτῃ', '. Ἡ δʼ']]
#
# Group 22:
#   - Index 94: αὕτη δʼ ἐστὶν ἡ αἴσθησις ὀσμῆς , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(14)
#   - Index 100: αὕτη δʼ ἐστὶν ἡ αἴσθησις ὀσμῆς , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(14)
#   Chosen sentence: αὕτη δʼ ἐστὶν ἡ αἴσθησις ὀσμῆς , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(14)
#
#   Entities: [['Physiology', 'αἴσθησις', 'ἐστὶν ἡ', 'ὀσμῆς. Εὐκίνητος'], ['Medical', 'ὀσμῆς', 'ἡ αἴσθησις', '. Εὐκίνητος δʼ']]
#
# Group 23:
#   - Index 103: Ἔτι δὲ σιαγόνες δύο , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(22)
#   - Index 123: Ἔτι δὲ σιαγόνες δύο , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(22)
#   Chosen sentence: Ἔτι δὲ σιαγόνες δύο , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(22)
#
#   Entities: [['Body Part', 'σιαγόνες', 'Ἔτι δὲ', 'δύο· τούτων'], ['Adjectives/Qualities', 'δύο', 'δὲ σιαγόνες', '· τούτων τὸ']]
#
# Group 24:
#   - Index 104: τούτων τὸ πρόσθιον γένειον, τὸ δʼ ὀπίσθιον γένυς , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L
Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(25)
#
#   Entities: [['Body Part', 'ῥῖνα', 'δὲ τὴν', 'χείλη δύο'], ['Body Part', 'χείλη', 'τὴν ῥῖνα', 'δύο, σὰρξ'], ['Adjectives/Qualities', 'δύο', 'ῥῖνα χείλη', ', σὰρξ εὐκίνητος'], ['Adjectives/Qualities', 'σὰρξ', 'χείλη δύο,', 'εὐκίνητος. Τὸ'], ['Adjectives/Qualities', 'εὐκίνητος', 'δύο, σὰρξ', '. Τὸ δʼ'], ['Topography', 'Μετὰ', 'ἄνω μόνος.', 'δὲ τὴν']]
#
# Group 27:
#   - Index 109: Τὸ δʼ ἐντὸς στόμα σιαγόνων καὶ χειλῶν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(25)
#   - Index 110: Τὸ δʼ ἐντὸς στόμα σιαγόνων καὶ χειλῶν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#   - Index 111: Τὸ δʼ ἐντὸς στόμα σιαγόνων καὶ χειλῶν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#   - Index 159: Τὸ δʼ ἐντὸς στόμα σιαγόνων καὶ χειλῶν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(25)
#   Chosen sentence: Τὸ δʼ ἐντὸς στόμα σιαγόνων καὶ χειλῶν, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(25)
#
#   Entities: [['Body Part', 'στόμα', 'δʼ ἐντὸς', 'σιαγόνων καὶ'], ['Body Part', 'σιαγόνων', 'ἐντὸς στόμα', 'καὶ χειλῶν'], ['Body Part', 'χειλῶν', 'σιαγόνων καὶ', '. Τούτου μέρη'], ['Topography', 'ἐντὸς', 'Τὸ δʼ', 'στόμα σιαγόνων']]
#
# Group 28:
#   - Index 112: Τούτου μέρη τὸ μὲν ὑπερῷα τὸ δὲ φάρυγξ, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#   - Index 113: Τούτου μέρη τὸ μὲν ὑπερῷα τὸ δὲ φάρυγξ, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(27)
#   - Index 130: Τούτου μέρη τὸ μὲν ὑπερῷα τὸ δὲ φάρυγξ, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#   - Index 172: Τούτου μέρη τὸ μὲν ὑπερῷα τὸ δὲ φάρυγξ, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#   - Index 173: Τούτου μέρη τὸ μὲν ὑπερῷα τὸ δὲ φάρυγξ, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#   - Index 174: Τούτου μέρη τὸ μὲν ὑπερῷα τὸ δὲ φάρυγξ, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#   - Index 175: Τούτου μέρη τὸ μὲν ὑπερῷα τὸ δὲ φάρυγξ, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#   Chosen sentence: Τούτου μέρη τὸ μὲν ὑπερῷα τὸ δὲ φάρυγξ, Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(26)
#
#   Entities: [['Body Part', 'ὑπερῷα', 'τὸ μὲν', 'τὸ δὲ'], ['Body Part', 'φάρυγξ', 'τὸ δὲ', '. Τὸ δʼ'], ['Adjectives/Qualities', 'μέρη', 'χειλῶν. Τούτου', 'τὸ μὲν'], ['Division', 'τὸ', 'Τούτου μέρη', 'μὲν ὑπερῷα'], ['Division', 'μὲν', 'μέρη τὸ', 'ὑπερῷα τὸ'], ['Division', 'τὸ', 'μὲν ὑπερῷα', 'δὲ φάρυγξ.'], ['Division', 'δὲ', 'ὑπερῷα τὸ', 'φάρυγξ. Τὸ']]
#
# Group 29:
#   - Index 114: Τὸ δʼ αἰσθητικὸν χυμοῦ γλῶττα , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(27)
#   - Index 131: Τὸ δʼ αἰσθητικὸν χυμοῦ γλῶττα , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L(27)
#   - Index 176: Τὸ δʼ αἰσθητικὸν χυμοῦ γλῶττα , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(73), L
# 211  [[Body Part, καρδίη, ἡ , αἰσθάνεταί ], [Body P...
# 212         [[Body Part, ἐγκέφαλος, αἴτιός ὁ, ἐστιν.]]
# 213  [[Body Part, ὦτα, καρδίῃ , καλεῖται], [Technic...
#
#                                                 Source
# 0    Coda, Aristotle, History of Animals, B(1), C(1...
# 1    Coda, Aristotle, History of Animals, B(1), C(1...
# 2    Coda, Aristotle, History of Animals, B(1), C(1...
# 3    Coda, Aristotle, History of Animals, B(1), C(1...
# 4    Coda, Aristotle, History of Animals, B(1), C(1...
# ..                                                 ...
# 209  Coda, Hippocrates, Sacred Disease, C(17), S(3)...
# 210  Coda, Hippocrates, Sacred Disease, C(17), S(3)...
# 211  Coda, Hippocrates, Sacred Disease, C(17), S(3)...
# 212  Coda, Hippocrates, Sacred Disease, C(17), S(3)...
# 213  Coda, Hippocrates, Sacred Disease, C(17), S(2)...
#
# [214 rows x 3 columns]

# %% [markdown]
# ## Fix similar words

# %%
import regex as re
import unicodedata


def build_exact_pattern(word):
    """
    Builds a regex pattern that matches the word exactly, including diacritics.
    """
    return re.escape(word)

def build_diacritic_agnostic_pattern(word, form=None, debug=None, max_errors=2, debug_patterns=None):
    """
    Builds a regex pattern that matches the word in a diacritic-agnostic manner.
    """
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = debug if debug is not None else app_config.DEBUG

    if not word:
        return None  # Return None for empty strings

    decomposed_word = unicodedata.normalize(form, word)
    pattern_parts = []
    for char in decomposed_word:
        if unicodedata.category(char) == 'Mn':  # Is a diacritic mark
            # This character is a diacritic; make its presence optional in the pattern
            pattern_parts.append(r'\p{M}*')  # Make diacritics optional
        else:
            # For non-diacritic characters, escape them and option
            pattern_parts.append(re.escape(char) + r'\p{M}*')  # Escape non-diacritics and allow diacritics

    pattern = ''.join(pattern_parts)
    logger.debug(f"Regex Pattern: {pattern}") if debug and debug_patterns else None

    # Construct the fuzzy pattern separately
    fuzzy_pattern = rf"(?:{pattern})"
    if max_errors > 0:
        fuzzy_pattern += rf"{{s<={max_errors}}}"

    logger.debug(f"word: {word}, fuzzy_pattern: {fuzzy_pattern}")  if debug and debug_patterns else None # Debug print

    return fuzzy_pattern

def find_word_index(sentence, word, word_before, word_after, form=None, debug=None, debug_patterns=None, max_errors=2, **kwargs):
    """
    Finds the index of a word within a sentence, allowing for various normalization options and
    tolerating diacritic variations and minor errors.
    Raises a ValueError if the word is not found in the sentence.
    """
    debug = debug if debug is not None else app_config.DEBUG

    form = form if form is not None else app_config.DEFAULT_FORM

    # Override/debug settings are explicitly set here
    kwargs['remove_accents'] = False
    kwargs['lowercase'] = True  
    kwargs['remove_extra_spaces'] = True
    kwargs["remove_brackets"] = False
    kwargs["form"] = form

    if not sentence or not word:
        raise ValueError("Sentence and word must be provided")

    # Normalize inputs
    try:
        normalized_sentence = normalize_text(sentence, **{**app_config.__dict__, **kwargs})
        normalized_word = normalize_text(word, **{**app_config.__dict__, **kwargs})
        normalized_word_before = normalize_text(word_before, **{**app_config.__dict__, **kwargs}) if word_before else ""
        normalized_word_after = normalize_text(word_after, **{**app_config.__dict__, **kwargs}) if word_after else ""
    except Exception as e:
        logger.error(f"Error normalizing inputs: {e}")
        raise ValueError(f"Could not normalize inputs: sentence={sentence}, word={word}, word_before={word_before}, word_after={word_after}")

    logger.debug(f"Input: sentence={sentence}, \n word={word}, word_before={word_before}, word_after={word_after}, form={form}, kwargs={kwargs}") if debug and debug_patterns else None
    logger.debug(f"Normalized sentence: {normalized_sentence}") if debug and debug_patterns else None
    logger.debug("normalized_word: %s, normalized_word_before: %s, normalized_word_after: %s", normalized_word, normalized_word_before, normalized_word_after) if debug and debug_patterns else None
    # Build exact and diacritic-agnostic patterns
    try:
        #exact_word_pattern = build_exact_pattern(normalized_word)
        #word_pattern = build_diacritic_agnostic_pattern(normalized_word, form=form, debug=debug, max_errors=max_errors)
        #exact_word_before_pattern = build_exact_pattern(normalized_word_before)
        #word_before_pattern = build_diacritic_agnostic_pattern(normalized_word_before, form=form, debug=debug, max_errors=max_errors)
        #exact_word_after_pattern = build_exact_pattern(normalized_word_after) if word_after else None
        #word_after_pattern = build_diacritic_agnostic_pattern(normalized_word_after, form=form, debug=debug, max_errors=max_errors)
        exact_word_pattern = build_exact_pattern(normalized_word)
        word_pattern = build_diacritic_agnostic_pattern(normalized_word, form=form, debug=debug, max_errors=max_errors)
        
        exact_word_before_pattern = build_exact_pattern(normalized_word_before) if normalized_word_before else None
        word_before_pattern = build_diacritic_agnostic_pattern(normalized_word_before, form=form, debug=debug, max_errors=max_errors) if normalized_word_before else None

        exact_word_after_pattern = build_exact_pattern(normalized_word_after) if normalized_word_after else None
        word_after_pattern = build_diacritic_agnostic_pattern(normalized_word_after, form=form, debug=debug, max_errors=max_errors) if normalized_word_after else None
        
        logger.debug(f"exact_word_pattern: {exact_word_pattern}") if debug and debug_patterns else None
        logger.debug(f"exact_word_before_pattern: {exact_word_before_pattern}") if debug else None
        logger.debug(f"exact_word_after_pattern: {exact_word_after_pattern}") if debug else None
        logger.debug(f"word_pattern: {word_pattern}") if debug and debug_patterns else None
        logger.debug(f"word_before_pattern: {word_before_pattern}") if debug else None
        logger.debug(f"word_after_pattern: {word_after_pattern}") if debug else None

    except Exception as e:
        logger.error(f"Error building patterns: {e}")
        raise ValueError(f"Could not build patterns for: word={word}, word_before={word_before}, word_after={word_after}")

    
    #patterns = create_patterns(sentence, exact_word_pattern=exact_word_pattern, exact_word_before_pattern=exact_word_before_pattern, exact_word_after_pattern=exact_word_after_pattern, word_before=word_before, word_after=word_after, max_errors=max_errors, debug=debug, debug_patterns=debug_patterns)
    patterns = create_patterns(sentence, exact_word_pattern=exact_word_pattern,
                            word_before=word_before, word_after=word_after, 
                            exact_word_before_pattern=exact_word_before_pattern, exact_word_after_pattern=exact_word_after_pattern)
    for pattern in patterns.values():
        logger.debug(f"Attempting with pattern: {pattern}") if debug and debug_patterns else None
        try:
            matches = re.finditer(pattern, normalized_sentence)
            for match in matches:
                match_word = match.group(1).rstrip()
                start, end = match.start(1), match.start(1) + len(match_word)
                return start, end, normalized_sentence
        except Exception as e:
            logger.debug(f"Word '{word}' not found in sentence '{sentence}'")

    #patterns = create_patterns(sentence, exact_word_pattern=exact_word_pattern, exact_word_before_pattern=exact_word_before_pattern, exact_word_after_pattern=exact_word_after_pattern, word_before=word_before, word_after=word_after, max_errors=max_errors, debug=debug, debug_patterns=debug_patterns)
    patterns = create_patterns(sentence=sentence, word_pattern=word_pattern, 
                           word_before=word_before, word_after=word_after, word_before_pattern=word_before_pattern, 
                           word_after_pattern=word_after_pattern)
    for pattern in patterns.values():
        logger.debug(f"Attempting with pattern: {pattern}") if debug and debug_patterns else None
        try:
            matches = re.finditer(pattern, normalized_sentence)
            for match in matches:
                match_word = match.group(1).rstrip()
                start, end = match.start(1), match.start(1) + len(match_word)
                return start, end, normalized_sentence
        except Exception as e:
            logger.debug(f"Word '{word}' not found in sentence '{sentence}'")

def create_patterns(sentence, exact_word_pattern=None, word_pattern=None, word_before=None, word_after=None, word_before_pattern=None, word_after_pattern=None, exact_word_before_pattern=None, exact_word_after_pattern=None, max_errors=2, debug=False, debug_patterns=False):
    patterns = {}
    optional_punct_pattern = r"[,;.!?]?\s*"  # Pattern for optional punctuation followed by optional whitespace

    logger.debug(f"exact_word_pattern: {exact_word_pattern}, word_pattern: {word_pattern}, word_before: {word_before}, word_after: {word_after}, word_before_pattern: {word_before_pattern}, word_after_pattern: {word_after_pattern}, exact_word_before_pattern: {exact_word_before_pattern}, exact_word_after_pattern: {exact_word_after_pattern}") if debug and debug_patterns else None
    
    # First, try to match the exact word pattern along with the exact word before and after patterns
    if exact_word_before_pattern and exact_word_after_pattern:
        logger.debug(f"THE WORD BEFORE PATTERN IS: {word_before_pattern}") if debug and debug_patterns else None
        logger.debug(f"THE WORD AFTER PATTERN IS: {word_after_pattern}") if debug and debug_patterns else None
        logger.debug(f"THE EXACT WORD BEFORE PATTERN IS: {exact_word_before_pattern}") if debug and debug_patterns else None
        logger.debug(f"THE EXACT WORD AFTER PATTERN IS: {exact_word_after_pattern}") if debug and debug_patterns else None
        #patterns['both_exact_before_and_after_pattern'] = rf"(?:(?<!\p{{L}}){exact_word_before_pattern}\s*{optional_punct_pattern})({exact_word_pattern}|{word_pattern})(?:{optional_punct_pattern}{exact_word_after_pattern}(?!\p{{L}}))"
        patterns['both_exact_before_and_after_pattern'] = rf"(?<={exact_word_before_pattern}\s*{optional_punct_pattern})({exact_word_pattern}|{word_pattern})(?=\s*{optional_punct_pattern}{exact_word_after_pattern})"
        logger.debug(f"exact_word_before_pattern in both_before_and_after: {exact_word_before_pattern}") if debug and debug_patterns else None
        logger.debug(f"exact_word_after_pattern in both_before_and_after: {exact_word_after_pattern}") if debug and debug_patterns else None
        logger.debug(f"both_before_and_after pattern: {patterns['both_exact_before_and_after_pattern']}") if debug and debug_patterns else None

    # When both before and after patterns are specified
    if word_before_pattern and word_after_pattern:
        #patterns['both_before_and_after'] = rf"(?<=(?<!\p{{L}}){word_before_pattern}\s*{optional_punct_pattern})({exact_word_pattern}|{word_pattern})(?:{optional_punct_pattern}{word_after_pattern}(?!\p{{L}}))"
        patterns['both_before_and_after'] = rf"(?<={word_before_pattern}\s*{optional_punct_pattern})({exact_word_pattern}|{word_pattern})(?=\s*{optional_punct_pattern}{word_after_pattern})"
        logger.debug(f"both_before_and_after pattern: {patterns['both_before_and_after']}") if debug and debug_patterns else None

    # When only the before pattern is specified and it's not a single non-word character
    logger.debug(f"THE WORD PATTERN IS: {word_pattern}") if debug and debug_patterns else None
    logger.debug(f"THE WORD BEFORE PATTERN IS: {word_before_pattern}") if debug and debug_patterns else None
    logger.debug(f"THE WORD AFTER PATTERN IS: {word_after_pattern}") if debug and debug_patterns else None
    logger.debug(f"THE EXACT WORD BEFORE PATTERN IS: {exact_word_before_pattern}") if debug and debug_patterns else None
    logger.debug(f"THE EXACT WORD AFTER PATTERN IS: {exact_word_after_pattern}") if debug and debug_patterns else None
    logger.debug("CHECKKKKKEKE %s %s %s", word_before_pattern, word_before, len(word_before)) if debug and debug_patterns and word_before else None
    #if any([exact_word_before_pattern, word_before_pattern]) and len(word_before) > 1:
    if word_before is not None and len(word_before.strip()) > 0:
        logger.debug("found word before!!! WooHOO!") if debug and debug_patterns else None
        #patterns['only_before'] = rf"(?<=(?<!\p{{L}}){exact_word_before_pattern}|{word_before_pattern}\s*{optional_punct_pattern})({exact_word_pattern}|{word_pattern})(?!\p{{L}})"
        patterns['only_before'] = rf"(?<={exact_word_before_pattern or ''}\s*{optional_punct_pattern})({exact_word_pattern}|{word_pattern})"
        logger.debug(f"only_before pattern: {patterns['only_before']}") if debug and debug_patterns else None
    
    # when only the after pattern is specified and it's not a single non-word character
    logger.debug(f"Checking word before : {word_before_pattern}, {word_before}") if debug and debug_patterns else None
    logger.debug(f"Checking word after : {word_after_pattern}, {word_after}") if debug and debug_patterns else None
    #if any([exact_word_after_pattern, word_after_pattern]) and len(word_after) > 1:
    if word_after is not None and len(word_after.strip()) > 0:
        #patterns['only_after'] = rf"({exact_word_pattern}|{word_pattern})(?:{optional_punct_pattern}{exact_word_after_pattern}|{word_after_pattern}(?!\p{{L}}))"
        patterns['only_after'] = rf"({exact_word_pattern}|{word_pattern})(?=\s*{optional_punct_pattern}{exact_word_after_pattern})"
        logger.debug(f"only_after pattern: {patterns['only_after']}") if debug and debug_patterns else None

    # When the before pattern is a single non-word character or None
    if any([exact_word_before_pattern, word_before_pattern]) and (word_before is None or len(word_before) <= 1):
        patterns['before_single_or_empty'] = rf"(?<=(?<!\p{{L}}){exact_word_before_pattern}|{word_before_pattern}\s*{optional_punct_pattern})({exact_word_pattern}|{word_pattern})(?!\p{{L}})"
        logger.debug(f"before_single_or_empty pattern: {patterns['before_single_or_empty']}") if debug and debug_patterns else None
        
    # When the after pattern is a single non-word character or None
    if any([exact_word_after_pattern, word_after_pattern]) and (word_after is None or len(word_after) <= 1):
        patterns['after_single_or_empty'] = rf"({exact_word_pattern}|{word_pattern})(?:(?={optional_punct_pattern}{exact_word_after_pattern}|{word_after_pattern})|$)(?!\p{{L}})"
        logger.debug(f"after_single_or_empty pattern: {patterns['after_single_or_empty']}") if debug and debug_patterns else None

    # Word at the start of the sentence (no preceding word boundary)
    patterns['start_of_sentence'] = rf"^({exact_word_pattern}|{word_pattern})(?=\s|\p{{P}}|$)"
    logger.debug(f"start_of_sentence pattern: {patterns['start_of_sentence']}") if debug and debug_patterns else None

    # Word at the end of the sentence (no following word boundary)
    #patterns['end_of_sentence'] = rf"(?<=^|\s|\p{{P}})({exact_word_pattern}|{word_pattern}){optional_punct_pattern}?$"
    patterns['end_of_sentence'] = rf"(?<=^|\s|\p{{P}})({exact_word_pattern}|{word_pattern})[{optional_punct_pattern}]?$"

    logger.debug(f"end_of_sentence pattern: {patterns['end_of_sentence']}") if debug and debug_patterns else None

    # Word anywhere in the sentence, not accounting for specific before/after context
    #patterns['anywhere_in_sentence'] = rf"(?<!\p{{L}})({exact_word_pattern}|{word_pattern})(?!\p{{L}})"
    #print(f"anywhere_in_sentence pattern: {patterns['anywhere_in_sentence']}") if debug and debug_patterns else None


    # Debugging code
    if debug and debug_patterns:
        # Check if 'both_before_and_after' pattern exists and print it
        if 'both_before_and_after' in patterns:
            logger.debug(f"both_before_and_after pattern: {patterns['both_before_and_after']}") if debug and debug_patterns else None
            logger.debug(f"both_before_and_after pattern matches sentence: {bool(re.search(patterns['both_before_and_after'], sentence))}") if debug and debug_patterns else None

        # Check if "exact_word_before_pattern" exists and print it
        if exact_word_before_pattern:
            logger.debug(f"exact_word_before_pattern: {exact_word_before_pattern}") if debug and debug_patterns else None
            logger.debug(f"exact_word_before_pattern matches sentence: {bool(re.search(exact_word_before_pattern, sentence))}") if debug and debug_patterns else None
            
        # Check if 'word_before_pattern' exists and print it
        if word_before_pattern:
            logger.debug(f"word_before_pattern: {word_before_pattern}") if debug and debug_patterns else None
            logger.debug(f"word_before_pattern matches sentence: {bool(re.search(word_before_pattern, sentence))}") if debug and debug_patterns else None

        # Check if "exact_word_after_pattern" exists and print it
        if exact_word_after_pattern:
            logger.debug(f"exact_word_after_pattern: {exact_word_after_pattern}") if debug and debug_patterns else None
            logger.debug(f"exact_word_after_pattern matches sentence: {bool(re.search(exact_word_after_pattern, sentence))}") if debug and debug_patterns else None
            
        # Check if 'word_after_pattern' exists and print it
        if word_after_pattern:
            logger.debug(f"word_after_pattern: {word_after_pattern}") if debug and debug_patterns else None
            logger.debug(f"word_after_pattern matches sentence: {bool(re.search(word_after_pattern, sentence))}") if debug and debug_patterns else None

    return patterns

# %%
def prepare_training_data(df, form=None, debug=None, debug_patterns=None, debug_inception=None, **kwargs):
    """
    Prepares the training data by finding entity indices within normalized sentences.
    Returns a list of training data and a list of words not found in their sentences.
    """
    # Apply normalization as per configurations or provided form
    debug = debug if debug is not None else app_config.DEBUG
    
    # Ensuring 'remove_accents' and 'lowercase' have fixed values for this function's purpose
    kwargs['remove_accents'] = False
    kwargs['lowercase'] = True  # Override/debug settings are explicitly set here
    kwargs['remove_extra_spaces'] = True
    kwargs["remove_brackets"] = False
    kwargs["form"] = form
    logger.debug("kwargs: ", kwargs) if debug else None

    TRAIN_DATA = []
    not_found_list = []
    found_entities = 0

    for i, (_, row) in enumerate(df.iterrows(), start=1):
        new_entities = []
        sentence = row['Quote']
        source = row['Source']
        logger.debug(f"Sentence {i}: {sentence}, Source: {source}") if debug else None
        for entity in row['Entities']:
            logger.debug (f"Entity: {entity}") if debug else None
            try:
                category, word, word_before, word_after = entity
                logger.debug(f"Category: {category}, Word: {word}, Word Before: {word_before}, Word After: {word_after}") if debug else None
                start, end, _ = find_word_index(sentence, word, word_before, word_after, **{**app_config.__dict__, **kwargs}, debug=debug)
                new_entities.append((start, end, category))
                found_entities += 1
            except Exception as e:
                logger.error(f"Error finding word index for entity {entity}: {e}")
                not_found_list.append((word, sentence))
        
        logger.debug(f"Found {len(new_entities)} entities in this sentence.") if debug else None
        normalized_sentence = normalize_text(sentence, **{**app_config.__dict__, **kwargs})
        TRAIN_DATA.append((normalized_sentence, {'entities': new_entities}, source))

    logger.info(f"Completed preparing training data from table. Total entries: {len(TRAIN_DATA)}. Entities found and registered: {found_entities}. Entities not found: {len(not_found_list)}")
    return TRAIN_DATA, not_found_list

# %%
Dataa = []
new_entities = []
#[['Body Part', 'γένειον', 'τὸ πρόσθιον', ', τὸ δʼ'], ['Body Part', 'γένυς', 'δʼ ὀπίσθιον', '. Κινεῖ δὲ'], ['Adjectives/Qualities', 'πρόσθιον', 'τούτων τὸ', 'γένειον, τὸ'], ['Adjectives/Qualities', 'ὀπίσθιον', 'τὸ δʼ', 'γένυς. Κινεῖ'], ['Division', 'τὸ', 'δύο· τούτων', 'πρόσθιον γένειον'], ['Division', 'τὸ', 'πρόσθιον γένειον,', 'δʼ ὀπίσθιον']]
#'Division', 'τὸ', 'δύο· τούτων', 'πρόσθιον γένειον'], ['Division', 'τὸ', 'πρόσθιον γένειον,', 'δʼ ὀπίσθιον']]
#sentence="τούτων τὸ πρόσθιον γένειον, τὸ δʼ ὀπίσθιον γένυς"
#word='τὸ'
#word_before='δύο· τούτων'
#word_after='πρόσθιον γένειον'

#word='τὸ'
#word_before='πρόσθιον γένειον,'
#word_after='δʼ ὀπίσθιον'

#sentence="ἐνίοις μὲν γὰρ εὐρύτερον τὸ πρὸς τῇ κοιλίᾳ, τὸ δὲ πρὸς τῷ τέλει στενώτερον (διόπερ αἱ κύνες μετὰ πόνου προΐενται τὴν τοιαύτην περίττωσιν), τοῖς δὲ πλείοσιν ἄνωθεν στενώτερον, πρὸς τῷ τέλει δ' εὐρύτερον"
#word='εὐρύτερον'
#word_before="τέλει δ'"
#word_after='. Μείζω δὲ'

#sentence = "ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ."
#word = "μέσῃ"
#word_before = "τῇ "
#word_after = ". ὑπό"

#sentence = "Ἔστι δʼ οὐ πολυσχιδὴς ὁ τοῦ ἀνθρώπου, ὥσπερ ἐνίων ζῳοτόκων, οὐδὲ λεῖος, ἀλλʼ ἔχει ἀνωμαλίαν"
#word = "ζῳοτόκων"
#word_before = "ὥσπερ ἐνίων"
#word_after = " οὐδὲ λεῖος"

#sentence = "ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ"
#word = "ἑκάστῃ"
#word_before = "αὑτῇ· ἐν"
#word_after = "γὰρ ἔχει"

#sentence = "Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη"
#word = "πνεύμονα"
#word_before = "δὲ τὸν"
#word_after = "ἐστι τὸ"

#sentence = "Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη"
#word = "φρένες"
#word_before = ", αἱ καλούμεναι"
#word_after = ", πρός μὲν"

#example that gets some of the previous word by mistake
#sentence = "διατέταται δὲ καὶ ἀπὸ τοῦ σπληνὸς φλὲψ ἐς τὰ ἀριστερὰ καὶ κάτω καὶ ἄνω, ὥσπερ καὶ ἀπὸ τοῦ ἥπατος, λεπτοτέρη δὲ καὶ ἀσθενεστέρη"
#word = "ἀριστερὰ"
#word_before = "ἐς"
#word_after = "καὶ"

#sentence = "καὶ τὸ μὲν παχύτατον καὶ μέγιστον καὶ κοιλότατον ἐς τὸν ἐγκέφαλον τελευτᾷ, τὸ δὲ ἐς τὸ οὖς τὸ δεξιὸν, τὸ δὲ ἐς τὸν ὀφθαλμὸν τὸν δεξιόν, τὸ δὲ ἐς τὸν μυκτῆρα"
#word = "δεξιόν"
#word_before = "τὸν ὀφθαλμὸν "
#word_after = "τὸ δὲ "


# Call the function with the test data
start, end, normalized_sentence = find_word_index(sentence, word, word_before, word_after, form='NFC', debug=True, debug_patterns=True, max_errors=2)

# Print the result
print(f"Start: {start}, End: {end}") 
print(f"Characters between start and end: '{normalized_sentence[start:end]}'")

#normalized_sentence = normalize_text(sentence, form='NFKC', remove_accents=False, lowercase=True, remove_extra_spaces=True)
Dataa.append((normalized_sentence, {'entities': [(start, end, 'LABEL')]}, 'SOURCE'))
print(Dataa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 57
#       2 new_entities = []
#       3 #[['Body Part', 'γένειον', 'τὸ πρόσθιον', ', τὸ δʼ'], ['Body Part', 'γένυς', 'δʼ ὀπίσθιον', '. Κινεῖ δὲ'], ['Adjectives/Qualities', 'πρόσθιον', 'τούτων τὸ', 'γένειον, τὸ'], ['Adjectives/Qualities', 'ὀπίσθιον', 'τὸ δʼ', 'γένυς. Κινεῖ'], ['Division', 'τὸ', 'δύο· τούτων', 'πρόσθιον γένειον'], ['Division', 'τὸ', 'πρόσθιον γένειον,', 'δʼ ὀπίσθιον']]
#       4 #'Division', 'τὸ', 'δύο· τούτων', 'πρόσθιον γένειον'], ['Division', 'τὸ', 'πρόσθιον γένειον,', 'δʼ ὀπίσθιον']]
#       5 #sentence="τούτων τὸ πρόσθιον γένειον, τὸ δʼ ὀπίσθιον γένυς"
#    (...)
#      55
#      56 # Call the function with the test data
# ---> 57 start, end, normalized_sentence = find_word_index(sentence, word, word_before, word_after, form='NFC', debug=True, debug_patterns=True, max_errors=2)
#      59 # Print the result
#      60 print(f"Start: {start}, End: {end}")
#
# NameError: name 'sentence' is not defined

# %% [markdown]
# # Add annotations from INCEpTION

# %%
# extract all files in inception folder to temp folder
from cassis import *
import zipfile
import tempfile
import os
from spacy.training import Example

# %%
import os
import zipfile
import tempfile
from cassis import *

TYPESYSTEM_FILENAME = "TypeSystem.xml"

def extract_and_process_zip_files(input_path, form=None, debug=None, debug_inception=None):
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = app_config.DEBUG

    with zipfile.ZipFile(input_path, 'r') as zip_ref:
        with tempfile.TemporaryDirectory() as tempdir:
            zip_ref.extractall(tempdir)
            # Get the basename of the .zip file for use as an identifier
            base_zip_filename = os.path.splitext(os.path.basename(input_path))[0]
            process_extracted_files(tempdir, base_zip_filename, form, debug, debug_inception)

def process_extracted_files(directory, base_zip_filename, form=None, debug=None, debug_inception=None):
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = debug if debug is not None else app_config.DEBUG

    typesystem = None
    # Load the typesystem only once
    try:
        with open(os.path.join(directory, TYPESYSTEM_FILENAME), 'rb') as f:
            typesystem = load_typesystem(f)
    except Exception as e:
        logger.error(f"Failed to load TypeSystem: {e}")
        return

    for f in os.listdir(directory):
        if f.endswith(".xmi"):
            # Pass the base name of the zip file concatenated with the XMI file name
            file_identifier = f"{os.path.splitext(f)[0]}"
            process_xmi_file(os.path.join(directory, f), typesystem, file_identifier, form, debug, debug_inception)

def process_xmi_file(filename, typesystem, file_identifier, form=None, debug=None, debug_inception=None):
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = app_config.DEBUG

    try:
        with open(filename, 'rb') as f:
            cas = load_cas_from_xmi(f, typesystem=typesystem)
            logger.debug(f"Processing file: {filename} as {file_identifier}") if debug_inception else None
            process_cas(cas, file_identifier, form, debug, debug_inception)
    except Exception as e:
        logger.error(f"Error processing file {filename}: {e}")

def process_cas(cas, file_identifier, form=None, debug=None, debug_inception=None):
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = app_config.DEBUG

    for sentence in cas.select(("de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Sentence")):
        process_sentence(sentence, cas, file_identifier, form, debug, debug_inception)

def calculate_token_positions(normalized_sentence_text, adjusted_token_start, normalized_token_text, last_match_end, debug=None):
    """
    Attempts to adjust token positions from original indices considering the normalized sentence text, 
    with awareness of potential non-uniform normalization effects.
    
    Args:
    - normalized_sentence_text (str): The full sentence text after normalization.
    - adjusted_token_start (int): Original start index of the token before normalization.
    - normalized_token_text (str): The specific token text after normalization.
    - debug (bool): If provided and True, enables debug outputs.

    Returns:
    Tuple[int, int]: Adjusted start and end indices of the token in the normalized sentence.
    """
    debug = debug if debug is not None else app_config.DEBUG

    # Validate input data
    if not normalized_sentence_text:
        logger.error("Normalized sentence text is empty.")
        return None

    # Attempt to find the closest match of the normalized token in the normalized text
    try:
        window_size = len(normalized_token_text)
        start_search = last_match_end if last_match_end is not None else 0
        new_token_begin = normalized_sentence_text.find(normalized_token_text, start_search)

        if new_token_begin == -1:
            logger.warning(f"Token '{normalized_token_text}' not found in the normalized text after position {start_search}.")
            return None

        new_token_end = new_token_begin + window_size
    
        logger.debug(f"Adjusted indices: {new_token_begin}-{new_token_end} for token '{normalized_token_text}' in normalized text.")
        return new_token_begin, new_token_end
    except Exception as e:
        logger.error(f"Unexpected error occurred while calculating token positions: {e}")
        return None


def process_sentence(sentence, cas, file_identifier, form=None, debug=None, debug_inception=None, **kwargs):
    """
    Processes each sentence from the CAS file, extracts entity tokens along with labels,
    calculates corrected token positions based on the cleaned sentence,
    and appends to INCEPTION_TRAIN_DATA for NER training.
    """
    # Apply normalization as per configurations or provided form
    debug = debug if debug is not None else app_config.DEBUG
    # Ensuring 'remove_accents' and 'lowercase' have fixed values for this function's purpose
    kwargs['remove_accents'] = False
    kwargs['lowercase'] = True  # Override/debug settings are explicitly set here
    kwargs['remove_extra_spaces'] = True
    kwargs["remove_brackets"] = False
    kwargs["form"] = form
    logger.debug("kwargs: %s", kwargs) if debug else None
    
    # Normalize inputs
    original_sentence_text = sentence.get_covered_text()
    normalized_sentence_text = normalize_text(original_sentence_text, **{**app_config.__dict__, **kwargs})
    
    sentence_start_offset = sentence.begin  # Sentence start relative to the full document

    logger.debug("Final FORM: %s", form) if debug_inception else None
    logger.debug("original sentence: %s", original_sentence_text) if debug_inception else None
    logger.debug("normalized_sentence_text: %s", normalized_sentence_text) if debug_inception else None
    
    spans = []
    last_match_end = None
    for token in cas.select_covered('webanno.custom.CategoryType', sentence):
        # Adjust token indices to be relative to the start of the sentence
        adjusted_token_start = token.begin - sentence_start_offset
        adjusted_token_end = token.end - sentence_start_offset
        logger.debug(f"Token index: {token.begin}-{token.end}, Adjusted index for sentence: {adjusted_token_start}-{adjusted_token_end}, Token text: {token.get_covered_text()}") if debug_inception else None
        
        normalized_token_text = normalize_text(token.get_covered_text(), **{**app_config.__dict__, **kwargs})
        token_positions = calculate_token_positions(normalized_sentence_text, adjusted_token_start, normalized_token_text, last_match_end, debug=debug_inception)
        if token_positions is None:
            logger.error(f"Error calculating positions for token '{token.get_covered_text()}' in sentence '{original_sentence_text}'")
            continue
        
        new_token_begin, new_token_end = token_positions
        spans.append((new_token_begin, new_token_end, token.value("Value")))
        last_match_end = new_token_end

    if spans:
        INCEPTION_TRAIN_DATA.append((normalized_sentence_text, {'entities': spans}, file_identifier))
        logger.debug("entities: %s", spans) if debug_inception else None
        logger.debug("normalized sentence: %s", normalized_sentence_text) if debug_inception else None
    return INCEPTION_TRAIN_DATA

# %%
import os
from typing import List, Tuple, Optional
import configparser
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor
import random

from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit
from sklearn.utils import indexable, _safe_indexing
from sklearn.utils.validation import _num_samples
from sklearn.model_selection._split import _validate_shuffle_split
from itertools import chain
import numpy as np

from spacy.tokens import DocBin

# Load configuration from a file
config = configparser.ConfigParser()
config.read('config.ini')

TEST_SIZE = config.getfloat('SPLIT', 'test_size', fallback=0.2)
RANDOM_STATE = config.getint('SPLIT', 'random_state', fallback=42)
DEBUG = config.getboolean('GENERAL', 'debug', fallback=False)

from spacy.tokens import Span, SpanGroup

Span.set_extension("labels", default=[], force=True)

def process_sentences(data, nlp, output_dir, output_file_name=None, form=None, debug=None):
    """
    Process the input data into a list of Doc objects using the SpanCategorizer approach.

    Args:
        data: The input data to be processed.
        nlp: The natural language processing object.
        output_dir: The output directory for serialized files.
        output_file_name: The base name for the output file (optional).
        form: The normalization form.
        debug: Flag to enable debug mode.

    Returns:
        A list of Doc objects.
    """

    debug = debug if debug is not None else DEBUG
    form = form if form is not None else DEBUG

    docs = []
    missing_spans = []
    total_spans = 0
    processed_docs = 0
    
    for data_entry in data:
        entity_text_changes = {}

        if len(data_entry) == 3:
            text, annot, file_identifier = data_entry
            entities = annot['entities']
            logger.debug(f"Current data_entry: {text}, {annot}, {file_identifier}")
        else:
            text, annot, file_identifier = data_entry
            entities = annot['entities']
            logger.debug(f"Current data_entry (without source identifier): {text}, {annot}")

        doc = nlp.make_doc(text)
        spans = []
        
        for entity in entities:
            start, end, label = entity
        
            if isinstance(label, float) and np.isnan(label):
                logger.warning(f"Skipping entity with 'nan' label: {text[start:end]} [{start},{end}] in sentence: {text} in {file_identifier}")
                continue

            if isinstance(label, str):
                label = [label]  # Convert single label to a list
            if all(l == l and l is not None for l in label):
                tokens = [token for token in doc if not (token.idx + len(token.text) <= start or token.idx >= end)]
                if tokens:
                    start = tokens[0].idx
                    end = tokens[-1].idx + len(tokens[-1].text)

                    # Create a span for each label
                    for l in label:
                        span = doc.char_span(start, end, label=l, alignment_mode="expand")
                        if span:
                            spans.append(span)
                        else:
                            logger.warning(f"Invalid span: {text[start:end]} [{start},{end}] cannot be mapped to a valid `Doc` span.")
                            missing_spans.append((text[start:end], label))
                            logger.warning(f"Missing span: {text[start:end]} [{start},{end}] with labels {label} in sentence: {text} in {file_identifier}")

        doc.spans["sc"] = spans
        doc.user_data["source_info"] = file_identifier
        docs.append(doc)
        logger.debug(f"Processed document {processed_docs} with {len(spans)} spans in {file_identifier}") if debug else None
        processed_docs += 1
        total_spans += len(spans)

        for original_text, new_text in entity_text_changes.items():
            logger.debug(f"Entity text changed from '{original_text}' to '{new_text}'")

    logger.info(f"{processed_docs} documents processed with a total of {total_spans} spans.")
    if missing_spans:
        logger.warning(f"Total missing spans: {len(missing_spans)}, Missing spans not mapped to SpaCy spans: {missing_spans}")

    if debug:
        doc = random.choice(docs)
        logger.info("Sample SpaCy spans, for line:")
        logger.info(f"Text: {doc.text}")
        logger.info(f"Spans: {[(span.text, span.label_) for span in doc.spans['sc']]} from source: {doc.user_data['source_info']}")

    if debug:
        for data_entry in data:
            entry_text = data_entry[1] if len(data_entry) == 3 else data_entry[0]
            if entry_text == doc.text:
                logger.info("\nOriginal table spans, for the same line:")
                annot_field = 2 if len(data_entry) == 3 else 1
                for span in data_entry[annot_field]['spans']:
                    span_text = entry_text[span[0]:span[1]]
                    logger.info(f"{span_text}, {span[2]}")
                break
        
    return docs

def create_label_array(docs: List) -> np.ndarray:
    """
    Create a NumPy array representing the labels for each document.

    Args:
        docs: A list of Doc objects.

    Returns:
        A NumPy array of shape (len(docs), num_unique_labels).
    """
    all_labels = set()
    for doc in docs:
        for span in doc.spans["sc"]:
            if isinstance(span.label_, list):
                all_labels.update(span.label_)
            else:
                all_labels.add(span.label_)

    unique_labels = sorted(all_labels)
    labels_nd_array = np.zeros((len(docs), len(unique_labels)), dtype=int)

    for i, doc in enumerate(docs):
        doc_labels = set(span.label_ for span in doc.spans["sc"])
        labels_nd_array[i, [unique_labels.index(label) for label in doc_labels]] = 1

    return labels_nd_array

def split_docs(merged_train_data, nlp, form, output_dir, store_user_data: bool = True, output_file_name: Optional[str] = None, debug=None):
    """
    Split the input data into train, dev, and test sets, and serialize them into binary files.

    Args:
        merged_train_data: The input data to be split.
        nlp: The natural language processing object.
        form: The normalization form.
        output_dir: The output directory for serialized files.
        store_user_data: Whether to store user data in the serialized files.
        output_file_name: The base name for the output file (optional).
    """

    debug = debug if debug is not None else DEBUG

    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)  # Ensure output directory exists
    
    # Check if spancat component exists
    spancat_exists = "spancat" in nlp.pipe_names
    if not spancat_exists:
        logger.warning("SpanCategorizer component not found in the pipeline. Adding it to the pipeline.")
        nlp.add_pipe("spancat", last=True)
    else:
        logger.debug("SpanCategorizer component found in the pipeline.")
        spancat = nlp.get_pipe("spancat")
        spancat.cfg["spans_key"] = "sc"
    
    # Process the merged train data to get docs
    docs = process_sentences(merged_train_data, nlp, output_dir, output_file_name=output_file_name, form=form)

    if docs:  # Check that docs is non-empty to avoid errors
        # Create a NumPy array representing the labels for each document
        labels_nd_array = create_label_array(docs)

        # Split the docs into train and test sets using multilabel stratification
        X_train, X_test = multilabel_train_test_split(docs, stratify=labels_nd_array, test_size=TEST_SIZE, random_state=RANDOM_STATE)

        # Split the test set into dev and test sets using multilabel stratification
        X_dev, X_test = multilabel_train_test_split(X_test, stratify=create_label_array(X_test), test_size=0.5, random_state=RANDOM_STATE)
    else:
        logger.info(f"No documents found for normalization form {form}. Skipping serialization.")
        return  # Early return if docs is empty to avoid proceeding with undefined variables

    subsets = {'train': X_train, 'dev': X_dev, 'test': X_test}

    # Use ThreadPoolExecutor for parallel serialization
    with ThreadPoolExecutor() as executor:
        futures = []
        for subset_name, subset_docs in subsets.items():
            if output_file_name is not None:
                output_path = output_dir / f"{subset_name}/spancat_{subset_name}/{output_file_name}_{subset_name}_{form}.spacy"
            else:
                output_path = output_dir / f"{subset_name}/spancat_{subset_name}/spancat_{subset_name}_{form}.spacy"

            future = executor.submit(serialize_docs, subset_docs, output_path, store_user_data, form, subset_name)
            futures.append(future)

        for future in futures:
            result = future.result()
            logger.debug(result) if DEBUG else None

    subsets = {'train': X_train, 'dev': X_dev, 'test': X_test}

    # Print the number of docs in each set
    logger.info(f"Train: {len(X_train)}")
    logger.info(f"Test: {len(X_test)}")
    logger.info(f"Dev: {len(X_dev)}")

def serialize_docs(docs, output_path, store_user_data, form, subset_name, debug=None):
    """
    Serialize a list of Doc objects into a binary file.

    Args:
        docs: A list of Doc objects.
        output_path: The output file path.
        store_user_data: Whether to store user data in the serialized file.
        form: The normalization form.
        subset_name: The name of the subset (train, dev, or test).

    Returns:
        A success message.
    """

    debug = debug if debug is not None else DEBUG

    doc_bin = DocBin(docs=docs, store_user_data=store_user_data)
    doc_bin.to_disk(output_path)
    return f"Saved {len(docs)} docs for normalization form {form} to {output_path}"

def multilabel_train_test_split(*arrays,
                                test_size=None,
                                train_size=None,
                                random_state=None,
                                shuffle=True,
                                stratify=None):
    """
    Train test split for multilabel classification. Uses the algorithm from:
    'Sechidis K., Tsoumakas G., Vlahavas I. (2011) On the Stratification of Multi-Label Data'.
    """
    if stratify is None:
        return train_test_split(*arrays, test_size=test_size, train_size=train_size,
                                random_state=random_state, stratify=None, shuffle=shuffle)

    assert shuffle, "Stratified train/test split is not implemented for shuffle=False"

    n_arrays = len(arrays)
    arrays = indexable(*arrays)
    n_samples = _num_samples(arrays[0])
    n_train, n_test = _validate_shuffle_split(
        n_samples, test_size, train_size, default_test_size=0.25
    )
    cv = MultilabelStratifiedShuffleSplit(test_size=n_test, train_size=n_train, random_state=RANDOM_STATE)
    train, test = next(cv.split(X=arrays[0], y=stratify))

    return list(
        chain.from_iterable(
            (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
        )
    )

# %%
def process_sentences_and_serialize(input_path, nlp, normalization_forms, output_dir, debug=None, debug_patterns=None, debug_inception=None, output_file_name: str = None):

    debug = debug if debug is not None else app_config.DEBUG

    for form in normalization_forms:
        # Prepare the training data for the current normalization form from Coda
        global INCEPTION_TRAIN_DATA
        global TRAIN_DATA
        global not_found_list
        global MERGED_TRAIN_DATA
        
        INCEPTION_TRAIN_DATA = []  # Reset INCEPTION_TRAIN_DATA for each form
        
        TRAIN_DATA, not_found_list = prepare_training_data(df_final, form=form, debug=debug, debug_patterns=debug_patterns, debug_inception=debug_inception, **app_config.__dict__)
        
        
        # Prepare the training data for the current normalization form from INCEpTION
        for file_path in Path(input_path).glob("*.zip"):
            print("file name: ",file_path.name)  # Progress indicator
            extract_and_process_zip_files(file_path, form, debug, debug_inception)
        
        #merge the two training data, while removing duplicates
        MERGED_TRAIN_DATA = TRAIN_DATA + INCEPTION_TRAIN_DATA
        
        split_docs(MERGED_TRAIN_DATA, nlp, form=form, output_dir=output_dir, output_file_name=output_file_name, debug=debug)
        return MERGED_TRAIN_DATA

# %%
INCEPTION_TRAIN_DATA

# %%
import spacy
import random

# Assuming `nlp` is your preloaded SpaCy model
#nlp = spacy.load("../training/SageMaker/transformer/PROIEL/Assembled/pos-trf-11-may-2024/model-best/")  # Example with a blank English model. Replace according to your model.
nlp = spacy.load("../training/transformer/proiel/assembled/trf_27_feb_25/model-best/")
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/spacy_transformers/layers/hf_shim.py:124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self._model.load_state_dict(torch.load(filelike, map_location=device))

# %%
logger.setLevel(logging.DEBUG)

process_sentences_and_serialize(input_path=Path("../assets/NER_assets/INCEpTION_files/"), nlp=nlp, normalization_forms=['NFC'], output_dir=Path("../corpus/"), debug=True, debug_patterns=False, debug_inception=False, output_file_name="spancat")
# Out:
# 2025-03-23 12:35:11,310 - DEBUG - root - kwargs:
# 2025-03-23 12:35:11,312 - DEBUG - root - Sentence 1: ἐν ἑκάστῃ γὰρ ἔχει αἷμα τῶν κοιλιῶν, λεπτότατον δʼ ἐστὶ τὸ ἐν τῇ μέσῃ, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(9)
# 2025-03-23 12:35:11,312 - DEBUG - root - Entity: ['Body Part', 'αἷμα', 'γὰρ ἔχει', 'τῶν κοιλιῶν']
# 2025-03-23 12:35:11,313 - DEBUG - root - Category: Body Part, Word: αἷμα, Word Before: γὰρ ἔχει, Word After: τῶν κοιλιῶν
# 2025-03-23 12:35:11,314 - DEBUG - root - exact_word_before_pattern: γὰρ\ ἔχει
# 2025-03-23 12:35:11,314 - DEBUG - root - exact_word_after_pattern: τῶν\ κοιλιῶν
# 2025-03-23 12:35:11,315 - DEBUG - root - word_before_pattern: (?:γ\p{M}*ὰ\p{M}*ρ\p{M}*\ \p{M}*ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,315 - DEBUG - root - word_after_pattern: (?:τ\p{M}*ῶ\p{M}*ν\p{M}*\ \p{M}*κ\p{M}*ο\p{M}*ι\p{M}*λ\p{M}*ι\p{M}*ῶ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,318 - DEBUG - root - Entity: ['Body Part', 'κοιλιῶν', 'αἷμα τῶν', ', λεπτότατον δʼ']
# 2025-03-23 12:35:11,318 - DEBUG - root - Category: Body Part, Word: κοιλιῶν, Word Before: αἷμα τῶν, Word After: , λεπτότατον δʼ
# 2025-03-23 12:35:11,319 - DEBUG - root - exact_word_before_pattern: αἷμα\ τῶν
# 2025-03-23 12:35:11,320 - DEBUG - root - exact_word_after_pattern: ,\ λεπτότατον\ δʼ
# 2025-03-23 12:35:11,320 - DEBUG - root - word_before_pattern: (?:α\p{M}*ἷ\p{M}*μ\p{M}*α\p{M}*\ \p{M}*τ\p{M}*ῶ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,320 - DEBUG - root - word_after_pattern: (?:,\p{M}*\ \p{M}*λ\p{M}*ε\p{M}*π\p{M}*τ\p{M}*ό\p{M}*τ\p{M}*α\p{M}*τ\p{M}*ο\p{M}*ν\p{M}*\ \p{M}*δ\p{M}*ʼ\p{M}*){s<=2}
# 2025-03-23 12:35:11,322 - DEBUG - root - Entity: ['Adjectives/Qualities', 'λεπτότατον', 'τῶν κοιλιῶν,', 'δʼ ἐστὶ']
# 2025-03-23 12:35:11,322 - DEBUG - root - Category: Adjectives/Qualities, Word: λεπτότατον, Word Before: τῶν κοιλιῶν,, Word After: δʼ ἐστὶ
# 2025-03-23 12:35:11,323 - DEBUG - root - exact_word_before_pattern: τῶν\ κοιλιῶν,
# 2025-03-23 12:35:11,325 - DEBUG - root - exact_word_after_pattern: δʼ\ ἐστὶ
# 2025-03-23 12:35:11,325 - DEBUG - root - word_before_pattern: (?:τ\p{M}*ῶ\p{M}*ν\p{M}*\ \p{M}*κ\p{M}*ο\p{M}*ι\p{M}*λ\p{M}*ι\p{M}*ῶ\p{M}*ν\p{M}*,\p{M}*){s<=2}
# 2025-03-23 12:35:11,326 - DEBUG - root - word_after_pattern: (?:δ\p{M}*ʼ\p{M}*\ \p{M}*ἐ\p{M}*σ\p{M}*τ\p{M}*ὶ\p{M}*){s<=2}
# 2025-03-23 12:35:11,327 - DEBUG - root - Entity: ['Adjectives/Qualities', 'μέσῃ', 'ἐν τῇ', '.']
# 2025-03-23 12:35:11,328 - DEBUG - root - Category: Adjectives/Qualities, Word: μέσῃ, Word Before: ἐν τῇ, Word After: .
# 2025-03-23 12:35:11,328 - DEBUG - root - exact_word_before_pattern: ἐν\ τῇ
# 2025-03-23 12:35:11,329 - DEBUG - root - exact_word_after_pattern: \.
# 2025-03-23 12:35:11,329 - DEBUG - root - word_before_pattern: (?:ἐ\p{M}*ν\p{M}*\ \p{M}*τ\p{M}*ῇ\p{M}*){s<=2}
# 2025-03-23 12:35:11,330 - DEBUG - root - word_after_pattern: (?:\.\p{M}*){s<=2}
# 2025-03-23 12:35:11,332 - DEBUG - root - Entity: ['Topography', 'ἐν', 'ἐν αὑτῇ·', 'ἑκάστῃ γὰρ']
# 2025-03-23 12:35:11,333 - DEBUG - root - Category: Topography, Word: ἐν, Word Before: ἐν αὑτῇ·, Word After: ἑκάστῃ γὰρ
# 2025-03-23 12:35:11,333 - DEBUG - root - exact_word_before_pattern: ἐν\ αὑτῇ·
# 2025-03-23 12:35:11,334 - DEBUG - root - exact_word_after_pattern: ἑκάστῃ\ γὰρ
# 2025-03-23 12:35:11,334 - DEBUG - root - word_before_pattern: (?:ἐ\p{M}*ν\p{M}*\ \p{M}*α\p{M}*ὑ\p{M}*τ\p{M}*ῇ\p{M}*·\p{M}*){s<=2}
# 2025-03-23 12:35:11,335 - DEBUG - root - word_after_pattern: (?:ἑ\p{M}*κ\p{M}*ά\p{M}*σ\p{M}*τ\p{M}*ῃ\p{M}*\ \p{M}*γ\p{M}*ὰ\p{M}*ρ\p{M}*){s<=2}
# 2025-03-23 12:35:11,336 - DEBUG - root - Entity: ['Topography', 'ἑκάστῃ', 'αὑτῇ· ἐν', 'γὰρ ἔχει']
# 2025-03-23 12:35:11,337 - DEBUG - root - Category: Topography, Word: ἑκάστῃ, Word Before: αὑτῇ· ἐν, Word After: γὰρ ἔχει
# 2025-03-23 12:35:11,337 - DEBUG - root - exact_word_before_pattern: αὑτῇ·\ ἐν
# 2025-03-23 12:35:11,338 - DEBUG - root - exact_word_after_pattern: γὰρ\ ἔχει
# 2025-03-23 12:35:11,339 - DEBUG - root - word_before_pattern: (?:α\p{M}*ὑ\p{M}*τ\p{M}*ῇ\p{M}*·\p{M}*\ \p{M}*ἐ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,339 - DEBUG - root - word_after_pattern: (?:γ\p{M}*ὰ\p{M}*ρ\p{M}*\ \p{M}*ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,340 - DEBUG - root - Entity: ['Topography', 'ἐν', 'ἐστὶ τὸ', 'τῇ μέσῃ']
# 2025-03-23 12:35:11,341 - DEBUG - root - Category: Topography, Word: ἐν, Word Before: ἐστὶ τὸ, Word After: τῇ μέσῃ
# 2025-03-23 12:35:11,344 - DEBUG - root - exact_word_before_pattern: ἐστὶ\ τὸ
# 2025-03-23 12:35:11,344 - DEBUG - root - exact_word_after_pattern: τῇ\ μέσῃ
# 2025-03-23 12:35:11,345 - DEBUG - root - word_before_pattern: (?:ἐ\p{M}*σ\p{M}*τ\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,345 - DEBUG - root - word_after_pattern: (?:τ\p{M}*ῇ\p{M}*\ \p{M}*μ\p{M}*έ\p{M}*σ\p{M}*ῃ\p{M}*){s<=2}
# 2025-03-23 12:35:11,346 - DEBUG - root - Found 7 entities in this sentence.
# 2025-03-23 12:35:11,347 - DEBUG - root - Sentence 2: Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(10)
# 2025-03-23 12:35:11,347 - DEBUG - root - Entity: ['Topography', 'Ὑπὸ', 'μέσῃ.', 'δὲ τὸν']
# 2025-03-23 12:35:11,348 - DEBUG - root - Category: Topography, Word: Ὑπὸ, Word Before: μέσῃ., Word After: δὲ τὸν
# 2025-03-23 12:35:11,349 - DEBUG - root - exact_word_before_pattern: μέσῃ\.
# 2025-03-23 12:35:11,349 - DEBUG - root - exact_word_after_pattern: δὲ\ τὸν
# 2025-03-23 12:35:11,349 - DEBUG - root - word_before_pattern: (?:μ\p{M}*έ\p{M}*σ\p{M}*ῃ\p{M}*\.\p{M}*){s<=2}
# 2025-03-23 12:35:11,350 - DEBUG - root - word_after_pattern: (?:δ\p{M}*ὲ\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,351 - DEBUG - root - Entity: ['Body Part', 'πνεύμονά', 'δὲ τὸν', 'ἐστι τὸ']
# 2025-03-23 12:35:11,352 - DEBUG - root - Category: Body Part, Word: πνεύμονά, Word Before: δὲ τὸν, Word After: ἐστι τὸ
# 2025-03-23 12:35:11,352 - DEBUG - root - exact_word_before_pattern: δὲ\ τὸν
# 2025-03-23 12:35:11,353 - DEBUG - root - exact_word_after_pattern: ἐστι\ τὸ
# 2025-03-23 12:35:11,353 - DEBUG - root - word_before_pattern: (?:δ\p{M}*ὲ\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,356 - DEBUG - root - word_after_pattern: (?:ἐ\p{M}*σ\p{M}*τ\p{M}*ι\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,357 - DEBUG - root - Entity: ['Body Part', 'διάζωμα', 'ἐστι τὸ', 'τὸ τοῦ']
# 2025-03-23 12:35:11,357 - DEBUG - root - Category: Body Part, Word: διάζωμα, Word Before: ἐστι τὸ, Word After: τὸ τοῦ
# 2025-03-23 12:35:11,358 - DEBUG - root - exact_word_before_pattern: ἐστι\ τὸ
# 2025-03-23 12:35:11,359 - DEBUG - root - exact_word_after_pattern: τὸ\ τοῦ
# 2025-03-23 12:35:11,359 - DEBUG - root - word_before_pattern: (?:ἐ\p{M}*σ\p{M}*τ\p{M}*ι\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,359 - DEBUG - root - word_after_pattern: (?:τ\p{M}*ὸ\p{M}*\ \p{M}*τ\p{M}*ο\p{M}*ῦ\p{M}*){s<=2}
# 2025-03-23 12:35:11,362 - DEBUG - root - Entity: ['Body Part', 'θώρακος', 'τὸ τοῦ', ', αἱ καλούμεναι']
# 2025-03-23 12:35:11,362 - DEBUG - root - Category: Body Part, Word: θώρακος, Word Before: τὸ τοῦ, Word After: , αἱ καλούμεναι
# 2025-03-23 12:35:11,363 - DEBUG - root - exact_word_before_pattern: τὸ\ τοῦ
# 2025-03-23 12:35:11,363 - DEBUG - root - exact_word_after_pattern: ,\ αἱ\ καλούμεναι
# 2025-03-23 12:35:11,364 - DEBUG - root - word_before_pattern: (?:τ\p{M}*ὸ\p{M}*\ \p{M}*τ\p{M}*ο\p{M}*ῦ\p{M}*){s<=2}
# 2025-03-23 12:35:11,364 - DEBUG - root - word_after_pattern: (?:,\p{M}*\ \p{M}*α\p{M}*ἱ\p{M}*\ \p{M}*κ\p{M}*α\p{M}*λ\p{M}*ο\p{M}*ύ\p{M}*μ\p{M}*ε\p{M}*ν\p{M}*α\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,365 - DEBUG - root - Entity: ['Body Part', 'φρένες', ', αἱ καλούμεναι', ', πρός μὲν']
# 2025-03-23 12:35:11,366 - DEBUG - root - Category: Body Part, Word: φρένες, Word Before: , αἱ καλούμεναι, Word After: , πρός μὲν
# 2025-03-23 12:35:11,366 - DEBUG - root - exact_word_before_pattern: ,\ αἱ\ καλούμεναι
# 2025-03-23 12:35:11,367 - DEBUG - root - exact_word_after_pattern: ,\ πρός\ μὲν
# 2025-03-23 12:35:11,367 - DEBUG - root - word_before_pattern: (?:,\p{M}*\ \p{M}*α\p{M}*ἱ\p{M}*\ \p{M}*κ\p{M}*α\p{M}*λ\p{M}*ο\p{M}*ύ\p{M}*μ\p{M}*ε\p{M}*ν\p{M}*α\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,368 - DEBUG - root - word_after_pattern: (?:,\p{M}*\ \p{M}*π\p{M}*ρ\p{M}*ό\p{M}*ς\p{M}*\ \p{M}*μ\p{M}*ὲ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,369 - DEBUG - root - Entity: ['Topography', 'πρός', 'καλούμεναι φρένες,', 'μέν τὰ']
# 2025-03-23 12:35:11,370 - DEBUG - root - Category: Topography, Word: πρός, Word Before: καλούμεναι φρένες,, Word After: μέν τὰ
# 2025-03-23 12:35:11,370 - DEBUG - root - exact_word_before_pattern: καλούμεναι\ φρένες,
# 2025-03-23 12:35:11,370 - DEBUG - root - exact_word_after_pattern: μέν\ τὰ
# 2025-03-23 12:35:11,371 - DEBUG - root - word_before_pattern: (?:κ\p{M}*α\p{M}*λ\p{M}*ο\p{M}*ύ\p{M}*μ\p{M}*ε\p{M}*ν\p{M}*α\p{M}*ι\p{M}*\ \p{M}*φ\p{M}*ρ\p{M}*έ\p{M}*ν\p{M}*ε\p{M}*ς\p{M}*,\p{M}*){s<=2}
# 2025-03-23 12:35:11,371 - DEBUG - root - word_after_pattern: (?:μ\p{M}*έ\p{M}*ν\p{M}*\ \p{M}*τ\p{M}*ὰ\p{M}*){s<=2}
# 2025-03-23 12:35:11,378 - DEBUG - root - Entity: ['Body Part', 'πλευρά', 'μὲν τὰ', 'καὶ τὰ']
# 2025-03-23 12:35:11,379 - DEBUG - root - Category: Body Part, Word: πλευρά, Word Before: μὲν τὰ, Word After: καὶ τὰ
# 2025-03-23 12:35:11,380 - DEBUG - root - exact_word_before_pattern: μὲν\ τὰ
# 2025-03-23 12:35:11,380 - DEBUG - root - exact_word_after_pattern: καὶ\ τὰ
# 2025-03-23 12:35:11,380 - DEBUG - root - word_before_pattern: (?:μ\p{M}*ὲ\p{M}*ν\p{M}*\ \p{M}*τ\p{M}*ὰ\p{M}*){s<=2}
# 2025-03-23 12:35:11,381 - DEBUG - root - word_after_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ὰ\p{M}*){s<=2}
# 2025-03-23 12:35:11,385 - DEBUG - root - Entity: ['Body Part', 'ὑποχόνδρια', 'καὶ τὰ', 'καὶ τὴν']
# 2025-03-23 12:35:11,385 - DEBUG - root - Category: Body Part, Word: ὑποχόνδρια, Word Before: καὶ τὰ, Word After: καὶ τὴν
# 2025-03-23 12:35:11,386 - DEBUG - root - exact_word_before_pattern: καὶ\ τὰ
# 2025-03-23 12:35:11,386 - DEBUG - root - exact_word_after_pattern: καὶ\ τὴν
# 2025-03-23 12:35:11,387 - DEBUG - root - word_before_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ὰ\p{M}*){s<=2}
# 2025-03-23 12:35:11,387 - DEBUG - root - word_after_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ὴ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,388 - DEBUG - root - Entity: ['Body Part', 'ῥάχιν', 'καὶ τὴν', 'συνηρτημέναι, ἐν']
# 2025-03-23 12:35:11,389 - DEBUG - root - Category: Body Part, Word: ῥάχιν, Word Before: καὶ τὴν, Word After: συνηρτημέναι, ἐν
# 2025-03-23 12:35:11,390 - DEBUG - root - exact_word_before_pattern: καὶ\ τὴν
# 2025-03-23 12:35:11,391 - DEBUG - root - exact_word_after_pattern: συνηρτημέναι,\ ἐν
# 2025-03-23 12:35:11,391 - DEBUG - root - word_before_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ὴ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,392 - DEBUG - root - word_after_pattern: (?:σ\p{M}*υ\p{M}*ν\p{M}*η\p{M}*ρ\p{M}*τ\p{M}*η\p{M}*μ\p{M}*έ\p{M}*ν\p{M}*α\p{M}*ι\p{M}*,\p{M}*\ \p{M}*ἐ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,393 - DEBUG - root - Entity: ['Topography', 'συνηρτημέναι', 'τὴν ῥάχιν', ', ἐν μέσῳ']
# 2025-03-23 12:35:11,394 - DEBUG - root - Category: Topography, Word: συνηρτημέναι, Word Before: τὴν ῥάχιν, Word After: , ἐν μέσῳ
# 2025-03-23 12:35:11,394 - DEBUG - root - exact_word_before_pattern: τὴν\ ῥάχιν
# 2025-03-23 12:35:11,395 - DEBUG - root - exact_word_after_pattern: ,\ ἐν\ μέσῳ
# 2025-03-23 12:35:11,396 - DEBUG - root - word_before_pattern: (?:τ\p{M}*ὴ\p{M}*ν\p{M}*\ \p{M}*ῥ\p{M}*ά\p{M}*χ\p{M}*ι\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,396 - DEBUG - root - word_after_pattern: (?:,\p{M}*\ \p{M}*ἐ\p{M}*ν\p{M}*\ \p{M}*μ\p{M}*έ\p{M}*σ\p{M}*ῳ\p{M}*){s<=2}
# 2025-03-23 12:35:11,398 - DEBUG - root - Entity: ['Topography', 'ἐν', 'συνηρ τημέναι,', 'μέσῳ δʼ']
# 2025-03-23 12:35:11,398 - DEBUG - root - Category: Topography, Word: ἐν, Word Before: συνηρ τημέναι,, Word After: μέσῳ δʼ
# 2025-03-23 12:35:11,399 - DEBUG - root - exact_word_before_pattern: συνηρ\ τημέναι,
# 2025-03-23 12:35:11,399 - DEBUG - root - exact_word_after_pattern: μέσῳ\ δʼ
# 2025-03-23 12:35:11,400 - DEBUG - root - word_before_pattern: (?:σ\p{M}*υ\p{M}*ν\p{M}*η\p{M}*ρ\p{M}*\ \p{M}*τ\p{M}*η\p{M}*μ\p{M}*έ\p{M}*ν\p{M}*α\p{M}*ι\p{M}*,\p{M}*){s<=2}
# 2025-03-23 12:35:11,400 - DEBUG - root - word_after_pattern: (?:μ\p{M}*έ\p{M}*σ\p{M}*ῳ\p{M}*\ \p{M}*δ\p{M}*ʼ\p{M}*){s<=2}
# 2025-03-23 12:35:11,401 - DEBUG - root - Entity: ['Topography', 'μέσῳ', 'τημέναι, ἐν', 'δʼ ἔχει']
# 2025-03-23 12:35:11,402 - DEBUG - root - Category: Topography, Word: μέσῳ, Word Before: τημέναι, ἐν, Word After: δʼ ἔχει
# 2025-03-23 12:35:11,402 - DEBUG - root - exact_word_before_pattern: τημέναι,\ ἐν
# 2025-03-23 12:35:11,403 - DEBUG - root - exact_word_after_pattern: δʼ\ ἔχει
# 2025-03-23 12:35:11,403 - DEBUG - root - word_before_pattern: (?:τ\p{M}*η\p{M}*μ\p{M}*έ\p{M}*ν\p{M}*α\p{M}*ι\p{M}*,\p{M}*\ \p{M}*ἐ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,404 - DEBUG - root - word_after_pattern: (?:δ\p{M}*ʼ\p{M}*\ \p{M}*ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,406 - DEBUG - root - Entity: ['Adjectives/Qualities', 'λεπτά', 'ἔχει τὰ', 'καὶ ὑμενώδη']
# 2025-03-23 12:35:11,406 - DEBUG - root - Category: Adjectives/Qualities, Word: λεπτά, Word Before: ἔχει τὰ, Word After: καὶ ὑμενώδη
# 2025-03-23 12:35:11,407 - DEBUG - root - exact_word_before_pattern: ἔχει\ τὰ
# 2025-03-23 12:35:11,410 - DEBUG - root - exact_word_after_pattern: καὶ\ ὑμενώδη
# 2025-03-23 12:35:11,411 - DEBUG - root - word_before_pattern: (?:ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*\ \p{M}*τ\p{M}*ὰ\p{M}*){s<=2}
# 2025-03-23 12:35:11,412 - DEBUG - root - word_after_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*ὑ\p{M}*μ\p{M}*ε\p{M}*ν\p{M}*ώ\p{M}*δ\p{M}*η\p{M}*){s<=2}
# 2025-03-23 12:35:11,415 - DEBUG - root - Entity: ['Adjectives/Qualities', 'ὑμενώδη', 'λεπτὰ καὶ ', '. Ἔχει']
# 2025-03-23 12:35:11,416 - DEBUG - root - Category: Adjectives/Qualities, Word: ὑμενώδη, Word Before: λεπτὰ καὶ , Word After: . Ἔχει
# 2025-03-23 12:35:11,416 - DEBUG - root - exact_word_before_pattern: λεπτὰ\ καὶ
# 2025-03-23 12:35:11,417 - DEBUG - root - exact_word_after_pattern: \.\ ἔχει
# 2025-03-23 12:35:11,417 - DEBUG - root - word_before_pattern: (?:λ\p{M}*ε\p{M}*π\p{M}*τ\p{M}*ὰ\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*){s<=2}
# 2025-03-23 12:35:11,418 - DEBUG - root - word_after_pattern: (?:\.\p{M}*\ \p{M}*ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,420 - DEBUG - root - Found 14 entities in this sentence.
# 2025-03-23 12:35:11,420 - DEBUG - root - Sentence 3: Ἔχει δὲ διʼ αὑτοῦ καὶ φλέβας τεταμένας, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84)
# 2025-03-23 12:35:11,421 - DEBUG - root - Entity: ['Topography', 'διʼ', 'Ἔχει δὲ', 'αὑτοῦ καὶ']
# 2025-03-23 12:35:11,422 - DEBUG - root - Category: Topography, Word: διʼ, Word Before: Ἔχει δὲ, Word After: αὑτοῦ καὶ
# 2025-03-23 12:35:11,422 - DEBUG - root - exact_word_before_pattern: ἔχει\ δὲ
# 2025-03-23 12:35:11,422 - DEBUG - root - exact_word_after_pattern: αὑτοῦ\ καὶ
# 2025-03-23 12:35:11,423 - DEBUG - root - word_before_pattern: (?:ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*\ \p{M}*δ\p{M}*ὲ\p{M}*){s<=2}
# 2025-03-23 12:35:11,423 - DEBUG - root - word_after_pattern: (?:α\p{M}*ὑ\p{M}*τ\p{M}*ο\p{M}*ῦ\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*){s<=2}
# 2025-03-23 12:35:11,424 - DEBUG - root - Entity: ['Medical', 'αὑτοῦ', 'δὲ διʼ', 'καὶ φλέβας']
# 2025-03-23 12:35:11,425 - DEBUG - root - Category: Medical, Word: αὑτοῦ, Word Before: δὲ διʼ, Word After: καὶ φλέβας
# 2025-03-23 12:35:11,425 - DEBUG - root - exact_word_before_pattern: δὲ\ διʼ
# 2025-03-23 12:35:11,426 - DEBUG - root - exact_word_after_pattern: καὶ\ φλέβας
# 2025-03-23 12:35:11,426 - DEBUG - root - word_before_pattern: (?:δ\p{M}*ὲ\p{M}*\ \p{M}*δ\p{M}*ι\p{M}*ʼ\p{M}*){s<=2}
# 2025-03-23 12:35:11,427 - DEBUG - root - word_after_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*φ\p{M}*λ\p{M}*έ\p{M}*β\p{M}*α\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,430 - DEBUG - root - Entity: ['Body Part', 'φλέβας', 'αὑτοῦ καὶ', 'τεταμένας· ']
# 2025-03-23 12:35:11,430 - DEBUG - root - Category: Body Part, Word: φλέβας, Word Before: αὑτοῦ καὶ, Word After: τεταμένας·
# 2025-03-23 12:35:11,431 - DEBUG - root - exact_word_before_pattern: αὑτοῦ\ καὶ
# 2025-03-23 12:35:11,431 - DEBUG - root - exact_word_after_pattern: τεταμένας·
# 2025-03-23 12:35:11,432 - DEBUG - root - word_before_pattern: (?:α\p{M}*ὑ\p{M}*τ\p{M}*ο\p{M}*ῦ\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*){s<=2}
# 2025-03-23 12:35:11,432 - DEBUG - root - word_after_pattern: (?:τ\p{M}*ε\p{M}*τ\p{M}*α\p{M}*μ\p{M}*έ\p{M}*ν\p{M}*α\p{M}*ς\p{M}*·\p{M}*){s<=2}
# 2025-03-23 12:35:11,433 - DEBUG - root - Entity: ['Topography', 'τεταμένας', 'καὶ φλέβας', '· εἰσί']
# 2025-03-23 12:35:11,434 - DEBUG - root - Category: Topography, Word: τεταμένας, Word Before: καὶ φλέβας, Word After: · εἰσί
# 2025-03-23 12:35:11,434 - DEBUG - root - exact_word_before_pattern: καὶ\ φλέβας
# 2025-03-23 12:35:11,435 - DEBUG - root - exact_word_after_pattern: ·\ εἰσί
# 2025-03-23 12:35:11,435 - DEBUG - root - word_before_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*φ\p{M}*λ\p{M}*έ\p{M}*β\p{M}*α\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,435 - DEBUG - root - word_after_pattern: (?:·\p{M}*\ \p{M}*ε\p{M}*ἰ\p{M}*σ\p{M}*ί\p{M}*){s<=2}
# 2025-03-23 12:35:11,438 - DEBUG - root - Found 4 entities in this sentence.
# 2025-03-23 12:35:11,439 - DEBUG - root - Sentence 4: εἰσὶ δʼαἱ τοῦ ἀνθρώπου φρένες παχεῖαι ὡς κατὰ λόγον τοῦ σώματος, Source: Coda, Aristotle, History of Animals, B(1), C(17), P(84)
# 2025-03-23 12:35:11,440 - DEBUG - root - Entity: ['Body Part', 'φρένες', 'ἀνθρώπου', 'παχεῖαι']
# 2025-03-23 12:35:11,440 - DEBUG - root - Category: Body Part, Word: φρένες, Word Before: ἀνθρώπου, Word After: παχεῖαι
# 2025-03-23 12:35:11,441 - DEBUG - root - exact_word_before_pattern: ἀνθρώπου
# 2025-03-23 12:35:11,441 - DEBUG - root - exact_word_after_pattern: παχεῖαι
# 2025-03-23 12:35:11,442 - DEBUG - root - word_before_pattern: (?:ἀ\p{M}*ν\p{M}*θ\p{M}*ρ\p{M}*ώ\p{M}*π\p{M}*ο\p{M}*υ\p{M}*){s<=2}
# 2025-03-23 12:35:11,443 - DEBUG - root - word_after_pattern: (?:π\p{M}*α\p{M}*χ\p{M}*ε\p{M}*ῖ\p{M}*α\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,444 - DEBUG - root - Entity: ['Adjectives/Qualities', 'παχεῖαι', 'φρένες', 'ὡς']
# 2025-03-23 12:35:11,445 - DEBUG - root - Category: Adjectives/Qualities, Word: παχεῖαι, Word Before: φρένες, Word After: ὡς
# 2025-03-23 12:35:11,446 - DEBUG - root - exact_word_before_pattern: φρένες
# 2025-03-23 12:35:11,446 - DEBUG - root - exact_word_after_pattern: ὡς
# 2025-03-23 12:35:11,447 - DEBUG - root - word_before_pattern: (?:φ\p{M}*ρ\p{M}*έ\p{M}*ν\p{M}*ε\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,447 - DEBUG - root - word_after_pattern: (?:ὡ\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,448 - DEBUG - root - Found 2 entities in this sentence.
# 2025-03-23 12:35:11,449 - DEBUG - root - Sentence 5: Ἡ μὲν οὖν ἀρτηρία τοῦτον ἔχει τὸν τρόπον, καὶ δέχεται μόνον τὸ πνεῦμα καὶ ἀφίησιν ἄλλο δʼ οὐθὲν οὔτε ξηρὸν οὔθʼ ὑγρόν, ἢ πόνον παρέχει, ἕως ἂν ἐκβήξῃ τὸ κατελθόν, Source: Coda, Aristotle, History of Animals, B(1), C(16), P(81), L(16)
# 2025-03-23 12:35:11,449 - DEBUG - root - Entity: ['Body Part', 'ἀρτηρία', 'οὖν', 'τοῦτον']
# 2025-03-23 12:35:11,450 - DEBUG - root - Category: Body Part, Word: ἀρτηρία, Word Before: οὖν, Word After: τοῦτον
# 2025-03-23 12:35:11,451 - DEBUG - root - exact_word_before_pattern: οὖν
# 2025-03-23 12:35:11,451 - DEBUG - root - exact_word_after_pattern: τοῦτον
# 2025-03-23 12:35:11,452 - DEBUG - root - word_before_pattern: (?:ο\p{M}*ὖ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,452 - DEBUG - root - word_after_pattern: (?:τ\p{M}*ο\p{M}*ῦ\p{M}*τ\p{M}*ο\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,453 - DEBUG - root - Entity: ['Pathology', 'πόνον', 'ἢ', 'παρέχει']
# 2025-03-23 12:35:11,453 - DEBUG - root - Category: Pathology, Word: πόνον, Word Before: ἢ, Word After: παρέχει
# 2025-03-23 12:35:11,454 - DEBUG - root - exact_word_before_pattern: ἢ
# 2025-03-23 12:35:11,455 - DEBUG - root - exact_word_after_pattern: παρέχει
# 2025-03-23 12:35:11,455 - DEBUG - root - word_before_pattern: (?:ἢ\p{M}*){s<=2}
# 2025-03-23 12:35:11,456 - DEBUG - root - word_after_pattern: (?:π\p{M}*α\p{M}*ρ\p{M}*έ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,460 - DEBUG - root - Entity: ['Body Part', 'πνεῦμα', 'μόνον τὸ', 'καὶ ἀφίησιν']
# 2025-03-23 12:35:11,461 - DEBUG - root - Category: Body Part, Word: πνεῦμα, Word Before: μόνον τὸ, Word After: καὶ ἀφίησιν
# 2025-03-23 12:35:11,461 - DEBUG - root - exact_word_before_pattern: μόνον\ τὸ
# 2025-03-23 12:35:11,462 - DEBUG - root - exact_word_after_pattern: καὶ\ ἀφίησιν
# 2025-03-23 12:35:11,463 - DEBUG - root - word_before_pattern: (?:μ\p{M}*ό\p{M}*ν\p{M}*ο\p{M}*ν\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,463 - DEBUG - root - word_after_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*ἀ\p{M}*φ\p{M}*ί\p{M}*η\p{M}*σ\p{M}*ι\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,464 - DEBUG - root - Entity: ['Adjectives/Qualities', 'ξηρὸν', 'οὐθὲν οὔτε', 'οὔθʼ ὑγρόν']
# 2025-03-23 12:35:11,465 - DEBUG - root - Category: Adjectives/Qualities, Word: ξηρὸν, Word Before: οὐθὲν οὔτε, Word After: οὔθʼ ὑγρόν
# 2025-03-23 12:35:11,466 - DEBUG - root - exact_word_before_pattern: οὐθὲν\ οὔτε
# 2025-03-23 12:35:11,466 - DEBUG - root - exact_word_after_pattern: οὔθʼ\ ὑγρόν
# 2025-03-23 12:35:11,466 - DEBUG - root - word_before_pattern: (?:ο\p{M}*ὐ\p{M}*θ\p{M}*ὲ\p{M}*ν\p{M}*\ \p{M}*ο\p{M}*ὔ\p{M}*τ\p{M}*ε\p{M}*){s<=2}
# 2025-03-23 12:35:11,467 - DEBUG - root - word_after_pattern: (?:ο\p{M}*ὔ\p{M}*θ\p{M}*ʼ\p{M}*\ \p{M}*ὑ\p{M}*γ\p{M}*ρ\p{M}*ό\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,470 - DEBUG - root - Entity: ['Adjectives/Qualities', 'ὑγρόν', 'ξηρὸν οὔθʼ', ', ἢ πόνον']
# 2025-03-23 12:35:11,471 - DEBUG - root - Category: Adjectives/Qualities, Word: ὑγρόν, Word Before: ξηρὸν οὔθʼ, Word After: , ἢ πόνον
# 2025-03-23 12:35:11,471 - DEBUG - root - exact_word_before_pattern: ξηρὸν\ οὔθʼ
# 2025-03-23 12:35:11,472 - DEBUG - root - exact_word_after_pattern: ,\ ἢ\ πόνον
# 2025-03-23 12:35:11,472 - DEBUG - root - word_before_pattern: (?:ξ\p{M}*η\p{M}*ρ\p{M}*ὸ\p{M}*ν\p{M}*\ \p{M}*ο\p{M}*ὔ\p{M}*θ\p{M}*ʼ\p{M}*){s<=2}
# 2025-03-23 12:35:11,473 - DEBUG - root - word_after_pattern: (?:,\p{M}*\ \p{M}*ἢ\p{M}*\ \p{M}*π\p{M}*ό\p{M}*ν\p{M}*ο\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,474 - DEBUG - root - Entity: ['Physiology', 'δέχεται', 'τρόπον, καὶ', 'μόνον τὸ']
# 2025-03-23 12:35:11,474 - DEBUG - root - Category: Physiology, Word: δέχεται, Word Before: τρόπον, καὶ, Word After: μόνον τὸ
# 2025-03-23 12:35:11,475 - DEBUG - root - exact_word_before_pattern: τρόπον,\ καὶ
# 2025-03-23 12:35:11,475 - DEBUG - root - exact_word_after_pattern: μόνον\ τὸ
# 2025-03-23 12:35:11,476 - DEBUG - root - word_before_pattern: (?:τ\p{M}*ρ\p{M}*ό\p{M}*π\p{M}*ο\p{M}*ν\p{M}*,\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*){s<=2}
# 2025-03-23 12:35:11,476 - DEBUG - root - word_after_pattern: (?:μ\p{M}*ό\p{M}*ν\p{M}*ο\p{M}*ν\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,477 - DEBUG - root - Entity: ['Physiology', 'ἀφίησιν', 'πνεῦμα καὶ', 'ἄλλο δʼ']
# 2025-03-23 12:35:11,478 - DEBUG - root - Category: Physiology, Word: ἀφίησιν, Word Before: πνεῦμα καὶ, Word After: ἄλλο δʼ
# 2025-03-23 12:35:11,478 - DEBUG - root - exact_word_before_pattern: πνεῦμα\ καὶ
# 2025-03-23 12:35:11,479 - DEBUG - root - exact_word_after_pattern: ἄλλο\ δʼ
# 2025-03-23 12:35:11,480 - DEBUG - root - word_before_pattern: (?:π\p{M}*ν\p{M}*ε\p{M}*ῦ\p{M}*μ\p{M}*α\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*){s<=2}
# 2025-03-23 12:35:11,481 - DEBUG - root - word_after_pattern: (?:ἄ\p{M}*λ\p{M}*λ\p{M}*ο\p{M}*\ \p{M}*δ\p{M}*ʼ\p{M}*){s<=2}
# 2025-03-23 12:35:11,482 - DEBUG - root - Entity: ['Physiology', 'ἐκβήξῃ', 'ἕως ἂν', 'τὸ κατελθόν']
# 2025-03-23 12:35:11,482 - DEBUG - root - Category: Physiology, Word: ἐκβήξῃ, Word Before: ἕως ἂν, Word After: τὸ κατελθόν
# 2025-03-23 12:35:11,483 - DEBUG - root - exact_word_before_pattern: ἕως\ ἂν
# 2025-03-23 12:35:11,483 - DEBUG - root - exact_word_after_pattern: τὸ\ κατελθόν
# 2025-03-23 12:35:11,484 - DEBUG - root - word_before_pattern: (?:ἕ\p{M}*ω\p{M}*ς\p{M}*\ \p{M}*ἂ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,484 - DEBUG - root - word_after_pattern: (?:τ\p{M}*ὸ\p{M}*\ \p{M}*κ\p{M}*α\p{M}*τ\p{M}*ε\p{M}*λ\p{M}*θ\p{M}*ό\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,486 - DEBUG - root - Found 8 entities in this sentence.
# 2025-03-23 12:35:11,487 - DEBUG - root - Sentence 6: Θέλει γὰρ εἶναι διμερὴς ὁ πλεύμων ἐν ἅπασι τοῖς ἔχουσιν αὐτόν, Source: Coda, Aristotle, History of Animals, B(1), C(16), P(80), L(33)
# 2025-03-23 12:35:11,487 - DEBUG - root - Entity: ['Adjectives/Qualities', 'διμερὴς', 'γὰρ εἶναι', 'ὁ πλεύμων ']
# 2025-03-23 12:35:11,488 - DEBUG - root - Category: Adjectives/Qualities, Word: διμερὴς, Word Before: γὰρ εἶναι, Word After: ὁ πλεύμων
# 2025-03-23 12:35:11,488 - DEBUG - root - exact_word_before_pattern: γὰρ\ εἶναι
# 2025-03-23 12:35:11,489 - DEBUG - root - exact_word_after_pattern: ὁ\ πλεύμων
# 2025-03-23 12:35:11,489 - DEBUG - root - word_before_pattern: (?:γ\p{M}*ὰ\p{M}*ρ\p{M}*\ \p{M}*ε\p{M}*ἶ\p{M}*ν\p{M}*α\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,490 - DEBUG - root - word_after_pattern: (?:ὁ\p{M}*\ \p{M}*π\p{M}*λ\p{M}*ε\p{M}*ύ\p{M}*μ\p{M}*ω\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,491 - DEBUG - root - Entity: ['Body Part', 'πλεύμων', 'διμερὴς ὁ ', 'ἐν ἅπασι']
# 2025-03-23 12:35:11,491 - DEBUG - root - Category: Body Part, Word: πλεύμων, Word Before: διμερὴς ὁ , Word After: ἐν ἅπασι
# 2025-03-23 12:35:11,492 - DEBUG - root - exact_word_before_pattern: διμερὴς\ ὁ
# 2025-03-23 12:35:11,492 - DEBUG - root - exact_word_after_pattern: ἐν\ ἅπασι
# 2025-03-23 12:35:11,493 - DEBUG - root - word_before_pattern: (?:δ\p{M}*ι\p{M}*μ\p{M}*ε\p{M}*ρ\p{M}*ὴ\p{M}*ς\p{M}*\ \p{M}*ὁ\p{M}*){s<=2}
# 2025-03-23 12:35:11,493 - DEBUG - root - word_after_pattern: (?:ἐ\p{M}*ν\p{M}*\ \p{M}*ἅ\p{M}*π\p{M}*α\p{M}*σ\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,494 - DEBUG - root - Found 2 entities in this sentence.
# 2025-03-23 12:35:11,495 - DEBUG - root - Sentence 7: ἀλλʼ ἐν μὲν τοῖς ζῳοτόκοις οὐχ ὁμοίως ἡ διάστασις φανερά, ἥκιστα δʼ ἐν ἀνθρώπῳ, Source: Coda, Aristotle, History of Animals, B(1), C(16), P(80), L(34)
# 2025-03-23 12:35:11,496 - DEBUG - root - Entity: ['Medical', 'διάστασις', 'ὁμοίως ἡ', 'φανερά, ἥκιστα']
# 2025-03-23 12:35:11,497 - DEBUG - root - Category: Medical, Word: διάστασις, Word Before: ὁμοίως ἡ, Word After: φανερά, ἥκιστα
# 2025-03-23 12:35:11,497 - DEBUG - root - exact_word_before_pattern: ὁμοίως\ ἡ
# 2025-03-23 12:35:11,498 - DEBUG - root - exact_word_after_pattern: φανερά,\ ἥκιστα
# 2025-03-23 12:35:11,499 - DEBUG - root - word_before_pattern: (?:ὁ\p{M}*μ\p{M}*ο\p{M}*ί\p{M}*ω\p{M}*ς\p{M}*\ \p{M}*ἡ\p{M}*){s<=2}
# 2025-03-23 12:35:11,499 - DEBUG - root - word_after_pattern: (?:φ\p{M}*α\p{M}*ν\p{M}*ε\p{M}*ρ\p{M}*ά\p{M}*,\p{M}*\ \p{M}*ἥ\p{M}*κ\p{M}*ι\p{M}*σ\p{M}*τ\p{M}*α\p{M}*){s<=2}
# 2025-03-23 12:35:11,500 - DEBUG - root - Entity: ['Adjectives/Qualities', 'φανερά', 'ἡ διάστασις', 'ἥκιστα δʼ']
# 2025-03-23 12:35:11,501 - DEBUG - root - Category: Adjectives/Qualities, Word: φανερά, Word Before: ἡ διάστασις, Word After: ἥκιστα δʼ
# 2025-03-23 12:35:11,501 - DEBUG - root - exact_word_before_pattern: ἡ\ διάστασις
# 2025-03-23 12:35:11,502 - DEBUG - root - exact_word_after_pattern: ἥκιστα\ δʼ
# 2025-03-23 12:35:11,502 - DEBUG - root - word_before_pattern: (?:ἡ\p{M}*\ \p{M}*δ\p{M}*ι\p{M}*ά\p{M}*σ\p{M}*τ\p{M}*α\p{M}*σ\p{M}*ι\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,503 - DEBUG - root - word_after_pattern: (?:ἥ\p{M}*κ\p{M}*ι\p{M}*σ\p{M}*τ\p{M}*α\p{M}*\ \p{M}*δ\p{M}*ʼ\p{M}*){s<=2}
# 2025-03-23 12:35:11,503 - DEBUG - root - Entity: ['Adjectives/Qualities', 'ἥκιστα', 'διάστασις φανερά', 'δʼ ἐν']
# 2025-03-23 12:35:11,504 - DEBUG - root - Category: Adjectives/Qualities, Word: ἥκιστα, Word Before: διάστασις φανερά, Word After: δʼ ἐν
# 2025-03-23 12:35:11,504 - DEBUG - root - exact_word_before_pattern: διάστασις\ φανερά
# 2025-03-23 12:35:11,505 - DEBUG - root - exact_word_after_pattern: δʼ\ ἐν
# 2025-03-23 12:35:11,505 - DEBUG - root - word_before_pattern: (?:δ\p{M}*ι\p{M}*ά\p{M}*σ\p{M}*τ\p{M}*α\p{M}*σ\p{M}*ι\p{M}*ς\p{M}*\ \p{M}*φ\p{M}*α\p{M}*ν\p{M}*ε\p{M}*ρ\p{M}*ά\p{M}*){s<=2}
# 2025-03-23 12:35:11,506 - DEBUG - root - word_after_pattern: (?:δ\p{M}*ʼ\p{M}*\ \p{M}*ἐ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,508 - DEBUG - root - Entity: ['Medical', 'ζῳοτόκοις', 'μὲν τοῖς', 'οὐχ ὁμοίως']
# 2025-03-23 12:35:11,509 - DEBUG - root - Category: Medical, Word: ζῳοτόκοις, Word Before: μὲν τοῖς, Word After: οὐχ ὁμοίως
# 2025-03-23 12:35:11,510 - DEBUG - root - exact_word_before_pattern: μὲν\ τοῖς
# 2025-03-23 12:35:11,510 - DEBUG - root - exact_word_after_pattern: οὐχ\ ὁμοίως
# 2025-03-23 12:35:11,512 - DEBUG - root - word_before_pattern: (?:μ\p{M}*ὲ\p{M}*ν\p{M}*\ \p{M}*τ\p{M}*ο\p{M}*ῖ\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,512 - DEBUG - root - word_after_pattern: (?:ο\p{M}*ὐ\p{M}*χ\p{M}*\ \p{M}*ὁ\p{M}*μ\p{M}*ο\p{M}*ί\p{M}*ω\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,514 - DEBUG - root - Found 4 entities in this sentence.
# 2025-03-23 12:35:11,515 - DEBUG - root - Sentence 8: Ἔστι δʼ οὐ πολυσχιδὴς ὁ τοῦ ἀνθρώπου, ὥσπερ ἐνίων ζῳοτόκων, οὐδὲ λεῖος, ἀλλʼ ἔχει ἀνωμαλίαν, Source: Coda, Aristotle, History of Animals, B(1), C(16), P(80), L(1)
# 2025-03-23 12:35:11,515 - DEBUG - root - Entity: ['Adjectives/Qualities', 'πολυσχιδὴς', 'δʼ οὐ ', ' ὁ τοῦ ']
# 2025-03-23 12:35:11,516 - DEBUG - root - Category: Adjectives/Qualities, Word: πολυσχιδὴς, Word Before: δʼ οὐ , Word After:  ὁ τοῦ
# 2025-03-23 12:35:11,516 - DEBUG - root - exact_word_before_pattern: δʼ\ οὐ
# 2025-03-23 12:35:11,517 - DEBUG - root - exact_word_after_pattern: ὁ\ τοῦ
# 2025-03-23 12:35:11,517 - DEBUG - root - word_before_pattern: (?:δ\p{M}*ʼ\p{M}*\ \p{M}*ο\p{M}*ὐ\p{M}*){s<=2}
# 2025-03-23 12:35:11,517 - DEBUG - root - word_after_pattern: (?:ὁ\p{M}*\ \p{M}*τ\p{M}*ο\p{M}*ῦ\p{M}*){s<=2}
# 2025-03-23 12:35:11,519 - DEBUG - root - Entity: ['Adjectives/Qualities', 'λεῖος', 'ζῳοτόκων, οὐδὲ', 'ἀλλʼ ἔχει ']
# 2025-03-23 12:35:11,519 - DEBUG - root - Category: Adjectives/Qualities, Word: λεῖος, Word Before: ζῳοτόκων, οὐδὲ, Word After: ἀλλʼ ἔχει
# 2025-03-23 12:35:11,520 - DEBUG - root - exact_word_before_pattern: ζῳοτόκων,\ οὐδὲ
# 2025-03-23 12:35:11,520 - DEBUG - root - exact_word_after_pattern: ἀλλʼ\ ἔχει
# 2025-03-23 12:35:11,521 - DEBUG - root - word_before_pattern: (?:ζ\p{M}*ῳ\p{M}*ο\p{M}*τ\p{M}*ό\p{M}*κ\p{M}*ω\p{M}*ν\p{M}*,\p{M}*\ \p{M}*ο\p{M}*ὐ\p{M}*δ\p{M}*ὲ\p{M}*){s<=2}
# 2025-03-23 12:35:11,521 - DEBUG - root - word_after_pattern: (?:ἀ\p{M}*λ\p{M}*λ\p{M}*ʼ\p{M}*\ \p{M}*ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11
p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,535 - DEBUG - root - Entity: ['Medical', 'ᾠοτόκα', 'τετραπόδων ὅσα', 'πολὺ τὸ ']
# 2025-03-23 12:35:11,536 - DEBUG - root - Category: Medical, Word: ᾠοτόκα, Word Before: τετραπόδων ὅσα, Word After: πολὺ τὸ
# 2025-03-23 12:35:11,536 - DEBUG - root - exact_word_before_pattern: τετραπόδων\ ὅσα
# 2025-03-23 12:35:11,537 - DEBUG - root - exact_word_after_pattern: πολὺ\ τὸ
# 2025-03-23 12:35:11,537 - DEBUG - root - word_before_pattern: (?:τ\p{M}*ε\p{M}*τ\p{M}*ρ\p{M}*α\p{M}*π\p{M}*ό\p{M}*δ\p{M}*ω\p{M}*ν\p{M}*\ \p{M}*ὅ\p{M}*σ\p{M}*α\p{M}*){s<=2}
# 2025-03-23 12:35:11,538 - DEBUG - root - word_after_pattern: (?:π\p{M}*ο\p{M}*λ\p{M}*ὺ\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,542 - DEBUG - root - Entity: ['Body Part', 'πλεύμονας', 'δύο ἔχειν', '· καὶ ἀπὸ']
# 2025-03-23 12:35:11,542 - DEBUG - root - Category: Body Part, Word: πλεύμονας, Word Before: δύο ἔχειν, Word After: · καὶ ἀπὸ
# 2025-03-23 12:35:11,543 - DEBUG - root - exact_word_before_pattern: δύο\ ἔχειν
# 2025-03-23 12:35:11,544 - DEBUG - root - exact_word_after_pattern: ·\ καὶ\ ἀπὸ
# 2025-03-23 12:35:11,544 - DEBUG - root - word_before_pattern: (?:δ\p{M}*ύ\p{M}*ο\p{M}*\ \p{M}*ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,545 - DEBUG - root - word_after_pattern: (?:·\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*ἀ\p{M}*π\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,547 - DEBUG - root - Entity: ['Adjectives/Qualities', 'μέρος', 'πολὺ τὸ', 'ἑκάτερον ἀπʼ']
# 2025-03-23 12:35:11,547 - DEBUG - root - Category: Adjectives/Qualities, Word: μέρος, Word Before: πολὺ τὸ, Word After: ἑκάτερον ἀπʼ
# 2025-03-23 12:35:11,548 - DEBUG - root - exact_word_before_pattern: πολὺ\ τὸ
# 2025-03-23 12:35:11,548 - DEBUG - root - exact_word_after_pattern: ἑκάτερον\ ἀπʼ
# 2025-03-23 12:35:11,555 - DEBUG - root - word_before_pattern: (?:π\p{M}*ο\p{M}*λ\p{M}*ὺ\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,556 - DEBUG - root - word_after_pattern: (?:ἑ\p{M}*κ\p{M}*ά\p{M}*τ\p{M}*ε\p{M}*ρ\p{M}*ο\p{M}*ν\p{M}*\ \p{M}*ἀ\p{M}*π\p{M}*ʼ\p{M}*){s<=2}
# 2025-03-23 12:35:11,557 - DEBUG - root - Entity: ['Adjectives/Qualities', 'δύο', 'ὥστε δοκεῖν', 'ἔχειν πλεύμονας']
# 2025-03-23 12:35:11,558 - DEBUG - root - Category: Adjectives/Qualities, Word: δύο, Word Before: ὥστε δοκεῖν, Word After: ἔχειν πλεύμονας
# 2025-03-23 12:35:11,558 - DEBUG - root - exact_word_before_pattern: ὥστε\ δοκεῖν
# 2025-03-23 12:35:11,559 - DEBUG - root - exact_word_after_pattern: ἔχειν\ πλεύμονας
# 2025-03-23 12:35:11,560 - DEBUG - root - word_before_pattern: (?:ὥ\p{M}*σ\p{M}*τ\p{M}*ε\p{M}*\ \p{M}*δ\p{M}*ο\p{M}*κ\p{M}*ε\p{M}*ῖ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,560 - DEBUG - root - word_after_pattern: (?:ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*ν\p{M}*\ \p{M}*π\p{M}*λ\p{M}*ε\p{M}*ύ\p{M}*μ\p{M}*ο\p{M}*ν\p{M}*α\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,562 - DEBUG - root - Entity: ['Topography', 'ἑκάτερον', 'τὸ μέρος', 'ἀπʼ ἀλλήλων']
# 2025-03-23 12:35:11,563 - DEBUG - root - Category: Topography, Word: ἑκάτερον, Word Before: τὸ μέρος, Word After: ἀπʼ ἀλλήλων
# 2025-03-23 12:35:11,564 - DEBUG - root - exact_word_before_pattern: τὸ\ μέρος
# 2025-03-23 12:35:11,564 - DEBUG - root - exact_word_after_pattern: ἀπʼ\ ἀλλήλων
# 2025-03-23 12:35:11,569 - DEBUG - root - word_before_pattern: (?:τ\p{M}*ὸ\p{M}*\ \p{M}*μ\p{M}*έ\p{M}*ρ\p{M}*ο\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,570 - DEBUG - root - word_after_pattern: (?:ἀ\p{M}*π\p{M}*ʼ\p{M}*\ \p{M}*ἀ\p{M}*λ\p{M}*λ\p{M}*ή\p{M}*λ\p{M}*ω\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,570 - DEBUG - root - Entity: ['Topography', 'ἀπʼ', 'μέρος ἑκάτερον', 'ἀλλήλων ἔσχισται']
# 2025-03-23 12:35:11,571 - DEBUG - root - Category: Topography, Word: ἀπʼ, Word Before: μέρος ἑκάτερον, Word After: ἀλλήλων ἔσχισται
# 2025-03-23 12:35:11,571 - DEBUG - root - exact_word_before_pattern: μέρος\ ἑκάτερον
# 2025-03-23 12:35:11,572 - DEBUG - root - exact_word_after_pattern: ἀλλήλων\ ἔσχισται
# 2025-03-23 12:35:11,572 - DEBUG - root - word_before_pattern: (?:μ\p{M}*έ\p{M}*ρ\p{M}*ο\p{M}*ς\p{M}*\ \p{M}*ἑ\p{M}*κ\p{M}*ά\p{M}*τ\p{M}*ε\p{M}*ρ\p{M}*ο\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,573 - DEBUG - root - word_after_pattern: (?:ἀ\p{M}*λ\p{M}*λ\p{M}*ή\p{M}*λ\p{M}*ω\p{M}*ν\p{M}*\ \p{M}*ἔ\p{M}*σ\p{M}*χ\p{M}*ι\p{M}*σ\p{M}*τ\p{M}*α\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,573 - DEBUG - root - Entity: ['Topography', 'ἀλλήλων', 'ἑκάτερον ἀπʼ', 'ἔσχισται, ὥστε']
# 2025-03-23 12:35:11,574 - DEBUG - root - Category: Topography, Word: ἀλλήλων, Word Before: ἑκάτερον ἀπʼ, Word After: ἔσχισται, ὥστε
# 2025-03-23 12:35:11,575 - DEBUG - root - exact_word_before_pattern: ἑκάτερον\ ἀπʼ
# 2025-03-23 12:35:11,575 - DEBUG - root - exact_word_after_pattern: ἔσχισται,\ ὥστε
# 2025-03-23 12:35:11,575 - DEBUG - root - word_before_pattern: (?:ἑ\p{M}*κ\p{M}*ά\p{M}*τ\p{M}*ε\p{M}*ρ\p{M}*ο\p{M}*ν\p{M}*\ \p{M}*ἀ\p{M}*π\p{M}*ʼ\p{M}*){s<=2}
# 2025-03-23 12:35:11,576 - DEBUG - root - word_after_pattern: (?:ἔ\p{M}*σ\p{M}*χ\p{M}*ι\p{M}*σ\p{M}*τ\p{M}*α\p{M}*ι\p{M}*,\p{M}*\ \p{M}*ὥ\p{M}*σ\p{M}*τ\p{M}*ε\p{M}*){s<=2}
# 2025-03-23 12:35:11,579 - DEBUG - root - Entity: ['Topography', 'ἔσχισται', 'ἀπʼ ἀλλήλων', ', ὥστε δοκεῖν']
# 2025-03-23 12:35:11,580 - DEBUG - root - Category: Topography, Word: ἔσχισται, Word Before: ἀπʼ ἀλλήλων, Word After: , ὥστε δοκεῖν
# 2025-03-23 12:35:11,580 - DEBUG - root - exact_word_before_pattern: ἀπʼ\ ἀλλήλων
# 2025-03-23 12:35:11,581 - DEBUG - root - exact_word_after_pattern: ,\ ὥστε\ δοκεῖν
# 2025-03-23 12:35:11,581 - DEBUG - root - word_before_pattern: (?:ἀ\p{M}*π\p{M}*ʼ\p{M}*\ \p{M}*ἀ\p{M}*λ\p{M}*λ\p{M}*ή\p{M}*λ\p{M}*ω\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,582 - DEBUG - root - word_after_pattern: (?:,\p{M}*\ \p{M}*ὥ\p{M}*σ\p{M}*τ\p{M}*ε\p{M}*\ \p{M}*δ\p{M}*ο\p{M}*κ\p{M}*ε\p{M}*ῖ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,583 - DEBUG - root - Found 9 entities in this sentence.
# 2025-03-23 12:35:11,584 - DEBUG - root - Sentence 10: Συνήρτηται δὲ καὶ τῇ μεγάλῃ φλεβὶ καὶ τῇ ἀορτῇ καλουμένῃ, Source: Coda, Aristotle, History of Animals, B(1), C(16), P(81), L(7)
# 2025-03-23 12:35:11,584 - DEBUG - root - Entity: ['Technical Appellation', 'μεγάλῃ φλεβὶ', 'καὶ τῇ', 'καὶ τῇ']
# 2025-03-23 12:35:11,587 - DEBUG - root - Category: Technical Appellation, Word: μεγάλῃ φλεβὶ, Word Before: καὶ τῇ, Word After: καὶ τῇ
# 2025-03-23 12:35:11,588 - DEBUG - root - exact_word_before_pattern: καὶ\ τῇ
# 2025-03-23 12:35:11,588 - DEBUG - root - exact_word_after_pattern: καὶ\ τῇ
# 2025-03-23 12:35:11,589 - DEBUG - root - word_before_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ῇ\p{M}*){s<=2}
# 2025-03-23 12:35:11,589 - DEBUG - root - word_after_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ῇ\p{M}*){s<=2}
# 2025-03-23 12:35:11,590 - DEBUG - root - Entity: ['Topography', 'Συνήρτηται', 'τοῦ πλεύμονος.', 'δὲ καὶ']
# 2025-03-23 12:35:11,591 - DEBUG - root - Category: Topography, Word: Συνήρτηται, Word Before: τοῦ πλεύμονος., Word After: δὲ καὶ
# 2025-03-23 12:35:11,591 - DEBUG - root - exact_word_before_pattern: τοῦ\ πλεύμονος\.
# 2025-03-23 12:35:11,592 - DEBUG - root - exact_word_after_pattern: δὲ\ καὶ
# 2025-03-23 12:35:11,592 - DEBUG - root - word_before_pattern: (?:τ\p{M}*ο\p{M}*ῦ\p{M}*\ \p{M}*π\p{M}*λ\p{M}*ε\p{M}*ύ\p{M}*μ\p{M}*ο\p{M}*ν\p{M}*ο\p{M}*ς\p{M}*\.\p{M}*){s<=2}
# 2025-03-23 12:35:11,593 - DEBUG - root - word_after_pattern: (?:δ\p{M}*ὲ\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*){s<=2}
# 2025-03-23 12:35:11,595 - DEBUG - root - Entity: ['Adjectives/Qualities', 'μεγάλῃ', 'καὶ τῇ', 'φλεβὶ καὶ']
# 2025-03-23 12:35:11,596 - DEBUG - root - Category: Adjectives/Qualities, Word: μεγάλῃ, Word Before: καὶ τῇ, Word After: φλεβὶ καὶ
# 2025-03-23 12:35:11,596 - DEBUG - root - exact_word_before_pattern: καὶ\ τῇ
# 2025-03-23 12:35:11,597 - DEBUG - root - exact_word_after_pattern: φλεβὶ\ καὶ
# 2025-03-23 12:35:11,597 - DEBUG - root - word_before_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ῇ\p{M}*){s<=2}
# 2025-03-23 12:35:11,598 - DEBUG - root - word_after_pattern: (?:φ\p{M}*λ\p{M}*ε\p{M}*β\p{M}*ὶ\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*){s<=2}
# 2025-03-23 12:35:11,599 - DEBUG - root - Entity: ['Body Part', 'φλεβὶ', 'τῇ μεγάλῃ', 'καὶ τῇ']
# 2025-03-23 12:35:11,600 - DEBUG - root - Category: Body Part, Word: φλεβὶ, Word Before: τῇ μεγάλῃ, Word After: καὶ τῇ
# 2025-03-23 12:35:11,600 - DEBUG - root - exact_word_before_pattern: τῇ\ μεγάλῃ
# 2025-03-23 12:35:11,600 - DEBUG - root - exact_word_after_pattern: καὶ\ τῇ
# 2025-03-23 12:35:11,601 - DEBUG - root - word_before_pattern: (?:τ\p{M}*ῇ\p{M}*\ \p{M}*μ\p{M}*ε\p{M}*γ\p{M}*ά\p{M}*λ\p{M}*ῃ\p{M}*){s<=2}
# 2025-03-23 12:35:11,601 - DEBUG - root - word_after_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ῇ\p{M}*){s<=2}
# 2025-03-23 12:35:11,602 - DEBUG - root - Entity: ['Technical Appellation', 'ἀορτῇ', 'καὶ τῇ', 'καλουμένῃ. Φυσωμένης']
# 2025-03-23 12:35:11,603 - DEBUG - root - Category: Technical Appellation, Word: ἀορτῇ, Word Before: καὶ τῇ, Word After: καλουμένῃ. Φυσωμένης
# 2025-03-23 12:35:11,603 - DEBUG - root - exact_word_before_pattern: καὶ\ τῇ
# 2025-03-23 12:35:11,604 - DEBUG - root - exact_word_after_pattern: καλουμένῃ\.\ φυσωμένης
# 2025-03-23 12:35:11,604 - DEBUG - root - word_before_pattern: (?:κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*τ\p{M}*ῇ\p{M}*){s<=2}
# 2025-03-23 12:35:11,605 - DEBUG - root - word_after_pattern: (?:κ\p{M}*α\p{M}*λ\p{M}*ο\p{M}*υ\p{M}*μ\p{M}*έ\p{M}*ν\p{M}*ῃ\p{M}*\.\p{M}*\ \p{M}*φ\p{M}*υ\p{M}*σ\p{M}*ω\p{M}*μ\p{M}*έ\p{M}*ν\p{M}*η\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,606 - DEBUG - root - Found 5 entities in this sentence.
# 2025-03-23 12:35:11,607 - DEBUG - root - Sentence 11: Ταῦτα δὲ διαφύσεις ἔχει χονδρώδεις εἰς ὀξὺ συνηκούσας, Source: Coda, Aristotle, History of Animals, B(1), C(16), P(81), L(9)
# 2025-03-23 12:35:11,608 - DEBUG - root - Entity: ['Body Part', 'διαφύσεις', 'Ταῦτα δὲ', 'ἔχει χονδρώδεις']
# 2025-03-23 12:35:11,611 - DEBUG - root - Category: Body Part, Word: διαφύσεις, Word Before: Ταῦτα δὲ, Word After: ἔχει χονδρώδεις
# 2025-03-23 12:35:11,612 - DEBUG - root - exact_word_before_pattern: ταῦτα\ δὲ
# 2025-03-23 12:35:11,613 - DEBUG - root - exact_word_after_pattern: ἔχει\ χονδρώδεις
# 2025-03-23 12:35:11,613 - DEBUG - root - word_before_pattern: (?:τ\p{M}*α\p{M}*ῦ\p{M}*τ\p{M}*α\p{M}*\ \p{M}*δ\p{M}*ὲ\p{M}*){s<=2}
# 2025-03-23 12:35:11,614 - DEBUG - root - word_after_pattern: (?:ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*\ \p{M}*χ\p{M}*ο\p{M}*ν\p{M}*δ\p{M}*ρ\p{M}*ώ\p{M}*δ\p{M}*ε\p{M}*ι\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,616 - DEBUG - root - Entity: ['Adjectives/Qualities', 'χονδρώδεις', 'διαφύσεις ἔχει', 'εἰς ὀξὺ']
# 2025-03-23 12:35:11,617 - DEBUG - root - Category: Adjectives/Qualities, Word: χονδρώδεις, Word Before: διαφύσεις ἔχει, Word After: εἰς ὀξὺ
# 2025-03-23 12:35:11,618 - DEBUG - root - exact_word_before_pattern: διαφύσεις\ ἔχει
# 2025-03-23 12:35:11,618 - DEBUG - root - exact_word_after_pattern: εἰς\ ὀξὺ
# 2025-03-23 12:35:11,618 - DEBUG - root - word_before_pattern: (?:δ\p{M}*ι\p{M}*α\p{M}*φ\p{M}*ύ\p{M}*σ\p{M}*ε\p{M}*ι\p{M}*ς\p{M}*\ \p{M}*ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,619 - DEBUG - root - word_after_pattern: (?:ε\p{M}*ἰ\p{M}*ς\p{M}*\ \p{M}*ὀ\p{M}*ξ\p{M}*ὺ\p{M}*){s<=2}
# 2025-03-23 12:35:11,620 - DEBUG - root - Entity: ['Topography', 'εἰς', 'ἔχει χονδρώδεις', 'ὀξὺ συνηκούσας']
# 2025-03-23 12:35:11,621 - DEBUG - root - Category: Topography, Word: εἰς, Word Before: ἔχει χονδρώδεις, Word After: ὀξὺ συνηκούσας
# 2025-03-23 12:35:11,621 - DEBUG - root - exact_word_before_pattern: ἔχει\ χονδρώδεις
# 2025-03-23 12:35:11,622 - DEBUG - root - exact_word_after_pattern: ὀξὺ\ συνηκούσας
# 2025-03-23 12:35:11,622 - DEBUG - root - word_before_pattern: (?:ἔ\p{M}*χ\p{M}*ε\p{M}*ι\p{M}*\ \p{M}*χ\p{M}*ο\p{M}*ν\p{M}*δ\p{M}*ρ\p{M}*ώ\p{M}*δ\p{M}*ε\p{M}*ι\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,623 - DEBUG - root - word_after_pattern: (?:ὀ\p{M}*ξ\p{M}*ὺ\p{M}*\ \p{M}*σ\p{M}*υ\p{M}*ν\p{M}*η\p{M}*κ\p{M}*ο\p{M}*ύ\p{M}*σ\p{M}*α\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,624 - DEBUG - root - Entity: ['Topography', 'ὀξὺ', 'χονδρώδεις εἰς', 'συνηκούσας· ἐκ']
# 2025-03-23 12:35:11,624 - DEBUG - root - Category: Topography, Word: ὀξὺ, Word Before: χονδρώδεις εἰς, Word After: συνηκούσας· ἐκ
# 2025-03-23 12:35:11,625 - DEBUG - root - exact_word_before_pattern: χονδρώδεις\ εἰς
# 2025-03-23 12:35:11,626 - DEBUG - root - exact_word_after_pattern: συνηκούσας·\ ἐκ
# 2025-03-23 12:35:11,626 - DEBUG - root - word_before_pattern: (?:χ\p{M}*ο\p{M}*ν\p{M}*δ\p{M}*ρ\p{M}*ώ\p{M}*δ\p{M}*ε\p{M}*ι\p{M}*ς\p{M}*\ \p{M}*ε\p{M}*ἰ\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,627 - DEBUG - root - word_after_pattern: (?:σ\p{M}*υ\p{M}*ν\p{M}*η\p{M}*κ\p{M}*ο\p{M}*ύ\p{M}*σ\p{M}*α\p{M}*ς\p{M}*·\p{M}*\ \p{M}*ἐ\p{M}*κ\p{M}*){s<=2}
# 2025-03-23 12:35:11,628 - DEBUG - root - Entity: ['Topography', 'συνηκούσας', 'εἰς ὀξὺ', '· ἐκ δὲ']
# 2025-03-23 12:35:11,629 - DEBUG - root - Category: Topography, Word: συνηκούσας, Word Before: εἰς ὀξὺ, Word After: · ἐκ δὲ
# 2025-03-23 12:35:11,630 - DEBUG - root - exact_word_before_pattern: εἰς\ ὀξὺ
# 2025-03-23 12:35:11,630 - DEBUG - root - exact_word_after_pattern: ·\ ἐκ\ δὲ
# 2025-03-23 12:35:11,631 - DEBUG - root - word_before_pattern: (?:ε\p{M}*ἰ\p{M}*ς\p{M}*\ \p{M}*ὀ\p{M}*ξ\p{M}*ὺ\p{M}*){s<=2}
# 2025-03-23 12:35:11,631 - DEBUG - root - word_after_pattern: (?:·\p{M}*\ \p{M}*ἐ\p{M}*κ\p{M}*\ \p{M}*δ\p{M}*ὲ\p{M}*){s<=2}
# 2025-03-23 12:35:11,633 - DEBUG - root - Found 5 entities in this sentence.
# 2025-03-23 12:35:11,634 - DEBUG - root - Sentence 12: Ἔτι προσώπου μέρος τὸ μὲν ὂν τῷ πνεύματι πόρος ῥίς , Source: Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(5)
# 2025-03-23 12:35:11,634 - DEBUG - root - Entity: ['Body Part', 'προσώπου', 'Ἔτι', 'μέρος τὸ']
# 2025-03-23 12:35:11,635 - DEBUG - root - Category: Body Part, Word: προσώπου, Word Before: Ἔτι, Word After: μέρος τὸ
# 2025-03-23 12:35:11,635 - DEBUG - root - exact_word_before_pattern: ἔτι
# 2025-03-23 12:35:11,636 - DEBUG - root - exact_word_after_pattern: μέρος\ τὸ
# 2025-03-23 12:35:11,636 - DEBUG - root - word_before_pattern: (?:ἔ\p{M}*τ\p{M}*ι\p{M}*){s<=2}
# 2025-03-23 12:35:11,637 - DEBUG - root - word_after_pattern: (?:μ\p{M}*έ\p{M}*ρ\p{M}*ο\p{M}*ς\p{M}*\ \p{M}*τ\p{M}*ὸ\p{M}*){s<=2}
# 2025-03-23 12:35:11,638 - DEBUG - root - Entity: ['Body Part', 'ῥίς', 'πνεύματι πόρος', '· καὶ γὰρ']
# 2025-03-23 12:35:11,638 - DEBUG - root - Category: Body Part, Word: ῥίς, Word Before: πνεύματι πόρος, Word After: · καὶ γὰρ
# 2025-03-23 12:35:11,639 - DEBUG - root - exact_word_before_pattern: πνεύματι\ πόρος
# 2025-03-23 12:35:11,639 - DEBUG - root - exact_word_after_pattern: ·\ καὶ\ γὰρ
# 2025-03-23 12:35:11,640 - DEBUG - root - word_before_pattern: (?:π\p{M}*ν\p{M}*ε\p{M}*ύ\p{M}*μ\p{M}*α\p{M}*τ\p{M}*ι\p{M}*\ \p{M}*π\p{M}*ό\p{M}*ρ\p{M}*ο\p{M}*ς\p{M}*){s<=2}
# 2025-03-23 12:35:11,642 - DEBUG - root - word_after_pattern: (?:·\p{M}*\ \p{M}*κ\p{M}*α\p{M}*ὶ\p{M}*\ \p{M}*γ\p{M}*ὰ\p{M}*ρ\p{M}*){s<=2}
# 2025-03-23 12:35:11,643 - DEBUG - root - Entity: ['Adjectives/Qualities', 'μέρος', 'Ἔτι προσώπου', 'τὸ μὲν']
# 2025-03-23 12:35:11,645 - DEBUG - root - Category: Adjectives/Qualities, Word: μέρος, Word Before: Ἔτι προσώπου, Word After: τὸ μὲν
# 2025-03-23 12:35:11,645 - DEBUG - root - exact_word_before_pattern: ἔτι\ προσώπου
# 2025-03-23 12:35:11,646 - DEBUG - root - exact_word_after_pattern: τὸ\ μὲν
# 2025-03-23 12:35:11,647 - DEBUG - root - word_before_pattern: (?:ἔ\p{M}*τ\p{M}*ι\p{M}*\ \p{M}*π\p{M}*ρ\p{M}*ο\p{M}*σ\p{M}*ώ\p{M}*π\p{M}*ο\p{M}*υ\p{M}*){s<=2}
# 2025-03-23 12:35:11,647 - DEBUG - root - word_after_pattern: (?:τ\p{M}*ὸ\p{M}*\ \p{M}*μ\p{M}*ὲ\p{M}*ν\p{M}*){s<=2}
# 2025-03-23 12:35:11,649 - DEBUG - root - Entity: ['Topography', 'πόρος', 'τῷ πνεύματι', 'ῥίς· καὶ']
# 2025-03-23 12:35:11,649 - DEBUG - root - Category: Topography, Word: πόρος, Word Before: τῷ πνεύματι, Word After: ῥίς· καὶ
# ...
#   {'entities': [(20, 23, 'Topography'),
#     (28, 35, 'Body Part'),
#     (73, 79, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ταύτῃ καὶ διαίρει τὸν οὐραχὸν ὁκόταν παλινδρομῇ τὸ πνεῦμα·',
#   {'entities': [(22, 29, 'Body Part'),
#     (37, 47, 'Physiology'),
#     (51, 57, 'Body Part')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('παλινδρομεῖ δὲ κατὰ δίκην·',
#   {'entities': [(0, 11, 'Physiology')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('κῶς γὰρ ἀνθρώπου τροφὴ ἄνεμος καὶ ὕδωρ τὰ ὠμά; ἀλλὰ μᾶλλον τιμωρίη ξυγγενέος πάθης.',
#   {'entities': [(42, 45, 'Adjectives/Qualities')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('περὶ δὲ οὗ λόγος, ἡ καρδίη μῦς ἐστι κάρτα ἰσχυρός, οὒ τῳ νεύρῳ, ἀλλὰ πιλήματι σαρκός.',
#   {'entities': [(20, 26, 'Body Part'),
#     (27, 30, 'Body Part'),
#     (36, 41, 'Adjectives/Qualities'),
#     (42, 49, 'Adjectives/Qualities'),
#     (57, 62, 'Adjectives/Qualities'),
#     (69, 77, 'Adjectives/Qualities'),
#     (78, 84, 'Body Part')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('καὶ δύο γαστέρας ἔχει διακεκριμένας ἐν ἑνὶ περιβόλῳ, τὴν μὲν ἔνθα, τὴν δὲ ἔνθα·',
#   {'entities': [(4, 7, 'Adjectives/Qualities'),
#     (8, 16, 'Body Part'),
#     (22, 35, 'Topography'),
#     (36, 38, 'Topography'),
#     (39, 42, 'Adjectives/Qualities'),
#     (43, 51, 'Body Part'),
#     (61, 65, 'Topography'),
#     (74, 78, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('οὐδὲν δʼ ἐοίκασιν ἀλλήλῃσιν·',
#   {'entities': [(9, 17, 'Adjectives/Qualities')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ἡ μὲν γὰρ ἐν τοῖσι δεξιοῖσιν ἐπὶ στόμα κεῖται ὁμιλέουσα τῇ ἑτέρῃ φλεβί, ἡ δὲ δεξιή φημι τῶν ἐν λαιοῖσι·',
#   {'entities': [(10, 12, 'Topography'),
#     (19, 28, 'Topography'),
#     (29, 32, 'Topography'),
#     (33, 38, 'Body Part'),
#     (39, 45, 'Topography'),
#     (46, 55, 'Topography'),
#     (59, 64, 'Adjectives/Qualities'),
#     (65, 70, 'Body Part'),
#     (77, 82, 'Body Part'),
#     (92, 94, 'Topography'),
#     (95, 102, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ἡ γὰρ πᾶσα καρδίη τούτοισι τὴν ἕδρην ἐμπεποίηται·',
#   {'entities': [(6, 10, 'Adjectives/Qualities'),
#     (11, 17, 'Body Part'),
#     (27, 30, 'Topography'),
#     (31, 36, 'Topography'),
#     (37, 48, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ἀτὰρ ἥδε καὶ πάμπαν εὐρυκοίλιος καὶ λαγαρωτέρη πολλῷ τῆς ἑτέρης, οὐδὲ τῆς καρδίης νέμεται τὴν ἐσχατιήν, ἀλλʼ ἐγκαταλέιπει τὸν οὐραχὸν στερεὸν καί ἔστιν ὥσπερ ἔξωθεν προσερραμμένη.',
#   {'entities': [(5, 8, 'Body Part'),
#     (13, 19, 'Adjectives/Qualities'),
#     (20, 31, 'Adjectives/Qualities'),
#     (36, 46, 'Adjectives/Qualities'),
#     (47, 52, 'Adjectives/Qualities'),
#     (57, 63, 'Body Part'),
#     (74, 81, 'Body Part'),
#     (82, 89, 'Topography'),
#     (94, 102, 'Body Part'),
#     (109, 121, 'Topography'),
#     (126, 133, 'Body Part'),
#     (134, 141, 'Adjectives/Qualities'),
#     (158, 164, 'Topography'),
#     (165, 178, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('παρὰ τὸν πήχυν δὲ περόναι παρήκουσι λεπταί πάνυ τέσσερις, οἱ το μὲν δύο ἄνω, αἱ δὲ δύο κάτω·',
#   {'entities': [(0, 4, 'Topography'),
#     (9, 14, 'Body Part'),
#     (18, 25, 'Body Part'),
#     (26, 35, 'Topography'),
#     (36, 42, 'Adjectives/Qualities'),
#     (72, 75, 'Topography'),
#     (87, 91, 'Topography')]},
#   'hippocrates places in man 6.5-6'),
#  ('καὶ πρὸς μὲν τὸν ἀγκῶνα δύο περόναι πεφυκυῖαι ἄνω ἐκ τοῦ ὀστέου αὗται σὺν τῷ ὀστέῳ πεφυκυίαι παρὰ τὸ τοῦ ὀστέου ἄρθρον ἤρθρωνται ἐς τὸ κύβιτον·',
#   {'entities': [(4, 8, 'Topography'),
#     (17, 23, 'Body Part'),
#     (28, 35, 'Body Part'),
#     (36, 45, 'Topography'),
#     (46, 49, 'Topography'),
#     (50, 52, 'Topography'),
#     (57, 63, 'Body Part'),
#     (77, 82, 'Body Part'),
#     (83, 92, 'Topography'),
#     (93, 97, 'Topography'),
#     (105, 111, 'Body Part'),
#     (112, 118, 'Body Part'),
#     (119, 128, 'Topography'),
#     (135, 142, 'Body Part')]},
#   'hippocrates places in man 6.5-6'),
#  ('αἱ δὲ κάτω κείμενοι καὶ ἐντὸς κεκλιμέναι, αὗται ἀμφότεραι συμβάλλουσαι πρὸς τὴν περόνην τὴν ἄνωθεν ἀπὸ τοῦ γυίου φερομένην, ἐντὸς τοῦ γυίου ἤρθρωνται, και περόνην καλουμένην ποιέουσιν, αυται ἑωυτῇσι συμβάλλουσαι ἐν τῷ κυβίτῳ ἐντός.',
#   {'entities': [(6, 10, 'Topography'),
#     (11, 19, 'Topography'),
#     (24, 29, 'Topography'),
#     (30, 40, 'Topography'),
#     (58, 70, 'Topography'),
#     (80, 87, 'Body Part'),
#     (92, 98, 'Topography'),
#     (99, 102, 'Topography'),
#     (107, 112, 'Body Part'),
#     (113, 122, 'Topography'),
#     (124, 129, 'Topography'),
#     (134, 139, 'Body Part'),
#     (140, 149, 'Topography'),
#     (155, 162, 'Technical Appellation'),
#     (199, 211, 'Topography'),
#     (212, 214, 'Topography'),
#     (218, 224, 'Body Part'),
#     (225, 230, 'Topography')]},
#   'hippocrates places in man 6.5-6'),
#  ('κάτω δὲ πρὸς τὴν χεῖρα τὸ ὀστέον ἄρθρον ἔχει·',
#   {'entities': [(0, 4, 'Topography'),
#     (8, 12, 'Topography'),
#     (17, 22, 'Body Part'),
#     (26, 32, 'Body Part'),
#     (33, 39, 'Body Part')]},
#   'hippocrates places in man 6.5-6'),
#  ('αἱ δὲ περόναι ταύτη ἁπαλαὶ ἐοῦσαι, αἱ μὲν δύο οὐκ ἐξήκουσιν ἐς τὸ ἄρθρον, ἡ δʼ ἄνω καὶ ἡ κάτω σύν τῷ ὀστέῳ ὄρθρωνται πρὸς τὴν χεῖρα, αἱ δὲ χείρες άρθρα έχουσι πολλά·',
#   {'entities': [(6, 13, 'Body Part'),
#     (20, 26, 'Adjectives/Qualities'),
#     (50, 59, 'Topography'),
#     (79, 82, 'Topography'),
#     (89, 93, 'Topography'),
#     (101, 106, 'Body Part'),
#     (126, 131, 'Body Part'),
#     (139, 145, 'Body Part'),
#     (146, 151, 'Body Part')]},
#   'hippocrates places in man 6.5-6'),
#  ('όσα γὰρ ἐστές πρὸς ἑαυτὰ συμβάλλουσι πάντα άρθρα ποιέουσι.',
#   {'entities': [(19, 24, 'Topography'), (25, 36, 'Topography')]},
#   'hippocrates places in man 6.5-6'),
#  ('ʼεν μὲν οὖν τῷ πρὸ τοῦτου βιβλίῳ τὴν ἐγχείρησιν, ὁποίαν τινὰ χρή ποιεῖσθαι τῶν περὶ τὴν χεῖρα μυῶν, ὑφηγησάμην, ἐνταῦθα δὲ κατὰ τὸν αὐτὸν τρόπον ἐπὶ τῶν σχελῶν ὁ λόγος ἔσται μοι.',
#   {'entities': [(88, 93, 'Body Part'),
#     (94, 98, 'Body Part'),
#     (145, 148, 'Topography'),
#     (153, 159, 'Body Part'),
#     (162, 167, 'Physiology')]},
#   'galen ΑΑ ΙΙ 4 Andrés '),
#  ('πρίν γὰρ τοὺς μῦς ἀκριβῶς ἐπιγνῶναι, νεύρων ἢ ἀγγείων ἀνατομὴν οὔτε αὐτὸν ποιήσασθαι δυνατόν, οὔτʼ ἄλλον διδάξαι.',
#   {'entities': [(14, 17, 'Body Part'),
#     (26, 35, 'Action Verbs'),
#     (37, 43, 'Body Part'),
#     (46, 53, 'Body Part'),
#     (54, 62, 'Action Verbs')]},
#   'galen ΑΑ ΙΙ 4 Andrés '),
#  ('χρὴ τοίνυν ἀποδεῖραι μὲν κάνταῦθα τὸ δέρμα, προσέχοντα τὸν νοῦν ἀκριβῶς τῇ πρώτῃ τοῦ πέλματος γενέσει, κατὰ τὴν ἀρχὴν τῆς πτέρνης τεταγμένῃ, μήπως κατὰ τοῦτο τὸ χωρίον ἀποσπάσῃς ἅμα τῷ δέρματι τὸν ὑποκείμενον αὐτῷ τένοντα, διʼ οὗ, ὥσπερ ἐπὶ χειρὸς εἴρηται, πλατυνθέντος τὸ ἄτριχόν τε ἅμα καὶ δυσπερίτρεπτον ὑποβέβληται δέρμα τῷ χώλῳ.',
#   {'entities': [(11, 20, 'Action Verbs'),
#     (37, 42, 'Body Part'),
#     (122, 129, 'Body Part'),
#     (168, 177, 'Action Verbs'),
#     (185, 192, 'Body Part'),
#     (197, 208, 'Topography'),
#     (214, 221, 'Body Part'),
#     (257, 269, 'Adjectives/Qualities'),
#     (273, 280, 'Adjectives/Qualities'),
#     (292, 306, 'Adjectives/Qualities'),
#     (307, 318, 'Topography'),
#     (319, 324, 'Body Part'),
#     (328, 332, 'Body Part')]},
#   'galen ΑΑ ΙΙ 4 Andrés '),
#   {'entities': [(28, 38, 'Action Verbs'),
#     (48, 59, 'Action Verbs'),
#     (73, 82, 'Technical appellation'),
#     (87, 97, 'Medical'),
#     (109, 118, 'Topography'),
#     (119, 125, 'Body Part'),
#     (126, 141, 'Topography'),
#     (142, 153, 'Action Verbs'),
#     (155, 162, 'Action Verbs'),
#     (170, 179, 'Action Verbs'),
#     (184, 197, 'Topography'),
#     (198, 205, 'Body Part')]},
#   'Gal. AA. 5, 7, 317, 2-20'),
#  ('οταν δʼ ἐν τῇ νῦν τομῇ διά τῆς ἀριστερᾶς χειρός ὑπηρεσίαν εποιήσω τῇ τεμνούσῃ, τοιαύτην ἄμεινόν τε μετά ἑτέρου καὶ τῇ πρώτη πασῶν ἐπιβολῇ ποιεῖσθαι·',
#   {'entities': [(31, 40, 'Topography'), (41, 47, 'Body Part')]},
#   'Gal. AA. 5, 7, 317, 2-20'),
#  ('κάλλιον γάρ οὕτως ἐργάσῃ τὴν εὐθεῖαν τομὴν ἀπὸ τοῦ ξιφοειδοῦς ἀρξάμενος.',
#   {'entities': [(18, 24, 'Action Verbs'),
#     (51, 61, 'Adjectives/Qualities'),
#     (62, 71, 'Action Verbs')]},
#   'Gal. AA. 5, 7, 317, 2-20'),
#  ('ἔστω δʼ ἡ τῆς χειρὸς ὑπηρεσία, τῶν τεττάρων δακτύλων κατὰ τὸ μῆκος τοῦ μυὸς ἐπιβαλλομένων, εἶθʼ, ὅταν στηριχθῶσιν ἐπʼ αὐτοῦ, πρὸς τὸ πλάγιον αγομένων ἀτρέμα.',
#   {'entities': [(14, 20, 'Body Part'),
#     (44, 52, 'Body Part'),
#     (53, 66, 'Topography'),
#     (71, 75, 'Body Part'),
#     (76, 89, 'Action Verbs'),
#     (125, 140, 'Topography'),
#     (141, 156, 'Action Verbs')]},
#   'Gal. AA. 5, 7, 317, 2-20'),
#  ('εἰ γὰρ ἐφʼ ἑκατέρου των μυών πραχθείη καλώς τούτο, σαφέστερόν γʼ αὐτῶν ἐστι τὸ μεταξύ, καθʼ ὃ την πρώτην έκέλευόν σε ποιεῖσθαι τομήν.',
#   {'entities': [(7, 19, 'Topography'),
#     (24, 28, 'Body Part'),
#     (76, 85, 'Topography'),
#     (127, 132, 'Medical')]},
#   'Gal. AA. 5, 7, 317, 2-20'),
#  ('ἀλλʼ ὅταν γε διέλης ὀρθῶς, ἀρκέσει καὶ μία χείρ, τὸν ἀνατεμνόμενον μῦν ἠρέμα πρὸς τὸ πλάγιον ἀπάγουσα.',
#   {'entities': [(43, 47, 'Body Part'),
#     (53, 66, 'Action Verbs'),
#     (67, 70, 'Body Part'),
#     (77, 92, 'Topography'),
#     (93, 101, 'Action Verbs')]},
#   'Gal. AA. 5, 7, 317, 2-20'),
#  ('δυνατόν, ὡς ἔφην, ἐστὶ καὶ διʼ ἀγκίστρου πράττειν αὐτό.',
#   {'entities': [(31, 40, 'Technical appellation')]},
#   'Gal. AA. 5, 7, 317, 2-20'),
#  ('ποιεῖσθαι δὲ τὴν εἰρημένην ἐγχείρησιν ἕως τῶν κατὰ τὸν ὀμφαλόν χωρίων, ἄχρι περ ἂν ἀξιόλογον ᾖ σοι τὸ γεγυμνωμένον τοῦ μυός.',
#   {'entities': [(46, 69, 'Topography'),
#     (102, 114, 'Action Verbs'),
#     (119, 123, 'Body Part')]},
#   'Gal. AA. 5, 7, 317, 2-20'),
#  ('ὀστέα χειρὸς εἰκοσιεπτὰ καὶ ποδὸς εἰκοσιτέσσαρα·',
#   {'entities': [(0, 5, 'Body Part'),
#     (6, 12, 'Body Part'),
#     (28, 33, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('τραχήλου ἐς τὸν μέγαν ἑπτά·',
#   {'entities': [(0, 8, 'Body Part'), (9, 11, 'Topography')]},
#   'On Nature of Bones 1'),
#  ('ὀσφύος πέντε·',
#   {'entities': [(0, 6, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ῥάχιος εἴκοσι·',
#   {'entities': [(0, 6, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('κεφαλῆς ξύν ὀπωπίοισιν ὀκτὼ ·',
#   {'entities': [(0, 7, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ξύμπαντα ὀγδοήκοντα ὀκτώ, σὺν ὄνυξιν ἑκατὸν ὀκτώ.',
#   {'entities': [(30, 36, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ἅ δʼ ἡμεῖς αὐτοὶ ἐξ ἀνθρώπου ὀστέων κατεμάθομεν, σφόνδυλοι οἱ ἄνω τῆς κληῖδος ξὺν τῷ μεγάλῳ ἑπτά·',
#   {'entities': [(29, 35, 'Body Part'),
#     (49, 58, 'Body Part'),
#     (62, 65, 'Topography'),
#     (70, 77, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('οἱ δὲ κατὰ τὰς πλευράς ὅσαιπερ αἱ πλευραὶ δώδεκα·',
#   {'entities': [(6, 10, 'Topography'),
#     (15, 22, 'Body Part'),
#     (34, 41, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('οἱ δὲ κατὰ κενεῶνας ἐκτός, ἐν ᾧ τὰ ἰσχία, ἐν τῇ ὀσφύι πέντε·',
#   {'entities': [(6, 10, 'Topography'),
#     (11, 19, 'Body Part'),
#     (27, 29, 'Topography'),
#     (35, 40, 'Body Part'),
#     (42, 44, 'Topography'),
#     (48, 53, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('τὸ δὲ σπέρμα οἷον κηρίον ἑκατέρωθεν τῆς κύστιος·',
#   {'entities': [(6, 12, 'Body Part'),
#     (25, 35, 'Topography'),
#     (40, 47, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ἐκ δʼ αὐτῶν φλέβες ἑκατέρωθεν τοῦ οὐρητῆρος ἐς τὸ αἰδοῖον τείνουσι.',
#   {'entities': [(0, 2, 'Topography'),
#     (12, 18, 'Body Part'),
#     (19, 29, 'Topography'),
#     (34, 43, 'Body Part'),
#     (44, 46, 'Topography'),
#     (50, 57, 'Body Part'),
#     (58, 66, 'Topography')]},
#   'On Nature of Bones 1'),
#  ('ποτὸν διὰ φάρυγγος καὶ διὰ στομάχου (λάρυγξ ἐς πλεύμονα καὶ ἀρτηρίην)·',
#   {'entities': [(6, 9, 'Topography'),
#     (10, 18, 'Body Part'),
#     (23, 26, 'Topography'),
#     (27, 35, 'Body Part'),
#     (37, 43, 'Body Part'),
#     (44, 46, 'Topography'),
#     (47, 55, 'Body Part'),
#     (60, 68, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ἀπὸ δὲ τούτων ἐς ἄκρην κύστιν.',
#   {'entities': [(0, 3, 'Topography'),
#     (14, 16, 'Topography'),
#     (23, 29, 'Body Part')]},
#   'On Nature of Bones 1'),
#  
]},
#   'Gal. AA, 2, 4, 91, 28 - 93, 16')]

# %% [markdown]
# # Data Statistics

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from typing import Tuple, List
from spacy.tokens import Doc
import spacy
from spacy.tokens import DocBin
import pandas as pd

def visualize_label_distribution(nlp_model_path: spacy.language.Language, choice: str='ents', form: str='NFC') -> Tuple[List[Doc], List[Doc], List[Doc]]:
    # Check if nlp exists
    try:
        nlp
    except NameError:
        nlp = spacy.load(nlp_model_path)
    
    # Check if spancat exists
    if 'spancat' not in nlp.pipe_names:
        spancat = nlp.add_pipe("spancat")
        spancat.cfg["spans_key"] = "sc"
        
    # Load the train, test and dev data
    FORMAT = form
    folder_name = "ner" if choice == "ents" else "spancat"
    file_name = "ner" if choice == "ents" else "spancat"

    train_docbin = DocBin().from_disk("../corpus/train/{0}_train/{1}_train_{2}.spacy".format(folder_name, file_name, FORMAT))
    train_docs = list(train_docbin.get_docs(nlp.vocab))
    dev_docbin = DocBin().from_disk("../corpus/dev/{0}_dev/{1}_dev_{2}.spacy".format(folder_name, file_name, FORMAT))
    dev_docs = list(dev_docbin.get_docs(nlp.vocab))
    test_docbin = DocBin().from_disk("../corpus/test/{0}_test/{1}_test_{2}.spacy".format(folder_name, file_name, FORMAT))
    test_docs = list(test_docbin.get_docs(nlp.vocab))

    # Print the number of sentences in train, test and dev data
    print ("train:", len(train_docs), "dev:", len(dev_docs), "test:", len(test_docs))
    # print names of files
    print ("train:", "../corpus/train/{0}_train/{1}_train_{2}.spacy".format(folder_name, file_name, FORMAT))

    sns.set(style="darkgrid")

    # Extract labels from each dataset
    if choice == 'ents':
        train_data_labels = pd.DataFrame([ent.label_ for doc in train_docs for ent in doc.ents], columns=['labels'])
        dev_data_labels = pd.DataFrame([ent.label_ for doc in dev_docs for ent in doc.ents], columns=['labels'])
        test_data_labels = pd.DataFrame([ent.label_ for doc in test_docs for ent in doc.ents], columns=['labels'])
    elif choice == 'spans':
        train_data_labels = pd.DataFrame([span.label_ for doc in train_docs for span in doc.spans["sc"]], columns=['labels'])
        dev_data_labels = pd.DataFrame([span.label_ for doc in dev_docs for span in doc.spans["sc"]], columns=['labels'])
        test_data_labels = pd.DataFrame([span.label_ for doc in test_docs for span in doc.spans["sc"]], columns=['labels'])
    else:
        raise ValueError("Invalid choice. Choose between 'ents' and 'spans'.")

    # Add a 'dataset' column to each dataframe
    train_data_labels['dataset'] = 'train'
    dev_data_labels['dataset'] = 'dev'
    test_data_labels['dataset'] = 'test'

    # Concatenate all dataframes
    all_data_labels = pd.concat([train_data_labels, dev_data_labels, test_data_labels], ignore_index=True)

    # Plot the distribution of labels in each dataset
    plt.figure(figsize=(20,10))
    barplot1 = sns.countplot(data=all_data_labels, x='labels', hue='dataset')
    plt.title(f"Distribution of {choice} labels in the train, test, and dev data")

    # Add count numbers above each column
    for p in barplot1.patches:
        barplot1.annotate(format(p.get_height(), '.0f'), 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha = 'center', va = 'center', 
                        xytext = (0, 10), 
                        textcoords = 'offset points')
    plt.xticks(rotation=45)  # Rotate x-axis labels

    # Plot the frequency of labels in the train data
    train_data_labels = train_data_labels['labels'].value_counts().reset_index()
    train_data_labels.columns = ['label', 'count']  # rename columns
    plt.figure(figsize=(20,10))
    barplot2 = sns.barplot(data=train_data_labels, x='label', y='count')  # use new column names
    plt.title(f"Frequency of {choice} labels in the train data")
    plt.xticks(rotation=45)

    # Add count numbers above each column
    for i, row in train_data_labels.iterrows():
        barplot2.text(i, row['count'], row['count'], color='black', ha="center")

    plt.show()
    
    return train_docs, dev_docs, test_docs
# Out:
# 2025-03-23 12:35:55,978 - DEBUG - matplotlib - matplotlib data path: /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data
# 2025-03-23 12:35:55,983 - DEBUG - matplotlib - CONFIGDIR=/root/.config/matplotlib
# 2025-03-23 12:35:55,984 - DEBUG - matplotlib - interactive is False
# 2025-03-23 12:35:55,985 - DEBUG - matplotlib - platform is linux
# 2025-03-23 12:35:56,036 - DEBUG - matplotlib - CACHEDIR=/root/.cache/matplotlib
# 2025-03-23 12:35:56,039 - DEBUG - matplotlib.font_manager - Using fontManager instance from /root/.cache/matplotlib/fontlist-v330.json

# %%
# draw the distribution of ner labels in the train, test and dev data
#train_docs, dev_docs, test_docs = visualize_label_distribution("../training/SageMaker/transformer/PROIEL/Assembled/pos-trf-11-may-2024/model-best/", choice='ents', form='NFKD')

# draw the distribution of spancat labels in the train, test and dev data
#train_docs, dev_docs, test_docs = visualize_label_distribution("../training/SageMaker/transformer/PROIEL/Assembled/pos-trf-11-may-2024/model-best/", choice='spans', form='NFC')
train_docs, dev_docs, test_docs = visualize_label_distribution("../training/transformer/proiel/assembled/trf_27_feb_25/model-best/", choice='spans', form='NFC')
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/spacy_transformers/layers/hf_shim.py:124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self._model.load_state_dict(torch.load(filelike, map_location=device))
# 2025-03-23 12:36:06,804 - DEBUG - matplotlib.pyplot - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2025-03-23 12:36:06,805 - DEBUG - matplotlib.pyplot - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2025-03-23 12:36:06,828 - DEBUG - matplotlib.font_manager - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# 2025-03-23 12:36:06,829 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,829 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:06,830 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 2.335
# 2025-03-23 12:36:06,830 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,831 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,831 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:06,832 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,833 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,833 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,834 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,834 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,835 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,836 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,836 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:06,837 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,838 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:06,838 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,839 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,839 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,840 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,840 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,841 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,841 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,842 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,843 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 2.05
# 2025-03-23 12:36:06,847 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,848 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,849 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 3.335
# 2025-03-23 12:36:06,850 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,850 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,851 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,851 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,852 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,852 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,853 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,853 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,854 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 3.05
# 2025-03-23 12:36:06,854 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,855 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusRoman-BoldItalic.otf', name='Nimbus Roman', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,855 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,855 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf', name='Liberation Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 4.335
# 2025-03-23 12:36:06,856 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerif.ttf', name='FreeSerif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,857 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-BdIta.otf', name='C059', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,857 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Bold.otf', name='Nimbus Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,858 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/droid/DroidSansFallbackFull.ttf', name='Droid Sans Fallback', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,858 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-L.ttf', name='Ubuntu', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2025-03-23 12:36:06,859 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-Roman.otf', name='C059', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,859 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-R.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,860 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWBookman-LightItalic.otf', name='URW Bookman', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2025-03-23 12:36:06,861 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-LI.ttf', name='Ubuntu', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2025-03-23 12:36:06,861 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/Loma-BoldOblique.otf', name='Loma', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,862 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-BI.ttf', name='Ubuntu', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,862 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-BoldItalic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:06,863 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/StandardSymbolsPS.otf', name='Standard Symbols PS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06,864 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf', name='Liberation Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:06,865 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMonoOblique.ttf', name='FreeMono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:06,865 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf', name='Liberation Sans Narrow', style='italic', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2025-03-23 12:36:06,866 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf', name='IPAPGothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:06
- DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,004 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,005 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,005 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,006 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,006 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,008 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,008 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,009 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,009 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,010 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,010 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,011 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,011 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 2.05
# 2025-03-23 12:36:07,012 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# ...
# 2025-03-23 12:36:07,042 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-Oblique.otf', name='Nimbus Sans Narrow', style='oblique', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2025-03-23 12:36:07,042 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unifont/unifont_upper.ttf', name='Unifont Upper', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2025-03-23 12:36:07,043 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-C.ttf', name='Ubuntu Condensed', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2025-03-23 12:36:07,043 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-Bold.otf', name='C059', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,044 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifBoldItalic.ttf', name='FreeSerif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,044 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWGothic-BookOblique.otf', name='URW Gothic', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,045 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-MI.ttf', name='Ubuntu', style='italic', variant='normal', weight=500, stretch='normal', size='scalable')) = 11.145
# 2025-03-23 12:36:07,045 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-RI.ttf', name='Ubuntu', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,046 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWBookman-Light.otf', name='URW Bookman', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2025-03-23 12:36:07,046 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-BoldItalic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 5.335
# 2025-03-23 12:36:07,047 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifItalic.ttf', name='FreeSerif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,047 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unifont/unifont.ttf', name='Unifont', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2025-03-23 12:36:07,048 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMonoBold.ttf', name='FreeMono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,048 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/Z003-MediumItalic.otf', name='Z003', style='italic', variant='normal', weight=500, stretch='normal', size='scalable')) = 11.145
# 2025-03-23 12:36:07,049 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWGothic-Book.otf', name='URW Gothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,049 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,049 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifBold.ttf', name='FreeSerif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,050 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-Italic.otf', name='P052', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,050 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf', name='Liberation Sans Narrow', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2025-03-23 12:36:07,051 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Regular.otf', name='Nimbus Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,052 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-BoldItalic.otf', name='Nimbus Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,052 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/ipafont-gothic/ipag.ttf', name='IPAGothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,053 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMonoBoldOblique.ttf', name='FreeMono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,053 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-BoldOblique.otf', name='Nimbus Sans Narrow', style='oblique', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# 2025-03-23 12:36:07,054 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-Roman.otf', name='P052', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,054 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMono-Bold.ttf', name='Noto Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,054 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Italic.otf', name='Nimbus Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,055 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Bold.ttf', name='Liberation Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,055 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-Regular.otf', name='Nimbus Mono PS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,056 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,056 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-BoldItalic.ttf', name='Liberation Sans Narrow', style='italic', variant='normal', weight=700, stretch='condensed', size='scalable')) = 11.535
# 2025-03-23 12:36:07,057 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-BI.ttf', name='Ubuntu Mono', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,057 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-BoldItalic.otf', name='Nimbus Mono PS', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,058 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWGothic-DemiOblique.otf', name='URW Gothic', style='oblique', variant='normal', weight=600, stretch='normal', size='scalable')) = 11.24
# 2025-03-23 12:36:07,058 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/unifont/unifont_csur.ttf', name='Unifont CSUR', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2025-03-23 12:36:07,059 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-Th.ttf', name='Ubuntu', style='normal', variant='normal', weight=250, stretch='normal', size='scalable')) = 10.1925
# 2025-03-23 12:36:07,059 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWGothic-Demi.otf', name='URW Gothic', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2025-03-23 12:36:07,060 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf', name='Liberation Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 4.05
# 2025-03-23 12:36:07,060 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWBookman-Demi.otf', name='URW Bookman', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2025-03-23 12:36:07,061 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoMono-Regular.ttf', name='Noto Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,061 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSansBold.ttf', name='FreeSans', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2025-03-23 12:36:07,062 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-M.ttf', name='Ubuntu', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2025-03-23 12:36:07,062 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,063 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-Bold.otf', name='Nimbus Mono PS', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,063 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-BoldItalic.otf', name='P052', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,064 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-Bold.otf', name='Nimbus Sans Narrow', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2025-03-23 12:36:07,064 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-Italic.otf', name='Nimbus Mono PS', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,065 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-Regular.otf', name='Nimbus Sans Narrow', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2025-03-23 12:36:07,065 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/D050000L.otf', name='D050000L', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,066 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-R.ttf', name='Ubuntu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,069 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusRoman-Bold.otf', name='Nimbus Roman', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,070 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-Italic.otf', name='C059', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,070 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,071 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoSansMono-Regular.ttf', name='Noto Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2025-03-23 12:36:07,071 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2025-03-23 12:36:07,072 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-Italic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 5.05
# 2025-03-23 12:36:07,072 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/tlwg/Loma-Oblique.otf', name='Loma', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2025-03-23 12:36:07,073 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2025-03-23 12:36:07,073 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 2.335
# 2025-03-23 12:36:07,074 - DEBUG - matplotlib.font_manager - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=11.0 to DejaVu Sans ('/root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 2.050000.

# %%
import spacy
from spacy.tokens import DocBin
#nlp = spacy.load("../training/SageMaker/transformer/PROIEL/Assembled/pos-trf-11-may-2024/model-best/")  # Example with a blank English model. Replace according to your model.
#nlp = spacy.load("../training/transformer/proiel/assembled/trf_27_feb_25/model-best/")
nlp = spacy.load("../training/transformer/proiel/assembled/trf_27_feb_25/model-best/")
spancat = nlp.add_pipe("spancat")
spancat.cfg["spans_key"] = "sc"
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/spacy_transformers/layers/hf_shim.py:124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self._model.load_state_dict(torch.load(filelike, map_location=device))

# %%
# load the train, test and dev data
#import spacy
from spacy.tokens import DocBin
#nlp = spacy.load("grc_proiel_trf")
FORMAT = 'NFC'
train_docbin = DocBin().from_disk("../corpus/train/spancat_train/spancat_train_{0}.spacy".format(FORMAT))
# get docs from new_docbin
train_docs = list(train_docbin.get_docs(nlp.vocab))
dev_docbin = DocBin().from_disk("../corpus/dev/spancat_dev/spancat_dev_{0}.spacy".format(FORMAT))
# get docs from new_docbin
dev_docs = list(dev_docbin.get_docs(nlp.vocab))
test_docbin = DocBin().from_disk("../corpus/test/spancat_test/spancat_test_{0}.spacy".format(FORMAT))
# get docs from new_docbin
test_docs = list(test_docbin.get_docs(nlp.vocab))
# count sentences in train, test and dev data
print ("train:", len(train_docs), "dev:", len(dev_docs), "test:", len(test_docs))
# find sentence and print spans
for doc in test_docs:
    # checking a sentenc that had a word with two labels
    #if doc.text == "ἢν δὲ ὀλίγον ᾖ καὶ ἐς ἀμφοτέρας τὰς φλέβας τὸν κατάρροον ποιήσηται ἢ ἐς τὰ ἐπὶ θάτερα, περιγίνονται ἐπίσημα ἐόντα": #NFKD
    #if doc.text == "ἢν δὲ ὀλίγον ᾖ καὶ ἐς ἀμφοτέρας τὰς φλέβας τὸν κατάρροον ποιήσηται ἢ ἐς τὰ ἐπὶ θάτερα, περιγίνονται ἐπίσημα ἐόντα": #NFKC
    #if doc.text == "ἐνίοις μὲν γὰρ εὐρύτερον τὸ πρὸς τῇ κοιλίᾳ, τὸ δὲ πρὸς τῷ τέλει στενώτερον (διόπερ αἱ κύνες μετὰ πόνου προΐενται τὴν τοιαύτην περίττωσιν), τοῖς δὲ πλείοσιν ἄνωθεν στενώτερον, πρὸς τῷ τέλει δʼ εὐρύτερον":
    #if doc.text == "φρένες δὲ προσπεφύκασι τῷ ἥπατι ἃς οὐ ῥηΐδιον χωρίσαι. δισσαὶ δὲ ἀπὸ | κληΐδων αἱ μὲν ἔνθεν αἱ δὲ ἔνθεν ὑπὸ στῆθος ἐς ἦτρον·": # nfkc
    #if doc.text == "φρένες δὲ προσπεφύκασι τῷ ἥπατι ἃς οὐ ῥηΐδιον χωρίσαι. δισσαὶ δὲ ἀπὸ | κληΐδων αἱ μὲν ἔνθεν αἱ δὲ ἔνθεν ὑπὸ στῆθος ἐς ἦτρον·": # nfkd
    #if doc.text =="Ἅμα δʼ ἡ ἀνάπνευσις καὶ ἔκπνευσις γίνεται εἰς τὸ στῆθος, καὶ ἀδύνατον χωρὶς τοῖς μυκτῆρσιν ἀναπνεῦσαι ἢ ἐκπνεῦσαι, διὰ τὸ ἐκ τοῦ στήθους εἶναι τὴν ἀναπνοὴν καὶ ἐκπνοὴν κατὰ τὸν γαργαρεῶνα, καὶ μὴ ἐκ τῆς κεφαλῆς τινι μέρει": # nfkd
    # chcking a sentence that had a NaN value before
    #if doc.text == "ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται":
        print("doc user data: ", doc.user_data)
        # find spans that have the same token and more than one label
        
        print(doc.text)
        for span in doc.spans["sc"]:
            print(span.text, span.start_char, span.end_char, span.label_)
            # print character text in location of indices of span
            #print(doc.text[span.start_char:span.end_char])      
        # print spansgroup assuming you have a SpanGroup named 'sc' in doc.spans
        span_group = doc.spans["sc"]

        print(f"SpanGroup '{span_group.name}' contains {len(span_group)} spans:")
        for span in span_group:
            print(f"- Span: '{span.text}' [{span.start_char}, {span.end_char}], Labels: {span.label_}")
        for span in doc.spans["sc"]:
            print(type(span.text), span.text, type(span.start_char), span.start_char, type(span.end_char), span.end_char, type(span.label_), span.label_)
# Out:
# train: 494 dev: 64 test: 58
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(1), C(17), P(84), L(10)'}
# ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη
# ὑπὸ 0 3 Topography
# πνεύμονά 11 19 Body Part
# διάζωμα 28 35 Body Part
# θώρακος 43 50 Body Part
# φρένες 66 72 Body Part
# πρὸς 74 78 Topography
# πλευρὰ 86 92 Body Part
# ὑποχόνδρια 100 110 Body Part
# ῥάχιν 119 124 Body Part
# συνηρτημέναι 125 137 Topography
# ἐν 139 141 Topography
# μέσῳ 142 146 Topography
# λεπτὰ 158 163 Adjectives/Qualities
# ὑμενώδη 168 175 Adjectives/Qualities
# SpanGroup 'sc' contains 14 spans:
# - Span: 'ὑπὸ' [0, 3], Labels: Topography
# - Span: 'πνεύμονά' [11, 19], Labels: Body Part
# - Span: 'διάζωμα' [28, 35], Labels: Body Part
# - Span: 'θώρακος' [43, 50], Labels: Body Part
# - Span: 'φρένες' [66, 72], Labels: Body Part
# - Span: 'πρὸς' [74, 78], Labels: Topography
# - Span: 'πλευρὰ' [86, 92], Labels: Body Part
# - Span: 'ὑποχόνδρια' [100, 110], Labels: Body Part
# - Span: 'ῥάχιν' [119, 124], Labels: Body Part
# - Span: 'συνηρτημέναι' [125, 137], Labels: Topography
# - Span: 'ἐν' [139, 141], Labels: Topography
# - Span: 'μέσῳ' [142, 146], Labels: Topography
# - Span: 'λεπτὰ' [158, 163], Labels: Adjectives/Qualities
# - Span: 'ὑμενώδη' [168, 175], Labels: Adjectives/Qualities
# <class 'str'> ὑπὸ <class 'int'> 0 <class 'int'> 3 <class 'str'> Topography
# <class 'str'> πνεύμονά <class 'int'> 11 <class 'int'> 19 <class 'str'> Body Part
# <class 'str'> διάζωμα <class 'int'> 28 <class 'int'> 35 <class 'str'> Body Part
# <class 'str'> θώρακος <class 'int'> 43 <class 'int'> 50 <class 'str'> Body Part
# <class 'str'> φρένες <class 'int'> 66 <class 'int'> 72 <class 'str'> Body Part
# <class 'str'> πρὸς <class 'int'> 74 <class 'int'> 78 <class 'str'> Topography
# <class 'str'> πλευρὰ <class 'int'> 86 <class 'int'> 92 <class 'str'> Body Part
# <class 'str'> ὑποχόνδρια <class 'int'> 100 <class 'int'> 110 <class 'str'> Body Part
# <class 'str'> ῥάχιν <class 'int'> 119 <class 'int'> 124 <class 'str'> Body Part
# <class 'str'> συνηρτημέναι <class 'int'> 125 <class 'int'> 137 <class 'str'> Topography
# <class 'str'> ἐν <class 'int'> 139 <class 'int'> 141 <class 'str'> Topography
# <class 'str'> μέσῳ <class 'int'> 142 <class 'int'> 146 <class 'str'> Topography
# <class 'str'> λεπτὰ <class 'int'> 158 <class 'int'> 163 <class 'str'> Adjectives/Qualities
# <class 'str'> ὑμενώδη <class 'int'> 168 <class 'int'> 175 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(1), C(11), P(72), L(14)'}
# εὐκίνητος δʼ ὁ μυκτήρ, καὶ οὐχ ὥσπερ τὸ οὖς ἀκίνητον κατʼ ἰδίαν
# μυκτήρ 15 21 Body Part
# οὖς 40 43 Body Part
# εὐκίνητος 0 9 Adjectives/Qualities
# ἀκίνητον 44 52 Adjectives/Qualities
# SpanGroup 'sc' contains 4 spans:
# - Span: 'μυκτήρ' [15, 21], Labels: Body Part
# - Span: 'οὖς' [40, 43], Labels: Body Part
# - Span: 'εὐκίνητος' [0, 9], Labels: Adjectives/Qualities
# - Span: 'ἀκίνητον' [44, 52], Labels: Adjectives/Qualities
# <class 'str'> μυκτήρ <class 'int'> 15 <class 'int'> 21 <class 'str'> Body Part
# <class 'str'> οὖς <class 'int'> 40 <class 'int'> 43 <class 'str'> Body Part
# <class 'str'> εὐκίνητος <class 'int'> 0 <class 'int'> 9 <class 'str'> Adjectives/Qualities
# <class 'str'> ἀκίνητον <class 'int'> 44 <class 'int'> 52 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(1), C(17), P(83), L(35)'}
# αἷμα δὲ πλεῖστον μὲν ὁ πλεύμων ἔχει τῶν ἐν τοῖς ζῴοις μορίων τοῖς ἔχουσί τε πλεύμονα καὶ ζῳοτοκοῦσιν ἐν αὑτοῖς τε καὶ ἐκτός
# αἷμα 0 4 Body Part
# πλεύμων 23 30 Body Part
# μορίων 54 60 Body Part
# πλεύμονα 76 84 Body Part
# πλεῖστον 8 16 Adjectives/Qualities
# SpanGroup 'sc' contains 5 spans:
# - Span: 'αἷμα' [0, 4], Labels: Body Part
# - Span: 'πλεύμων' [23, 30], Labels: Body Part
# - Span: 'μορίων' [54, 60], Labels: Body Part
# - Span: 'πλεύμονα' [76, 84], Labels: Body Part
# - Span: 'πλεῖστον' [8, 16], Labels: Adjectives/Qualities
# <class 'str'> αἷμα <class 'int'> 0 <class 'int'> 4 <class 'str'> Body Part
# <class 'str'> πλεύμων <class 'int'> 23 <class 'int'> 30 <class 'str'> Body Part
# <class 'str'> μορίων <class 'int'> 54 <class 'int'> 60 <class 'str'> Body Part
# <class 'str'> πλεύμονα <class 'int'> 76 <class 'int'> 84 <class 'str'> Body Part
# <class 'str'> πλεῖστον <class 'int'> 8 <class 'int'> 16 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(1), C(16), P(81), L(24)'}
# δὲ κοιλία ἡ τοῦ ἀνθρώπου ὁμοία τῇ κυνείᾳ ἐστίν
# κοιλία 3 9 Body Part
# ἀνθρώπου 16 24 Medical
# ὁμοία 25 30 Adjectives/Qualities
# κυνείᾳ 34 40 Medical
# SpanGroup 'sc' contains 4 spans:
# - Span: 'κοιλία' [3, 9], Labels: Body Part
# - Span: 'ἀνθρώπου' [16, 24], Labels: Medical
# - Span: 'ὁμοία' [25, 30], Labels: Adjectives/Qualities
# - Span: 'κυνείᾳ' [34, 40], Labels: Medical
# <class 'str'> κοιλία <class 'int'> 3 <class 'int'> 9 <class 'str'> Body Part
# <class 'str'> ἀνθρώπου <class 'int'> 16 <class 'int'> 24 <class 'str'> Medical
# <class 'str'> ὁμοία <class 'int'> 25 <class 'int'> 30 <class 'str'> Adjectives/Qualities
# <class 'str'> κυνείᾳ <class 'int'> 34 <class 'int'> 40 <class 'str'> Medical
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(1), C(16), P(81), L(25)'}
# οὐ πολλῷ γὰρ τοῦ ἐντέρου μείζων, ἀλλʼ ἐοικυῖα οἱονεὶ ἐντέρῳ τινὶ εὖρος ἔχοντι
# ἐντέρου 17 24 Body Part
# μείζων 25 31 Adjectives/Qualities
# ἐοικυῖα 38 45 Adjectives/Qualities
# ἐντέρῳ 53 59 Body Part
# εὖρος 65 70 Adjectives/Qualities
# SpanGroup 'sc' contains 5 spans:
# - Span: 'ἐντέρου' [17, 24], Labels: Body Part
# - Span: 'μείζων' [25, 31], Labels: Adjectives/Qualities
# - Span: 'ἐοικυῖα' [38, 45], Labels: Adjectives/Qualities
# - Span: 'ἐντέρῳ' [53, 59], Labels: Body Part
# - Span: 'εὖρος' [65, 70], Labels: Adjectives/Qualities
# <class 'str'> ἐντέρου <class 'int'> 17 <class 'int'> 24 <class 'str'> Body Part
# <class 'str'> μείζων <class 'int'> 25 <class 'int'> 31 <class 'str'> Adjectives/Qualities
# <class 'str'> ἐοικυῖα <class 'int'> 38 <class 'int'> 45 <class 'str'> Adjectives/Qualities
# <class 'str'> ἐντέρῳ <class 'int'> 53 <class 'int'> 59 <class 'str'> Body Part
# <class 'str'> εὖρος <class 'int'> 65 <class 'int'> 70 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(4), P(136), L(24)'}
# τὸν αὐτὸν δὲ τρόπον καὶ τὰ τῆς ἐλάττονος φλεβός, καλουμένης δʼ ἀορτῆς, ἔσχισται μέρη, συμπαρακολουθοῦντα τοῖς τῆς μεγάλης
# ἀορτῆς 63 69 Body Part
# φλεβός 41 47 Body Part
# μέρη 80 84 Body Part
# τοῖς 105 109 Body Part
# μεγάλης 114 121 Body Part
# ἐλάττονος 31 40 Adjectives/Qualities
# ἔσχισται 71 79 Topography
# συμπαρακολουθοῦντα 86 104 Topography
# καλουμένης 49 59 Technical Appellation
# ἀορτῆς 63 69 Technical Appellation
# SpanGroup 'sc' contains 10 spans:
# - Span: 'ἀορτῆς' [63, 69], Labels: Body Part
# - Span: 'φλεβός' [41, 47], Labels: Body Part
# - Span: 'μέρη' [80, 84], Labels: Body Part
# - Span: 'τοῖς' [105, 109], Labels: Body Part
# - Span: 'μεγάλης' [114, 121], Labels: Body Part
# - Span: 'ἐλάττονος' [31, 40], Labels: Adjectives/Qualities
# - Span: 'ἔσχισται' [71, 79], Labels: Topography
# - Span: 'συμπαρακολουθοῦντα' [86, 104], Labels: Topography
# - Span: 'καλουμένης' [49, 59], Labels: Technical Appellation
# - Span: 'ἀορτῆς' [63, 69], Labels: Technical Appellation
# <class 'str'> ἀορτῆς <class 'int'> 63 <class 'int'> 69 <class 'str'> Body Part
# <class 'str'> φλεβός <class 'int'> 41 <class 'int'> 47 <class 'str'> Body Part
# <class 'str'> μέρη <class 'int'> 80 <class 'int'> 84 <class 'str'> Body Part
# <class 'str'> τοῖς <class 'int'> 105 <class 'int'> 109 <class 'str'> Body Part
# <class 'str'> μεγάλης <class 'int'> 114 <class 'int'> 121 <class 'str'> Body Part
# <class 'str'> ἐλάττονος <class 'int'> 31 <class 'int'> 40 <class 'str'> Adjectives/Qualities
# <class 'str'> ἔσχισται <class 'int'> 71 <class 'int'> 79 <class 'str'> Topography
# <class 'str'> συμπαρακολουθοῦντα <class 'int'> 86 <class 'int'> 104 <class 'str'> Topography
# <class 'str'> καλουμένης <class 'int'> 49 <class 'int'> 59 <class 'str'> Technical Appellation
# <class 'str'> ἀορτῆς <class 'int'> 63 <class 'int'> 69 <class 'str'> Technical Appellation
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(4), P(136), L(29)'}
# τὰ μὲν οὖν ἄνωθεν τῆς καρδίας τοῦτον ἔχουσι τὸν τρόπον αἱ φλέβες
# μὲν 3 6 Division
# καρδίας 22 29 Body Part
# φλέβες 58 64 Body Part
# ἄνωθεν 11 17 Topography
# τὰ 0 2 Division
# SpanGroup 'sc' contains 5 spans:
# - Span: 'μὲν' [3, 6], Labels: Division
# - Span: 'καρδίας' [22, 29], Labels: Body Part
# - Span: 'φλέβες' [58, 64], Labels: Body Part
# - Span: 'ἄνωθεν' [11, 17], Labels: Topography
# - Span: 'τὰ' [0, 2], Labels: Division
# <class 'str'> μὲν <class 'int'> 3 <class 'int'> 6 <class 'str'> Division
# <class 'str'> καρδίας <class 'int'> 22 <class 'int'> 29 <class 'str'> Body Part
# <class 'str'> φλέβες <class 'int'> 58 <class 'int'> 64 <class 'str'> Body Part
# <class 'str'> ἄνωθεν <class 'int'> 11 <class 'int'> 17 <class 'str'> Topography
# <class 'str'> τὰ <class 'int'> 0 <class 'int'> 2 <class 'str'> Division
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(4), P(137), L(2)'}
# διὸ ἀποσχαζόντων τῶν ἰατρῶν ταύτην ἀπολύονταί τινων πόνων περὶ τὸ ἧπαρ
# ταύτην 28 34 Body Part
# ἧπαρ 66 70 Body Part
# περὶ 58 62 Topography
# SpanGroup 'sc' contains 3 spans:
# - Span: 'ταύτην' [28, 34], Labels: Body Part
# - Span: 'ἧπαρ' [66, 70], Labels: Body Part
# - Span: 'περὶ' [58, 62], Labels: Topography
# <class 'str'> ταύτην <class 'int'> 28 <class 'int'> 34 <class 'str'> Body Part
# <class 'str'> ἧπαρ <class 'int'> 66 <class 'int'> 70 <class 'str'> Body Part
# <class 'str'> περὶ <class 'int'> 58 <class 'int'> 62 <class 'str'> Topography
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(4), P(137), L(12)'}
# πᾶσαι δʼ αὗται εἰς μίαν φλέβα τελευτῶσιν μεγάλην, παρὰ πᾶν τὸ ἔντερον καὶ τὴν κοιλίαν μέχρι τοῦ στομάχου τεταμένην
# αὗται 9 14 Body Part
# φλέβα 24 29 Body Part
# ἔντερον 62 69 Body Part
# κοιλίαν 78 85 Body Part
# στομάχου 96 104 Body Part
# πᾶσαι 0 5 Adjectives/Qualities
# μίαν 19 23 Adjectives/Qualities
# μεγάλην 41 48 Adjectives/Qualities
# πᾶν 55 58 Adjectives/Qualities
# εἰς 15 18 Topography
# τελευτῶσιν 30 40 Topography
# παρὰ 50 54 Topography
# μέχρι 86 91 Topography
# τεταμένην 105 114 Topography
# SpanGroup 'sc' contains 14 spans:
# - Span: 'αὗται' [9, 14], Labels: Body Part
# - Span: 'φλέβα' [24, 29], Labels: Body Part
# - Span: 'ἔντερον' [62, 69], Labels: Body Part
# - Span: 'κοιλίαν' [78, 85], Labels: Body Part
# - Span: 'στομάχου' [96, 104], Labels: Body Part
# - Span: 'πᾶσαι' [0, 5], Labels: Adjectives/Qualities
# - Span: 'μίαν' [19, 23], Labels: Adjectives/Qualities
# - Span: 'μεγάλην' [41, 48], Labels: Adjectives/Qualities
# - Span: 'πᾶν' [55, 58], Labels: Adjectives/Qualities
# - Span: 'εἰς' [15, 18], Labels: Topography
# - Span: 'τελευτῶσιν' [30, 40], Labels: Topography
# - Span: 'παρὰ' [50, 54], Labels: Topography
# - Span: 'μέχρι' [86, 91], Labels: Topography
# - Span: 'τεταμένην' [105, 114], Labels: Topography
# <class 'str'> αὗται <class 'int'> 9 <class 'int'> 14 <class 'str'> Body Part
# <class 'str'> φλέβα <class 'int'> 24 <class 'int'> 29 <class 'str'> Body Part
# <class 'str'> ἔντερον <class 'int'> 62 <class 'int'> 69 <class 'str'> Body Part
# <class 'str'> κοιλίαν <class 'int'> 78 <class 'int'> 85 <class 'str'> Body Part
# <class 'str'> στομάχου <class 'int'> 96 <class 'int'> 104 <class 'str'> Body Part
# <class 'str'> πᾶσαι <class 'int'> 0 <class 'int'> 5 <class 'str'> Adjectives/Qualities
# <class 'str'> μίαν <class 'int'> 19 <class 'int'> 23 <class 'str'> Adjectives/Qualities
# <class 'str'> μεγάλην <class 'int'> 41 <class 'int'> 48 <class 'str'> Adjectives/Qualities
# <class 'str'> πᾶν <class 'int'> 55 <class 'int'> 58 <class 'str'> Adjectives/Qualities
# <class 'str'> εἰς <class 'int'> 15 <class 'int'> 18 <class 'str'> Topography
# <class 'str'> τελευτῶσιν <class 'int'> 30 <class 'int'> 40 <class 'str'> Topography
# <class 'str'> παρὰ <class 'int'> 50 <class 'int'> 54 <class 'str'> Topography
# <class 'str'> μέχρι <class 'int'> 86 <class 'int'> 91 <class 'str'> Topography
# <class 'str'> τεταμένην <class 'int'> 105 <class 'int'> 114 <class 'str'> Topography
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(3), P(134), L(1)'}
# ἡ μὲν οὖν μεγάλη φλὲψ ἐκ τῆς μεγίστης ἤρτηται κοιλίας τῆς ἄνω καὶ ἐν τοῖς δεξιοῖς, εἶτα διὰ τοῦ κοίλου τοῦ μέσου γίνεται πάλιν φλέψ, ὡς οὔσης τῆς κοιλίας μορίου τῆς φλεβὸς ἐν ᾧ λιμνάζει τὸ αἷμα
# μεγάλη φλὲψ 10 21 Body Part
# κοιλίας 46 53 Body Part
# κοίλου 96 102 Body Part
# φλέψ 127 131 Body Part
# κοιλίας 146 153 Body Part
# μορίου 154 160 Body Part
# φλεβὸς 165 171 Body Part
# αἷμα 189 193 Body Part
# μεγίστης 29 37 Adjectives/Qualities
# μέσου 107 112 Adjectives/Qualities
# ἐκ 22 24 Topography
# ἤρτηται 38 45 Topography
# ἄνω 58 61 Topography
# ἐν 66 68 Topography
# δεξιοῖς 74 81 Topography
# διὰ 88 91 Topography
# γίνεται 113 120 Topography
# πάλιν 121 126 Topography
# ἐν 172 174 Topography
# ᾧ 175 176 Topography
# SpanGroup 'sc' contains 20 spans:
# - Span: 'μεγάλη φλὲψ' [10, 21], Labels: Body Part
# - Span: 'κοιλίας' [46, 53], Labels: Body Part
# - Span: 'κοίλου' [96, 102], Labels: Body Part
# - Span: 'φλέψ' [127, 131], Labels: Body Part
# - Span: 'κοιλίας' [146, 153], Labels: Body Part
# - Span: 'μορίου' [154, 160], Labels: Body Part
# - Span: 'φλεβὸς' [165, 171], Labels: Body Part
# - Span: 'αἷμα' [189, 193], Labels: Body Part
# - Span: 'μεγίστης' [29, 37], Labels: Adjectives/Qualities
# - Span: 'μέσου' [107, 112], Labels: Adjectives/Qualities
# - Span: 'ἐκ' [22, 24], Labels: Topography
# - Span: 'ἤρτηται' [38, 45], Labels: Topography
# - Span: 'ἄνω' [58, 61], Labels: Topography
# - Span: 'ἐν' [66, 68], Labels: Topography
# - Span: 'δεξιοῖς' [74, 81], Labels: Topography
# - Span: 'διὰ' [88, 91], Labels: Topography
# - Span: 'γίνεται' [113, 120], Labels: Topography
# - Span: 'πάλιν' [121, 126], Labels: Topography
# - Span: 'ἐν' [172, 174], Labels: Topography
# - Span: 'ᾧ' [175, 176], Labels: Topography
# <class 'str'> μεγάλη φλὲψ <class 'int'> 10 <class 'int'> 21 <class 'str'> Body Part
# <class 'str'> κοιλίας <class 'int'> 46 <class 'int'> 53 <class 'str'> Body Part
# <class 'str'> κοίλου <class 'int'> 96 <class 'int'> 102 <class 'str'> Body Part
# <class 'str'> φλέψ <class 'int'> 127 <class 'int'> 131 <class 'str'> Body Part
# <class 'str'> κοιλίας <class 'int'> 146 <class 'int'> 153 <class 'str'> Body Part
# <class 'str'> μορίου <class 'int'> 154 <class 'int'> 160 <class 'str'> Body Part
# <class 'str'> φλεβὸς <class 'int'> 165 <class 'int'> 171 <class 'str'> Body Part
# <class 'str'> αἷμα <class 'int'> 189 <class 'int'> 193 <class 'str'> Body Part
# <class 'str'> μεγίστης <class 'int'> 29 <class 'int'> 37 <class 'str'> Adjectives/Qualities
# <class 'str'> μέσου <class 'int'> 107 <class 'int'> 112 <class 'str'> Adjectives/Qualities
# <class 'str'> ἐκ <class 'int'> 22 <class 'int'> 24 <class 'str'> Topography
# <class 'str'> ἤρτηται <class 'int'> 38 <class 'int'> 45 <class 'str'> Topography
# <class 'str'> ἄνω <class 'int'> 58 <class 'int'> 61 <class 'str'> Topography
# <class 'str'> ἐν <class 'int'> 66 <class 'int'> 68 <class 'str'> Topography
# <class 'str'> δεξιοῖς <class 'int'> 74 <class 'int'> 81 <class 'str'> Topography
# <class 'str'> διὰ <class 'int'> 88 <class 'int'> 91 <class 'str'> Topography
# <class 'str'> γίνεται <class 'int'> 113 <class 'int'> 120 <class 'str'> Topography
# <class 'str'> πάλιν <class 'int'> 121 <class 'int'> 126 <class 'str'> Topography
# <class 'str'> ἐν <class 'int'> 172 <class 'int'> 174 <class 'str'> Topography
# <class 'str'> ᾧ <class 'int'> 175 <class 'int'> 176 <class 'str'> Topography
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(3), P(134), L(12)'}
# τείνει δὲ πρῶτον μὲν ἄνω ἀπὸ τῆς καρδίας τῆς μεγάλης φλεβὸς μόριον πρὸς τὸν πλεύμονα καὶ τὴν σύναψιν τῆς ἀορτῆς, ἄσχιστος καὶ μεγάλη οὖσα φλέψ
# καρδίας 33 40 Body Part
# μεγάλης φλεβὸς 45 59 Body Part
# πλεύμονα 76 84 Body Part
# ἀορτῆς 105 111 Body Part
# φλέψ 138 142 Body Part
# ἄσχιστος 113 121 Adjectives/Qualities
# μεγάλη 126 132 Adjectives/Qualities
# τείνει 0 6 Topography
# ἄνω 21 24 Topography
# ἀπὸ 25 28 Topography
# πρὸς 67 71 Topography
# σύναψιν 93 100 Topography
# SpanGroup 'sc' contains 12 spans:
# - Span: 'καρδίας' [33, 40], Labels: Body Part
# - Span: 'μεγάλης φλεβὸς' [45, 59], Labels: Body Part
# - Span: 'πλεύμονα' [76, 84], Labels: Body Part
# - Span: 'ἀορτῆς' [105, 111], Labels: Body Part
# - Span: 'φλέψ' [138, 142], Labels: Body Part
# - Span: 'ἄσχιστος' [113, 121], Labels: Adjectives/Qualities
# - Span: 'μεγάλη' [126, 132], Labels: Adjectives/Qualities
# - Span: 'τείνει' [0, 6], Labels: Topography
# - Span: 'ἄνω' [21, 24], Labels: Topography
# - Span: 'ἀπὸ' [25, 28], Labels: Topography
# - Span: 'πρὸς' [67, 71], Labels: Topography
# - Span: 'σύναψιν' [93, 100], Labels: Topography
# <class 'str'> καρδίας <class 'int'> 33 <class 'int'> 40 <class 'str'> Body Part
# <class 'str'> μεγάλης φλεβὸς <class 'int'> 45 <class 'int'> 59 <class 'str'> Body Part
# <class 'str'> πλεύμονα <class 'int'> 76 <class 'int'> 84 <class 'str'> Body Part
# <class 'str'> ἀορτῆς <class 'int'> 105 <class 'int'> 111 <class 'str'> Body Part
# <class 'str'> φλέψ <class 'int'> 138 <class 'int'> 142 <class 'str'> Body Part
# <class 'str'> ἄσχιστος <class 'int'> 113 <class 'int'> 121 <class 'str'> Adjectives/Qualities
# <class 'str'> μεγάλη <class 'int'> 126 <class 'int'> 132 <class 'str'> Adjectives/Qualities
# <class 'str'> τείνει <class 'int'> 0 <class 'int'> 6 <class 'str'> Topography
# <class 'str'> ἄνω <class 'int'> 21 <class 'int'> 24 <class 'str'> Topography
# <class 'str'> ἀπὸ <class 'int'> 25 <class 'int'> 28 <class 'str'> Topography
# <class 'str'> πρὸς <class 'int'> 67 <class 'int'> 71 <class 'str'> Topography
# <class 'str'> σύναψιν <class 'int'> 93 <class 'int'> 100 <class 'str'> Topography
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(4), P(138), L(7)'}
# τείνουσι δʼ ἀπὸ τε τῆς ἀορτῆς καὶ τῆς μεγάλης φλεβὸς ἀπὸ τῶν σχιζομένων καὶ ἄλλαι, αἱ μὲν ἐπὶ τοὺς βουβῶνας πρῶτον μεγάλαι καὶ κοῖλαι, ἔπειτα διὰ τῶν σκελῶν τελευτῶσιν εἰς τοὺς
# ἀορτῆς 23 29 Body Part
# μεγάλης 38 45 Body Part
# φλεβὸς 46 52 Body Part
# σχιζομένων 61 71 Body Part
# ἄλλαι 76 81 Body Part
# αἱ 83 85 Division
# βουβῶνας 99 107 Body Part
# σκελῶν 150 156 Body Part
# ἄλλαι 76 81 Adjectives/Qualities
# μεγάλαι 115 122 Adjectives/Qualities
# κοῖλαι 127 133 Adjectives/Qualities
# τείνουσι 0 8 Topography
# ἀπὸ 12 15 Topography
# ἀπὸ 53 56 Topography
# ἐπὶ 90 93 Topography
# διὰ 142 145 Topography
# τελευτῶσιν 157 167 Topography
# εἰς 168 171 Topography
# μὲν 86 89 Division
# SpanGroup 'sc' contains 19 spans:
# - Span: 'ἀορτῆς' [23, 29], Labels: Body Part
# - Span: 'μεγάλης' [38, 45], Labels: Body Part
# - Span: 'φλεβὸς' [46, 52], Labels: Body Part
# - Span: 'σχιζομένων' [61, 71], Labels: Body Part
# - Span: 'ἄλλαι' [76, 81], Labels: Body Part
# - Span: 'αἱ' [83, 85], Labels: Division
# - Span: 'βουβῶνας' [99, 107], Labels: Body Part
# - Span: 'σκελῶν' [150, 156], Labels: Body Part
# - Span: 'ἄλλαι' [76, 81], Labels: Adjectives/Qualities
# - Span: 'μεγάλαι' [115, 122], Labels: Adjectives/Qualities
# - Span: 'κοῖλαι' [127, 133], Labels: Adjectives/Qualities
# - Span: 'τείνουσι' [0, 8], Labels: Topography
# - Span: 'ἀπὸ' [12, 15], Labels: Topography
# - Span: 'ἀπὸ' [53, 56], Labels: Topography
# - Span: 'ἐπὶ' [90, 93], Labels: Topography
# - Span: 'διὰ' [142, 145], Labels: Topography
# - Span: 'τελευτῶσιν' [157, 167], Labels: Topography
# - Span: 'εἰς' [168, 171], Labels: Topography
# - Span: 'μὲν' [86, 89], Labels: Division
# <class 'str'> ἀορτῆς <class 'int'> 23 <class 'int'> 29 <class 'str'> Body Part
# <class 'str'> μεγάλης <class 'int'> 38 <class 'int'> 45 <class 'str'> Body Part
# <class 'str'> φλεβὸς <class 'int'> 46 <class 'int'> 52 <class 'str'> Body Part
# <class 'str'> σχιζομένων <class 'int'> 61 <class 'int'> 71 <class 'str'> Body Part
# <class 'str'> ἄλλαι <class 'int'> 76 <class 'int'> 81 <class 'str'> Body Part
# <class 'str'> αἱ <class 'int'> 83 <class 'int'> 85 <class 'str'> Division
# <class 'str'> βουβῶνας <class 'int'> 99 <class 'int'> 107 <class 'str'> Body Part
# <class 'str'> σκελῶν <class 'int'> 150 <class 'int'> 156 <class 'str'> Body Part
# <class 'str'> ἄλλαι <class 'int'> 76 <class 'int'> 81 <class 'str'> Adjectives/Qualities
# <class 'str'> μεγάλαι <class 'int'> 115 <class 'int'> 122 <class 'str'> Adjectives/Qualities
# <class 'str'> κοῖλαι <class 'int'> 127 <class 'int'> 133 <class 'str'> Adjectives/Qualities
# <class 'str'> τείνουσι <class 'int'> 0 <class 'int'> 8 <class 'str'> Topography
# <class 'str'> ἀπὸ <class 'int'> 12 <class 'int'> 15 <class 'str'> Topography
# <class 'str'> ἀπὸ <class 'int'> 53 <class 'int'> 56 <class 'str'> Topography
# <class 'str'> ἐπὶ <class 'int'> 90 <class 'int'> 93 <class 'str'> Topography
# <class 'str'> διὰ <class 'int'> 142 <class 'int'> 145 <class 'str'> Topography
# <class 'str'> τελευτῶσιν <class 'int'> 157 <class 'int'> 167 <class 'str'> Topography
# <class 'str'> εἰς <class 'int'> 168 <class 'int'> 171 <class 'str'> Topography
# <class 'str'> μὲν <class 'int'> 86 <class 'int'> 89 <class 'str'> Division
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(4), P(139), L(25)'}
# ἡ δὲ μεγάλη φλὲψ ἐν πᾶσι μάλιστα διάδηλος, καὶ τοῖς μικροῖς
# μεγάλη 5 11 Body Part
# φλὲψ 12 16 Body Part
# διάδηλος 33 41 Adjectives/Qualities
# μικροῖς 52 59 Medical
# SpanGroup 'sc' contains 4 spans:
# - Span: 'μεγάλη' [5, 11], Labels: Body Part
# - Span: 'φλὲψ' [12, 16], Labels: Body Part
# - Span: 'διάδηλος' [33, 41], Labels: Adjectives/Qualities
# - Span: 'μικροῖς' [52, 59], Labels: Medical
# <class 'str'> μεγάλη <class 'int'> 5 <class 'int'> 11 <class 'str'> Body Part
# <class 'str'> φλὲψ <class 'int'> 12 <class 'int'> 16 <class 'str'> Body Part
# <class 'str'> διάδηλος <class 'int'> 33 <class 'int'> 41 <class 'str'> Adjectives/Qualities
# <class 'str'> μικροῖς <class 'int'> 52 <class 'int'> 59 <class 'str'> Medical
# doc user data:  {'source_info': 'Coda, Aristotle, History of Animals, B(3), C(3), P(135), L(33)'}
# ὑπεράνω δὲ τούτων ἀπὸ τῆς ἐκ τῆς καρδίας τεταμένης πάλιν ἡ ὅλη σχίζεται εἰς δύο τόπους
# καρδίας 33 40 Body Part
# ἡ 57 58 Body Part
# τόπους 80 86 Body Part
# ὅλη 59 62 Adjectives/Qualities
# δύο 76 79 Adjectives/Qualities
# ὑπεράνω 0 7 Topography
# ἀπὸ 18 21 Topography
# ἐκ 26 28 Topography
# τεταμένης 41 50 Topography
# σχίζεται 63 71 Topography
# εἰς 72 75 Topography
# SpanGroup 'sc' contains 11 spans:
# - Span: 'καρδίας' [33, 40], Labels: Body Part
# - Span: 'ἡ' [57, 58], Labels: Body Part
# - Span: 'τόπους' [80, 86], Labels: Body Part
# - Span: 'ὅλη' [59, 62], Labels: Adjectives/Qualities
# - Span: 'δύο' [76, 79], Labels: Adjectives/Qualities
# - Span: 'ὑπεράνω' [0, 7], Labels: Topography
# - Span: 'ἀπὸ' [18, 21], Labels: Topography
# - Span: 'ἐκ' [26, 28], Labels: Topography
# - Span: 'τεταμένης' [41, 50], Labels: Topography
# - Span: 'σχίζεται' [63, 71], Labels: Topography
# - Span: 'εἰς' [72, 75], Labels: Topography
# <class 'str'> καρδίας <class 'int'> 33 <class 'int'> 40 <class 'str'> Body Part
# <class 'str'> ἡ <class 'int'> 57 <class 'int'> 58 <class 'str'> Body Part
# <class 'str'> τόπους <class 'int'> 80 <class 'int'> 86 <class 'str'> Body Part
# <class 'str'> ὅλη <class 'int'> 59 <class 'int'> 62 <class 'str'> Adjectives/Qualities
# <class 'str'> δύο <class 'int'> 76 <class 'int'> 79 <class 'str'> Adjectives/Qualities
# <class 'str'> ὑπεράνω <class 'int'> 0 <class 'int'> 7 <class 'str'> Topography
# <class 'str'> ἀπὸ <class 'int'> 18 <class 'int'> 21 <class 'str'> Topography
# <class 'str'> ἐκ <class 'int'> 26 <class 'int'> 28 <class 'str'> Topography
# <class 'str'> τεταμένης <class 'int'> 41 <class 'int'> 50 <class 'str'> Topography
# <class 'str'> σχίζεται <class 'int'> 63 <class 'int'> 71 <class 'str'> Topography
# <class 'str'> εἰς <class 'int'> 72 <class 'int'> 75 <class 'str'> Topography
# doc user data:  {'source_info': 'Coda, Aristotle, Parts of Animals, B(3), C(14), P(100), L(13)'}
# καὶ γὰρ δέξασθαι τὴν εἰσελθοῦσαν τροφὴν καὶ τὴν ἐξικμασμένην ἀναγκαῖον ἐκπέμψαι,καὶ μὴ τὸν αὐτὸν τόπον εἶναι τῆς τε ἀπέπτου καὶ τοῦ περιττώματος, εἶναί τέ τινα δεῖ τόπον ἐν ᾧ μεταβάλλει
# δέξασθαι 8 16 Physiology
# εἰσελθοῦσαν 21 32 Physiology
# τροφὴν 33 39 Medical
# ἐκπέμψαι 71 79 Physiology
# ἀπέπτου 116 123 Medical
# περιττώματος 132 144 Medical
# ἐν 170 172 Topography
# μεταβάλλει 175 185 Physiology
# SpanGroup 'sc' contains 8 spans:
# - Span: 'δέξασθαι' [8, 16], Labels: Physiology
# - Span: 'εἰσελθοῦσαν' [21, 32], Labels: Physiology
# - Span: 'τροφὴν' [33, 39], Labels: Medical
# - Span: 'ἐκπέμψαι' [71, 79], Labels: Physiology
# - Span: 'ἀπέπτου' [116, 123], Labels: Medical
# - Span: 'περιττώματος' [132, 144], Labels: Medical
# - Span: 'ἐν' [170, 172], Labels: Topography
# - Span: 'μεταβάλλει' [175, 185], Labels: Physiology
# <class 'str'> δέξασθαι <class 'int'> 8 <class 'int'> 16 <class 'str'> Physiology
# <class 'str'> εἰσελθοῦσαν <class 'int'> 21 <class 'int'> 32 <class 'str'> Physiology
# <class 'str'> τροφὴν <class 'int'> 33 <class 'int'> 39 <class 'str'> Medical
# <class 'str'> ἐκπέμψαι <class 'int'> 71 <class 'int'> 79 <class 'str'> Physiology
# <class 'str'> ἀπέπτου <class 'int'> 116 <class 'int'> 123 <class 'str'> Medical
# <class 'str'> περιττώματος <class 'int'> 132 <class 'int'> 144 <class 'str'> Medical
# <class 'str'> ἐν <class 'int'> 170 <class 'int'> 172 <class 'str'> Topography
# <class 'str'> μεταβάλλει <class 'int'> 175 <class 'int'> 185 <class 'str'> Physiology
# doc user data:  {'source_info': 'Coda, Aristotle, Parts of Animals, B(3), C(13), P(104), L(29)'}
# ἐπεὶ δʼ ἐν τῇ ἄνω μὲν κοιλίᾳ κατὰ τὴν πρώτην εἴσοδον τῆς τροφῆς νεαρὰν ἀναγκαῖον εἶναι τὴν τροφήν, κάτω δὲ προϊοῦσαν κοπρώδη καὶ ἐξικμασμένην, ἀναγκαῖον εἶναί τι καὶ τὸ μεταξύ, ἐν ᾧ μεταβάλλει καὶ οὔτʼ ἔτι πρόσφατος οὔτʼ ἤδη κόπρος
# ἐν 8 10 Topography
# ἄνω μὲν κοιλίᾳ 14 28 Body Part
# ἄνω μὲν κοιλίᾳ 14 28 Technical Appellation
# μὲν 18 21 Symmetry/Opposition
# εἴσοδον 45 52 Physiology
# κάτω 99 103 Body Part
# δὲ 104 106 Symmetry/Opposition
# προϊοῦσαν 107 116 Physiology
# μεταξύ 169 175 Topography
# ἐν 177 179 Topography
# μεταβάλλει 182 192 Physiology
# SpanGroup 'sc' contains 11 spans:
# - Span: 'ἐν' [8, 10], Labels: Topography
# - Span: 'ἄνω μὲν κοιλίᾳ' [14, 28], Labels: Body Part
# - Span: 'ἄνω μὲν κοιλίᾳ' [14, 28], Labels: Technical Appellation
# - Span: 'μὲν' [18, 21], Labels: Symmetry/Opposition
# - Span: 'εἴσοδον' [45, 52], Labels: Physiology
# - Span: 'κάτω' [99, 103], Labels: Body Part
# - Span: 'δὲ' [104, 106], Labels: Symmetry/Opposition
# - Span: 'προϊοῦσαν' [107, 116], Labels: Physiology
# - Span: 'μεταξύ' [169, 175], Labels: Topography
# - Span: 'ἐν' [177, 179], Labels: Topography
# - Span: 'μεταβάλλει' [182, 192], Labels: Physiology
# <class 'str'> ἐν <class 'int'> 8 <class 'int'> 10 <class 'str'> Topography
# <class 'str'> ἄνω μὲν κοιλίᾳ <class 'int'> 14 <class 'int'> 28 <class 'str'> Body Part
# <class 'str'> ἄνω μὲν κοιλίᾳ <class 'int'> 14 <class 'int'> 28 <class 'str'> Technical Appellation
# <class 'str'> μὲν <class 'int'> 18 <class 'int'> 21 <class 'str'> Symmetry/Opposition
# <class 'str'> εἴσοδον <class 'int'> 45 <class 'int'> 52 <class 'str'> Physiology
# <class 'str'> κάτω <class 'int'> 99 <class 'int'> 103 <class 'str'> Body Part
# <class 'str'> δὲ <class 'int'> 104 <class 'int'> 106 <class 'str'> Symmetry/Opposition
# <class 'str'> προϊοῦσαν <class 'int'> 107 <class 'int'> 116 <class 'str'> Physiology
# <class 'str'> μεταξύ <class 'int'> 169 <class 'int'> 175 <class 'str'> Topography
# <class 'str'> ἐν <class 'int'> 177 <class 'int'> 179 <class 'str'> Topography
# <class 'str'> μεταβάλλει <class 'int'> 182 <class 'int'> 192 <class 'str'> Physiology
# doc user data:  {'source_info': 'Coda, Aristotle, Parts of Animals, B(3), C(13), P(105), L(36)'}
# τοῦτο γὰρ μεταξὺ τῆς τʼ ἄνω, ἐν ᾗ τὸ ἄπεπτον, καὶ τῆς κάτω, ἐν ᾗ τὸ ἄχρηστον ἤδη περίττωμα
# μεταξὺ 10 16 Topography
# ἄνω 24 27 Body Part
# ἐν 29 31 Topography
# κάτω 54 58 Body Part
# ἐν 60 62 Topography
# SpanGroup 'sc' contains 5 spans:
# - Span: 'μεταξὺ' [10, 16], Labels: Topography
# - Span: 'ἄνω' [24, 27], Labels: Body Part
# - Span: 'ἐν' [29, 31], Labels: Topography
# - Span: 'κάτω' [54, 58], Labels: Body Part
# - Span: 'ἐν' [60, 62], Labels: Topography
# <class 'str'> μεταξὺ <class 'int'> 10 <class 'int'> 16 <class 'str'> Topography
# <class 'str'> ἄνω <class 'int'> 24 <class 'int'> 27 <class 'str'> Body Part
# <class 'str'> ἐν <class 'int'> 29 <class 'int'> 31 <class 'str'> Topography
# <class 'str'> κάτω <class 'int'> 54 <class 'int'> 58 <class 'str'> Body Part
# <class 'str'> ἐν <class 'int'> 60 <class 'int'> 62 <class 'str'> Topography
# doc user data:  {'source_info': 'Coda, Hippocrates, Sacred Disease, C(3), S(5), P(12), L(7)'}
# διατέταται δὲ καὶ ἀπὸ τοῦ σπληνὸς φλὲψ ἐς τὰ ἀριστερὰ καὶ κάτω καὶ ἄνω, ὥσπερ καὶ ἀπὸ τοῦ ἥπατος, λεπτοτέρη δὲ καὶ ἀσθενεστέρη
# διατέταται 0 10 Topography
# ἀπὸ 18 21 Topography
# σπληνὸς 26 33 Body Part
# φλὲψ 34 38 Body Part
# ἀριστερὰ 45 53 Topography
# κάτω 58 62 Topography
# ἄνω 67 70 Topography
# ἀπὸ 82 85 Topography
# ἥπατος 90 96 Body Part
# λεπτοτέρη 98 107 Adjectives/Qualities
# ἀσθενεστέρη 115 126 Adjectives/Qualities
# SpanGroup 'sc' contains 11 spans:
# - Span: 'διατέταται' [0, 10], Labels: Topography
# - Span: 'ἀπὸ' [18, 21], Labels: Topography
# - Span: 'σπληνὸς' [26, 33], Labels: Body Part
# - Span: 'φλὲψ' [34, 38], Labels: Body Part
# - Span: 'ἀριστερὰ' [45, 53], Labels: Topography
# - Span: 'κάτω' [58, 62], Labels: Topography
# - Span: 'ἄνω' [67, 70], Labels: Topography
# - Span: 'ἀπὸ' [82, 85], Labels: Topography
# - Span: 'ἥπατος' [90, 96], Labels: Body Part
# - Span: 'λεπτοτέρη' [98, 107], Labels: Adjectives/Qualities
# - Span: 'ἀσθενεστέρη' [115, 126], Labels: Adjectives/Qualities
# <class 'str'> διατέταται <class 'int'> 0 <class 'int'> 10 <class 'str'> Topography
# <class 'str'> ἀπὸ <class 'int'> 18 <class 'int'> 21 <class 'str'> Topography
# <class 'str'> σπληνὸς <class 'int'> 26 <class 'int'> 33 <class 'str'> Body Part
# <class 'str'> φλὲψ <class 'int'> 34 <class 'int'> 38 <class 'str'> Body Part
# <class 'str'> ἀριστερὰ <class 'int'> 45 <class 'int'> 53 <class 'str'> Topography
# <class 'str'> κάτω <class 'int'> 58 <class 'int'> 62 <class 'str'> Topography
# <class 'str'> ἄνω <class 'int'> 67 <class 'int'> 70 <class 'str'> Topography
# <class 'str'> ἀπὸ <class 'int'> 82 <class 'int'> 85 <class 'str'> Topography
# <class 'str'> ἥπατος <class 'int'> 90 <class 'int'> 96 <class 'str'> Body Part
# <class 'str'> λεπτοτέρη <class 'int'> 98 <class 'int'> 107 <class 'str'> Adjectives/Qualities
# <class 'str'> ἀσθενεστέρη <class 'int'> 115 <class 'int'> 126 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Coda, Hippocrates, Sacred Disease, C(8), S(3), P(17), L(17)'}
# ἀσθενέστερα μέντοι ὁμοίως τὰ μέλεα εἰκὸς εἶναι, τῶν φλεβῶν κακωθεισέων
# μέλεα 29 34 Body Part
# φλεβῶν 52 58 Body Part
# SpanGroup 'sc' contains 2 spans:
# - Span: 'μέλεα' [29, 34], Labels: Body Part
# - Span: 'φλεβῶν' [52, 58], Labels: Body Part
# <class 'str'> μέλεα <class 'int'> 29 <class 'int'> 34 <class 'str'> Body Part
# <class 'str'> φλεβῶν <class 'int'> 52 <class 'int'> 58 <class 'str'> Body Part
# doc user data:  {'source_info': 'Coda, Hippocrates, Sacred Disease, C(10), S(5), P(20), L(17)'}
# κίνδυνος δὲ πολὺς καὶ ἦρος παθέειν τωὐτὸ τοῦτο, ἢν ἡλιωθῇ ἡ κεφαλή, τὸ δὲ θέρες ἥκιστα, οὐ γὰρ γίνονται μεταβολαὶ ἐξαπιναῖοι
# κεφαλή 60 66 Body Part
# SpanGroup 'sc' contains 1 spans:
# - Span: 'κεφαλή' [60, 66], Labels: Body Part
# <class 'str'> κεφαλή <class 'int'> 60 <class 'int'> 66 <class 'str'> Body Part
# doc user data:  {'source_info': 'Aristotle_Historia_Animalium_511a22-34'}
# ἔτι δὲ διαφορὰ καὶ ἥδε πρὸς ἀλλήλας ἐστὶ τῶν ὑστερῶν.
# ὑστερῶν 45 52 Body Part
# SpanGroup 'sc' contains 1 spans:
# - Span: 'ὑστερῶν' [45, 52], Labels: Body Part
# <class 'str'> ὑστερῶν <class 'int'> 45 <class 'int'> 52 <class 'str'> Body Part
# doc user data:  {'source_info': 'Aristotle_Historia_Animalium_496b34-497a18'}
# ἐν πᾶσι δʼ ἔχει ὁμοίως τοῖς ἄλλοις καὶ τοῦτο.
# ὁμοίως 16 22 Adjectives/Qualities
# SpanGroup 'sc' contains 1 spans:
# - Span: 'ὁμοίως' [16, 22], Labels: Adjectives/Qualities
# <class 'str'> ὁμοίως <class 'int'> 16 <class 'int'> 22 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Aristotle_Historia_Animalium_496b34-497a18'}
# ἐκ δὲ τοῦ κοίλου τῶν νεφρῶν φέρουσιν εἰς τὴν κύστιν πόροι δύο νεανικοί, καὶ ἄλλοι ἐκ τῆς ἀορτῆς ἰσχυροὶ καὶ συνεχεῖς.
# ἐκ 0 2 Topography
# κοίλου 10 16 Body Part
# νεφρῶν 21 27 Body Part
# εἰς 37 40 Topography
# κύστιν 45 51 Body Part
# πόροι 52 57 Body Part
# δύο 58 61 Adjectives/Qualities
# νεανικοί 62 70 Adjectives/Qualities
# ἐκ 82 84 Topography
# ἀορτῆς 89 95 Body Part
# ἰσχυροὶ 96 103 Adjectives/Qualities
# συνεχεῖς. 108 117 Adjectives/Qualities
# SpanGroup 'sc' contains 12 spans:
# - Span: 'ἐκ' [0, 2], Labels: Topography
# - Span: 'κοίλου' [10, 16], Labels: Body Part
# - Span: 'νεφρῶν' [21, 27], Labels: Body Part
# - Span: 'εἰς' [37, 40], Labels: Topography
# - Span: 'κύστιν' [45, 51], Labels: Body Part
# - Span: 'πόροι' [52, 57], Labels: Body Part
# - Span: 'δύο' [58, 61], Labels: Adjectives/Qualities
# - Span: 'νεανικοί' [62, 70], Labels: Adjectives/Qualities
# - Span: 'ἐκ' [82, 84], Labels: Topography
# - Span: 'ἀορτῆς' [89, 95], Labels: Body Part
# - Span: 'ἰσχυροὶ' [96, 103], Labels: Adjectives/Qualities
# - Span: 'συνεχεῖς.' [108, 117], Labels: Adjectives/Qualities
# <class 'str'> ἐκ <class 'int'> 0 <class 'int'> 2 <class 'str'> Topography
# <class 'str'> κοίλου <class 'int'> 10 <class 'int'> 16 <class 'str'> Body Part
# <class 'str'> νεφρῶν <class 'int'> 21 <class 'int'> 27 <class 'str'> Body Part
# <class 'str'> εἰς <class 'int'> 37 <class 'int'> 40 <class 'str'> Topography
# <class 'str'> κύστιν <class 'int'> 45 <class 'int'> 51 <class 'str'> Body Part
# <class 'str'> πόροι <class 'int'> 52 <class 'int'> 57 <class 'str'> Body Part
# <class 'str'> δύο <class 'int'> 58 <class 'int'> 61 <class 'str'> Adjectives/Qualities
# <class 'str'> νεανικοί <class 'int'> 62 <class 'int'> 70 <class 'str'> Adjectives/Qualities
# <class 'str'> ἐκ <class 'int'> 82 <class 'int'> 84 <class 'str'> Topography
# <class 'str'> ἀορτῆς <class 'int'> 89 <class 'int'> 95 <class 'str'> Body Part
# <class 'str'> ἰσχυροὶ <class 'int'> 96 <class 'int'> 103 <class 'str'> Adjectives/Qualities
# <class 'str'> συνεχεῖς. <class 'int'> 108 <class 'int'> 117 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Aristotle, History of Animals, 3.7, p. 142-143 Balme ready'}
# οὐδὲν γὰρ ἔχει ζῷον ὀστοῦν περὶ τὴν κοιλίαν.
# ἔχει 10 14 Topography
# ζῷον 15 19 Body Part
# ὀστοῦν 20 26 Body Part
# περὶ 27 31 Topography
# κοιλίαν 36 43 Body Part
# SpanGroup 'sc' contains 5 spans:
# - Span: 'ἔχει' [10, 14], Labels: Topography
# - Span: 'ζῷον' [15, 19], Labels: Body Part
# - Span: 'ὀστοῦν' [20, 26], Labels: Body Part
# - Span: 'περὶ' [27, 31], Labels: Topography
# - Span: 'κοιλίαν' [36, 43], Labels: Body Part
# <class 'str'> ἔχει <class 'int'> 10 <class 'int'> 14 <class 'str'> Topography
# <class 'str'> ζῷον <class 'int'> 15 <class 'int'> 19 <class 'str'> Body Part
# <class 'str'> ὀστοῦν <class 'int'> 20 <class 'int'> 26 <class 'str'> Body Part
# <class 'str'> περὶ <class 'int'> 27 <class 'int'> 31 <class 'str'> Topography
# <class 'str'> κοιλίαν <class 'int'> 36 <class 'int'> 43 <class 'str'> Body Part
# doc user data:  {'source_info': 'Aristotle_Historia_Animalium_510b5-20'}
# ὅσα μὲν οὖν ἐστι ζῳοτόκα καὶ δίποδα ἢ τετράποδα, τούτων μὲν ἡ ὑστέρα πάντων ἐστὶ κάτω τοῦ ὑποζώματος, οἷον ἀνθρώπῳ καὶ κυνὶ καὶ ὑῒ καὶ ἵππῳ καὶ βοΐ·
# ὅσα 0 3 Adjectives/Qualities
# ζῳοτόκα 17 24 Adjectives/Qualities
# δίποδα 29 35 Adjectives/Qualities
# τετράποδα 38 47 Adjectives/Qualities
# ὑστέρα 62 68 Body Part
# πάντων 69 75 Adjectives/Qualities
# κάτω 81 85 Topography
# ὑποζώματος 90 100 Body Part
# οἷον 102 106 Adjectives/Qualities
# SpanGroup 'sc' contains 9 spans:
# - Span: 'ὅσα' [0, 3], Labels: Adjectives/Qualities
# - Span: 'ζῳοτόκα' [17, 24], Labels: Adjectives/Qualities
# - Span: 'δίποδα' [29, 35], Labels: Adjectives/Qualities
# - Span: 'τετράποδα' [38, 47], Labels: Adjectives/Qualities
# - Span: 'ὑστέρα' [62, 68], Labels: Body Part
# - Span: 'πάντων' [69, 75], Labels: Adjectives/Qualities
# - Span: 'κάτω' [81, 85], Labels: Topography
# - Span: 'ὑποζώματος' [90, 100], Labels: Body Part
# - Span: 'οἷον' [102, 106], Labels: Adjectives/Qualities
# <class 'str'> ὅσα <class 'int'> 0 <class 'int'> 3 <class 'str'> Adjectives/Qualities
# <class 'str'> ζῳοτόκα <class 'int'> 17 <class 'int'> 24 <class 'str'> Adjectives/Qualities
# <class 'str'> δίποδα <class 'int'> 29 <class 'int'> 35 <class 'str'> Adjectives/Qualities
# <class 'str'> τετράποδα <class 'int'> 38 <class 'int'> 47 <class 'str'> Adjectives/Qualities
# <class 'str'> ὑστέρα <class 'int'> 62 <class 'int'> 68 <class 'str'> Body Part
# <class 'str'> πάντων <class 'int'> 69 <class 'int'> 75 <class 'str'> Adjectives/Qualities
# <class 'str'> κάτω <class 'int'> 81 <class 'int'> 85 <class 'str'> Topography
# <class 'str'> ὑποζώματος <class 'int'> 90 <class 'int'> 100 <class 'str'> Body Part
# <class 'str'> οἷον <class 'int'> 102 <class 'int'> 106 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Gal. AA. 5, 7, 313, 28 - 315, 19'}
# κατʼ αὐτὸ δὲ τοῦτο καὶ τοῦ διαστήματός ἐστι τὸ μέσον, ὃ διέστηκεν ή κορυφή τοῦ ξιφοειδούς χόνδρου τῆς συμβολῆς τῶν τῆς ἥβης ὀτῶν.
# τὸ μέσον 44 52 Topography
# κορυφή 68 74 Topography
# τοῦ ξιφοειδούς χόνδρου 75 97 Medical
# τῆς συμβολῆς τῶν τῆς ἥβης ὀτῶν 98 128 Medical
# SpanGroup 'sc' contains 4 spans:
# - Span: 'τὸ μέσον' [44, 52], Labels: Topography
# - Span: 'κορυφή' [68, 74], Labels: Topography
# - Span: 'τοῦ ξιφοειδούς χόνδρου' [75, 97], Labels: Medical
# - Span: 'τῆς συμβολῆς τῶν τῆς ἥβης ὀτῶν' [98, 128], Labels: Medical
# <class 'str'> τὸ μέσον <class 'int'> 44 <class 'int'> 52 <class 'str'> Topography
# <class 'str'> κορυφή <class 'int'> 68 <class 'int'> 74 <class 'str'> Topography
# <class 'str'> τοῦ ξιφοειδούς χόνδρου <class 'int'> 75 <class 'int'> 97 <class 'str'> Medical
# <class 'str'> τῆς συμβολῆς τῶν τῆς ἥβης ὀτῶν <class 'int'> 98 <class 'int'> 128 <class 'str'> Medical
# doc user data:  {'source_info': 'Gal. AA. 5, 7, 313, 28 - 315, 19'}
# οἱ γάρτοι μύες οἱ σαρκώδεις, οὓς ὀρθοὺς ὀλίγον ἔμπροσθεν ὠνόμαζον, ὑπὸ τῆς εἰρημένης διορίζονται γραμμῆς, ἥτις εἰκότως ἐστὶ λευκοτέρα τῶν πέριξ, οὐδεμιᾶς ὑποκειμένης αὐτῇ σαρκός.
# μύες 10 14 Body Part
# σαρκώδεις 18 27 Adjectives/Qualities
# ὀρθοὺς 33 39 Adjectives/Qualities
# λευκοτέρα 124 133 Adjectives/Qualities
# πέριξ 138 143 Topography
# ὑποκειμένης 154 165 Topography
# σαρκός 171 177 Body Part
# SpanGroup 'sc' contains 7 spans:
# - Span: 'μύες' [10, 14], Labels: Body Part
# - Span: 'σαρκώδεις' [18, 27], Labels: Adjectives/Qualities
# - Span: 'ὀρθοὺς' [33, 39], Labels: Adjectives/Qualities
# - Span: 'λευκοτέρα' [124, 133], Labels: Adjectives/Qualities
# - Span: 'πέριξ' [138, 143], Labels: Topography
# - Span: 'ὑποκειμένης' [154, 165], Labels: Topography
# - Span: 'σαρκός' [171, 177], Labels: Body Part
# <class 'str'> μύες <class 'int'> 10 <class 'int'> 14 <class 'str'> Body Part
# <class 'str'> σαρκώδεις <class 'int'> 18 <class 'int'> 27 <class 'str'> Adjectives/Qualities
# <class 'str'> ὀρθοὺς <class 'int'> 33 <class 'int'> 39 <class 'str'> Adjectives/Qualities
# <class 'str'> λευκοτέρα <class 'int'> 124 <class 'int'> 133 <class 'str'> Adjectives/Qualities
# <class 'str'> πέριξ <class 'int'> 138 <class 'int'> 143 <class 'str'> Topography
# <class 'str'> ὑποκειμένης <class 'int'> 154 <class 'int'> 165 <class 'str'> Topography
# <class 'str'> σαρκός <class 'int'> 171 <class 'int'> 177 <class 'str'> Body Part
# doc user data:  {'source_info': 'Aristotle, History of Animals, 1.7, pp. 68-69 Balme skull'}
# κεφαλῆς μὲν οὖν μέρη τὸ μὲν τριχωτὸν κρανίον καλεῖται.
# κεφαλῆς 0 7 Body Part
# μέρη 16 20 Body Part
# τριχωτὸν 28 36 Adjectives/Qualities
# κρανίον 37 44 Body Part
# καλεῖται 45 53 Technical Appellation
# SpanGroup 'sc' contains 5 spans:
# - Span: 'κεφαλῆς' [0, 7], Labels: Body Part
# - Span: 'μέρη' [16, 20], Labels: Body Part
# - Span: 'τριχωτὸν' [28, 36], Labels: Adjectives/Qualities
# - Span: 'κρανίον' [37, 44], Labels: Body Part
# - Span: 'καλεῖται' [45, 53], Labels: Technical Appellation
# <class 'str'> κεφαλῆς <class 'int'> 0 <class 'int'> 7 <class 'str'> Body Part
# <class 'str'> μέρη <class 'int'> 16 <class 'int'> 20 <class 'str'> Body Part
# <class 'str'> τριχωτὸν <class 'int'> 28 <class 'int'> 36 <class 'str'> Adjectives/Qualities
# <class 'str'> κρανίον <class 'int'> 37 <class 'int'> 44 <class 'str'> Body Part
# <class 'str'> καλεῖται <class 'int'> 45 <class 'int'> 53 <class 'str'> Technical Appellation
# doc user data:  {'source_info': 'Aristotle, History of Animals, 3.7, p. 141-142 Balme'}
# τὰ δʼ ὀστᾶ τοῖς ζῴοις ἀφʼ ἑνὸς πάντα συνήρτηται καὶ συνεχῆ ἐστιν ἀλλήλοις ὥσπερ αἱ φλέβες·
# ὀστᾶ 6 10 Body Part
# ἀφʼ 22 25 Topography
# συνήρτηται 37 47 Topography
# συνεχῆ 52 58 Adjectives/Qualities
# φλέβες 83 89 Body Part
# SpanGroup 'sc' contains 5 spans:
# - Span: 'ὀστᾶ' [6, 10], Labels: Body Part
# - Span: 'ἀφʼ' [22, 25], Labels: Topography
# - Span: 'συνήρτηται' [37, 47], Labels: Topography
# - Span: 'συνεχῆ' [52, 58], Labels: Adjectives/Qualities
# - Span: 'φλέβες' [83, 89], Labels: Body Part
# <class 'str'> ὀστᾶ <class 'int'> 6 <class 'int'> 10 <class 'str'> Body Part
# <class 'str'> ἀφʼ <class 'int'> 22 <class 'int'> 25 <class 'str'> Topography
# <class 'str'> συνήρτηται <class 'int'> 37 <class 'int'> 47 <class 'str'> Topography
# <class 'str'> συνεχῆ <class 'int'> 52 <class 'int'> 58 <class 'str'> Adjectives/Qualities
# <class 'str'> φλέβες <class 'int'> 83 <class 'int'> 89 <class 'str'> Body Part
# doc user data:  {'source_info': 'Gal. AA. 5, 7, 321, 8-23'}
# τοὺς μέντοι λοιποὺς τρεῖς μῦς ἀποτέμνειν οἷόν τέ σοι καὶ χωρὶς τοῦ γυμνώσαι τι τῶν ὑπερκειμένων.
# μῦς 26 29 Body Part
# ἀποτέμνειν 30 40 Action Verbs
# γυμνώσαι 67 75 Action Verbs
# ὑπερκειμένων 83 95 Topography
# SpanGroup 'sc' contains 4 spans:
# - Span: 'μῦς' [26, 29], Labels: Body Part
# - Span: 'ἀποτέμνειν' [30, 40], Labels: Action Verbs
# - Span: 'γυμνώσαι' [67, 75], Labels: Action Verbs
# - Span: 'ὑπερκειμένων' [83, 95], Labels: Topography
# <class 'str'> μῦς <class 'int'> 26 <class 'int'> 29 <class 'str'> Body Part
# <class 'str'> ἀποτέμνειν <class 'int'> 30 <class 'int'> 40 <class 'str'> Action Verbs
# <class 'str'> γυμνώσαι <class 'int'> 67 <class 'int'> 75 <class 'str'> Action Verbs
# <class 'str'> ὑπερκειμένων <class 'int'> 83 <class 'int'> 95 <class 'str'> Topography
# doc user data:  {'source_info': 'Gal. AA. 5, 7, 321, 8-23'}
# ὥσπερ γὰρ τὸν πρῶτον, ἀπὸ τοῦ τένοντος ἀρξάμενος ἄχρι τῆς ἄνωθεν ἐκφύσεως ἀνέτεμες, ἀκολουθήσας τῇ συνεχείᾳ τῶν ἰνῶν, οὕτως καὶ τὸν δεύτερον ἀνατεμεῖς, ἀπὸ τοῦ τένοντος μὲν πρῶτον ἐπὶ τὰς ἶναι αὐτοῦ μεταβάς, ἐφεξῆς δὲ τὸ συνεχὲς ἐκείνων φυλάξας ἄχρι τῆς ἐκφύσεως, ἣν ὀλίγον ἔμπροσθεν εἶπον.
# τένοντος 30 38 Body Part
# ἄνωθεν 58 64 Topography
# ἐκφύσεως 65 73 Body Part
# ἀνέτεμες 74 82 Action Verbs
# ἀκολουθήσας 84 95 Action Verbs
# ἰνῶν 112 116 Body Part
# ἀνατεμεῖς 141 150 Action Verbs
# τένοντος 160 168 Body Part
# ἶναι 188 192 Body Part
# μεταβάς 199 206 Action Verbs
# φυλάξας 237 244 Action Verbs
# ἐκφύσεως 254 262 Body Part
# SpanGroup 'sc' contains 12 spans:
# - Span: 'τένοντος' [30, 38], Labels: Body Part
# - Span: 'ἄνωθεν' [58, 64], Labels: Topography
# - Span: 'ἐκφύσεως' [65, 73], Labels: Body Part
# - Span: 'ἀνέτεμες' [74, 82], Labels: Action Verbs
# - Span: 'ἀκολουθήσας' [84, 95], Labels: Action Verbs
# - Span: 'ἰνῶν' [112, 116], Labels: Body Part
# - Span: 'ἀνατεμεῖς' [141, 150], Labels: Action Verbs
# - Span: 'τένοντος' [160, 168], Labels: Body Part
# - Span: 'ἶναι' [188, 192], Labels: Body Part
# - Span: 'μεταβάς' [199, 206], Labels: Action Verbs
# - Span: 'φυλάξας' [237, 244], Labels: Action Verbs
# - Span: 'ἐκφύσεως' [254, 262], Labels: Body Part
# <class 'str'> τένοντος <class 'int'> 30 <class 'int'> 38 <class 'str'> Body Part
# <class 'str'> ἄνωθεν <class 'int'> 58 <class 'int'> 64 <class 'str'> Topography
# <class 'str'> ἐκφύσεως <class 'int'> 65 <class 'int'> 73 <class 'str'> Body Part
# <class 'str'> ἀνέτεμες <class 'int'> 74 <class 'int'> 82 <class 'str'> Action Verbs
# <class 'str'> ἀκολουθήσας <class 'int'> 84 <class 'int'> 95 <class 'str'> Action Verbs
# <class 'str'> ἰνῶν <class 'int'> 112 <class 'int'> 116 <class 'str'> Body Part
# <class 'str'> ἀνατεμεῖς <class 'int'> 141 <class 'int'> 150 <class 'str'> Action Verbs
# <class 'str'> τένοντος <class 'int'> 160 <class 'int'> 168 <class 'str'> Body Part
# <class 'str'> ἶναι <class 'int'> 188 <class 'int'> 192 <class 'str'> Body Part
# <class 'str'> μεταβάς <class 'int'> 199 <class 'int'> 206 <class 'str'> Action Verbs
# <class 'str'> φυλάξας <class 'int'> 237 <class 'int'> 244 <class 'str'> Action Verbs
# <class 'str'> ἐκφύσεως <class 'int'> 254 <class 'int'> 262 <class 'str'> Body Part
# doc user data:  {'source_info': 'hippocrates places in man 6.9-10'}
# πρὸς δὲ τὸν πόδα ἡ κνήμη κατὰ τὰ σφυρὰ ἄρθρον ἔχει, καὶ ἄλλο κατώτερον τῶν σφυρῶν, καὶ ἐν τοῖσι ποσὶν ἄρθρα πολλά, ὥσπερ καὶ ἐν τῇσι χερσίν·
# πρὸς 0 4 Topography
# πόδα 12 16 Body Part
# κνήμη 19 24 Body Part
# σφυρὰ 33 38 Body Part
# ἄρθρον 39 45 Body Part
# κατώτερον 61 70 Topography
# σφυρῶν 75 81 Body Part
# ἄρθρα 102 107 Body Part
# χερσίν 133 139 Topography
# SpanGroup 'sc' contains 9 spans:
# - Span: 'πρὸς' [0, 4], Labels: Topography
# - Span: 'πόδα' [12, 16], Labels: Body Part
# - Span: 'κνήμη' [19, 24], Labels: Body Part
# - Span: 'σφυρὰ' [33, 38], Labels: Body Part
# - Span: 'ἄρθρον' [39, 45], Labels: Body Part
# - Span: 'κατώτερον' [61, 70], Labels: Topography
# - Span: 'σφυρῶν' [75, 81], Labels: Body Part
# - Span: 'ἄρθρα' [102, 107], Labels: Body Part
# - Span: 'χερσίν' [133, 139], Labels: Topography
# <class 'str'> πρὸς <class 'int'> 0 <class 'int'> 4 <class 'str'> Topography
# <class 'str'> πόδα <class 'int'> 12 <class 'int'> 16 <class 'str'> Body Part
# <class 'str'> κνήμη <class 'int'> 19 <class 'int'> 24 <class 'str'> Body Part
# <class 'str'> σφυρὰ <class 'int'> 33 <class 'int'> 38 <class 'str'> Body Part
# <class 'str'> ἄρθρον <class 'int'> 39 <class 'int'> 45 <class 'str'> Body Part
# <class 'str'> κατώτερον <class 'int'> 61 <class 'int'> 70 <class 'str'> Topography
# <class 'str'> σφυρῶν <class 'int'> 75 <class 'int'> 81 <class 'str'> Body Part
# <class 'str'> ἄρθρα <class 'int'> 102 <class 'int'> 107 <class 'str'> Body Part
# <class 'str'> χερσίν <class 'int'> 133 <class 'int'> 139 <class 'str'> Topography
# doc user data:  {'source_info': 'hippocrates places in man 6.1-2'}
# αἱ μὲν τέσσερας έχουσαι, κατὰ τὰ ὦτα ἑκατέρωθεν ραφή, άλλη έμπροσθεν, ἄλλη ἐξόπισθεν τῆς κεφαλῆς, οὕτω μὲν ἡ τὰς τέσσερας ἔχουσα·
# κατὰ 25 29 Topography
# ὦτα 33 36 Body Part
# ἑκατέρωθεν 37 47 Topography
# ραφή 48 52 Body Part
# έμπροσθεν 59 68 Topography
# ἐξόπισθεν 75 84 Topography
# κεφαλῆς 89 96 Body Part
# SpanGroup 'sc' contains 7 spans:
# - Span: 'κατὰ' [25, 29], Labels: Topography
# - Span: 'ὦτα' [33, 36], Labels: Body Part
# - Span: 'ἑκατέρωθεν' [37, 47], Labels: Topography
# - Span: 'ραφή' [48, 52], Labels: Body Part
# - Span: 'έμπροσθεν' [59, 68], Labels: Topography
# - Span: 'ἐξόπισθεν' [75, 84], Labels: Topography
# - Span: 'κεφαλῆς' [89, 96], Labels: Body Part
# <class 'str'> κατὰ <class 'int'> 25 <class 'int'> 29 <class 'str'> Topography
# <class 'str'> ὦτα <class 'int'> 33 <class 'int'> 36 <class 'str'> Body Part
# <class 'str'> ἑκατέρωθεν <class 'int'> 37 <class 'int'> 47 <class 'str'> Topography
# <class 'str'> ραφή <class 'int'> 48 <class 'int'> 52 <class 'str'> Body Part
# <class 'str'> έμπροσθεν <class 'int'> 59 <class 'int'> 68 <class 'str'> Topography
# <class 'str'> ἐξόπισθεν <class 'int'> 75 <class 'int'> 84 <class 'str'> Topography
# <class 'str'> κεφαλῆς <class 'int'> 89 <class 'int'> 96 <class 'str'> Body Part
# doc user data:  {'source_info': 'Gal. AA. 5, 7, 319, 21 - 321, 8'}
# ἀλλʼ ὅταν γʼ ἱκανῶς ᾖς γεγυμνασμένος ἐν οἷς εἶπον, ἐπιχείρησον εὐθὺς ἐξ ἀρχῆς μετὰ τὴν εὐθεῖαν τομὴν ἀποχωρίζειν τῶν ὀρθίων μυῶν πρῶτον μὲν τὸν ἐπιπολῆς τένοντα τοῦ μεγίστου μυός, ἔπειτʼ ἐφεξῆς τὸν ὑπʼ αὐτῷ δεύτερον, ὃς ἀπὸ τοῦ δευτέρου φύεται.
# γεγυμνασμένος 23 36 Action Verbs
# ἀποχωρίζειν 101 112 Action Verbs
# ὀρθίων μυῶν 117 128 Medical
# ἐπιπολῆς 144 152 Topography
# τένοντα 153 160 Body Part
# μεγίστου 165 173 Adjectives/Qualities
# μυός 174 178 Body Part
# ὑπʼ 198 201 Topography
# SpanGroup 'sc' contains 8 spans:
# - Span: 'γεγυμνασμένος' [23, 36], Labels: Action Verbs
# - Span: 'ἀποχωρίζειν' [101, 112], Labels: Action Verbs
# - Span: 'ὀρθίων μυῶν' [117, 128], Labels: Medical
# - Span: 'ἐπιπολῆς' [144, 152], Labels: Topography
# - Span: 'τένοντα' [153, 160], Labels: Body Part
# - Span: 'μεγίστου' [165, 173], Labels: Adjectives/Qualities
# - Span: 'μυός' [174, 178], Labels: Body Part
# - Span: 'ὑπʼ' [198, 201], Labels: Topography
# <class 'str'> γεγυμνασμένος <class 'int'> 23 <class 'int'> 36 <class 'str'> Action Verbs
# <class 'str'> ἀποχωρίζειν <class 'int'> 101 <class 'int'> 112 <class 'str'> Action Verbs
# ...
# <class 'str'> ἐγκέφαλον <class 'int'> 137 <class 'int'> 146 <class 'str'> Body Part
# <class 'str'> περιτεταμένης <class 'int'> 147 <class 'int'> 160 <class 'str'> Body Part
# doc user data:  {'source_info': 'On Anatomy (2)'}
# ἀπὸ δὲ τῆς καρδίης ἐς ἧπαρ βρογχίη πολλὴ καθήκει, καὶ μετὰ βρογχίης φλὲψ μεγάλη καλευμένη, διʼ ἧς οὖλον τὸ σκῆνος τρέφεται.
# καρδίης 11 18 Body Part
# ἧπαρ 22 26 Body Part
# βρογχίη 27 34 Body Part
# πολλὴ 35 40 Adjectives/Qualities
# καθήκει 41 48 Topography
# βρογχίης 59 67 Body Part
# φλὲψ 68 72 Body Part
# μεγάλη 73 79 Adjectives/Qualities
# καλευμένη 80 89 Technical Appellation
# οὖλον 98 103 Adjectives/Qualities
# σκῆνος 107 113 Adjectives/Qualities
# τρέφεται 114 122 Physiology
# SpanGroup 'sc' contains 12 spans:
# - Span: 'καρδίης' [11, 18], Labels: Body Part
# - Span: 'ἧπαρ' [22, 26], Labels: Body Part
# - Span: 'βρογχίη' [27, 34], Labels: Body Part
# - Span: 'πολλὴ' [35, 40], Labels: Adjectives/Qualities
# - Span: 'καθήκει' [41, 48], Labels: Topography
# - Span: 'βρογχίης' [59, 67], Labels: Body Part
# - Span: 'φλὲψ' [68, 72], Labels: Body Part
# - Span: 'μεγάλη' [73, 79], Labels: Adjectives/Qualities
# - Span: 'καλευμένη' [80, 89], Labels: Technical Appellation
# - Span: 'οὖλον' [98, 103], Labels: Adjectives/Qualities
# - Span: 'σκῆνος' [107, 113], Labels: Adjectives/Qualities
# - Span: 'τρέφεται' [114, 122], Labels: Physiology
# <class 'str'> καρδίης <class 'int'> 11 <class 'int'> 18 <class 'str'> Body Part
# <class 'str'> ἧπαρ <class 'int'> 22 <class 'int'> 26 <class 'str'> Body Part
# <class 'str'> βρογχίη <class 'int'> 27 <class 'int'> 34 <class 'str'> Body Part
# <class 'str'> πολλὴ <class 'int'> 35 <class 'int'> 40 <class 'str'> Adjectives/Qualities
# <class 'str'> καθήκει <class 'int'> 41 <class 'int'> 48 <class 'str'> Topography
# <class 'str'> βρογχίης <class 'int'> 59 <class 'int'> 67 <class 'str'> Body Part
# <class 'str'> φλὲψ <class 'int'> 68 <class 'int'> 72 <class 'str'> Body Part
# <class 'str'> μεγάλη <class 'int'> 73 <class 'int'> 79 <class 'str'> Adjectives/Qualities
# <class 'str'> καλευμένη <class 'int'> 80 <class 'int'> 89 <class 'str'> Technical Appellation
# <class 'str'> οὖλον <class 'int'> 98 <class 'int'> 103 <class 'str'> Adjectives/Qualities
# <class 'str'> σκῆνος <class 'int'> 107 <class 'int'> 113 <class 'str'> Adjectives/Qualities
# <class 'str'> τρέφεται <class 'int'> 114 <class 'int'> 122 <class 'str'> Physiology
# doc user data:  {'source_info': 'Galen, AA, 2, 4, 87 1-28 Garofalo. 295-296 Kühn'}
# οἱ μὲν γὰρ μεγάλοι τῶν μυῶν καὶ μετὰ τὴν τελευτὴν τοῦ ζῴου δύνανται τεινόμενοι τὰς ἑαυτῶν ἐνεργείας ἐπιδεικνύναι χωρίς τοῦ περικόψαι τὰς σάρκας·
# μυῶν 23 27 Body Part
# περικόψαι 123 132 Action Verbs
# SpanGroup 'sc' contains 2 spans:
# - Span: 'μυῶν' [23, 27], Labels: Body Part
# - Span: 'περικόψαι' [123, 132], Labels: Action Verbs
# <class 'str'> μυῶν <class 'int'> 23 <class 'int'> 27 <class 'str'> Body Part
# <class 'str'> περικόψαι <class 'int'> 123 <class 'int'> 132 <class 'str'> Action Verbs
# doc user data:  {'source_info': 'Hippocratic_De corde Part B chs 5-9'}
# ἡ δὲ ἑτέρη κεῖται ὑπένερθε μὲν μάλιστα καὶ κατʼ ἰθυωρίην μάλιστα μὲν μαζῷ ἀριστερῷ ὅπῃ καὶ διασημαίνει τὸ ἅλμα.
# ἑτέρη 5 10 Body Part
# κεῖται 11 17 Topography
# ὑπένερθε 18 26 Topography
# μάλιστα 31 38 Adjectives/Qualities
# κατʼ 43 47 Topography
# ἰθυωρίην 48 56 Topography
# μάλιστα 57 64 Adjectives/Qualities
# μαζῷ 69 73 Body Part
# ἀριστερῷ 74 82 Topography
# ὅπῃ 83 86 Topography
# ἅλμα 106 110 Physiology
# SpanGroup 'sc' contains 11 spans:
# - Span: 'ἑτέρη' [5, 10], Labels: Body Part
# - Span: 'κεῖται' [11, 17], Labels: Topography
# - Span: 'ὑπένερθε' [18, 26], Labels: Topography
# - Span: 'μάλιστα' [31, 38], Labels: Adjectives/Qualities
# - Span: 'κατʼ' [43, 47], Labels: Topography
# - Span: 'ἰθυωρίην' [48, 56], Labels: Topography
# - Span: 'μάλιστα' [57, 64], Labels: Adjectives/Qualities
# - Span: 'μαζῷ' [69, 73], Labels: Body Part
# - Span: 'ἀριστερῷ' [74, 82], Labels: Topography
# - Span: 'ὅπῃ' [83, 86], Labels: Topography
# - Span: 'ἅλμα' [106, 110], Labels: Physiology
# <class 'str'> ἑτέρη <class 'int'> 5 <class 'int'> 10 <class 'str'> Body Part
# <class 'str'> κεῖται <class 'int'> 11 <class 'int'> 17 <class 'str'> Topography
# <class 'str'> ὑπένερθε <class 'int'> 18 <class 'int'> 26 <class 'str'> Topography
# <class 'str'> μάλιστα <class 'int'> 31 <class 'int'> 38 <class 'str'> Adjectives/Qualities
# <class 'str'> κατʼ <class 'int'> 43 <class 'int'> 47 <class 'str'> Topography
# <class 'str'> ἰθυωρίην <class 'int'> 48 <class 'int'> 56 <class 'str'> Topography
# <class 'str'> μάλιστα <class 'int'> 57 <class 'int'> 64 <class 'str'> Adjectives/Qualities
# <class 'str'> μαζῷ <class 'int'> 69 <class 'int'> 73 <class 'str'> Body Part
# <class 'str'> ἀριστερῷ <class 'int'> 74 <class 'int'> 82 <class 'str'> Topography
# <class 'str'> ὅπῃ <class 'int'> 83 <class 'int'> 86 <class 'str'> Topography
# <class 'str'> ἅλμα <class 'int'> 106 <class 'int'> 110 <class 'str'> Physiology
# doc user data:  {'source_info': 'Hippocratic_De corde Part B chs 5-9'}
# ἀλλὰ γὰρ ἤδη καὶ τοῦ πνεύμονος ἐνδύεται μετὰ προσηνίης καὶ κολάζει τὴν ἀκρασίην τοῦ θερμοῦ περιβαλλομένη·
# πνεύμονος 21 30 Body Part
# ἐνδύεται 31 39 Topography
# μετὰ 40 44 Topography
# προσηνίης 45 54 Adjectives/Qualities
# ἀκρασίην 71 79 Medical
# περιβαλλομένη 91 104 Topography
# SpanGroup 'sc' contains 6 spans:
# - Span: 'πνεύμονος' [21, 30], Labels: Body Part
# - Span: 'ἐνδύεται' [31, 39], Labels: Topography
# - Span: 'μετὰ' [40, 44], Labels: Topography
# - Span: 'προσηνίης' [45, 54], Labels: Adjectives/Qualities
# - Span: 'ἀκρασίην' [71, 79], Labels: Medical
# - Span: 'περιβαλλομένη' [91, 104], Labels: Topography
# <class 'str'> πνεύμονος <class 'int'> 21 <class 'int'> 30 <class 'str'> Body Part
# <class 'str'> ἐνδύεται <class 'int'> 31 <class 'int'> 39 <class 'str'> Topography
# <class 'str'> μετὰ <class 'int'> 40 <class 'int'> 44 <class 'str'> Topography
# <class 'str'> προσηνίης <class 'int'> 45 <class 'int'> 54 <class 'str'> Adjectives/Qualities
# <class 'str'> ἀκρασίην <class 'int'> 71 <class 'int'> 79 <class 'str'> Medical
# <class 'str'> περιβαλλομένη <class 'int'> 91 <class 'int'> 104 <class 'str'> Topography
# doc user data:  {'source_info': 'Aristotle_Historia_Animalium_497a18-35'}
# πρὸς δὲ τὸν καυλὸν τὸν τῆς κύστεως συνήρτηται τὸ αἰδοῖον, τὸ μὲν ἐξωτάτω τρῆμα συνερρωγὸς εἰς τὸ αὐτό, μικρὸν δʼ ὑποκάτω τὸ μὲν εἰς τοὺς ὄρχεις φέρει τῶν τρημάτων τὸ δʼ εἰς τὴν κύστιν, νευρῶδες καὶ χονδρῶδες ὄν.
# πρὸς 0 4 Topography
# καυλὸν 12 18 Body Part
# κύστεως 27 34 Body Part
# συνήρτηται 35 45 Topography
# αἰδοῖον 49 56 Body Part
# ἐξωτάτω 65 72 Topography
# τρῆμα 73 78 Body Part
# συνερρωγὸς 79 89 Topography
# εἰς 90 93 Topography
# ὑποκάτω 113 120 Topography
# εἰς 128 131 Topography
# ὄρχεις 137 143 Body Part
# τρημάτων 154 162 Body Part
# εἰς 169 172 Topography
# κύστιν 177 183 Body Part
# νευρῶδες 185 193 Adjectives/Qualities
# χονδρῶδες 198 207 Adjectives/Qualities
# SpanGroup 'sc' contains 17 spans:
# - Span: 'πρὸς' [0, 4], Labels: Topography
# - Span: 'καυλὸν' [12, 18], Labels: Body Part
# - Span: 'κύστεως' [27, 34], Labels: Body Part
# - Span: 'συνήρτηται' [35, 45], Labels: Topography
# - Span: 'αἰδοῖον' [49, 56], Labels: Body Part
# - Span: 'ἐξωτάτω' [65, 72], Labels: Topography
# - Span: 'τρῆμα' [73, 78], Labels: Body Part
# - Span: 'συνερρωγὸς' [79, 89], Labels: Topography
# - Span: 'εἰς' [90, 93], Labels: Topography
# - Span: 'ὑποκάτω' [113, 120], Labels: Topography
# - Span: 'εἰς' [128, 131], Labels: Topography
# - Span: 'ὄρχεις' [137, 143], Labels: Body Part
# - Span: 'τρημάτων' [154, 162], Labels: Body Part
# - Span: 'εἰς' [169, 172], Labels: Topography
# - Span: 'κύστιν' [177, 183], Labels: Body Part
# - Span: 'νευρῶδες' [185, 193], Labels: Adjectives/Qualities
# - Span: 'χονδρῶδες' [198, 207], Labels: Adjectives/Qualities
# <class 'str'> πρὸς <class 'int'> 0 <class 'int'> 4 <class 'str'> Topography
# <class 'str'> καυλὸν <class 'int'> 12 <class 'int'> 18 <class 'str'> Body Part
# <class 'str'> κύστεως <class 'int'> 27 <class 'int'> 34 <class 'str'> Body Part
# <class 'str'> συνήρτηται <class 'int'> 35 <class 'int'> 45 <class 'str'> Topography
# <class 'str'> αἰδοῖον <class 'int'> 49 <class 'int'> 56 <class 'str'> Body Part
# <class 'str'> ἐξωτάτω <class 'int'> 65 <class 'int'> 72 <class 'str'> Topography
# <class 'str'> τρῆμα <class 'int'> 73 <class 'int'> 78 <class 'str'> Body Part
# <class 'str'> συνερρωγὸς <class 'int'> 79 <class 'int'> 89 <class 'str'> Topography
# <class 'str'> εἰς <class 'int'> 90 <class 'int'> 93 <class 'str'> Topography
# <class 'str'> ὑποκάτω <class 'int'> 113 <class 'int'> 120 <class 'str'> Topography
# <class 'str'> εἰς <class 'int'> 128 <class 'int'> 131 <class 'str'> Topography
# <class 'str'> ὄρχεις <class 'int'> 137 <class 'int'> 143 <class 'str'> Body Part
# <class 'str'> τρημάτων <class 'int'> 154 <class 'int'> 162 <class 'str'> Body Part
# <class 'str'> εἰς <class 'int'> 169 <class 'int'> 172 <class 'str'> Topography
# <class 'str'> κύστιν <class 'int'> 177 <class 'int'> 183 <class 'str'> Body Part
# <class 'str'> νευρῶδες <class 'int'> 185 <class 'int'> 193 <class 'str'> Adjectives/Qualities
# <class 'str'> χονδρῶδες <class 'int'> 198 <class 'int'> 207 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Aristotle_Historia_Animalium_497a18-35'}
# λεκτέον δὲ καὶ περὶ ὑστερῶν κοινῇ πασῶν ἐν τοῖς ἑπομένοις·
# ὑστερῶν 20 27 Body Part
# SpanGroup 'sc' contains 1 spans:
# - Span: 'ὑστερῶν' [20, 27], Labels: Body Part
# <class 'str'> ὑστερῶν <class 'int'> 20 <class 'int'> 27 <class 'str'> Body Part
# doc user data:  {'source_info': 'Hippocrates epidemics 2.4.2'}
# δύο δὲ τόνοι ἀπʼ ἐγκεφάλου ὑπὸ τὸ ὀστέον τοῦ μεγάλου σπονδύλου ἄνωθεν καὶ πρὸς τοῦ στομάχου μᾶλλον.
# τόνοι 7 12 Body Part
# ἐγκεφάλου 17 26 Body Part
# ὑπὸ 27 30 Topography
# ὀστέον 34 40 Body Part
# μεγάλου 45 52 Adjectives/Qualities
# σπονδύλου 53 62 Body Part
# ἄνωθεν 63 69 Topography
# πρὸς 74 78 Topography
# στομάχου 83 91 Body Part
# SpanGroup 'sc' contains 9 spans:
# - Span: 'τόνοι' [7, 12], Labels: Body Part
# - Span: 'ἐγκεφάλου' [17, 26], Labels: Body Part
# - Span: 'ὑπὸ' [27, 30], Labels: Topography
# - Span: 'ὀστέον' [34, 40], Labels: Body Part
# - Span: 'μεγάλου' [45, 52], Labels: Adjectives/Qualities
# - Span: 'σπονδύλου' [53, 62], Labels: Body Part
# - Span: 'ἄνωθεν' [63, 69], Labels: Topography
# - Span: 'πρὸς' [74, 78], Labels: Topography
# - Span: 'στομάχου' [83, 91], Labels: Body Part
# <class 'str'> τόνοι <class 'int'> 7 <class 'int'> 12 <class 'str'> Body Part
# <class 'str'> ἐγκεφάλου <class 'int'> 17 <class 'int'> 26 <class 'str'> Body Part
# <class 'str'> ὑπὸ <class 'int'> 27 <class 'int'> 30 <class 'str'> Topography
# <class 'str'> ὀστέον <class 'int'> 34 <class 'int'> 40 <class 'str'> Body Part
# <class 'str'> μεγάλου <class 'int'> 45 <class 'int'> 52 <class 'str'> Adjectives/Qualities
# <class 'str'> σπονδύλου <class 'int'> 53 <class 'int'> 62 <class 'str'> Body Part
# <class 'str'> ἄνωθεν <class 'int'> 63 <class 'int'> 69 <class 'str'> Topography
# <class 'str'> πρὸς <class 'int'> 74 <class 'int'> 78 <class 'str'> Topography
# <class 'str'> στομάχου <class 'int'> 83 <class 'int'> 91 <class 'str'> Body Part
# doc user data:  {'source_info': 'Hippocratic_De corde Part A chs 1-4'}
# καρδίη σχῆμα μὲν ὁκοίη πυραμίς, χροιὴν δὲ κατακορὴς φοινικέη.
# καρδίη 0 6 Body Part
# σχῆμα 7 12 Adjectives/Qualities
# ὁκοίη 17 22 Adjectives/Qualities
# πυραμίς 23 30 Adjectives/Qualities
# χροιὴν 32 38 Adjectives/Qualities
# κατακορὴς 42 51 Adjectives/Qualities
# φοινικέη 52 60 Adjectives/Qualities
# SpanGroup 'sc' contains 7 spans:
# - Span: 'καρδίη' [0, 6], Labels: Body Part
# - Span: 'σχῆμα' [7, 12], Labels: Adjectives/Qualities
# - Span: 'ὁκοίη' [17, 22], Labels: Adjectives/Qualities
# - Span: 'πυραμίς' [23, 30], Labels: Adjectives/Qualities
# - Span: 'χροιὴν' [32, 38], Labels: Adjectives/Qualities
# - Span: 'κατακορὴς' [42, 51], Labels: Adjectives/Qualities
# - Span: 'φοινικέη' [52, 60], Labels: Adjectives/Qualities
# <class 'str'> καρδίη <class 'int'> 0 <class 'int'> 6 <class 'str'> Body Part
# <class 'str'> σχῆμα <class 'int'> 7 <class 'int'> 12 <class 'str'> Adjectives/Qualities
# <class 'str'> ὁκοίη <class 'int'> 17 <class 'int'> 22 <class 'str'> Adjectives/Qualities
# <class 'str'> πυραμίς <class 'int'> 23 <class 'int'> 30 <class 'str'> Adjectives/Qualities
# <class 'str'> χροιὴν <class 'int'> 32 <class 'int'> 38 <class 'str'> Adjectives/Qualities
# <class 'str'> κατακορὴς <class 'int'> 42 <class 'int'> 51 <class 'str'> Adjectives/Qualities
# <class 'str'> φοινικέη <class 'int'> 52 <class 'int'> 60 <class 'str'> Adjectives/Qualities
# doc user data:  {'source_info': 'Hippocratic_De corde Part A chs 1-4'}
# ἀλλὰ πῶς ὕδωρ ἀναιδὲς ἐνοροῦον ὄχλον καὶ βῆχα παρέχει πολλήν; οὕνεκα, φημί, ἀπάντικρυ τῆς ἀναπνοῆς φέρεται.
# ἀναιδὲς 14 21 Adjectives/Qualities
# πολλήν 54 60 Adjectives/Qualities
# ἀπάντικρυ 76 85 Topography
# SpanGroup 'sc' contains 3 spans:
# - Span: 'ἀναιδὲς' [14, 21], Labels: Adjectives/Qualities
# - Span: 'πολλήν' [54, 60], Labels: Adjectives/Qualities
# - Span: 'ἀπάντικρυ' [76, 85], Labels: Topography
# <class 'str'> ἀναιδὲς <class 'int'> 14 <class 'int'> 21 <class 'str'> Adjectives/Qualities
# <class 'str'> πολλήν <class 'int'> 54 <class 'int'> 60 <class 'str'> Adjectives/Qualities
# <class 'str'> ἀπάντικρυ <class 'int'> 76 <class 'int'> 85 <class 'str'> Topography
# doc user data:  {'source_info': 'Hippocratic_De corde Part A chs 1-4'}
# τοῦτο δὲ τὸ ὑγρὸν ἀπάγει τοῦ πνεύμονος ἅμα τῷ ἠέρι.
# ἀπάγει 18 24 Topography
# πνεύμονος 29 38 Body Part
# SpanGroup 'sc' contains 2 spans:
# - Span: 'ἀπάγει' [18, 24], Labels: Topography
# - Span: 'πνεύμονος' [29, 38], Labels: Body Part
# <class 'str'> ἀπάγει <class 'int'> 18 <class 'int'> 24 <class 'str'> Topography
# <class 'str'> πνεύμονος <class 'int'> 29 <class 'int'> 38 <class 'str'> Body Part
# doc user data:  {'source_info': 'Hippocratic_De corde Part A chs 1-4'}
# περὶ δὲ οὗ λόγος, ἡ καρδίη μῦς ἐστι κάρτα ἰσχυρός, οὒ τῳ νεύρῳ, ἀλλὰ πιλήματι σαρκός.
# καρδίη 20 26 Body Part
# μῦς 27 30 Body Part
# κάρτα 36 41 Adjectives/Qualities
# ἰσχυρός 42 49 Adjectives/Qualities
# νεύρῳ 57 62 Adjectives/Qualities
# πιλήματι 69 77 Adjectives/Qualities
# σαρκός 78 84 Body Part
# SpanGroup 'sc' contains 7 spans:
# - Span: 'καρδίη' [20, 26], Labels: Body Part
# - Span: 'μῦς' [27, 30], Labels: Body Part
# - Span: 'κάρτα' [36, 41], Labels: Adjectives/Qualities
# - Span: 'ἰσχυρός' [42, 49], Labels: Adjectives/Qualities
# - Span: 'νεύρῳ' [57, 62], Labels: Adjectives/Qualities
# - Span: 'πιλήματι' [69, 77], Labels: Adjectives/Qualities
# - Span: 'σαρκός' [78, 84], Labels: Body Part
# <class 'str'> καρδίη <class 'int'> 20 <class 'int'> 26 <class 'str'> Body Part
# <class 'str'> μῦς <class 'int'> 27 <class 'int'> 30 <class 'str'> Body Part
# <class 'str'> κάρτα <class 'int'> 36 <class 'int'> 41 <class 'str'> Adjectives/Qualities
# <class 'str'> ἰσχυρός <class 'int'> 42 <class 'int'> 49 <class 'str'> Adjectives/Qualities
# <class 'str'> νεύρῳ <class 'int'> 57 <class 'int'> 62 <class 'str'> Adjectives/Qualities
# <class 'str'> πιλήματι <class 'int'> 69 <class 'int'> 77 <class 'str'> Adjectives/Qualities
# <class 'str'> σαρκός <class 'int'> 78 <class 'int'> 84 <class 'str'> Body Part
# doc user data:  {'source_info': 'On Nature of Bones 1'}
# οἱ δὲ κατὰ τὰς πλευράς ὅσαιπερ αἱ πλευραὶ δώδεκα·
# κατὰ 6 10 Topography
# πλευράς 15 22 Body Part
# πλευραὶ 34 41 Body Part
# SpanGroup 'sc' contains 3 spans:
# - Span: 'κατὰ' [6, 10], Labels: Topography
# - Span: 'πλευράς' [15, 22], Labels: Body Part
# - Span: 'πλευραὶ' [34, 41], Labels: Body Part
# <class 'str'> κατὰ <class 'int'> 6 <class 'int'> 10 <class 'str'> Topography
# <class 'str'> πλευράς <class 'int'> 15 <class 'int'> 22 <class 'str'> Body Part
# <class 'str'> πλευραὶ <class 'int'> 34 <class 'int'> 41 <class 'str'> Body Part
# doc user data:  {'source_info': 'On Nature of Bones 1'}
# ἀπὸ δὲ τούτων ἐς ἄκρην κύστιν.
# ἀπὸ 0 3 Topography
# ἐς 14 16 Topography
# κύστιν 23 29 Body Part
# SpanGroup 'sc' contains 3 spans:
# - Span: 'ἀπὸ' [0, 3], Labels: Topography
# - Span: 'ἐς' [14, 16], Labels: Topography
# - Span: 'κύστιν' [23, 29], Labels: Body Part
# <class 'str'> ἀπὸ <class 'int'> 0 <class 'int'> 3 <class 'str'> Topography
# <class 'str'> ἐς <class 'int'> 14 <class 'int'> 16 <class 'str'> Topography
# <class 'str'> κύστιν <class 'int'> 23 <class 'int'> 29 <class 'str'> Body Part

# %%
# check pipeline for catspan
nlp.pipe_names
# get spancat component
spancat = nlp.get_pipe("spancat")
# get spancat component config
spancat.cfg
# use spans_key to get spans
spancat.cfg["spans_key"]
from spacy.tokens import Span

Span.set_extension("labels", default=None, force=True)

for doc in train_docs:
    seen_tokens = {}
    for span in doc.spans[spancat.cfg["spans_key"]]:
        if span.root.i not in seen_tokens:
            seen_tokens[span.root.i] = [span.label_]
            #print(f"NOT SEEEEN Token: {doc[span.root.i]}, Labels: {span.label_}")
        else:
            seen_tokens[span.root.i].append(span.label_)
            #print(f"ALREADY SEEN Token: {doc[span.root.i]}, Labels: {span.label_}")
    
    for token_index, labels in seen_tokens.items():
        if len(set(labels)) < len(labels):
            print(f"Token: {doc[token_index]}, Labels: {labels}, {doc.text}")

# %%
# debug ner data in spacy
import random
# sample random from train_docs
doc = random.choice(train_docs)
print (doc.text)
for ent in doc.ents:
    print (ent.text, ent.label_)
print ("Spacy entities, for line:")
print (doc.text)
print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# ἔστι δʼ ἡ μὲν ἀρτηρία χονδρώδης τὴν φύσιν καὶ ὀλίγαιμος, πολλοῖς λεπτοῖς φλεβίοις περιεχομένη, κεῖται δʼ ἐπὶ μὲν τὰ ἄνω πρὸς τὸ στόμα κατὰ τὴν ἐκ τῶν μυκτήρων σύντρησιν εἰς τὸ στόμα, ᾗ καὶ ὅταν πίνοντες ἀνασπάσωσί τι τοῦ ποτοῦ, χωρεῖ ἐκ τοῦ στόματος διὰ τῶν μυκτήρων ἔξω
# Spacy entities, for line:
# ἔστι δʼ ἡ μὲν ἀρτηρία χονδρώδης τὴν φύσιν καὶ ὀλίγαιμος, πολλοῖς λεπτοῖς φλεβίοις περιεχομένη, κεῖται δʼ ἐπὶ μὲν τὰ ἄνω πρὸς τὸ στόμα κατὰ τὴν ἐκ τῶν μυκτήρων σύντρησιν εἰς τὸ στόμα, ᾗ καὶ ὅταν πίνοντες ἀνασπάσωσί τι τοῦ ποτοῦ, χωρεῖ ἐκ τοῦ στόματος διὰ τῶν μυκτήρων ἔξω
# []

# %%
from IPython.display import Markdown, display

def print_words_at_indices(sentence, entities, source):
    for start, end, label in entities:
        word = sentence[start:end]
        display(Markdown(sentence[:start] + f"**[{word}]**" + sentence[end:]))
        print(f"Word: {word}, Label: {label}, Source: {source}")

# Example usage:
# Assuming TRAIN_DATA2 is already defined and is not empty.
#sentence, entities_dict = TRAIN_DATA[207]  # Get the first sentence and its entities.
#entities = entities_dict['entities']  # Get the list of entity tuples.
#print_words_at_indices(sentence, entities)
sentence, entities_dict, source = MERGED_TRAIN_DATA[252]  # Get the first sentence and its entities.
entities = entities_dict['entities']  # Get the list of entity tuples.
print_words_at_indices(sentence, entities, source)
# Out:
# **[κινεῖται]** δὲ τοῖς μὲν ἄλλοις ζῴοις ἅπασιν ἡ κάτωθεν σιαγών·
# Word: κινεῖται, Label: Topography, Source: Aristotle, History of Animals, 3.7, p. 142-143 Balme ready
# κινεῖται δὲ τοῖς μὲν **[ἄλλοις ζῴοις]** ἅπασιν ἡ κάτωθεν σιαγών·
# Word: ἄλλοις ζῴοις, Label: Adjectives/Qualities, Source: Aristotle, History of Animals, 3.7, p. 142-143 Balme ready
# κινεῖται δὲ τοῖς μὲν ἄλλοις ζῴοις **[ἅπασιν]** ἡ κάτωθεν σιαγών·
# Word: ἅπασιν, Label: Adjectives/Qualities, Source: Aristotle, History of Animals, 3.7, p. 142-143 Balme ready
# κινεῖται δὲ τοῖς μὲν ἄλλοις ζῴοις ἅπασιν ἡ **[κάτωθεν]** σιαγών·
# Word: κάτωθεν, Label: Topography, Source: Aristotle, History of Animals, 3.7, p. 142-143 Balme ready
# κινεῖται δὲ τοῖς μὲν ἄλλοις ζῴοις ἅπασιν ἡ κάτωθεν **[σιαγών]**·
# Word: σιαγών, Label: Body Part, Source: Aristotle, History of Animals, 3.7, p. 142-143 Balme ready

# %%
def compare_spans(obj1, obj2):
    """
    Compares the spans of two spaCy objects.
    
    Args:
        obj1 (spacy.tokens.DocBin): The first spaCy object.
        obj2 (spacy.tokens.DocBin): The second spaCy object.
        
    Returns:
        None
    """
    docs1 = list(obj1.get_docs(nlp.vocab))
    docs2 = list(obj2.get_docs(nlp.vocab))
    
    if len(docs1) != len(docs2):
        print(f"Objects have different number of documents: {len(docs1)} vs {len(docs2)}")
        return
    
    for doc1, doc2 in zip(docs1, docs2):
        if doc1.text != doc2.text:
            print(f"Documents have different text:\n{doc1.text}\n{doc2.text}")
            continue
        
        spans1 = list(doc1.spans["sc"])
        spans2 = list(doc2.spans["sc"])
        
        if len(spans1) != len(spans2):
            print(f"Documents have different number of spans: {len(spans1)} vs {len(spans2)}")
            print("Spans in doc1:")
            for span in spans1:
                print(f"- Span: '{span.text}' [{span.start_char}, {span.end_char}], Labels: {span.label_}")
            print("Spans in doc2:")
            for span in spans2:
                print(f"- Span: '{span.text}' [{span.start_char}, {span.end_char}], Labels: {span.label_}")
            continue
        
        for span1, span2 in zip(spans1, spans2):
            if (span1.start_char != span2.start_char or
                span1.end_char != span2.end_char or
                span1.label_ != span2.label_):
                print(f"Document 1 text: {doc1.text}")
                print(f"Document 1 user data: {doc1.user_data}")
                print(f"Document 2 text: {doc2.text}")
                print(f"Document 2 user data: {doc2.user_data}")
                print(f"Span 1: '{span1.text}' [{span1.start_char}, {span1.end_char}], Labels: {span1.label_}")
                #print all the spans in this doc
                for span in spans1:
                    print(f"- Span: '{span.text}' [{span.start_char}, {span.end_char}], Labels: {span.label_}")
                print(f"Span 2: '{span2.text}' [{span2.start_char}, {span2.end_char}], Labels: {span2.label_}")
                 #print all the spans in this doc
                for span in spans2:
                    print(f"- Span: '{span.text}' [{span.start_char}, {span.end_char}], Labels: {span.label_}")



import spacy
from spacy.tokens import DocBin
nlp = spacy.load("../training/SageMaker/transformer/PROIEL/Assembled/pos-trf-11-may-2024/model-best/")  # Example with a blank English model. Replace according to your model.
spancat = nlp.add_pipe("spancat")
spancat.cfg["spans_key"] = "sc"

# Load your spaCy objects
obj1 = DocBin().from_disk("../corpus/train/spancat_train/spancat_train_NFKD.spacy")
obj2 = DocBin().from_disk("../corpus/train/spancat_train/spancat_train_NFC.spacy")

# Compare the spans
compare_spans(obj1, obj2)
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'grc_pipeline' (0.0.0) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/spacy_transformers/layers/hf_shim.py:124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self._model.load_state_dict(torch.load(filelike, map_location=device))
# Objects have different number of documents: 412 vs 494

# %% [markdown]
# # Training - Sweep

# %%
import wandb
wandb.init(project="Greek SpanCategorizer sweeps", entity="atlomy-nlp")

# %%
import typer
from pathlib import Path
from spacy.training.loop import train
from spacy.training.initialize import init_nlp
from spacy import util
from thinc.api import Config
import wandb
import spacy

spacy.require_gpu()

def sweep_spancategorizer(default_config: Path, training_data: Path, dev_data: Path, model_source: Path, output_path: Path):
    sweep_config = {"method": "bayes"}
    metric = {"name": "spans_sc_f", "goal": "maximize"}
    sweep_config["metric"] = metric
    early_terminate = {"type": "hyperband", "min_iter": 3, "s": 2, "eta": 3}
    parameters_dict = {
        "training.dropout": {"distribution": "uniform", "min": 0.1, "max": 0.4},
        "training.optimizer.learn_rate": {"distribution": "uniform", "min": 0.00001, "max": 0.1},
        "training.batcher.size": {"distribution": "int_uniform", "min": 64, "max": 1000},
        "nlp.batch_size": {"values": [128, 256, 512, 1024]},
        "components.spancat.threshold": {"distribution": "uniform", "min": 0.1, "max": 0.5}
    }
    sweep_config["early_terminate"] = early_terminate
    sweep_config["parameters"] = parameters_dict

    def train_spacy():
        loaded_local_config = util.load_config(default_config)
        with wandb.init() as run:
            sweeps_config = Config(util.dot_to_dict(run.config))
            merged_config = Config(loaded_local_config).merge(sweeps_config)

            # Update paths
            merged_config["paths"]["train"] = training_data
            merged_config["paths"]["dev"] = dev_data
            merged_config["paths"]["source_path"] = model_source
            merged_config["training"]["max_epochs"] = 30  # Set a reasonable max_epochs value

            print(merged_config)
            nlp = init_nlp(merged_config, use_gpu=0)
            output_path.mkdir(parents=True, exist_ok=True)
            train(nlp, output_path, use_gpu=0)

            # Save the final model
            output_dir = output_path / f"final_model"
            output_dir.mkdir(parents=True, exist_ok=True)
            nlp.to_disk(output_dir)

    sweep_id = wandb.sweep(sweep_config, project="Greek SpanCategorizer sweeps")
    wandb.agent(sweep_id, train_spacy, count=20)

# if __name__ == "__main__":
#     typer.run(main)

# %%
sweep_spancategorizer(default_config="../configs/ner_2Xnorm-SpanCategorizer_new.cfg", training_data="../corpus/train/spancat_train/", dev_data="../corpus/dev/spancat_dev/", model_source="../training/SageMaker/transformer/PROIEL/Assembled/pos-trf-11-may-2024/model-best", output_path=Path("../training/ATLOMY_G_NER_pipeline/spancat_210524_sweep/"))
