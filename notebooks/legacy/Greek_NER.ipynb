# %%
import os
import re
import spacy
import pandas as pd
import logging

# import requirements for converting the dataframe to Spacy Docs
from collections import defaultdict
from unicodedata import normalize
import regex
import random

# Get the root logger
logger = logging.getLogger()

# Remove all handlers from the logger
for handler in logger.handlers[:]:
    logger.removeHandler(handler)

# Add a new handler to the logger
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(name)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

logger.setLevel(logging.DEBUG)

# %%
# config.py

class Config:
    DEFAULT_FORM = 'NFKD'
    REMOVE_ACCENTS = False
    LOWERCASE = False
    STANDARDIZE_APOSTROPHE = True
    REMOVE_BRACKETS = False
    REMOVE_TRAILING_NUMBERS = False
    REMOVE_EXTRA_SPACES = False
    DEBUG = False

# Instantiating the Config class for application-wide access.
app_config = Config()

import re
import unicodedata

# apostrophes and correct_apostrophe are defined as follows:
apostrophes = ["᾽", "᾿", "'", "’", "‘"]
correct_apostrophe = "ʼ"

def clean_and_remove_accents(text: str) -> str:
    """
    Cleans the given text by removing diacritics (accents), except for specific characters,
    and converting it to lowercase.
    """
    allowed_characters = [' ̓', "᾿", "᾽", "'", "’", "‘", 'ʼ', '̓']  # Including the Greek apostrophe
    if not isinstance(text, str):
        raise ValueError("Input must be a string.")
    try:
        non_accent_chars = [c for c in unicodedata.normalize('NFKD', text) 
        if unicodedata.category(c) != 'Mn' or c in allowed_characters]
        return ''.join(non_accent_chars)
    
    except Exception as e:
        # A more generic exception handling if unexpected errors occur
        print(f"An error occurred: {e}")
        return text
    

def normalize_text(text: str, 
                   form: str = None, 
                   remove_accents: bool = None, 
                   lowercase: bool = None, 
                   standardize_apostrophe: bool = None, 
                   remove_brackets: bool = None, 
                   remove_trailing_numbers: bool = None, 
                   remove_extra_spaces: bool = None, 
                   debug: bool = None) -> str:
    """
    Applies multiple text normalization and cleaning steps on the input text.

    Parameters:
    - text (str): The text to be normalized.
    - form (str): Unicode normalization form ('NFC', 'NFD', 'NFKC', 'NFKD').
    - remove_accents (bool): If True, removes accents from the text.
    - lowercase (bool): If True, the text is converted to lowercase.
    - standardize_apostrophe (bool): If True, replaces all defined apostrophe characters with a standard one.
    - remove_brackets_only (bool): If True, removes the brackets themselves.
    - remove_trailing_numbers (bool): If True, strips leading or trailing digits from the text.
    - remove_extra_spaces (bool): If True, removes extra spaces and leading/trailing spaces.
    - debug (bool): If True, prints before and after states for each operation.
    
    Returns:
    - str: The processed text.
    """
    
    # Fetch default settings from app_config if not provided
    form = form if form is not None else app_config.DEFAULT_FORM
    remove_accents = remove_accents if remove_accents is not None else app_config.REMOVE_ACCENTS
    lowercase = lowercase if lowercase is not None else app_config.LOWERCASE
    standardize_apostrophe = standardize_apostrophe if standardize_apostrophe is not None else app_config.STANDARDIZE_APOSTROPHE
    remove_brackets = remove_brackets if remove_brackets is not None else app_config.REMOVE_BRACKETS
    remove_trailing_numbers = remove_trailing_numbers if remove_trailing_numbers is not None else app_config.REMOVE_TRAILING_NUMBERS
    remove_extra_spaces = remove_extra_spaces if remove_extra_spaces is not None else app_config.REMOVE_EXTRA_SPACES
    debug = debug if debug is not None else app_config.DEBUG
    
    normalized_text = text  # Initialize normalized_text with the original text

    # Function to print before and after states for each operation during debugging
    def debug_print(operation_name, before, after):
        if debug:
            logger.debug(f"{operation_name} - Before: {before}")
            logger.debug(f"{operation_name} - After: {after}")

    # Standardize apostrophe characters if required
    if standardize_apostrophe:
        before_text = normalized_text
        for apos in apostrophes:
            normalized_text = normalized_text.replace(apos, correct_apostrophe)
        debug_print("Standardizing apostrophes", before_text, normalized_text)
        
    if remove_accents:
        before_text = normalized_text
        try:
            normalized_text = clean_and_remove_accents(normalized_text)
        except Exception as e:
            logger.error(f"An error occurred while removing accents: {e}")
            # Decide what to do here: return the original text, a special value, or stop the process
            return text        
        debug_print("Removing accents", before_text, normalized_text)
        
    # Convert to lowercase if required
    if lowercase:
        before_text = normalized_text
        normalized_text = normalized_text.lower()
        debug_print("Lowercase conversion", before_text, normalized_text)

    # Unicode normalization
    if form:
        before_text = normalized_text
        normalized_text = unicodedata.normalize(form, normalized_text)
        debug_print("Unicode normalization", before_text, normalized_text)
            
    # Remove brackets only if required
    if remove_brackets:
        before_text = normalized_text
        normalized_text = re.sub(r'[\(\)\[\]]', '', normalized_text)
        debug_print("Removing brackets", before_text, normalized_text)
        
    # Remove trailing numbers if required
    if remove_trailing_numbers:
        before_text = normalized_text
        normalized_text = re.sub(r'^\d+|\d+$', '', normalized_text)
        debug_print("Removing trailing numbers", before_text, normalized_text)

    # Remove multiple spaces and leading/trailing spaces
    if remove_extra_spaces:
        before_text = normalized_text
        normalized_text = ' '.join(normalized_text.split()).strip()
        debug_print("Removing extra spaces", before_text, normalized_text)

    return normalized_text

# %% [markdown]
# # Load and process data from Coda

# %%
# Load the dataset
FILE_PATH = "../assets/NER_assets/Ancient_Words_12_5_22.csv"
df = pd.read_csv(FILE_PATH)

# Renaming columns
df.rename(columns={'Word': 'Keyword', 'Category Types': 'Label'}, inplace=True)

# Filling NaN values more efficiently and appropriately
for early_col, new_col in [('Early Quote', 'Quote'), ('Early Word Before', 'Word Before'), 
                           ('Early Word After', 'Word After'), ('Early Category Type', 'Label')]:
    df[new_col].fillna(df[early_col], inplace=True)

# Dropping rows with no Keyword and non-Greek Keywords
pat = '[ء-ي]+'
df = df.dropna(subset=['Keyword']).copy()
df = df[~df['Keyword'].str.contains(pat, na=False)]

# Cleaning data with combined regex patterns

# Define a dictionary of patterns and replacements for the entire dataframe
df_replacements = {
    '\d+': '',  # Numbers
    '-': '',  # Hyphens
    ' +': ' ',  # Multiple spaces
}

# Apply the replacements to the text columns ('Early Quote', 'Quote', 'Early Word Before', 'Word Before', 'Early Word After', 'Word After', 'Keyword')
for col in ['Early Quote', 'Quote', 'Early Word Before', 'Word Before', 'Early Word After', 'Word After', 'Keyword']:
    for pattern, replacement in df_replacements.items():
        df[col].replace(pattern, replacement, regex=True, inplace=True)

# Define a dictionary of patterns and replacements for the 'Keyword' column
keyword_replacements = {
    '\n': '',  # New line
    ',': '',  # Comma
    '\.': '',  # Period
    '\·': '',  # Interpunkt
    '\s+$': ''  # End punctuation
}

# Apply the replacements to the 'Keyword' column
for pattern, replacement in keyword_replacements.items():
    df['Keyword'].replace(pattern, replacement, regex=True, inplace=True)
# Resetting the dataframe index
df.reset_index(drop=True, inplace=True)

# Normalizing the text in the columns
columns_to_normalize = ['Early Quote', 'Quote', 'Early Word Before', 'Word Before', 'Early Word After', 'Word After', 'Keyword']

for col in columns_to_normalize:
    if df[col].dtype == 'object':
        df[col] = df[col].apply(lambda x: normalize_text(x) if pd.notna(x) else x)

# %%
len(df)
# Out:
# 1524

# %%
def create_source_description(row):
    formatted_values = []
    for col in ['Modern Edition', 'Book', 'Chapter', 'Section', 'Page', 'Line Number']:
        value = row[col]
        if pd.notna(value) and value != '':
            # Handling special case for Modern Edition
            formatted_value = str(value) if col == 'Modern Edition' else f"{col[0]}({int(value)})" if isinstance(value, (int, float)) else f"{col[0]}({value})"
            formatted_values.append(formatted_value)
    source = ', '.join(formatted_values)
    return f"Coda, {source}"

df['Source'] = df.apply(create_source_description, axis=1)

# %% [markdown]
# ## Fix similar sentences

# %%
def ngrams(sentence, n=2):
    """Returns a list of n-grams from the sentence."""
    # Convert sentence to lowercase and split into tokens/words
    tokens = sentence.lower().split()
    # Generate n-grams
    return set(zip(*[tokens[i:] for i in range(n)]))

def jaccard_similarity(set1, set2):

    debug = app_config.DEBUG

    """Calculate the Jaccard Similarity between two sets, handling empty sets."""
    try:
        intersection = len(set1.intersection(set2))
        print(f"Intersection: {intersection}") if debug else None
        
        union = len(set1.union(set2))
        print(f"Union: {union}") if debug else None
        
        return intersection / union if union != 0 else 0
    except Exception as e:
        print(f"An error occurred: {e}") if debug else None
        return None

# Assuming df_grouped is your DataFrame and 'Quote' is the column with sentences.
threshold = 0.5  # Example threshold, adjust based on your requirements
groups = []
df_grouped = df.copy()
df_grouped["Quote_ngrams"] = df_grouped["Quote"].apply(lambda x: ngrams(x, n=2)) # Create n-grams for each quote

for i, base_row in df_grouped.iterrows():
    similar_found = False
    base_ngrams = base_row["Quote_ngrams"]
    
    for group in groups:
        representative_index = group[0]  # Use the first sentence of each group as the representative
        representative_ngrams = df_grouped.loc[representative_index, "Quote_ngrams"]
        
        if jaccard_similarity(base_ngrams, representative_ngrams) >= threshold:
            group.append(i)
            similar_found = True
            break
            
    if not similar_found:
        groups.append([i])  # Start a new group
        
from collections import Counter

# Initialize a list to hold the data for the new DataFrame
new_data = []

for group_indices in groups:
    # Extract sentences and their corresponding rows for the current group
    group_rows = df_grouped.iloc[group_indices]
    
    # Determine the most frequent sentence in the group
    sentence_counts = Counter(group_rows['Quote'])
    most_freq_sentence, _ = sentence_counts.most_common(1)[0]
    
    # Determine the most complete (longest) sentence in the group after removing whitespace
    most_complete_sentence = group_rows.loc[group_rows['Quote'].str.len().idxmax(), 'Quote']
    
    # Choose the sentence to use based on frequency and completeness
    sentence_to_use = most_freq_sentence if len(most_freq_sentence) >= len(most_complete_sentence) else most_complete_sentence
    
    # Consolidate labels, keywords, words before, and words after into lists
    entities = group_rows[['Label', 'Keyword', 'Word Before', 'Word After']].values.tolist()
    
    source_detail = group_rows.loc[group_rows['Quote'].str.len().idxmax(), 'Source']  # Use source of most complete sentence
    
    # Append to new data list: the chosen sentence, the consolidated entities and the source
    new_data.append({'Quote': sentence_to_use, 'Entities': entities, 'Source': source_detail})

# Create a new DataFrame from the new data
df_final = pd.DataFrame(new_data)

# Print the groups, their sentences with their original index, and the chosen sentence for verification
for i, group_indices in enumerate(groups):
    print(f"Group {i + 1}:")
    for index in group_indices:
        print(f"  - Index {index}: {df_grouped.loc[index, 'Quote']}, Source: {df_grouped.loc[index, 'Source']}")
    print(f"  Chosen sentence: {df_final.loc[i, 'Quote']}, Source: {df_final.loc[i, 'Source']}\n")
    print(f"  Entities: {df_final.loc[i, 'Entities']}\n")
        
# Structure of df_final:
# 'Quote': The representative sentence of the group.
# 'Entities': A list of lists for each sentence, containing label, keyword, word before, and word after.
# Out:
# Group 1:
#   - Index 0: ὁ ἐγκέφαλος ἐστὶ τοῦ ἀνθρώπου διπλόος ὥσπερ καὶ τοῖσιν ἄλλοισι ζώοισιν ἅπασι, Source: Coda, Hippocrates, Sacred Disease, C(3), S(2), P(11), L(9)
#   - Index 1: ὁ ἐγκέφαλος ἐστὶ τοῦ ἀνθρώπου διπλόος ὥσπερ καὶ τοῖσιν ἄλλοισι ζώοισιν ἅπασι, Source: Coda, Hippocrates, Sacred Disease, C(3), S(2), P(11), L(10)
#   Chosen sentence: ὁ ἐγκέφαλος ἐστὶ τοῦ ἀνθρώπου διπλόος ὥσπερ καὶ τοῖσιν ἄλλοισι ζώοισιν ἅπασι, Source: Coda, Hippocrates, Sacred Disease, C(3), S(2), P(11), L(9)
#
#   Entities: [['Body Part', 'ἐγκέφαλος', 'ὁ ', 'ἐστὶ τοῦ'], ['Adjectives/Qualities', 'διπλόος', 'ἀνθρώπου ', 'ὥσπερ ']]
#
# Group 2:
#   - Index 2: τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή, Source: Coda, Hippocrates, Sacred Disease, C(3), S(2), P(11), L(11)
#   - Index 3: τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή, Source: Coda, Hippocrates, Sacred Disease, C(3), S(2), P(11), L(11)
#   - Index 4: τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή, Source: Coda, Hippocrates, Sacred Disease, C(3), S(2), P(11), L(11)
#   - Index 5: τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή, Source: Coda, Hippocrates, Sacred Disease, C(3), S(2), P(11), L(11)
#   Chosen sentence: τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή, Source: Coda, Hippocrates, Sacred Disease, C(3), S(2), P(11), L(11)
#
#   Entities: [['Topography', 'μέσον', 'δὲ', 'αὐτοῦ'], ['Topography', 'διείργει', 'αὐτοῦ', 'μῆνιγξ'], ['Body Part', 'μῆνιγξ', 'διείργει ', 'λεπτή'], ['Adjectives/Qualities', 'λεπτή', 'μῆνιγξ', '.']]
τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#   - Index 24: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#   - Index 25: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#   - Index 26: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#   - Index 27: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#   - Index 28: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#   - Index 29: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#   - Index 30: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#   - Index 31: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(18)
#   - Index 32: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(18)
#   - Index 33: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(18)
#   - Index 34: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(18)
#   - Index 35: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(18)
#   - Index 36: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(19)
#   - Index 37: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(19)
#   - Index 38: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(19)
#   - Index 39: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(19)
#   - Index 40: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(19)
#   Chosen sentence: τὸ μέν τι τῆς φλεβὸς κάτω τείνει διὰ τῶν ἐπὶ δεξιὰ παρʼ αὐτὸν τὸν νεφρὸν καὶ τὴν ψοὴν ἐς τὸ ἐντὸς τοῦ μηροῦ καὶ καθήκει ἐς τὸν πόδα καὶ καλεῖται κοίλη φλέψ, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(17)
#
#   Entities: [['Body Part', 'φλεβὸς', 'τῆς', 'κάτω'], ['Topography', 'κάτω', 'φλεβὸς', 'τείνει'], ['Topography', 'τείνει', 'κάτω', 'διὰ'], ['Topography', 'διὰ', 'τείνει', 'τῶν'], ['Topography', 'ἐπὶ', 'τῶν', 'δεξιὰ'], ['Topography', 'δεξιὰ', 'ἐπὶ', 'παρʼ '], ['Topography', 'παρʼ', 'δεξιὰ', 'αὐτὸν'], ['Topography', 'αὐτὸν', 'παρʼ ', 'τὸν'], ['Body Part', 'νεφρὸν', 'τὸν', 'καὶ'], ['Body Part', 'ψοὴν', 'τὴν ', 'ἐς '], ['Topography', 'ἐς', 'ψοὴν ', 'τὸ '], ['Topography', 'ἐντὸς', 'τὸ ', 'τοῦ '], ['Body Part', 'μηροῦ', 'τοῦ ', 'καὶ '], ['Topography', 'καθήκει', 'καὶ ', 'ἐς '], ['Topography', 'ἐς', 'καθήκει ', 'τὸν '], ['Body Part', 'πόδα', 'τὸν ', 'καὶ '], ['Adjectives/Qualities', 'κοίλη', 'καλεῖται ', 'φλέψ'], ['Adjectives/Qualities', 'φλέψ', 'κοίλη ', '·']]
#
# Group 7:
#   - Index 41: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(20)
#   - Index 42: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(20)
#   - Index 43: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(20)
#   - Index 44: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(20)
#   - Index 45: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(20)
#   - Index 46: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(20)
#   - Index 47: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(21)
#   - Index 48: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(21)
#   - Index 49: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(21)
#   - Index 50: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(21)
#   - Index 51: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(21)
#   - Index 52: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(22)
#   - Index 53: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(22)
#   - Index 54: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(22)
#   - Index 55: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(22)
#   - Index 56: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(22)
#   - Index 57: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(1)
#   - Index 58: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(1)
#   - Index 59: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(1)
#   - Index 60: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(1)
#   - Index 61: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(1)
#   - Index 62: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(2)
#   - Index 63: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(2)
#   - Index 64: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(3)
#   - Index 65: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(12), L(3)
#   Chosen sentence: ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται, Source: Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L
# %%
# check the first 5 rows of the dataframe
df_final
# Out:
#                                                  Quote  \
# 0    ὁ ἐγκέφαλος ἐστὶ τοῦ ἀνθρώπου διπλόος...
# 1      τὸ δὲ μέσον αὐτοῦ διείργει μῆνιγξ λεπτή
# 2    διότι οὐκ αἰεὶ κατὰ τωὐτὸ τῆς κεφαλὴς...
# 3    Καὶ φλέβες δʼ ἐς αὐτὸν τείνουσιν ἐξ ἅ...
# 4        Καὶ ἡ μὲν ἀπὸ τοῦ ἥπατος ὧδʼ ἔχει
# ..                                                 ...
# 209  Διὰ τοῦτο πάντα τὰ τοιαῦτα ζῷα τὴν καλ...
# 210  τοῦτο γὰρ μεταξὺ τῆς τʼ ἄνω, ἐν ᾗ το...
# 211  Τότε γὰρ ἤδη μεταίχμιον γίνεται τῶν τό...
# 212   Τοῖς μὲν οὖν θήλεσι γίνεται ὅπου ἂν...
# 213  οἱ δʼ ἄρρενες ἔχουσι πρὸ τοῦ τυφλοῦ κα...
#
#                                               Entities  \
# 0    [[Body Part, ἐγκέφαλος, ὁ , ἐστὶ τοῦ], [...
# 1    [[Topography, μέσον, δὲ, αὐτοῦ], [Topograp...
# 2    [[Body Part, κεφαλὴς, τῆς , ἀλγεῖ], [Patho...
# 3    [[Body Part, φλέβες, Καὶ, δʼ], [Topography, ...
# 4    [[Topography, ἀπὸ, μὲν, τοῦ], [Body Part, ...
# ..                                                 ...
# 209  [[Body Part, νῆστιν, καλουμένην ἔχει, καὶ...
# 210  [[Topography, μεταξὺ, τοῦτο γὰρ, τῆς τʼ], ...
# 211  [[Adjectives/Qualities, μεταίχμιον, γὰρ ἤδ...
# 212  [[Topography, ὅπου, θήλεσι γίνεται, ἂν τ...
# 213  [[Topography, πρὸ, ἄρρενες ἔχουσι, τοῦ τ...
#
#                                                 Source
# 0    Coda, Hippocrates, Sacred Disease, C(3), S(2),...
# 1    Coda, Hippocrates, Sacred Disease, C(3), S(2),...
# 2    Coda, Hippocrates, Sacred Disease, C(3), S(2),...
# 3    Coda, Hippocrates, Sacred Disease, C(3), S(3),...
# 4    Coda, Hippocrates, Sacred Disease, C(3), S(3),...
# ..                                                 ...
# 209  Coda, Aristotle, Parts of Animals, B(3), C(13)...
# 210  Coda, Aristotle, Parts of Animals, B(3), C(13)...
# 211  Coda, Aristotle, Parts of Animals, B(3), C(13)...
# 212  Coda, Aristotle, Parts of Animals, B(3), C(13)...
# 213  Coda, Aristotle, Parts of Animals, B(3), C(13)...
#
# [214 rows x 3 columns]

# %% [markdown]
# ## Fix similar words

# %%
import regex as re
import unicodedata


def build_exact_pattern(word):
    """
    Builds a regex pattern that matches the word exactly, including diacritics.
    """
    return re.escape(word)

def build_diacritic_agnostic_pattern(word, form=None, debug=None, max_errors=2, debug_patterns=None):
    """
    Builds a regex pattern that matches the word in a diacritic-agnostic manner.
    """
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = debug if debug is not None else app_config.DEBUG

    if not word:
        return None  # Return None for empty strings

    decomposed_word = unicodedata.normalize(form, word)
    pattern_parts = []
    for char in decomposed_word:
        if unicodedata.category(char) == 'Mn':  # Is a diacritic mark
            # This character is a diacritic; make its presence optional in the pattern
            pattern_parts.append(r'?\p{M}*')  # Make diacritics optional
        else:
            # For non-diacritic characters, escape them and option
            pattern_parts.append(re.escape(char) + r'\p{M}*')  # Escape non-diacritics and allow diacritics

    pattern = ''.join(pattern_parts)
    logger.debug(f"Regex Pattern: {pattern}") if debug and debug_patterns else None

    # Construct the fuzzy pattern separately
    fuzzy_pattern = rf"(?:{pattern})"
    if max_errors > 0:
        fuzzy_pattern += rf"{{s<={max_errors}}}"

    logger.debug(f"word: {word}, fuzzy_pattern: {fuzzy_pattern}")  if debug and debug_patterns else None # Debug print

    return fuzzy_pattern

def find_word_index(sentence, word, word_before, word_after, form=None, debug=None, debug_patterns=None, max_errors=2, **kwargs):
    """
    Finds the index of a word within a sentence, allowing for various normalization options and
    tolerating diacritic variations and minor errors.
    Raises a ValueError if the word is not found in the sentence.
    """
    debug = debug if debug is not None else app_config.DEBUG

    form = form if form is not None else app_config.DEFAULT_FORM

    # Override/debug settings are explicitly set here
    kwargs['remove_accents'] = False
    kwargs['lowercase'] = True  
    kwargs['remove_extra_spaces'] = True
    kwargs["remove_brackets"] = False
    kwargs["form"] = form

    # Normalize inputs
    try:
        normalized_sentence = normalize_text(sentence, **{**app_config.__dict__, **kwargs})
        normalized_word = normalize_text(word, **{**app_config.__dict__, **kwargs})
        normalized_word_before = normalize_text(word_before, **{**app_config.__dict__, **kwargs}) if word_before else ""
        normalized_word_after = normalize_text(word_after, **{**app_config.__dict__, **kwargs}) if word_after else ""
    except Exception as e:
        logger.error(f"Error normalizing inputs: {e}")
        raise ValueError(f"Could not normalize inputs: sentence={sentence}, word={word}, word_before={word_before}, word_after={word_after}")

    logger.debug(f"Input: sentence={sentence}, \n word={word}, word_before={word_before}, word_after={word_after}, form={form}, kwargs={kwargs}") if debug and debug_patterns else None
    logger.debug(f"Normalized sentence: {normalized_sentence}") if debug and debug_patterns else None
    logger.debug("normalized_word: ", normalized_word, "normalized_word_before: ", normalized_word_before, "normalized_word_after: ", normalized_word_after) if debug and debug_patterns else None

    # Build exact and diacritic-agnostic patterns
    try:
        exact_word_pattern = build_exact_pattern(normalized_word)
        word_pattern = build_diacritic_agnostic_pattern(normalized_word, form=form, debug=debug, max_errors=max_errors)
        exact_word_before_pattern = build_exact_pattern(normalized_word_before)
        word_before_pattern = build_diacritic_agnostic_pattern(normalized_word_before, form=form, debug=debug, max_errors=max_errors)
        exact_word_after_pattern = build_exact_pattern(normalized_word_after) if word_after else None
        word_after_pattern = build_diacritic_agnostic_pattern(normalized_word_after, form=form, debug=debug, max_errors=max_errors)
        logger.debug(f"exact_word_pattern: {exact_word_pattern}") if debug and debug_patterns else None
        logger.debug(f"exact_word_before_pattern: {exact_word_before_pattern}") if debug else None
        logger.debug(f"exact_word_after_pattern: {exact_word_after_pattern}") if debug else None
        logger.debug(f"word_pattern: {word_pattern}") if debug and debug_patterns else None
        logger.debug(f"word_before_pattern: {word_before_pattern}") if debug else None
        logger.debug(f"word_after_pattern: {word_after_pattern}") if debug else None

    except Exception as e:
        logger.error(f"Error building patterns: {e}")
        raise ValueError(f"Could not build patterns for: word={word}, word_before={word_before}, word_after={word_after}")

    
    patterns = create_patterns(exact_word_pattern=exact_word_pattern, exact_word_before_pattern=exact_word_before_pattern, exact_word_after_pattern=exact_word_after_pattern, max_errors=max_errors, debug=debug, debug_patterns=debug_patterns)
    
    # Attempt to find an exact match first
    for pattern_name, pattern in patterns.items():
        logger.debug(f"Attempting with pattern: {pattern_name} with exact word pattern: {exact_word_pattern}") if debug and debug_patterns else None
        logger.debug(f"exact Pattern attempt: {pattern}")  if debug and debug_patterns else None # Print the pattern
        try:
            matches = re.finditer(pattern, normalized_sentence)
            # print each match and the groups
            for match in matches:
                #print all groups in match
                # Determine the group index containing the matched word
                start, end = match.start(1), match.end(1)  # Get the start and end indices of the matched word
                matched_word = match.group(1)  # Group containing the matched word
                if matched_word:  # check if matched_word is not None
                    matched_word = matched_word.rstrip()
                    start, end = match.start(1), match.start(1) + len(matched_word)  # Adjust the end index
                    if re.match(rf"{matched_word}{{e<={max_errors}}}", normalized_word, re.IGNORECASE) and len(matched_word) == len(normalized_word):
                        if debug and debug_patterns:
                            logger.debug(f"*Match found*: {matched_word} with exact word pattern {pattern_name} at indices {start}-{end}")
                        return start, end, normalized_sentence  # Return the start and end indices of the matched word
            logger.debug(f"!! No match found with exact word pattern: {pattern_name}") if debug and debug_patterns else None
        except Exception as e:
            logger.error(f"Error matching pattern '{pattern_name}': {e}") 


    # If no exact match is found, attempt to find a diacritic-agnostic match
    patterns = create_patterns(word_pattern=word_pattern, word_before_pattern=word_before_pattern, word_after_pattern=word_after_pattern, word_before=word_before, word_after=word_after, max_errors=max_errors, debug=debug, debug_patterns=debug_patterns)

    for pattern_name, pattern in patterns.items():
        logger.debug(f"Attempting diacritic-agnostic match with pattern: {pattern_name}") if debug and debug_patterns else None
        try:
            matches = re.finditer(pattern, normalized_sentence)
            for match in matches:
                start, end = match.start(1), match.end(1)  # Get the start and end indices of the matched word
                matched_word = match.group(1)  # Group containing the matched word
                if matched_word:  # check if matched_word is not None
                    matched_word = matched_word.rstrip()
                    start, end = match.start(1), match.start(1) + len(matched_word)  # Adjust the end index
                    if re.match(rf"{matched_word}{{e<={max_errors}}}", normalized_word, re.IGNORECASE) and len(matched_word) == len(normalized_word):
                        if debug:
                            logger.debug(f"* Diacritic-agnostic match found*: {matched_word} with pattern {pattern_name} at indices {start}-{end}") if debug and debug_patterns else None
                        return start, end, normalized_sentence  # Return the start and end indices of the matched word
            logger.debug(f"!! No match found with diacritic-agnostic pattern: {pattern_name}") if debug and debug_patterns else None
        except Exception as e:
            logger.error(f"Error matching pattern '{pattern_name}': {e}")

    # If no match is found, raise a ValueError
    raise ValueError(f"Word '{word}' not found in sentence '{sentence}'")

def create_patterns(exact_word_pattern=None, word_pattern=None, word_before=None, word_after=None, word_before_pattern=None, word_after_pattern=None, exact_word_before_pattern=None, exact_word_after_pattern=None, max_errors=2, debug=False, debug_patterns=False):
    patterns = {}

    # First, try to match the exact word pattern along with the exact word before and after patterns
    if exact_word_before_pattern and exact_word_after_pattern:
        both_exact_before_and_after_pattern = rf"(?:(?<!\p{{L}}){exact_word_before_pattern}\s*)({exact_word_pattern}|{word_pattern})(?:\s*{exact_word_after_pattern}(?!\p{{L}}))"
        logger.debug(f"exact_word_before_pattern in both_before_and_after: {exact_word_before_pattern}") if debug and debug_patterns else None
        logger.debug(f"exact_word_after_pattern in both_before_and_after: {exact_word_after_pattern}") if debug and debug_patterns else None
        logger.debug(f"both_before_and_after pattern: {both_exact_before_and_after_pattern}") if debug and debug_patterns else None
        patterns['both_before_and_after'] = both_exact_before_and_after_pattern        

    # When both before and after patterns are specified
    if word_before_pattern and word_after_pattern:
        patterns['both_before_and_after'] = rf"(?:(?<!\p{{L}}){word_before_pattern}\s*)({exact_word_pattern}|{word_pattern})(?:\s*{word_after_pattern}(?!\p{{L}}))"
        logger.debug(f"both_before_and_after pattern: {patterns['both_before_and_after']}") if debug and debug_patterns else None

    # When the before pattern is a single non-word character or None
    if exact_word_before_pattern or word_before_pattern and (len(word_before) <= 1 or word_before is None):
        patterns['before_single_or_empty'] = rf"(?:(?<!\p{{L}}){exact_word_before_pattern}|{word_before_pattern}\s*)({exact_word_pattern}|{word_pattern})(?!\p{{L}})"
        logger.debug(f"before_single_or_empty pattern: {patterns['before_single_or_empty']}") if debug and debug_patterns else None

    # When only the before pattern is specified and it's not a single non-word character
    logger.debug("CHECKKKKKEKE", word_before_pattern, word_before, len(word_before)) if debug and debug_patterns and word_before else None
    if exact_word_before_pattern or word_before_pattern and len(word_before) > 1:
        logger.debug("found word before!!! WooHOO!") if debug and debug_patterns else None
        patterns['only_before'] = rf"(?:(?<!\p{{L}}){exact_word_before_pattern}|{word_before_pattern}\s*)?({exact_word_pattern}|{word_pattern})(?!\p{{L}})"
        logger.debug(f"only_before pattern: {patterns['only_before']}") if debug and debug_patterns else None
    
    # when only the after pattern is specified and it's not a single non-word character
    if exact_word_after_pattern or word_after_pattern and len(word_after) > 1:
        patterns['only_after'] = rf"({exact_word_pattern}|{word_pattern})(?:\s*{exact_word_after_pattern}|{word_after_pattern}(?!\p{{L}}))"
        logger.debug(f"only_after pattern: {patterns['only_after']}") if debug and debug_patterns else None

    # When the after pattern is a single non-word character or None
    if exact_word_after_pattern or word_after_pattern and (len(word_after) <= 1 or word_after is None):
        patterns['after_single_or_empty'] = rf"({exact_word_pattern}|{word_pattern})(?:(?=\s?{exact_word_after_pattern}|{word_after_pattern})|$)(?!\p{{L}})"
        logger.debug(f"after_single_or_empty pattern: {patterns['after_single_or_empty']}") if debug and debug_patterns else None

    # Word at the start of the sentence (no preceding word boundary)
    patterns['start_of_sentence'] = rf"^({exact_word_pattern}|{word_pattern})(?=\s|\p{{P}}|$)"
    logger.debug(f"start_of_sentence pattern: {patterns['start_of_sentence']}") if debug and debug_patterns else None

    # Word at the end of the sentence (no following word boundary)
    patterns['end_of_sentence'] = rf"(?<=^|\s|\p{{P}})({exact_word_pattern}|{word_pattern})$"
    logger.debug(f"end_of_sentence pattern: {patterns['end_of_sentence']}") if debug and debug_patterns else None

    # Word anywhere in the sentence, not accounting for specific before/after context
    #patterns['anywhere_in_sentence'] = rf"(?<!\p{{L}})({exact_word_pattern}|{word_pattern})(?!\p{{L}})"
    #print(f"anywhere_in_sentence pattern: {patterns['anywhere_in_sentence']}") if debug and debug_patterns else None


    # Debugging code
    if debug and debug_patterns:
        # Check if 'both_before_and_after' pattern exists and print it
        if 'both_before_and_after' in patterns:
            logger.debug(f"both_before_and_after pattern: {patterns['both_before_and_after']}")
            logger.debug(f"both_before_and_after pattern matches sentence: {bool(re.search(patterns['both_before_and_after'], sentence))}")

        # Check if "exact_word_before_pattern" exists and print it
        if exact_word_before_pattern:
            logger.debug(f"exact_word_before_pattern: {exact_word_before_pattern}")
            logger.debug(f"exact_word_before_pattern matches sentence: {bool(re.search(exact_word_before_pattern, sentence))}")
            
        # Check if 'word_before_pattern' exists and print it
        if word_before_pattern:
            logger.debug(f"word_before_pattern: {word_before_pattern}")
            logger.debug(f"word_before_pattern matches sentence: {bool(re.search(word_before_pattern, sentence))}")

        # Check if "exact_word_after_pattern" exists and print it
        if exact_word_after_pattern:
            logger.debug(f"exact_word_after_pattern: {exact_word_after_pattern}")
            logger.debug(f"exact_word_after_pattern matches sentence: {bool(re.search(exact_word_after_pattern, sentence))}")
            
        # Check if 'word_after_pattern' exists and print it
        if word_after_pattern:
            logger.debug(f"word_after_pattern: {word_after_pattern}")
            logger.debug(f"word_after_pattern matches sentence: {bool(re.search(word_after_pattern, sentence))}")

    return patterns

# %%
def prepare_training_data(df, form=None, debug=None, debug_patterns=None, debug_inception=None, **kwargs):
    """
    Prepares the training data by finding entity indices within normalized sentences.
    Returns a list of training data and a list of words not found in their sentences.
    """
    # Apply normalization as per configurations or provided form
    debug = debug if debug is not None else app_config.DEBUG
    
    # Ensuring 'remove_accents' and 'lowercase' have fixed values for this function's purpose
    kwargs['remove_accents'] = False
    kwargs['lowercase'] = True  # Override/debug settings are explicitly set here
    kwargs['remove_extra_spaces'] = True
    kwargs["remove_brackets"] = False
    kwargs["form"] = form
    logger.debug("kwargs: ", kwargs) if debug else None

    TRAIN_DATA = []
    not_found_list = []
    found_entities = 0

    for i, (_, row) in enumerate(df.iterrows(), start=1):
        new_entities = []
        sentence = row['Quote']
        source = row['Source']
        logger.debug(f"Sentence {i}: {sentence}, Source: {source}") if debug else None
        for entity in row['Entities']:
            logger.debug (f"Entity: {entity}") if debug else None
            try:
                category, word, word_before, word_after = entity
                logger.debug(f"Category: {category}, Word: {word}, Word Before: {word_before}, Word After: {word_after}") if debug else None
                start, end, _ = find_word_index(sentence, word, word_before, word_after, **{**app_config.__dict__, **kwargs}, debug=debug)
                new_entities.append((start, end, category))
                found_entities += 1
            except Exception as e:
                logger.error(f"Error finding word index for entity {entity}: {e}")
                not_found_list.append((word, sentence))
        
        logger.debug(f"Found {len(new_entities)} entities in this sentence.") if debug else None
        normalized_sentence = normalize_text(sentence, **{**app_config.__dict__, **kwargs})
        TRAIN_DATA.append((normalized_sentence, {'entities': new_entities}, source))

    logger.info(f"Completed preparing training data from table. Total entries: {len(TRAIN_DATA)}. Entities found and registered: {found_entities}. Entities not found: {len(not_found_list)}")
    return TRAIN_DATA, not_found_list

# %%
Dataa = []
new_entities = []
#('ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται'
#'Coda, Hippocrates, Sacred Disease, C(3), S(4), P(11), L(20)')
#[['Topography', 'ἄνω', 'ἑτέρη ', 'τείνει '], ['Topography', 'τείνει', 'ἄνω ', 'διὰ '], ['Topography', 'διὰ', 'τείνει ', 'τῶν '], ['Body Part', 'φρενῶν', 'τῶν ', 'καὶ '], ['Body Part', 'πλεύμονος', 'τοῦ ', 'τῶν'], [nan, 'τῶν', 'πλεύμονος ', 'δεξιῶν'], ['Topography', 'δεξιῶν', 'τῶν', 'ἀπέσχισται '], ['Topography', 'ἀπέσχισται', 'δεξιῶν', 'δὲ '], ['Topography', 'ἐς', 'καὶ ', 'τὴν '], ['Body Part', 'καρδίην', 'τὴν ', 'καὶ '], ['Topography', 'ἐς', 'καὶ ', 'τὸν'], ['Body Part', 'βραχίονα', 'τὸν', 'τὸν'], ['Topography', 'δεξιόν', 'τὸν', 'καὶ '], ['Topography', 'ἄνω', 'λοιπὸν ', 'φέρει '], ['Topography', 'φέρει', 'ἄνω ', 'διὰ '], ['Topography', 'διὰ', 'φέρει ', 'τῆς '], ['Body Part', 'κληῗδος', 'τῆς', 'ἐς '], ['Topography', 'τὰ δεξιὰ', 'ἐς', 'τοῦ αὐχένος'], ['Body Part', 'αὐχένος', 'τοῦ ', 'ἐς '], ['Topography', 'ἐς', 'αὐχένος', 'αὐτὸ '], ['Body Part', 'δέρμα', 'αὐτὸ τὸ ', 'ὥστε'], ['Topography', 'κατάδηλος', 'ὥστε', 'εἶναι'], ['Topography', 'κρύπτεται', 'οὖς ', 'καὶ'], ['Topography', 'ἐνταῦθα', 'καὶ', 'σχίζεται'], ['Topography', 'σχίζεται', 'ἐνταῦθα ', '.']]
#sentence = 'ἡ δʼ ἑτέρη ἄνω τείνει διὰ τῶν φρενῶν καὶ τοῦ πλεύμονος τῶν δεξιῶν, ἀπέσχισται δὲ καὶ ἐς τὴν καρδίην καὶ ἐς τὸν βραχίονα τὸν δεξιόν, καὶ τὸ δὲ λοιπὸν ἄνω φέρει διὰ τῆς κληῗδος ἐς τὰ δεξιὰ τοῦ αὐχένος, ἐς αὐτὸ τὸ δέρμα ὥστε κατάδηλος εἶναι, παρʼ αὐτὸ δὲ τὸ οὖς κρύπτεται καὶ ἐνταῦθα σχίζεται'
#word = 'ἀπέσχισται'
#word_before = 'τείνει διὰ'
#word_after = 'φρενῶν καὶ'
#κάτω κοιλίας
#[['Body Part', 'γένειον', 'τὸ πρόσθιον', ', τὸ δʼ'], ['Body Part', 'γένυς', 'δʼ ὀπίσθιον', '. Κινεῖ δὲ'], ['Adjectives/Qualities', 'πρόσθιον', 'τούτων τὸ', 'γένειον, τὸ'], ['Adjectives/Qualities', 'ὀπίσθιον', 'τὸ δʼ', 'γένυς. Κινεῖ'], ['Division', 'τὸ', 'δύο· τούτων', 'πρόσθιον γένειον'], ['Division', 'τὸ', 'πρόσθιον γένειον,', 'δʼ ὀπίσθιον']]
#'Division', 'τὸ', 'δύο· τούτων', 'πρόσθιον γένειον'], ['Division', 'τὸ', 'πρόσθιον γένειον,', 'δʼ ὀπίσθιον']]
sentence="τούτων τὸ πρόσθιον γένειον, τὸ δʼ ὀπίσθιον γένυς"
word='τὸ'
word_before='δύο· τούτων'
word_after='πρόσθιον γένειον'

#word='τὸ'
#word_before='πρόσθιον γένειον,'
#word_after='δʼ ὀπίσθιον'

# Call the function with the test data
start, end, normalized_sentence = find_word_index(sentence, word, word_before, word_after, form='NFKD', debug=True, debug_patterns=True, max_errors=2)

# Print the result
print(f"Start: {start}, End: {end}") 
print(f"Characters between start and end: '{normalized_sentence[start:end]}'")

#normalized_sentence = normalize_text(sentence, form='NFKC', remove_accents=False, lowercase=True, remove_extra_spaces=True)
Dataa.append((normalized_sentence, {'entities': [(start, end, 'LABEL')]}, 'SOURCE'))
print(Dataa)
# Out:
# 2024-05-15 18:02:34,701 - DEBUG - root - Input: sentence=τούτων τὸ πρόσθιον γένειον, τὸ δʼ ὀπίσθιον γένυς,
#  word=τὸ, word_before=δύο· τούτων, word_after=πρόσθιον γένειον, form=NFKD, kwargs={'remove_accents': False, 'lowercase': True, 'remove_extra_spaces': True, 'remove_brackets': False, 'form': 'NFKD'}
# 2024-05-15 18:02:34,702 - DEBUG - root - Normalized sentence: τούτων τὸ πρόσθιον γένειον, τὸ δʼ ὀπίσθιον γένυς
# --- Logging error ---
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_909/2334249003.py", line 48, in <module>
#     start, end, normalized_sentence = find_word_index(sentence, word, word_before, word_after, form='NFKD', debug=True, debug_patterns=True, max_errors=2)
#   File "/tmp/ipykernel_909/4003486178.py", line 73, in find_word_index
#     logger.debug("normalized_word: ", normalized_word, "normalized_word_before: ", normalized_word_before, "normalized_word_after: ", normalized_word_after) if debug and debug_patterns else None
# Message: 'normalized_word: '
# Arguments: ('τὸ', 'normalized_word_before: ', 'δύο· τούτων', 'normalized_word_after: ', 'πρόσθιον γένειον')
# 2024-05-15 18:02:34,704 - DEBUG - root - exact_word_pattern: τὸ
# 2024-05-15 18:02:34,704 - DEBUG - root - exact_word_before_pattern: δύο·\ τούτων
# 2024-05-15 18:02:34,705 - DEBUG - root - exact_word_after_pattern: πρόσθιον\ γένειον
# 2024-05-15 18:02:34,705 - DEBUG - root - word_pattern: (?:τ\p{M}*ο\p{M}*?\p{M}*){s<=2}
# 2024-05-15 18:02:34,706 - DEBUG - root - word_before_pattern: (?:δ\p{M}*υ\p{M}*?\p{M}*ο\p{M}*·\p{M}*\ \p{M}*τ\p{M}*ο\p{M}*υ\p{M}*?\p{M}*τ\p{M}*ω\p{M}*ν\p{M}*){s<=2}
# 2024-05-15 18:02:34,706 - DEBUG - root - word_after_pattern: (?:π\p{M}*ρ\p{M}*ο\p{M}*?\p{M}*σ\p{M}*θ\p{M}*ι\p{M}*ο\p{M}*ν\p{M}*\ \p{M}*γ\p{M}*ε\p{M}*?\p{M}*ν\p{M}*ε\p{M}*ι\p{M}*ο\p{M}*ν\p{M}*){s<=2}
# 2024-05-15 18:02:34,706 - DEBUG - root - exact_word_before_pattern in both_before_and_after: δύο·\ τούτων
# 2024-05-15 18:02:34,708 - DEBUG - root - exact_word_after_pattern in both_before_and_after: πρόσθιον\ γένειον
# 2024-05-15 18:02:34,709 - DEBUG - root - both_before_and_after pattern: (?:(?<!\p{L})δύο·\ τούτων\s*)(τὸ|None)(?:\s*πρόσθιον\ γένειον(?!\p{L}))
# 2024-05-15 18:02:34,709 - DEBUG - root - before_single_or_empty pattern: (?:(?<!\p{L})δύο·\ τούτων|None\s*)(τὸ|None)(?!\p{L})
# 2024-05-15 18:02:34,709 - DEBUG - root - found word before!!! WooHOO!
# 2024-05-15 18:02:34,710 - DEBUG - root - only_before pattern: (?:(?<!\p{L})δύο·\ τούτων|None\s*)?(τὸ|None)(?!\p{L})
# 2024-05-15 18:02:34,711 - DEBUG - root - only_after pattern: (τὸ|None)(?:\s*πρόσθιον\ γένειον|None(?!\p{L}))
# 2024-05-15 18:02:34,712 - DEBUG - root - after_single_or_empty pattern: (τὸ|None)(?:(?=\s?πρόσθιον\ γένειον|None)|$)(?!\p{L})
# 2024-05-15 18:02:34,712 - DEBUG - root - start_of_sentence pattern: ^(τὸ|None)(?=\s|\p{P}|$)
# 2024-05-15 18:02:34,713 - DEBUG - root - end_of_sentence pattern: (?<=^|\s|\p{P})(τὸ|None)$
# 2024-05-15 18:02:34,714 - DEBUG - root - both_before_and_after pattern: (?:(?<!\p{L})δύο·\ τούτων\s*)(τὸ|None)(?:\s*πρόσθιον\ γένειον(?!\p{L}))
# 2024-05-15 18:02:34,715 - DEBUG - root - both_before_and_after pattern matches sentence: False
# 2024-05-15 18:02:34,715 - DEBUG - root - exact_word_before_pattern: δύο·\ τούτων
# 2024-05-15 18:02:34,716 - DEBUG - root - exact_word_before_pattern matches sentence: False
# 2024-05-15 18:02:34,717 - DEBUG - root - exact_word_after_pattern: πρόσθιον\ γένειον
# 2024-05-15 18:02:34,718 - DEBUG - root - exact_word_after_pattern matches sentence: True
# 2024-05-15 18:02:34,719 - DEBUG - root - Attempting with pattern: both_before_and_after with exact word pattern: τὸ
# 2024-05-15 18:02:34,720 - DEBUG - root - exact Pattern attempt: (?:(?<!\p{L})δύο·\ τούτων\s*)(τὸ|None)(?:\s*πρόσθιον\ γένειον(?!\p{L}))
# 2024-05-15 18:02:34,720 - DEBUG - root - !! No match found with exact word pattern: both_before_and_after
# 2024-05-15 18:02:34,720 - DEBUG - root - Attempting with pattern: before_single_or_empty with exact word pattern: τὸ
# 2024-05-15 18:02:34,721 - DEBUG - root - exact Pattern attempt: (?:(?<!\p{L})δύο·\ τούτων|None\s*)(τὸ|None)(?!\p{L})
# 2024-05-15 18:02:34,722 - DEBUG - root - !! No match found with exact word pattern: before_single_or_empty
# 2024-05-15 18:02:34,722 - DEBUG - root - Attempting with pattern: only_before with exact word pattern: τὸ
# 2024-05-15 18:02:34,723 - DEBUG - root - exact Pattern attempt: (?:(?<!\p{L})δύο·\ τούτων|None\s*)?(τὸ|None)(?!\p{L})
# 2024-05-15 18:02:34,724 - DEBUG - root - *Match found*: τὸ with exact word pattern only_before at indices 8-11
# Start: 8, End: 11
# Characters between start and end: 'τὸ'
# [('τούτων τὸ πρόσθιον γένειον, τὸ δʼ ὀπίσθιον γένυς', {'entities': [(8, 11, 'LABEL')]}, 'SOURCE')]

# %% [markdown]
# # Add annotations from INCEpTION

# %%
# extract all files in inception folder to temp folder
from cassis import *
import zipfile
import tempfile
import os
from spacy.training import Example

# %%
import os
import zipfile
import tempfile
from cassis import *

TYPESYSTEM_FILENAME = "TypeSystem.xml"

def extract_and_process_zip_files(input_path, form=None, debug=None, debug_inception=None):
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = app_config.DEBUG

    with zipfile.ZipFile(input_path, 'r') as zip_ref:
        with tempfile.TemporaryDirectory() as tempdir:
            zip_ref.extractall(tempdir)
            # Get the basename of the .zip file for use as an identifier
            base_zip_filename = os.path.splitext(os.path.basename(input_path))[0]
            process_extracted_files(tempdir, base_zip_filename, form, debug, debug_inception)

def process_extracted_files(directory, base_zip_filename, form=None, debug=None, debug_inception=None):
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = debug if debug is not None else app_config.DEBUG

    typesystem = None
    # Load the typesystem only once
    try:
        with open(os.path.join(directory, TYPESYSTEM_FILENAME), 'rb') as f:
            typesystem = load_typesystem(f)
    except Exception as e:
        logger.error(f"Failed to load TypeSystem: {e}")
        return

    for f in os.listdir(directory):
        if f.endswith(".xmi"):
            # Pass the base name of the zip file concatenated with the XMI file name
            file_identifier = f"{os.path.splitext(f)[0]}"
            process_xmi_file(os.path.join(directory, f), typesystem, file_identifier, form, debug, debug_inception)

def process_xmi_file(filename, typesystem, file_identifier, form=None, debug=None, debug_inception=None):
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = app_config.DEBUG

    try:
        with open(filename, 'rb') as f:
            cas = load_cas_from_xmi(f, typesystem=typesystem)
            logger.debug(f"Processing file: {filename} as {file_identifier}") if debug_inception else None
            process_cas(cas, file_identifier, form, debug, debug_inception)
    except Exception as e:
        logger.error(f"Error processing file {filename}: {e}")

def process_cas(cas, file_identifier, form=None, debug=None, debug_inception=None):
    # Apply normalization as per configurations or provided form
    form = form if form is not None else app_config.DEFAULT_FORM
    debug = app_config.DEBUG

    for sentence in cas.select(("de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Sentence")):
        process_sentence(sentence, cas, file_identifier, form, debug, debug_inception)



def calculate_token_positions(normalized_sentence_text, adjusted_token_start, normalized_token_text, debug=None):
    """
    Attempts to adjust token positions from original indices considering the normalized sentence text, 
    with awareness of potential non-uniform normalization effects.
    
    Args:
    - normalized_sentence_text (str): The full sentence text after normalization.
    - adjusted_token_start (int): Original start index of the token before normalization.
    - normalized_token_text (str): The specific token text after normalization.
    - debug (bool): If provided and True, enables debug outputs.

    Returns:
    Tuple[int, int]: Adjusted start and end indices of the token in the normalized sentence.
    """
    debug = debug if debug is not None else app_config.DEBUG

    # Validate input data
    if not normalized_sentence_text:
        logger.error("Normalized sentence text is empty.")
        return None

    # Attempt to find the closest match of the normalized token in the normalized text
    try:
        window_size = len(normalized_token_text)
        positions = [(i, i + window_size) for i in range(len(normalized_sentence_text) - window_size + 1)
                     if normalized_sentence_text[i:i+window_size] == normalized_token_text]

        if not positions:
            logger.warning(f"Token '{normalized_token_text}' not found in the normalized text.")
            return None
    
        # Choose the position that is closest to the original position
        new_token_begin, new_token_end = min(positions, key=lambda pos: abs(pos[0] - adjusted_token_start))
    
        logger.debug(f"Adjusted indices: {new_token_begin}-{new_token_end} for token '{normalized_token_text}' in normalized text.")
        return new_token_begin, new_token_end
    except Exception as e:
        logger.error(f"Unexpected error occurred while calculating token positions: {e}")
        return None


def process_sentence(sentence, cas, file_identifier, form=None, debug=None, debug_inception=None, **kwargs):
    """
    Processes each sentence from the CAS file, extracts entity tokens along with labels,
    calculates corrected token positions based on the cleaned sentence,
    and appends to INCEPTION_TRAIN_DATA for NER training.
    """
    # Apply normalization as per configurations or provided form
    debug = debug if debug is not None else app_config.DEBUG
    # Ensuring 'remove_accents' and 'lowercase' have fixed values for this function's purpose
    kwargs['remove_accents'] = False
    kwargs['lowercase'] = True  # Override/debug settings are explicitly set here
    kwargs['remove_extra_spaces'] = True
    kwargs["remove_brackets"] = False
    kwargs["form"] = form
    logger.debug("kwargs: %s", kwargs) if debug else None

    # Normalize inputs
    ents = []
    original_sentence_text = sentence.get_covered_text()
    normalized_sentence_text = normalize_text(original_sentence_text, **{**app_config.__dict__, **kwargs})
    
    sentence_start_offset = sentence.begin  # Sentence start relative to the full document

    logger.debug("Final FORM: %s", form) if debug_inception else None
    logger.debug("original sentence: %s", original_sentence_text) if debug_inception else None
    logger.debug("normalized_sentence_text: %s", normalized_sentence_text) if debug_inception else None

    for token in cas.select_covered('webanno.custom.CategoryType', sentence):
        # Adjust token indices to be relative to the start of the sentence
        adjusted_token_start = token.begin - sentence_start_offset
        adjusted_token_end = token.end - sentence_start_offset
        logger.debug(f"Token index: {token.begin}-{token.end}, Adjusted index for sentence: {adjusted_token_start}-{adjusted_token_end}, Token text: {token.get_covered_text()}") if debug_inception else None
        normalized_token_text = normalize_text(token.get_covered_text(), **{**app_config.__dict__, **kwargs})
        token_positions = calculate_token_positions(normalized_sentence_text, adjusted_token_start, normalized_token_text, debug=debug_inception)
        if token_positions is None:
            logger.error(f"Error calculating positions for token '{token.get_covered_text()}' in sentence '{original_sentence_text}'")
            continue
        
        new_token_begin, new_token_end = token_positions
        original_sentence_text = sentence.get_covered_text()
        #token_text = token.get_covered_text()  # This returns the original token text

        logger.debug("normalized_token_text: %s", normalized_token_text) if debug_inception else None
        logger.debug("new_token_begin: %s, new_token_end: %s, token value: %s", new_token_begin, new_token_end, token.value("Value")) if debug_inception else None
        ents.append((new_token_begin, new_token_end, token.value("Value")))  # Append the new token positions and the label to the entities list

    if ents:  # Only consider sentences with entities
        INCEPTION_TRAIN_DATA.append((normalized_sentence_text, {'entities': ents}, file_identifier))
        logger.debug("normalized sentence: %s", normalized_sentence_text) if debug_inception else None
    return INCEPTION_TRAIN_DATA

# %%
def process_sentences_and_serialize(input_path, nlp, normalization_forms, output_dir, debug=None, debug_patterns=None, debug_inception=None, output_file_name: str = None):

    debug = debug if debug is not None else app_config.DEBUG

    for form in normalization_forms:
        # Prepare the training data for the current normalization form from Coda
        global INCEPTION_TRAIN_DATA
        INCEPTION_TRAIN_DATA = []  # Reset INCEPTION_TRAIN_DATA for each form
        
        global TRAIN_DATA, not_found_list
        TRAIN_DATA, not_found_list = prepare_training_data(df_final, form=form, debug=debug, debug_patterns=debug_patterns, debug_inception=debug_inception, **app_config.__dict__)
        
        
        # Prepare the training data for the current normalization form from INCEpTION
        for file_path in Path(input_path).glob("*.zip"):
            print("file name: ",file_path.name)  # Progress indicator
            extract_and_process_zip_files(file_path, form, debug, debug_inception)
        
        #merge the two training data, while removing duplicates
        global MERGED_TRAIN_DATA
        MERGED_TRAIN_DATA = TRAIN_DATA + INCEPTION_TRAIN_DATA
        
        split_docs(MERGED_TRAIN_DATA, nlp, form=form, output_dir=output_dir, output_file_name=output_file_name, debug=debug)
        return MERGED_TRAIN_DATA

# %%
import os
from typing import List, Tuple, Optional
import configparser
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor
import random

from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit
from sklearn.utils import indexable, _safe_indexing
from sklearn.utils.validation import _num_samples
from sklearn.model_selection._split import _validate_shuffle_split
from itertools import chain
import numpy as np

from spacy.tokens import DocBin

# Load configuration from a file
config = configparser.ConfigParser()
config.read('config.ini')

TEST_SIZE = config.getfloat('SPLIT', 'test_size', fallback=0.2)
RANDOM_STATE = config.getint('SPLIT', 'random_state', fallback=42)
DEBUG = config.getboolean('GENERAL', 'debug', fallback=False)

def process_sentences(data, nlp, output_dir, output_file_name=None, form=None, debug=None):
    """
    Process the input data into a list of Doc objects.

    Args:
        data: The input data to be processed.
        nlp: The natural language processing object.
        output_dir: The output directory for serialized files.
        output_file_name: The base name for the output file (optional).
        form: The normalization form.

    Returns:
        A list of Doc objects.
    """

    debug = debug if debug is not None else DEBUG
    form = form if form is not None else DEBUG

    docs = []
    missing_entities = []
    total_entities = 0
    processed_docs = 0
    
    # Create a dictionary to track changes in entity text    
    for data_entry in data:
        entity_text_changes = {}

        if len(data_entry) == 3:
            text, annot, file_identifier = data_entry
            logger.debug(f"Current data_entry: {text}, {annot}, {file_identifier}")
        else:
            file_identifier = "Coda"
            text, annot = data_entry
            logger.debug(f"Current data_entry (without source identifier): {text}, {annot}")

        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annot["entities"]:
            logger.debug(f"start: {start}, end: {end}, label: {label}")
            if label == label and label is not None:  # Checks for NaN and None
                # Get the original and new entity text
                original_entity_text = text[start:end]
                
                # Find the tokens that overlap with the entity
                tokens = [token for token in doc if not (token.idx + len(token.text) <= start or token.idx >= end)]
                if tokens:
                    # Adjust start and end to match the token boundaries
                    start = tokens[0].idx
                    end = tokens[-1].idx + len(tokens[-1].text)
                    
                    #logging.debug(f"start is: {start}")
                    #logging.debug(f"end is: {end}")
                    span = doc.char_span(start, end, label=label, alignment_mode="expand")
                    #logger.debug(f"span is: {span}")
                    if span:
                        ents.append(span)
                        # Get the new entity text from the Span
                        new_entity_text = span.text                    
                        # If the entity text has changed, add it to the dictionary
                        if original_entity_text != new_entity_text:
                            entity_text_changes[original_entity_text] = new_entity_text
                    else:
                        logger.warning(f"Invalid span: {text[start:end]} [{start},{end}] cannot be mapped to a valid `Doc` span.")
                        
        # Before filtering
        unfiltered_ents = ents
        #filter overlapping entities
        filtered_ents = spacy.util.filter_spans(unfiltered_ents)
        # After filtering, appending to doc
        doc.ents = filtered_ents
        doc.user_data["source_info"] = file_identifier
        docs.append(doc)
        logger.debug(f"Processed document {processed_docs} with {len(filtered_ents)} entities in {file_identifier}") if debug else None
        processed_docs += 1
        total_entities += len(filtered_ents)

        # Print the changes in entity text
        for original_text, new_text in entity_text_changes.items():
            logger.debug(f"Entity text changed from '{original_text}' to '{new_text}'")
    
        # Validation: Check missed annotations
        for start, end, label in annot["entities"]:
            # Find the tokens that overlap with the entity
            tokens = [token for token in doc if not (token.idx + len(token.text) <= start or token.idx >= end)]
            if tokens:
                # Adjust start and end to match the token boundaries
                start = tokens[0].idx
                end = tokens[-1].idx + len(tokens[-1].text)

                if not any(start == ent.start_char and end == ent.end_char and label == ent.label_ for ent in filtered_ents):
                    missing_entities.append((text[start:end], label))
                    logger.warning(f"Missing entity: {text[start:end]} [{start},{end}] with label {label} in sentence: {text} in {file_identifier}")

                    # Check if the missing entity was in the unfiltered entities
                    if any(start == ent.start_char and end == ent.end_char and label == ent.label_ for ent in unfiltered_ents):
                        logger.warning(f"The entity was filtered out by spacy.util.filter_spans")
                                            
    logger.info(f"{processed_docs} documents processed with a total of {total_entities} entities.")
    if missing_entities:
        logger.warning(f"total missing entities: {len(missing_entities)}, Missing entities not mapped to SpaCy entities: {missing_entities}")

    # Random checks
    if debug:
        # doc 288
        doc = random.choice(docs)
        logger.info("Sample SpaCy entities, for line:")
        logger.info(f"Text: {doc.text}")
        logger.info(f"Entities: {[(ent.text, ent.label_) for ent in doc.ents]} from source: {doc.user_data['source_info']}")

    # Find and display details for the randomly chosen document from MERGED_TRAIN_DATA
    if debug:
        for data_entry in data:
            entry_text = data_entry[1] if len(data_entry) == 3 else data_entry[0]
            if entry_text == doc.text:
                logger.info("\nOriginal table entities, for the same line:")
                annot_field = 2 if len(data_entry) == 3 else 1
                for entity in data_entry[annot_field]['entities']:
                    entity_text = entry_text[entity[0]:entity[1]]
                    logger.info(f"{entity_text}, {entity[2]}")
                break
    return docs

def create_label_array(docs: List) -> np.ndarray:
    """
    Create a NumPy array representing the labels for each document.

    Args:
        docs: A list of Doc objects.

    Returns:
        A NumPy array of shape (len(docs), num_unique_labels).
    """
    labels_ints = []
    for doc in docs:
        labels_ints.extend([token.ent_iob_ for token in doc])

    unique_labels = np.unique(labels_ints)
    labels_nd_array = np.zeros((len(docs), len(unique_labels)), dtype=int)

    for i, doc in enumerate(docs):
        doc_labels = [token.ent_iob_ for token in doc]
        labels_nd_array[i, np.isin(unique_labels, doc_labels)] = 1

    return labels_nd_array

def split_docs(merged_train_data, nlp, form, output_dir, store_user_data: bool = True, output_file_name: Optional[str] = None, debug=None):
    """
    Split the input data into train, dev, and test sets, and serialize them into binary files.

    Args:
        merged_train_data: The input data to be split.
        nlp: The natural language processing object.
        form: The normalization form.
        output_dir: The output directory for serialized files.
        store_user_data: Whether to store user data in the serialized files.
        output_file_name: The base name for the output file (optional).
    """

    debug = debug if debug is not None else DEBUG

    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)  # Ensure output directory exists

    # Process the merged train data to get docs
    docs = process_sentences(merged_train_data, nlp, output_dir, output_file_name=output_file_name, form=form)

    if docs:  # Check that docs is non-empty to avoid errors
        # Create a NumPy array representing the labels for each document
        labels_nd_array = create_label_array(docs)

        # Split the docs into train and test sets using multilabel stratification
        X_train, X_test = multilabel_train_test_split(docs, stratify=labels_nd_array, test_size=TEST_SIZE, random_state=RANDOM_STATE)

        # Split the test set into dev and test sets using multilabel stratification
        X_dev, X_test = multilabel_train_test_split(X_test, stratify=create_label_array(X_test), test_size=0.5, random_state=RANDOM_STATE)
    else:
        logger.info(f"No documents found for normalization form {form}. Skipping serialization.")
        return  # Early return if docs is empty to avoid proceeding with undefined variables

    subsets = {'train': X_train, 'dev': X_dev, 'test': X_test}

    # Use ThreadPoolExecutor for parallel serialization
    with ThreadPoolExecutor() as executor:
        futures = []
        for subset_name, subset_docs in subsets.items():
            if output_file_name is not None:
                output_path = output_dir / f"{subset_name}/ner_{subset_name}/{output_file_name}_{subset_name}_{form}.spacy"
            else:
                output_path = output_dir / f"{subset_name}/ner_{subset_name}/ner_{subset_name}_{form}.spacy"

            future = executor.submit(serialize_docs, subset_docs, output_path, store_user_data, form, subset_name)
            futures.append(future)

        for future in futures:
            result = future.result()
            logger.debug(result) if DEBUG else None

    # Print the number of docs in each set
    logger.info(f"Train: {len(X_train)}")
    logger.info(f"Test: {len(X_test)}")
    logger.info(f"Dev: {len(X_dev)}")

def serialize_docs(docs, output_path, store_user_data, form, subset_name, debug=None):
    """
    Serialize a list of Doc objects into a binary file.

    Args:
        docs: A list of Doc objects.
        output_path: The output file path.
        store_user_data: Whether to store user data in the serialized file.
        form: The normalization form.
        subset_name: The name of the subset (train, dev, or test).

    Returns:
        A success message.
    """

    debug = debug if debug is not None else DEBUG

    doc_bin = DocBin(docs=docs, store_user_data=store_user_data)
    doc_bin.to_disk(output_path)
    return f"Saved {len(docs)} docs for normalization form {form} to {output_path}"

def multilabel_train_test_split(*arrays,
                                test_size=None,
                                train_size=None,
                                random_state=None,
                                shuffle=True,
                                stratify=None):
    """
    Train test split for multilabel classification. Uses the algorithm from:
    'Sechidis K., Tsoumakas G., Vlahavas I. (2011) On the Stratification of Multi-Label Data'.
    """
    if stratify is None:
        return train_test_split(*arrays, test_size=test_size, train_size=train_size,
                                random_state=random_state, stratify=None, shuffle=shuffle)

    assert shuffle, "Stratified train/test split is not implemented for shuffle=False"

    n_arrays = len(arrays)
    arrays = indexable(*arrays)
    n_samples = _num_samples(arrays[0])
    n_train, n_test = _validate_shuffle_split(
        n_samples, test_size, train_size, default_test_size=0.25
    )
    cv = MultilabelStratifiedShuffleSplit(test_size=n_test, train_size=n_train, random_state=RANDOM_STATE)
    train, test = next(cv.split(X=arrays[0], y=stratify))

    return list(
        chain.from_iterable(
            (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
        )
    )

# %%
import spacy
import random

# Assuming `nlp` is your preloaded SpaCy model
nlp = spacy.load("../training/SageMaker/transformer/PROIEL/Assembled/pos-trf-11-may-2024/model-best/")  # Example with a blank English model. Replace according to your model.
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/spacy_transformers/layers/hf_shim.py:137: UserWarning: Error loading saved torch state_dict with strict=True, likely due to differences between 'transformers' versions. Attempting to load with strict=False as a fallback...
#
# If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current 'transformers' and 'spacy-transformers' versions. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
import cProfile

def main():
    # Your existing code...
    process_sentences_and_serialize(input_path=Path("../assets/NER_assets/INCEpTION_files/"), nlp=nlp, normalization_forms=["NFKC"], output_dir=Path("../corpus/"), debug=False, debug_patterns=False, debug_inception=True, output_file_name="Tess")

if __name__ == '__main__':
    main()
# Out:
# 2024-05-15 18:02:58,204 - ERROR - root - Error finding word index for entity ['Adjectives/Qualities', 'μονοφυές', 'γὰρ ὡς', 'ἑκάτερον, καὶ']: Word 'μονοφυές' not found in sentence 'καὶ γὰρ ὡς μονοφυὲς ἑκάτερον, καὶ ὡς ἀνθʼ ἑνὸς δύο παραπλησίαν ἔχοντα τὴν φύσιν.'
# 2024-05-15 18:02:58,242 - ERROR - root - Error finding word index for entity ['Topography', 'πρός', 'καλούμεναι φρένες,', 'μέν τὰ']: Word 'πρός' not found in sentence 'Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη'
# 2024-05-15 18:02:58,267 - ERROR - root - Error finding word index for entity ['Body Part', 'κοῖλον', 'συνήρτηται', 'ἐστίν']: Word 'κοῖλον' not found in sentence 'ᾗ δὲ συνήρτηται κοῖλόν ἐστιν'
# 2024-05-15 18:02:58,283 - ERROR - root - Error finding word index for entity ['Adjectives/Qualities', 'ξηρόν', 'οὔτε', 'οὔθʼ']: Word 'ξηρόν' not found in sentence 'Ἡ μὲν οὖν ἀρτηρία τοῦτον ἔχει τὸν τρόπον, καὶ δέχεται μόνον τὸ πνεῦμα καὶ ἀφίησιν ἄλλο δʼ οὐθὲν οὔτε ξηρὸν οὔθʼ ὑγρόν, ἢ πόνον παρέχει, ἕως ἂν ἐκβήξῃ τὸ κατελθόν'
# 2024-05-15 18:02:58,870 - INFO - root - Completed preparing training data from table. Total entries: 214. Entities found and registered: 1520. Entities not found: 4
# 2024-05-15 18:02:58,918 - DEBUG - root - Processing file: /tmp/tmptb7h2wvt/Aristotle_Historia_Animalium_511a22-34.xmi as Aristotle_Historia_Animalium_511a22-34
# 2024-05-15 18:02:58,918 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:58,919 - DEBUG - root - original sentence: Ἔχει δὲ τὴν ὑστέραν, ὅσα μὲν ζῳοτοκεῖ
# καὶ ἐν αὑτοῖς καὶ εἰς τὸ ἐμφανές, ἄνωθεν τῆς κοιλίας,
# ὅσα δ’ ᾠοτοκεῖ, πάντα κάτωθεν  πρὸς τῇ ὀσφύϊ.
# 2024-05-15 18:02:58,919 - DEBUG - root - normalized_sentence_text: ἔχει δὲ τὴν ὑστέραν, ὅσα μὲν ζῳοτοκεῖ καὶ ἐν αὑτοῖς καὶ εἰς τὸ ἐμφανές, ἄνωθεν τῆς κοιλίας, ὅσα δʼ ᾠοτοκεῖ, πάντα κάτωθεν πρὸς τῇ ὀσφύϊ.
# 2024-05-15 18:02:58,920 - DEBUG - root - Token index: 12-19, Adjusted index for sentence: 12-19, Token text: ὑστέραν
# 2024-05-15 18:02:58,920 - DEBUG - root - Adjusted indices: 12-19 for token 'ὑστέραν' in normalized text.
# 2024-05-15 18:02:58,921 - DEBUG - root - normalized_token_text: ὑστέραν
# 2024-05-15 18:02:58,921 - DEBUG - root - new_token_begin: 12, new_token_end: 19, token value: Body Part
# 2024-05-15 18:02:58,921 - DEBUG - root - Token index: 21-24, Adjusted index for sentence: 21-24, Token text: ὅσα
# 2024-05-15 18:02:58,922 - DEBUG - root - Adjusted indices: 21-24 for token 'ὅσα' in normalized text.
# 2024-05-15 18:02:58,922 - DEBUG - root - normalized_token_text: ὅσα
# 2024-05-15 18:02:58,923 - DEBUG - root - new_token_begin: 21, new_token_end: 24, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,923 - DEBUG - root - Token index: 29-37, Adjusted index for sentence: 29-37, Token text: ζῳοτοκεῖ
# 2024-05-15 18:02:58,924 - DEBUG - root - Adjusted indices: 29-37 for token 'ζῳοτοκεῖ' in normalized text.
# 2024-05-15 18:02:58,924 - DEBUG - root - normalized_token_text: ζῳοτοκεῖ
# 2024-05-15 18:02:58,925 - DEBUG - root - new_token_begin: 29, new_token_end: 37, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,925 - DEBUG - root - Token index: 44-46, Adjusted index for sentence: 44-46, Token text: ἐν
# 2024-05-15 18:02:58,926 - DEBUG - root - Adjusted indices: 42-44 for token 'ἐν' in normalized text.
# 2024-05-15 18:02:58,926 - DEBUG - root - normalized_token_text: ἐν
# 2024-05-15 18:02:58,926 - DEBUG - root - new_token_begin: 42, new_token_end: 44, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,927 - DEBUG - root - Token index: 47-53, Adjusted index for sentence: 47-53, Token text: αὑτοῖς
# 2024-05-15 18:02:58,927 - DEBUG - root - Adjusted indices: 45-51 for token 'αὑτοῖς' in normalized text.
# 2024-05-15 18:02:58,928 - DEBUG - root - normalized_token_text: αὑτοῖς
# 2024-05-15 18:02:58,928 - DEBUG - root - new_token_begin: 45, new_token_end: 51, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,929 - DEBUG - root - Token index: 58-61, Adjusted index for sentence: 58-61, Token text: εἰς
# 2024-05-15 18:02:58,929 - DEBUG - root - Adjusted indices: 56-59 for token 'εἰς' in normalized text.
# 2024-05-15 18:02:58,930 - DEBUG - root - normalized_token_text: εἰς
# 2024-05-15 18:02:58,930 - DEBUG - root - new_token_begin: 56, new_token_end: 59, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,931 - DEBUG - root - Token index: 62-64, Adjusted index for sentence: 62-64, Token text: τὸ
# 2024-05-15 18:02:58,931 - DEBUG - root - Adjusted indices: 60-62 for token 'τὸ' in normalized text.
# 2024-05-15 18:02:58,932 - DEBUG - root - normalized_token_text: τὸ
# 2024-05-15 18:02:58,932 - DEBUG - root - new_token_begin: 60, new_token_end: 62, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,937 - DEBUG - root - Token index: 65-72, Adjusted index for sentence: 65-72, Token text: ἐμφανές
# 2024-05-15 18:02:58,937 - DEBUG - root - Adjusted indices: 63-70 for token 'ἐμφανές' in normalized text.
# 2024-05-15 18:02:58,938 - DEBUG - root - normalized_token_text: ἐμφανές
# 2024-05-15 18:02:58,938 - DEBUG - root - new_token_begin: 63, new_token_end: 70, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,939 - DEBUG - root - Token index: 74-80, Adjusted index for sentence: 74-80, Token text: ἄνωθεν
# 2024-05-15 18:02:58,939 - DEBUG - root - Adjusted indices: 72-78 for token 'ἄνωθεν' in normalized text.
# 2024-05-15 18:02:58,940 - DEBUG - root - normalized_token_text: ἄνωθεν
# 2024-05-15 18:02:58,940 - DEBUG - root - new_token_begin: 72, new_token_end: 78, token value: Topography
# 2024-05-15 18:02:58,941 - DEBUG - root - Token index: 85-92, Adjusted index for sentence: 85-92, Token text: κοιλίας
# 2024-05-15 18:02:58,941 - DEBUG - root - Adjusted indices: 83-90 for token 'κοιλίας' in normalized text.
# 2024-05-15 18:02:58,942 - DEBUG - root - normalized_token_text: κοιλίας
# 2024-05-15 18:02:58,942 - DEBUG - root - new_token_begin: 83, new_token_end: 90, token value: Body Part
# 2024-05-15 18:02:58,943 - DEBUG - root - Token index: 96-99, Adjusted index for sentence: 96-99, Token text: ὅσα
# 2024-05-15 18:02:58,943 - DEBUG - root - Adjusted indices: 92-95 for token 'ὅσα' in normalized text.
# 2024-05-15 18:02:58,944 - DEBUG - root - normalized_token_text: ὅσα
# 2024-05-15 18:02:58,944 - DEBUG - root - new_token_begin: 92, new_token_end: 95, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,947 - DEBUG - root - Token index: 103-110, Adjusted index for sentence: 103-110, Token text: ᾠοτοκεῖ
# 2024-05-15 18:02:58,948 - DEBUG - root - Adjusted indices: 99-106 for token 'ᾠοτοκεῖ' in normalized text.
# 2024-05-15 18:02:58,948 - DEBUG - root - normalized_token_text: ᾠοτοκεῖ
# 2024-05-15 18:02:58,948 - DEBUG - root - new_token_begin: 99, new_token_end: 106, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,949 - DEBUG - root - Token index: 112-117, Adjusted index for sentence: 112-117, Token text: πάντα
# 2024-05-15 18:02:58,949 - DEBUG - root - Adjusted indices: 108-113 for token 'πάντα' in normalized text.
# 2024-05-15 18:02:58,950 - DEBUG - root - normalized_token_text: πάντα
# 2024-05-15 18:02:58,950 - DEBUG - root - new_token_begin: 108, new_token_end: 113, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,951 - DEBUG - root - Token index: 118-125, Adjusted index for sentence: 118-125, Token text: κάτωθεν
# 2024-05-15 18:02:58,951 - DEBUG - root - Adjusted indices: 114-121 for token 'κάτωθεν' in normalized text.
# 2024-05-15 18:02:58,952 - DEBUG - root - normalized_token_text: κάτωθεν
# 2024-05-15 18:02:58,952 - DEBUG - root - new_token_begin: 114, new_token_end: 121, token value: Topography
# 2024-05-15 18:02:58,953 - DEBUG - root - Token index: 127-131, Adjusted index for sentence: 127-131, Token text: πρὸς
# 2024-05-15 18:02:58,953 - DEBUG - root - Adjusted indices: 122-126 for token 'πρὸς' in normalized text.
# 2024-05-15 18:02:58,954 - DEBUG - root - normalized_token_text: πρὸς
# 2024-05-15 18:02:58,954 - DEBUG - root - new_token_begin: 122, new_token_end: 126, token value: Topography
# 2024-05-15 18:02:58,955 - DEBUG - root - Token index: 135-140, Adjusted index for sentence: 135-140, Token text: ὀσφύϊ
# 2024-05-15 18:02:58,955 - DEBUG - root - Adjusted indices: 130-135 for token 'ὀσφύϊ' in normalized text.
# 2024-05-15 18:02:58,956 - DEBUG - root - normalized_token_text: ὀσφύϊ
# 2024-05-15 18:02:58,956 - DEBUG - root - new_token_begin: 130, new_token_end: 135, token value: Body Part
# 2024-05-15 18:02:58,957 - DEBUG - root - normalized sentence: ἔχει δὲ τὴν ὑστέραν, ὅσα μὲν ζῳοτοκεῖ καὶ ἐν αὑτοῖς καὶ εἰς τὸ ἐμφανές, ἄνωθεν τῆς κοιλίας, ὅσα δʼ ᾠοτοκεῖ, πάντα κάτωθεν πρὸς τῇ ὀσφύϊ.
# 2024-05-15 18:02:58,960 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:58,961 - DEBUG - root - original sentence: Ὅσα δ’ εἰς
# τὸ φανερὸν μὲν ζῳοτοκεῖ ἐν αὑτοῖς δ’ ᾠοτοκεῖ, ἐπαμφοτερίζει·
# 2024-05-15 18:02:58,961 - DEBUG - root - normalized_sentence_text: ὅσα δʼ εἰς τὸ φανερὸν μὲν ζῳοτοκεῖ ἐν αὑτοῖς δʼ ᾠοτοκεῖ, ἐπαμφοτερίζει·
# 2024-05-15 18:02:58,962 - DEBUG - root - Token index: 142-145, Adjusted index for sentence: 0-3, Token text: Ὅσα
# 2024-05-15 18:02:58,962 - DEBUG - root - Adjusted indices: 0-3 for token 'ὅσα' in normalized text.
# 2024-05-15 18:02:58,963 - DEBUG - root - normalized_token_text: ὅσα
# 2024-05-15 18:02:58,963 - DEBUG - root - new_token_begin: 0, new_token_end: 3, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,964 - DEBUG - root - Token index: 149-152, Adjusted index for sentence: 7-10, Token text: εἰς
# 2024-05-15 18:02:58,964 - DEBUG - root - Adjusted indices: 7-10 for token 'εἰς' in normalized text.
# 2024-05-15 18:02:58,964 - DEBUG - root - normalized_token_text: εἰς
# 2024-05-15 18:02:58,965 - DEBUG - root - new_token_begin: 7, new_token_end: 10, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,965 - DEBUG - root - Token index: 154-156, Adjusted index for sentence: 12-14, Token text: τὸ
# 2024-05-15 18:02:58,966 - DEBUG - root - Adjusted indices: 11-13 for token 'τὸ' in normalized text.
# 2024-05-15 18:02:58,966 - DEBUG - root - normalized_token_text: τὸ
# 2024-05-15 18:02:58,967 - DEBUG - root - new_token_begin: 11, new_token_end: 13, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,967 - DEBUG - root - Token index: 157-164, Adjusted index for sentence: 15-22, Token text: φανερὸν
# 2024-05-15 18:02:58,968 - DEBUG - root - Adjusted indices: 14-21 for token 'φανερὸν' in normalized text.
# 2024-05-15 18:02:58,971 - DEBUG - root - normalized_token_text: φανερὸν
# 2024-05-15 18:02:58,971 - DEBUG - root - new_token_begin: 14, new_token_end: 21, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,972 - DEBUG - root - Token index: 169-177, Adjusted index for sentence: 27-35, Token text: ζῳοτοκεῖ
# 2024-05-15 18:02:58,972 - DEBUG - root - Adjusted indices: 26-34 for token 'ζῳοτοκεῖ' in normalized text.
# 2024-05-15 18:02:58,973 - DEBUG - root - normalized_token_text: ζῳοτοκεῖ
# 2024-05-15 18:02:58,974 - DEBUG - root - new_token_begin: 26, new_token_end: 34, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,974 - DEBUG - root - Token index: 178-180, Adjusted index for sentence: 36-38, Token text: ἐν
# 2024-05-15 18:02:58,975 - DEBUG - root - Adjusted indices: 35-37 for token 'ἐν' in normalized text.
# 2024-05-15 18:02:58,975 - DEBUG - root - normalized_token_text: ἐν
# 2024-05-15 18:02:58,976 - DEBUG - root - new_token_begin: 35, new_token_end: 37, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,977 - DEBUG - root - Token index: 181-187, Adjusted index for sentence: 39-45, Token text: αὑτοῖς
# 2024-05-15 18:02:58,978 - DEBUG - root - Adjusted indices: 38-44 for token 'αὑτοῖς' in normalized text.
# 2024-05-15 18:02:58,978 - DEBUG - root - normalized_token_text: αὑτοῖς
# 2024-05-15 18:02:58,979 - DEBUG - root - new_token_begin: 38, new_token_end: 44, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,979 - DEBUG - root - Token index: 191-198, Adjusted index for sentence: 49-56, Token text: ᾠοτοκεῖ
# 2024-05-15 18:02:58,980 - DEBUG - root - Adjusted indices: 48-55 for token 'ᾠοτοκεῖ' in normalized text.
# 2024-05-15 18:02:58,980 - DEBUG - root - normalized_token_text: ᾠοτοκεῖ
# 2024-05-15 18:02:58,981 - DEBUG - root - new_token_begin: 48, new_token_end: 55, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,981 - DEBUG - root - Token index: 200-213, Adjusted index for sentence: 58-71, Token text: ἐπαμφοτερίζει
# 2024-05-15 18:02:58,981 - DEBUG - root - Adjusted indices: 57-70 for token 'ἐπαμφοτερίζει' in normalized text.
# 2024-05-15 18:02:58,982 - DEBUG - root - normalized_token_text: ἐπαμφοτερίζει
# 2024-05-15 18:02:58,982 - DEBUG - root - new_token_begin: 57, new_token_end: 70, token value: Topography
# 2024-05-15 18:02:58,983 - DEBUG - root - normalized sentence: ὅσα δʼ εἰς τὸ φανερὸν μὲν ζῳοτοκεῖ ἐν αὑτοῖς δʼ ᾠοτοκεῖ, ἐπαμφοτερίζει·
# 2024-05-15 18:02:58,983 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:58,984 - DEBUG - root - original sentence: τὸ μὲν γὰρ κάτωθεν πρὸς τὴν ὀσφὺν αὐτῆς μέρος ἐστίν,
# ἐν ᾗ τὰ περιττὰ ᾠά, τὸ δὲ περὶ τὴν ἔξοδον ἐπάνω τῶν ἐντέρων.
# 2024-05-15 18:02:58,984 - DEBUG - root - normalized_sentence_text: τὸ μὲν γὰρ κάτωθεν πρὸς τὴν ὀσφὺν αὐτῆς μέρος ἐστίν, ἐν ᾗ τὰ περιττὰ ᾠά, τὸ δὲ περὶ τὴν ἔξοδον ἐπάνω τῶν ἐντέρων.
# 2024-05-15 18:02:58,987 - DEBUG - root - Token index: 228-235, Adjusted index for sentence: 11-18, Token text: κάτωθεν
# 2024-05-15 18:02:58,987 - DEBUG - root - Adjusted indices: 11-18 for token 'κάτωθεν' in normalized text.
# 2024-05-15 18:02:58,988 - DEBUG - root - normalized_token_text: κάτωθεν
# 2024-05-15 18:02:58,988 - DEBUG - root - new_token_begin: 11, new_token_end: 18, token value: Topography
# 2024-05-15 18:02:58,989 - DEBUG - root - Token index: 236-240, Adjusted index for sentence: 19-23, Token text: πρὸς
# 2024-05-15 18:02:58,989 - DEBUG - root - Adjusted indices: 19-23 for token 'πρὸς' in normalized text.
# 2024-05-15 18:02:58,990 - DEBUG - root - normalized_token_text: πρὸς
# 2024-05-15 18:02:58,990 - DEBUG - root - new_token_begin: 19, new_token_end: 23, token value: Topography
# 2024-05-15 18:02:58,991 - DEBUG - root - Token index: 245-250, Adjusted index for sentence: 28-33, Token text: ὀσφὺν
# 2024-05-15 18:02:58,991 - DEBUG - root - Adjusted indices: 28-33 for token 'ὀσφὺν' in normalized text.
# 2024-05-15 18:02:58,992 - DEBUG - root - normalized_token_text: ὀσφὺν
# 2024-05-15 18:02:58,992 - DEBUG - root - new_token_begin: 28, new_token_end: 33, token value: Body Part
# 2024-05-15 18:02:58,993 - DEBUG - root - Token index: 257-262, Adjusted index for sentence: 40-45, Token text: μέρος
# 2024-05-15 18:02:58,993 - DEBUG - root - Adjusted indices: 40-45 for token 'μέρος' in normalized text.
# 2024-05-15 18:02:58,994 - DEBUG - root - normalized_token_text: μέρος
# 2024-05-15 18:02:58,994 - DEBUG - root - new_token_begin: 40, new_token_end: 45, token value: Body Part
# 2024-05-15 18:02:58,994 - DEBUG - root - Token index: 271-273, Adjusted index for sentence: 54-56, Token text: ἐν
# 2024-05-15 18:02:58,995 - DEBUG - root - Adjusted indices: 53-55 for token 'ἐν' in normalized text.
# 2024-05-15 18:02:58,995 - DEBUG - root - normalized_token_text: ἐν
# 2024-05-15 18:02:58,996 - DEBUG - root - new_token_begin: 53, new_token_end: 55, token value: Topography
# 2024-05-15 18:02:58,997 - DEBUG - root - Token index: 279-286, Adjusted index for sentence: 62-69, Token text: περιττὰ
# 2024-05-15 18:02:58,997 - DEBUG - root - Adjusted indices: 61-68 for token 'περιττὰ' in normalized text.
# 2024-05-15 18:02:58,998 - DEBUG - root - normalized_token_text: περιττὰ
# 2024-05-15 18:02:58,998 - DEBUG - root - new_token_begin: 61, new_token_end: 68, token value: Adjectives/Qualities
# 2024-05-15 18:02:58,998 - DEBUG - root - Token index: 297-301, Adjusted index for sentence: 80-84, Token text: περὶ
# 2024-05-15 18:02:58,999 - DEBUG - root - Adjusted indices: 79-83 for token 'περὶ' in normalized text.
# 2024-05-15 18:02:58,999 - DEBUG - root - normalized_token_text: περὶ
# 2024-05-15 18:02:59,000 - DEBUG - root - new_token_begin: 79, new_token_end: 83, token value: Topography
# 2024-05-15 18:02:59,000 - DEBUG - root - Token index: 306-312, Adjusted index for sentence: 89-95, Token text: ἔξοδον
# 2024-05-15 18:02:59,001 - DEBUG - root - Adjusted indices: 88-94 for token 'ἔξοδον' in normalized text.
# 2024-05-15 18:02:59,001 - DEBUG - root - normalized_token_text: ἔξοδον
# 2024-05-15 18:02:59,001 - DEBUG - root - new_token_begin: 88, new_token_end: 94, token value: Body Part
# 2024-05-15 18:02:59,002 - DEBUG - root - Token index: 313-318, Adjusted index for sentence: 96-101, Token text: ἐπάνω
# 2024-05-15 18:02:59,002 - DEBUG - root - Adjusted indices: 95-100 for token 'ἐπάνω' in normalized text.
# 2024-05-15 18:02:59,003 - DEBUG - root - normalized_token_text: ἐπάνω
# 2024-05-15 18:02:59,003 - DEBUG - root - new_token_begin: 95, new_token_end: 100, token value: Topography
# 2024-05-15 18:02:59,004 - DEBUG - root - Token index: 323-330, Adjusted index for sentence: 106-113, Token text: ἐντέρων
# 2024-05-15 18:02:59,004 - DEBUG - root - Adjusted indices: 105-112 for token 'ἐντέρων' in normalized text.
# 2024-05-15 18:02:59,005 - DEBUG - root - normalized_token_text: ἐντέρων
# 2024-05-15 18:02:59,005 - DEBUG - root - new_token_begin: 105, new_token_end: 112, token value: Body Part
# 2024-05-15 18:02:59,006 - DEBUG - root - normalized sentence: τὸ μὲν γὰρ κάτωθεν πρὸς τὴν ὀσφὺν αὐτῆς μέρος ἐστίν, ἐν ᾗ τὰ περιττὰ ᾠά, τὸ δὲ περὶ τὴν ἔξοδον ἐπάνω τῶν ἐντέρων.
# 2024-05-15 18:02:59,006 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,007 - DEBUG - root - original sentence: Ἔτι
# δὲ διαφορὰ καὶ ἥδε πρὸς ἀλλήλας ἐστὶ τῶν ὑστερῶν.
# 2024-05-15 18:02:59,012 - DEBUG - root - normalized_sentence_text: ἔτι δὲ διαφορὰ καὶ ἥδε πρὸς ἀλλήλας ἐστὶ τῶν ὑστερῶν.
# 2024-05-15 18:02:59,013 - DEBUG - root - Token index: 380-387, Adjusted index for sentence: 48-55, Token text: ὑστερῶν
# 2024-05-15 18:02:59,013 - DEBUG - root - Adjusted indices: 45-52 for token 'ὑστερῶν' in normalized text.
# 2024-05-15 18:02:59,016 - DEBUG - root - normalized_token_text: ὑστερῶν
# 2024-05-15 18:02:59,016 - DEBUG - root - new_token_begin: 45, new_token_end: 52, token value: Body Part
# 2024-05-15 18:02:59,017 - DEBUG - root - normalized sentence: ἔτι δὲ διαφορὰ καὶ ἥδε πρὸς ἀλλήλας ἐστὶ τῶν ὑστερῶν.
# 2024-05-15 18:02:59,018 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,018 - DEBUG - root - original sentence: Τὰ μὲν
# γὰρ κερατοφόρα καὶ μὴ ἀμφώδοντα ἔχει κοτυληδόνας ἐν
# τῇ ὑστέρᾳ, ὅταν ἔχῃ τὸ ἔμβρυον, καὶ τῶν ἀμφωδόντων
# οἷον δασύπους καὶ μῦς καὶ νυκτερίς·
# 2024-05-15 18:02:59,019 - DEBUG - root - normalized_sentence_text: τὰ μὲν γὰρ κερατοφόρα καὶ μὴ ἀμφώδοντα ἔχει κοτυληδόνας ἐν τῇ ὑστέρᾳ, ὅταν ἔχῃ τὸ ἔμβρυον, καὶ τῶν ἀμφωδόντων οἷον δασύπους καὶ μῦς καὶ νυκτερίς·
# 2024-05-15 18:02:59,019 - DEBUG - root - Token index: 401-411, Adjusted index for sentence: 12-22, Token text: κερατοφόρα
# 2024-05-15 18:02:59,020 - DEBUG - root - Adjusted indices: 11-21 for token 'κερατοφόρα' in normalized text.
# 2024-05-15 18:02:59,020 - DEBUG - root - normalized_token_text: κερατοφόρα
# 2024-05-15 18:02:59,021 - DEBUG - root - new_token_begin: 11, new_token_end: 21, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,021 - DEBUG - root - Token index: 419-428, Adjusted index for sentence: 30-39, Token text: ἀμφώδοντα
# 2024-05-15 18:02:59,021 - DEBUG - root - Adjusted indices: 29-38 for token 'ἀμφώδοντα' in normalized text.
# 2024-05-15 18:02:59,022 - DEBUG - root - normalized_token_text: ἀμφώδοντα
# 2024-05-15 18:02:59,022 - DEBUG - root - new_token_begin: 29, new_token_end: 38, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,023 - DEBUG - root - Token index: 434-445, Adjusted index for sentence: 45-56, Token text: κοτυληδόνας
# 2024-05-15 18:02:59,023 - DEBUG - root - Adjusted indices: 44-55 for token 'κοτυληδόνας' in normalized text.
# 2024-05-15 18:02:59,024 - DEBUG - root - normalized_token_text: κοτυληδόνας
# 2024-05-15 18:02:59,024 - DEBUG - root - new_token_begin: 44, new_token_end: 55, token value: Body Part
# 2024-05-15 18:02:59,025 - DEBUG - root - Token index: 446-448, Adjusted index for sentence: 57-59, Token text: ἐν
# 2024-05-15 18:02:59,025 - DEBUG - root - Adjusted indices: 56-58 for token 'ἐν' in normalized text.
# 2024-05-15 18:02:59,026 - DEBUG - root - normalized_token_text: ἐν
# 2024-05-15 18:02:59,026 - DEBUG - root - new_token_begin: 56, new_token_end: 58, token value: Topography
# 2024-05-15 18:02:59,027 - DEBUG - root - Token index: 454-460, Adjusted index for sentence: 65-71, Token text: ὑστέρᾳ
# 2024-05-15 18:02:59,027 - DEBUG - root - Adjusted indices: 62-68 for token 'ὑστέρᾳ' in normalized text.
# 2024-05-15 18:02:59,027 - DEBUG - root - normalized_token_text: ὑστέρᾳ
# 2024-05-15 18:02:59,028 - DEBUG - root - new_token_begin: 62, new_token_end: 68, token value: Body Part
# 2024-05-15 18:02:59,028 - DEBUG - root - Token index: 491-501, Adjusted index for sentence: 102-112, Token text: ἀμφωδόντων
# 2024-05-15 18:02:59,028 - DEBUG - root - Adjusted indices: 99-109 for token 'ἀμφωδόντων' in normalized text.
# 2024-05-15 18:02:59,029 - DEBUG - root - normalized_token_text: ἀμφωδόντων
# 2024-05-15 18:02:59,029 - DEBUG - root - new_token_begin: 99, new_token_end: 109, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,030 - DEBUG - root - normalized sentence: τὰ μὲν γὰρ κερατοφόρα καὶ μὴ ἀμφώδοντα ἔχει κοτυληδόνας ἐν τῇ ὑστέρᾳ, ὅταν ἔχῃ τὸ ἔμβρυον, καὶ τῶν ἀμφωδόντων οἷον δασύπους καὶ μῦς καὶ νυκτερίς·
# 2024-05-15 18:02:59,030 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,030 - DEBUG - root - original sentence: τὰ δ’ ἄλλα τὰ ἀμφώδοντα
# καὶ ζῳοτόκα καὶ ὑπόποδα πάντα λείαν ἔχει τὴν
# ὑστέραν, καὶ ἡ τῶν ἐμβρύων ἐξάρτησις ἐξ αὐτῆς ἐστι τῆς
# ὑστέρας, ἀλλ’ οὐκ ἐκ κοτυληδόνος.
# 2024-05-15 18:02:59,031 - DEBUG - root - normalized_sentence_text: τὰ δʼ ἄλλα τὰ ἀμφώδοντα καὶ ζῳοτόκα καὶ ὑπόποδα πάντα λείαν ἔχει τὴν ὑστέραν, καὶ ἡ τῶν ἐμβρύων ἐξάρτησις ἐξ αὐτῆς ἐστι τῆς ὑστέρας, ἀλλʼ οὐκ ἐκ κοτυληδόνος.
# 2024-05-15 18:02:59,031 - DEBUG - root - Token index: 549-553, Adjusted index for sentence: 6-10, Token text: ἄλλα
# 2024-05-15 18:02:59,032 - DEBUG - root - Adjusted indices: 6-10 for token 'ἄλλα' in normalized text.
# 2024-05-15 18:02:59,032 - DEBUG - root - normalized_token_text: ἄλλα
# 2024-05-15 18:02:59,033 - DEBUG - root - new_token_begin: 6, new_token_end: 10, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,033 - DEBUG - root - Token index: 557-566, Adjusted index for sentence: 14-23, Token text: ἀμφώδοντα
# 2024-05-15 18:02:59,033 - DEBUG - root - Adjusted indices: 14-23 for token 'ἀμφώδοντα' in normalized text.
# 2024-05-15 18:02:59,034 - DEBUG - root - normalized_token_text: ἀμφώδοντα
# 2024-05-15 18:02:59,034 - DEBUG - root - new_token_begin: 14, new_token_end: 23, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,035 - DEBUG - root - Token index: 573-580, Adjusted index for sentence: 30-37, Token text: ζῳοτόκα
# 2024-05-15 18:02:59,035 - DEBUG - root - Adjusted indices: 28-35 for token 'ζῳοτόκα' in normalized text.
# 2024-05-15 18:02:59,036 - DEBUG - root - normalized_token_text: ζῳοτόκα
# 2024-05-15 18:02:59,036 - DEBUG - root - new_token_begin: 28, new_token_end: 35, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,037 - DEBUG - root - Token index: 585-592, Adjusted index for sentence: 42-49, Token text: ὑπόποδα
# 2024-05-15 18:02:59,037 - DEBUG - root - Adjusted indices: 40-47 for token 'ὑπόποδα' in normalized text.
# 2024-05-15 18:02:59,038 - DEBUG - root - normalized_token_text: ὑπόποδα
# 2024-05-15 18:02:59,038 - DEBUG - root - new_token_begin: 40, new_token_end: 47, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,038 - DEBUG - root - Token index: 593-598, Adjusted index for sentence: 50-55, Token text: πάντα
# 2024-05-15 18:02:59,041 - DEBUG - root - Adjusted indices: 48-53 for token 'πάντα' in normalized text.
# 2024-05-15 18:02:59,041 - DEBUG - root - normalized_token_text: πάντα
# 2024-05-15 18:02:59,042 - DEBUG - root - new_token_begin: 48, new_token_end: 53, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,047 - DEBUG - root - Token index: 599-604, Adjusted index for sentence: 56-61, Token text: λείαν
# 2024-05-15 18:02:59,048 - DEBUG - root - Adjusted indices: 54-59 for token 'λείαν' in normalized text.
# 2024-05-15 18:02:59,048 - DEBUG - root - normalized_token_text: λείαν
# 2024-05-15 18:02:59,049 - DEBUG - root - new_token_begin: 54, new_token_end: 59, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,049 - DEBUG - root - Token index: 615-622, Adjusted index for sentence: 72-79, Token text: ὑστέραν
# 2024-05-15 18:02:59,050 - DEBUG - root - Adjusted indices: 69-76 for token 'ὑστέραν' in normalized text.
# 2024-05-15 18:02:59,051 - DEBUG - root - normalized_token_text: ὑστέραν
# 2024-05-15 18:02:59,052 - DEBUG - root - new_token_begin: 69, new_token_end: 76, token value: Body Part
# 2024-05-15 18:02:59,052 - DEBUG - root - Token index: 642-651, Adjusted index for sentence: 99-108, Token text: ἐξάρτησις
# 2024-05-15 18:02:59,053 - DEBUG - root - Adjusted indices: 96-105 for token 'ἐξάρτησις' in normalized text.
# 2024-05-15 18:02:59,053 - DEBUG - root - normalized_token_text: ἐξάρτησις
# 2024-05-15 18:02:59,053 - DEBUG - root - new_token_begin: 96, new_token_end: 105, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,054 - DEBUG - root - Token index: 652-654, Adjusted index for sentence: 109-111, Token text: ἐξ
# 2024-05-15 18:02:59,054 - DEBUG - root - Adjusted indices: 106-108 for token 'ἐξ' in normalized text.
# 2024-05-15 18:02:59,055 - DEBUG - root - normalized_token_text: ἐξ
# 2024-05-15 18:02:59,055 - DEBUG - root - new_token_begin: 106, new_token_end: 108, token value: Topography
# 2024-05-15 18:02:59,056 - DEBUG - root - Token index: 655-660, Adjusted index for sentence: 112-117, Token text: αὐτῆς
# 2024-05-15 18:02:59,056 - DEBUG - root - Adjusted indices: 109-114 for token 'αὐτῆς' in normalized text.
# 2024-05-15 18:02:59,057 - DEBUG - root - normalized_token_text: αὐτῆς
# 2024-05-15 18:02:59,057 - DEBUG - root - new_token_begin: 109, new_token_end: 114, token value: Topography
# 2024-05-15 18:02:59,058 - DEBUG - root - Token index: 671-678, Adjusted index for sentence: 128-135, Token text: ὑστέρας
# 2024-05-15 18:02:59,058 - DEBUG - root - Adjusted indices: 124-131 for token 'ὑστέρας' in normalized text.
# 2024-05-15 18:02:59,059 - DEBUG - root - normalized_token_text: ὑστέρας
# 2024-05-15 18:02:59,059 - DEBUG - root - new_token_begin: 124, new_token_end: 131, token value: Body Part
# 2024-05-15 18:02:59,060 - DEBUG - root - Token index: 689-691, Adjusted index for sentence: 146-148, Token text: ἐκ
# 2024-05-15 18:02:59,064 - DEBUG - root - Adjusted indices: 142-144 for token 'ἐκ' in normalized text.
# 2024-05-15 18:02:59,064 - DEBUG - root - normalized_token_text: ἐκ
# 2024-05-15 18:02:59,065 - DEBUG - root - new_token_begin: 142, new_token_end: 144, token value: Topography
# 2024-05-15 18:02:59,065 - DEBUG - root - Token index: 692-703, Adjusted index for sentence: 149-160, Token text: κοτυληδόνος
# 2024-05-15 18:02:59,066 - DEBUG - root - Adjusted indices: 145-156 for token 'κοτυληδόνος' in normalized text.
# 2024-05-15 18:02:59,066 - DEBUG - root - normalized_token_text: κοτυληδόνος
# 2024-05-15 18:02:59,067 - DEBUG - root - new_token_begin: 145, new_token_end: 156, token value: Body Part
# 2024-05-15 18:02:59,067 - DEBUG - root - normalized sentence: τὰ δʼ ἄλλα τὰ ἀμφώδοντα καὶ ζῳοτόκα καὶ ὑπόποδα πάντα λείαν ἔχει τὴν ὑστέραν, καὶ ἡ τῶν ἐμβρύων ἐξάρτησις ἐξ αὐτῆς ἐστι τῆς ὑστέρας, ἀλλʼ οὐκ ἐκ κοτυληδόνος.
# file name:  Aristotle_Historia_Animalium_511a22-34.zip
# file name:  Aristotle_Historia_Animalium_496b34-497a18.zip
# 2024-05-15 18:02:59,115 - DEBUG - root - Processing file: /tmp/tmpu5pw6jwv/Aristotle_Historia_Animalium_496b34-497a18.xmi as Aristotle_Historia_Animalium_496b34-497a18
# 2024-05-15 18:02:59,116 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,117 - DEBUG - root - original sentence: Μετὰ δὲ ταῦτα οἱ νεφροὶ πρὸς αὐτῇ τῇ
# ῥάχει κεῖνται, ὅμοιοι τὴν φύσιν ὄντες τοῖς βοείοις.
# 2024-05-15 18:02:59,117 - DEBUG - root - normalized_sentence_text: μετὰ δὲ ταῦτα οἱ νεφροὶ πρὸς αὐτῇ τῇ ῥάχει κεῖνται, ὅμοιοι τὴν φύσιν ὄντες τοῖς βοείοις.
# 2024-05-15 18:02:59,118 - DEBUG - root - Token index: 17-23, Adjusted index for sentence: 17-23, Token text: νεφροὶ
# 2024-05-15 18:02:59,119 - DEBUG - root - Adjusted indices: 17-23 for token 'νεφροὶ' in normalized text.
# 2024-05-15 18:02:59,119 - DEBUG - root - normalized_token_text: νεφροὶ
# 2024-05-15 18:02:59,119 - DEBUG - root - new_token_begin: 17, new_token_end: 23, token value: Body Part
# 2024-05-15 18:02:59,120 - DEBUG - root - Token index: 24-28, Adjusted index for sentence: 24-28, Token text: πρὸς
# 2024-05-15 18:02:59,120 - DEBUG - root - Adjusted indices: 24-28 for token 'πρὸς' in normalized text.
# 2024-05-15 18:02:59,121 - DEBUG - root - normalized_token_text: πρὸς
# 2024-05-15 18:02:59,121 - DEBUG - root - new_token_begin: 24, new_token_end: 28, token value: Topography
# 2024-05-15 18:02:59,122 - DEBUG - root - Token index: 42-47, Adjusted index for sentence: 42-47, Token text: ῥάχει
# 2024-05-15 18:02:59,122 - DEBUG - root - Adjusted indices: 37-42 for token 'ῥάχει' in normalized text.
# 2024-05-15 18:02:59,123 - DEBUG - root - normalized_token_text: ῥάχει
# 2024-05-15 18:02:59,123 - DEBUG - root - new_token_begin: 37, new_token_end: 42, token value: Body Part
# 2024-05-15 18:02:59,124 - DEBUG - root - Token index: 48-55, Adjusted index for sentence: 48-55, Token text: κεῖνται
# 2024-05-15 18:02:59,125 - DEBUG - root - Adjusted indices: 43-50 for token 'κεῖνται' in normalized text.
# 2024-05-15 18:02:59,125 - DEBUG - root - normalized_token_text: κεῖνται
# 2024-05-15 18:02:59,129 - DEBUG - root - new_token_begin: 43, new_token_end: 50, token value: Topography
# 2024-05-15 18:02:59,129 - DEBUG - root - Token index: 57-63, Adjusted index for sentence: 57-63, Token text: ὅμοιοι
# 2024-05-15 18:02:59,130 - DEBUG - root - Adjusted indices: 52-58 for token 'ὅμοιοι' in normalized text.
# 2024-05-15 18:02:59,130 - DEBUG - root - normalized_token_text: ὅμοιοι
# 2024-05-15 18:02:59,130 - DEBUG - root - new_token_begin: 52, new_token_end: 58, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,131 - DEBUG - root - Token index: 85-92, Adjusted index for sentence: 85-92, Token text: βοείοις
# 2024-05-15 18:02:59,131 - DEBUG - root - Adjusted indices: 80-87 for token 'βοείοις' in normalized text.
# 2024-05-15 18:02:59,132 - DEBUG - root - normalized_token_text: βοείοις
# 2024-05-15 18:02:59,132 - DEBUG - root - new_token_begin: 80, new_token_end: 87, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,133 - DEBUG - root - normalized sentence: μετὰ δὲ ταῦτα οἱ νεφροὶ πρὸς αὐτῇ τῇ ῥάχει κεῖνται, ὅμοιοι τὴν φύσιν ὄντες τοῖς βοείοις.
# 2024-05-15 18:02:59,133 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,134 - DEBUG - root - original sentence: Ἀνώτερος
# δὲ ὁ δεξιός ἐστιν ἐν πᾶσι τοῖς ζῴοις τοῖς ἔχουσι νεφρούς·
# 2024-05-15 18:02:59,134 - DEBUG - root - normalized_sentence_text: ἀνώτερος δὲ ὁ δεξιός ἐστιν ἐν πᾶσι τοῖς ζῴοις τοῖς ἔχουσι νεφρούς·
# 2024-05-15 18:02:59,135 - DEBUG - root - Token index: 94-102, Adjusted index for sentence: 0-8, Token text: Ἀνώτερος
# 2024-05-15 18:02:59,135 - DEBUG - root - Adjusted indices: 0-8 for token 'ἀνώτερος' in normalized text.
# 2024-05-15 18:02:59,136 - DEBUG - root - normalized_token_text: ἀνώτερος
# 2024-05-15 18:02:59,136 - DEBUG - root - new_token_begin: 0, new_token_end: 8, token value: Topography
# 2024-05-15 18:02:59,137 - DEBUG - root - Token index: 110-116, Adjusted index for sentence: 16-22, Token text: δεξιός
# 2024-05-15 18:02:59,137 - DEBUG - root - Adjusted indices: 14-20 for token 'δεξιός' in normalized text.
# 2024-05-15 18:02:59,137 - DEBUG - root - normalized_token_text: δεξιός
# 2024-05-15 18:02:59,138 - DEBUG - root - new_token_begin: 14, new_token_end: 20, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,138 - DEBUG - root - Token index: 136-141, Adjusted index for sentence: 42-47, Token text: ζῴοις
# 2024-05-15 18:02:59,143 - DEBUG - root - Adjusted indices: 40-45 for token 'ζῴοις' in normalized text.
# 2024-05-15 18:02:59,143 - DEBUG - root - normalized_token_text: ζῴοις
# 2024-05-15 18:02:59,144 - DEBUG - root - new_token_begin: 40, new_token_end: 45, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,144 - DEBUG - root - Token index: 154-161, Adjusted index for sentence: 60-67, Token text: νεφρούς
# 2024-05-15 18:02:59,145 - DEBUG - root - Adjusted indices: 58-65 for token 'νεφρούς' in normalized text.
# 2024-05-15 18:02:59,145 - DEBUG - root - normalized_token_text: νεφρούς
# 2024-05-15 18:02:59,146 - DEBUG - root - new_token_begin: 58, new_token_end: 65, token value: Body Part
# 2024-05-15 18:02:59,146 - DEBUG - root - normalized sentence: ἀνώτερος δὲ ὁ δεξιός ἐστιν ἐν πᾶσι τοῖς ζῴοις τοῖς ἔχουσι νεφρούς·
# 2024-05-15 18:02:59,147 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,149 - DEBUG - root - original sentence: καὶ ἐλάττω δὲ πιμελὴν ἔχει τοῦ ἀριστεροῦ καὶ αὐχμηρότερος
# ὁ δεξιός.
# 2024-05-15 18:02:59,150 - DEBUG - root - normalized_sentence_text: καὶ ἐλάττω δὲ πιμελὴν ἔχει τοῦ ἀριστεροῦ καὶ αὐχμηρότερος ὁ δεξιός.
# 2024-05-15 18:02:59,150 - DEBUG - root - Token index: 169-175, Adjusted index for sentence: 4-10, Token text: ἐλάττω
# 2024-05-15 18:02:59,151 - DEBUG - root - Adjusted indices: 4-10 for token 'ἐλάττω' in normalized text.
# 2024-05-15 18:02:59,151 - DEBUG - root - normalized_token_text: ἐλάττω
# 2024-05-15 18:02:59,152 - DEBUG - root - new_token_begin: 4, new_token_end: 10, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,153 - DEBUG - root - Token index: 179-186, Adjusted index for sentence: 14-21, Token text: πιμελὴν
# 2024-05-15 18:02:59,153 - DEBUG - root - Adjusted indices: 14-21 for token 'πιμελὴν' in normalized text.
# 2024-05-15 18:02:59,153 - DEBUG - root - normalized_token_text: πιμελὴν
# 2024-05-15 18:02:59,154 - DEBUG - root - new_token_begin: 14, new_token_end: 21, token value: Body Part
# 2024-05-15 18:02:59,154 - DEBUG - root - Token index: 196-205, Adjusted index for sentence: 31-40, Token text: ἀριστεροῦ
# 2024-05-15 18:02:59,155 - DEBUG - root - Adjusted indices: 31-40 for token 'ἀριστεροῦ' in normalized text.
# 2024-05-15 18:02:59,155 - DEBUG - root - normalized_token_text: ἀριστεροῦ
# 2024-05-15 18:02:59,155 - DEBUG - root - new_token_begin: 31, new_token_end: 40, token value: Topography
# 2024-05-15 18:02:59,156 - DEBUG - root - Token index: 210-222, Adjusted index for sentence: 45-57, Token text: αὐχμηρότερος
# 2024-05-15 18:02:59,158 - DEBUG - root - Adjusted indices: 45-57 for token 'αὐχμηρότερος' in normalized text.
# 2024-05-15 18:02:59,159 - DEBUG - root - normalized_token_text: αὐχμηρότερος
# 2024-05-15 18:02:59,160 - DEBUG - root - new_token_begin: 45, new_token_end: 57, token value: Topography
# 2024-05-15 18:02:59,160 - DEBUG - root - Token index: 226-232, Adjusted index for sentence: 61-67, Token text: δεξιός
# 2024-05-15 18:02:59,161 - DEBUG - root - Adjusted indices: 60-66 for token 'δεξιός' in normalized text.
# 2024-05-15 18:02:59,161 - DEBUG - root - normalized_token_text: δεξιός
# 2024-05-15 18:02:59,161 - DEBUG - root - new_token_begin: 60, new_token_end: 66, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,162 - DEBUG - root - normalized sentence: καὶ ἐλάττω δὲ πιμελὴν ἔχει τοῦ ἀριστεροῦ καὶ αὐχμηρότερος ὁ δεξιός.
# 2024-05-15 18:02:59,163 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,164 - DEBUG - root - original sentence: Ἐν πᾶσι δ’ ἔχει ὁμοίως τοῖς ἄλλοις
# καὶ τοῦτο.
# 2024-05-15 18:02:59,164 - DEBUG - root - normalized_sentence_text: ἐν πᾶσι δʼ ἔχει ὁμοίως τοῖς ἄλλοις καὶ τοῦτο.
# 2024-05-15 18:02:59,165 - DEBUG - root - Token index: 250-256, Adjusted index for sentence: 16-22, Token text: ὁμοίως
# 2024-05-15 18:02:59,165 - DEBUG - root - Adjusted indices: 16-22 for token 'ὁμοίως' in normalized text.
# 2024-05-15 18:02:59,166 - DEBUG - root - normalized_token_text: ὁμοίως
# 2024-05-15 18:02:59,166 - DEBUG - root - new_token_begin: 16, new_token_end: 22, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,167 - DEBUG - root - normalized sentence: ἐν πᾶσι δʼ ἔχει ὁμοίως τοῖς ἄλλοις καὶ τοῦτο.
# 2024-05-15 18:02:59,167 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,167 - DEBUG - root - original sentence: Φέρουσι δὲ εἰς αὐτοὺς πόροι ἔκ τε τῆς μεγάλης
# φλεβὸς καὶ τῆς ἀορτῆς, πλὴν οὐκ εἰς τὸ κοῖλον.
# 2024-05-15 18:02:59,168 - DEBUG - root - normalized_sentence_text: φέρουσι δὲ εἰς αὐτοὺς πόροι ἔκ τε τῆς μεγάλης φλεβὸς καὶ τῆς ἀορτῆς, πλὴν οὐκ εἰς τὸ κοῖλον.
# 2024-05-15 18:02:59,168 - DEBUG - root - Token index: 281-288, Adjusted index for sentence: 0-7, Token text: Φέρουσι
# 2024-05-15 18:02:59,169 - DEBUG - root - Adjusted indices: 0-7 for token 'φέρουσι' in normalized text.
# 2024-05-15 18:02:59,169 - DEBUG - root - normalized_token_text: φέρουσι
# 2024-05-15 18:02:59,170 - DEBUG - root - new_token_begin: 0, new_token_end: 7, token value: Topography
# 2024-05-15 18:02:59,171 - DEBUG - root - Token index: 292-295, Adjusted index for sentence: 11-14, Token text: εἰς
# 2024-05-15 18:02:59,171 - DEBUG - root - Adjusted indices: 11-14 for token 'εἰς' in normalized text.
# 2024-05-15 18:02:59,171 - DEBUG - root - normalized_token_text: εἰς
# 2024-05-15 18:02:59,172 - DEBUG - root - new_token_begin: 11, new_token_end: 14, token value: Topography
# 2024-05-15 18:02:59,172 - DEBUG - root - Token index: 303-308, Adjusted index for sentence: 22-27, Token text: πόροι
# 2024-05-15 18:02:59,173 - DEBUG - root - Adjusted indices: 22-27 for token 'πόροι' in normalized text.
# 2024-05-15 18:02:59,173 - DEBUG - root - normalized_token_text: πόροι
# 2024-05-15 18:02:59,174 - DEBUG - root - new_token_begin: 22, new_token_end: 27, token value: Body Part
# 2024-05-15 18:02:59,174 - DEBUG - root - Token index: 309-311, Adjusted index for sentence: 28-30, Token text: ἔκ
# 2024-05-15 18:02:59,175 - DEBUG - root - Adjusted indices: 28-30 for token 'ἔκ' in normalized text.
# 2024-05-15 18:02:59,175 - DEBUG - root - normalized_token_text: ἔκ
# 2024-05-15 18:02:59,176 - DEBUG - root - new_token_begin: 28, new_token_end: 30, token value: Topography
# 2024-05-15 18:02:59,176 - DEBUG - root - Token index: 319-326, Adjusted index for sentence: 38-45, Token text: μεγάλης
# 2024-05-15 18:02:59,177 - DEBUG - root - Adjusted indices: 38-45 for token 'μεγάλης' in normalized text.
# 2024-05-15 18:02:59,177 - DEBUG - root - normalized_token_text: μεγάλης
# 2024-05-15 18:02:59,177 - DEBUG - root - new_token_begin: 38, new_token_end: 45, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,178 - DEBUG - root - Token index: 328-334, Adjusted index for sentence: 47-53, Token text: φλεβὸς
# 2024-05-15 18:02:59,178 - DEBUG - root - Adjusted indices: 46-52 for token 'φλεβὸς' in normalized text.
# 2024-05-15 18:02:59,179 - DEBUG - root - normalized_token_text: φλεβὸς
# 2024-05-15 18:02:59,179 - DEBUG - root - new_token_begin: 46, new_token_end: 52, token value: Body Part
# 2024-05-15 18:02:59,180 - DEBUG - root - Token index: 343-349, Adjusted index for sentence: 62-68, Token text: ἀορτῆς
# 2024-05-15 18:02:59,180 - DEBUG - root - Adjusted indices: 61-67 for token 'ἀορτῆς' in normalized text.
# 2024-05-15 18:02:59,180 - DEBUG - root - normalized_token_text: ἀορτῆς
# 2024-05-15 18:02:59,181 - DEBUG - root - new_token_begin: 61, new_token_end: 67, token value: Body Part
# 2024-05-15 18:02:59,181 - DEBUG - root - Token index: 360-363, Adjusted index for sentence: 79-82, Token text: εἰς
# 2024-05-15 18:02:59,182 - DEBUG - root - Adjusted indices: 78-81 for token 'εἰς' in normalized text.
# 2024-05-15 18:02:59,182 - DEBUG - root - normalized_token_text: εἰς
# 2024-05-15 18:02:59,183 - DEBUG - root - new_token_begin: 78, new_token_end: 81, token value: Topography
# 2024-05-15 18:02:59,183 - DEBUG - root - Token index: 367-373, Adjusted index for sentence: 86-92, Token text: κοῖλον
# 2024-05-15 18:02:59,184 - DEBUG - root - Adjusted indices: 85-91 for token 'κοῖλον' in normalized text.
# 2024-05-15 18:02:59,184 - DEBUG - root - normalized_token_text: κοῖλον
# 2024-05-15 18:02:59,184 - DEBUG - root - new_token_begin: 85, new_token_end: 91, token value: Body Part
# 2024-05-15 18:02:59,185 - DEBUG - root - normalized sentence: φέρουσι δὲ εἰς αὐτοὺς πόροι ἔκ τε τῆς μεγάλης φλεβὸς καὶ τῆς ἀορτῆς, πλὴν οὐκ εἰς τὸ κοῖλον.
# 2024-05-15 18:02:59,185 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,186 - DEBUG - root - original sentence: Ἔχουσι
# γὰρ οἱ νεφροὶ ἐν μέσῳ κοῖλον, οἱ μὲν μεῖζον οἱ δ’ ἔλαττον,
# πλὴν οἱ τῆς φώκης·
# 2024-05-15 18:02:59,186 - DEBUG - root - normalized_sentence_text: ἔχουσι γὰρ οἱ νεφροὶ ἐν μέσῳ κοῖλον, οἱ μὲν μεῖζον οἱ δʼ ἔλαττον, πλὴν οἱ τῆς φώκης·
# 2024-05-15 18:02:59,187 - DEBUG - root - Token index: 393-399, Adjusted index for sentence: 18-24, Token text: νεφροὶ
# 2024-05-15 18:02:59,187 - DEBUG - root - Adjusted indices: 14-20 for token 'νεφροὶ' in normalized text.
# 2024-05-15 18:02:59,188 - DEBUG - root - normalized_token_text: νεφροὶ
# 2024-05-15 18:02:59,188 - DEBUG - root - new_token_begin: 14, new_token_end: 20, token value: Body Part
# 2024-05-15 18:02:59,189 - DEBUG - root - Token index: 400-402, Adjusted index for sentence: 25-27, Token text: ἐν
# 2024-05-15 18:02:59,189 - DEBUG - root - Adjusted indices: 21-23 for token 'ἐν' in normalized text.
# 2024-05-15 18:02:59,190 - DEBUG - root - normalized_token_text: ἐν
# 2024-05-15 18:02:59,199 - DEBUG - root - new_token_begin: 21, new_token_end: 23, token value: Topography
# 2024-05-15 18:02:59,200 - DEBUG - root - Token index: 403-407, Adjusted index for sentence: 28-32, Token text: μέσῳ
# 2024-05-15 18:02:59,201 - DEBUG - root - Adjusted indices: 24-28 for token 'μέσῳ' in normalized text.
# 2024-05-15 18:02:59,202 - DEBUG - root - normalized_token_text: μέσῳ
# 2024-05-15 18:02:59,202 - DEBUG - root - new_token_begin: 24, new_token_end: 28, token value: Topography
# 2024-05-15 18:02:59,202 - DEBUG - root - Token index: 408-414, Adjusted index for sentence: 33-39, Token text: κοῖλον
# 2024-05-15 18:02:59,203 - DEBUG - root - Adjusted indices: 29-35 for token 'κοῖλον' in normalized text.
# 2024-05-15 18:02:59,205 - DEBUG - root - normalized_token_text: κοῖλον
# 2024-05-15 18:02:59,206 - DEBUG - root - new_token_begin: 29, new_token_end: 35, token value: Body Part
# 2024-05-15 18:02:59,206 - DEBUG - root - Token index: 423-429, Adjusted index for sentence: 48-54, Token text: μεῖζον
# 2024-05-15 18:02:59,207 - DEBUG - root - Adjusted indices: 44-50 for token 'μεῖζον' in normalized text.
# 2024-05-15 18:02:59,207 - DEBUG - root - normalized_token_text: μεῖζον
# 2024-05-15 18:02:59,208 - DEBUG - root - new_token_begin: 44, new_token_end: 50, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,208 - DEBUG - root - Token index: 436-443, Adjusted index for sentence: 61-68, Token text: ἔλαττον
# 2024-05-15 18:02:59,209 - DEBUG - root - Adjusted indices: 57-64 for token 'ἔλαττον' in normalized text.
# 2024-05-15 18:02:59,209 - DEBUG - root - normalized_token_text: ἔλαττον
# 2024-05-15 18:02:59,210 - DEBUG - root - new_token_begin: 57, new_token_end: 64, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,210 - DEBUG - root - normalized sentence: ἔχουσι γὰρ οἱ νεφροὶ ἐν μέσῳ κοῖλον, οἱ μὲν μεῖζον οἱ δʼ ἔλαττον, πλὴν οἱ τῆς φώκης·
# 2024-05-15 18:02:59,211 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,211 - DEBUG - root - original sentence: οὗτοι δ’ ὅμοιοι τοῖς βοείοις ὄντες
# στερεώτατοι πάντων εἰσίν.
# 2024-05-15 18:02:59,212 - DEBUG - root - normalized_sentence_text: οὗτοι δʼ ὅμοιοι τοῖς βοείοις ὄντες στερεώτατοι πάντων εἰσίν.
# 2024-05-15 18:02:59,212 - DEBUG - root - Token index: 475-481, Adjusted index for sentence: 9-15, Token text: ὅμοιοι
# 2024-05-15 18:02:59,213 - DEBUG - root - Adjusted indices: 9-15 for token 'ὅμοιοι' in normalized text.
# 2024-05-15 18:02:59,213 - DEBUG - root - normalized_token_text: ὅμοιοι
# 2024-05-15 18:02:59,214 - DEBUG - root - new_token_begin: 9, new_token_end: 15, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,214 - DEBUG - root - Token index: 502-513, Adjusted index for sentence: 36-47, Token text: στερεώτατοι
# 2024-05-15 18:02:59,215 - DEBUG - root - Adjusted indices: 35-46 for token 'στερεώτατοι' in normalized text.
# 2024-05-15 18:02:59,215 - DEBUG - root - normalized_token_text: στερεώτατοι
# 2024-05-15 18:02:59,216 - DEBUG - root - new_token_begin: 35, new_token_end: 46, token value: Adjectives/Qualities
# 2024-05-15 18:02:59,216 - DEBUG - root - normalized sentence: οὗτοι δʼ ὅμοιοι τοῖς βοείοις ὄντες στερεώτατοι πάντων εἰσίν.
# 2024-05-15 18:02:59,217 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,217 - DEBUG - root - original sentence: Οἱ δὲ πόροι οἱ τείνοντες εἰς αὐτοὺς
# εἰς τὸ σῶμα καταναλίσκονται τῶν νεφρῶν·
# 2024-05-15 18:02:59,218 - DEBUG - root - normalized_sentence_text: οἱ δὲ πόροι οἱ τείνοντες εἰς αὐτοὺς εἰς τὸ σῶμα καταναλίσκονται τῶν νεφρῶν·
# 2024-05-15 18:02:59,218 - DEBUG - root - Token index: 534-539, Adjusted index for sentence: 6-11, Token text: πόροι
# 2024-05-15 18:02:59,218 - DEBUG - root - Adjusted indices: 6-11 for token 'πόροι' in normalized text.
# 2024-05-15 18:02:59,219 - DEBUG - root - normalized_token_text: πόροι
# 2024-05-15 18:02:59,220 - DEBUG - root - new_token_begin: 6, new_token_end: 11, token value: Body Part
# 2024-05-15 18:02:59,220 - DEBUG - root - Token index: 543-552, Adjusted index for sentence: 15-24, Token text: τείνοντες
# 2024-05-15 18:02:59,221 - DEBUG - root - Adjusted indices: 15-24 for token 'τείνοντες' in normalized text.
# 2024-05-15 18:02:59,221 - DEBUG - root - normalized_token_text: τείνοντες
# 2024-05-15 18:02:59,221 - DEBUG - root - new_token_begin: 15, new_token_end: 24, token value: Topography
# 2024-05-15 18:02:59,222 - DEBUG - root - Token index: 553-556, Adjusted index for sentence: 25-28, Token text: εἰς
# 2024-05-15 18:02:59,222 - DEBUG - root - Adjusted indices: 25-28 for token 'εἰς' in normalized text.
# 2024-05-15 18:02:59,223 - DEBUG - root - normalized_token_text: εἰς
# 2024-05-15 18:02:59,223 - DEBUG - root - new_token_begin: 25, new_token_end: 28, token value: Topography
# 2024-05-15 18:02:59,223 - DEBUG - root - Token index: 565-568, Adjusted index for sentence: 37-40, Token text: εἰς
# 2024-05-15 18:02:59,224 - DEBUG - root - Adjusted indices: 36-39 for token 'εἰς' in normalized text.
# 2024-05-15 18:02:59,224 - DEBUG - root - normalized_token_text: εἰς
# 2024-05-15 18:02:59,225 - DEBUG - root - new_token_begin: 36, new_token_end: 39, token value: Topography
# 2024-05-15 18:02:59,225 - DEBUG - root - Token index: 577-592, Adjusted index for sentence: 49-64, Token text: καταναλίσκονται
# 2024-05-15 18:02:59,225 - DEBUG - root - Adjusted indices: 48-63 for token 'καταναλίσκονται' in normalized text.
# 2024-05-15 18:02:59,226 - DEBUG - root - normalized_token_text: καταναλίσκονται
# 2024-05-15 18:02:59,226 - DEBUG - root - new_token_begin: 48, new_token_end: 63, token value: Topography
# 2024-05-15 18:02:59,235 - DEBUG - root - Token index: 597-603, Adjusted index for sentence: 69-75, Token text: νεφρῶν
# 2024-05-15 18:02:59,236 - DEBUG - root - Adjusted indices: 68-74 for token 'νεφρῶν' in normalized text.
# 2024-05-15 18:02:59,237 - DEBUG - root - normalized_token_text: νεφρῶν
# 2024-05-15 18:02:59,237 - DEBUG - root - new_token_begin: 68, new_token_end: 74, token value: Body Part
# 2024-05-15 18:02:59,238 - DEBUG - root - normalized sentence: οἱ δὲ πόροι οἱ τείνοντες εἰς αὐτοὺς εἰς τὸ σῶμα καταναλίσκονται τῶν νεφρῶν·
# 2024-05-15 18:02:59,238 - DEBUG - root - Final FORM: NFKC
# 2024-05-15 18:02:59,238 - DEBUG - root - original sentence: σημεῖον δ’ ὅτι
# οὐ περαίνουσι τὸ μὴ ἔχειν αἷμα μηδὲ πήγνυσθαι ἐν αὐτοῖς.
# 2024-05-15 18:02:59,239 - DEBUG - root - normalized_sentence_text: σημεῖον δʼ ὅτι οὐ περαίνουσι τὸ μὴ ἔχειν αἷμα μηδὲ πήγνυσθαι ἐν αὐτοῖς.
# 2024-05-15 18:02:59,239 - DEBUG - root - Token index: 625-635, Adjusted index for sentence: 20-30, Token text: περαίνουσι
# 2024-05-15 18:02:59,240 - DEBUG - root - Adjusted indices: 18-28 for token 'περαίνουσι' in normalized text.
# 2024-05-15 18:02:59,240 - DEBUG - root - normalized_token_text: περαίνουσι
# 2024-05-15 18:02:59,241 - DEBUG - root - new_token_begin: 18, new_token_end: 28, token value: Topography
# 2024-05-15 18:02:59,243 - DEBUG - root - Token index: 648-652, Adjusted index for sentence: 43-47, Token text: αἷμα
# 2024-05-15 18:02:59,243 - DEBUG - root - Adjusted indices: 41-45 for token 'αἷμα' in normalized text.
# 2024-05-15 18:02:59,244 - DEBUG - root - normalized_token_text: αἷμα
# ...
# 2024-05-15 18:03:09,643 - DEBUG - root - Current data_entry: ἀπὸ μὲν τῆς καρδίης ἐπί τι χωρίον ἐν τοῖσιν ἀριστεροῖσι μᾶλλον ἐοῦσα, ἔπειτα ὑποκάτω τῆς ἀρτηρίης ἔστʼ ἂν καταναλωθῇ καὶ ἔλθῃ ὅθεν ἡ ἡπατῖτις ἐμετεωρίσθη., {'entities': [(0, 3, 'Topography'), (12, 19, 'Body Part'), (34, 62, 'Topography'), (77, 84, 'Topography'), (89, 97, 'Body Part'), (121, 125, 'Topography'), (133, 141, 'Body Part'), (142, 153, 'Topography')]}, Hippocrates epidemics 2.4.1 pt.2
# 2024-05-15 18:03:09,644 - DEBUG - root - start: 0, end: 3, label: Topography
part'), ('διαπετεῖς', 'Topography'), ('ἐπιγάστριον', 'Body Part'), ('δέρμα', 'Body Part'), ('μηροῦ', 'Body Part'), ('μεγάλῃ', 'Adjectives/Qualities'), ('φλεβὶ', 'Body Part'), ('μεγάλης', 'Adjectives/Qualities'), ('φλεβὸς', 'Body Part'), ('καλούμεναι', 'Adjectives/Qualities'), ('πύλαι', 'Technical Appellation'), ('μεγάλῃ', 'Adjectives/Qualities'), ('φλεβὶ', 'Body Part'), ('ἰσχίον', 'Body Part'), ('ὀστοῦν', 'Body Part'), ('ἰσχίον', 'Body Part'), ('ὀστοῦ', 'Body Part'), ('μηροῦ', 'Body Part'), ('μηρῷ', 'Body Part')]
# 2024-05-15 18:03:10,016 - INFO - root - Train: 406
# 2024-05-15 18:03:10,017 - INFO - root - Test: 51
# 2024-05-15 18:03:10,017 - INFO - root - Dev: 51

# %%
logger.setLevel(logging.DEBUG)

process_sentences_and_serialize(input_path=Path("../assets/NER_assets/INCEpTION_files/"), nlp=nlp, normalization_forms=['NFKD'], output_dir=Path("../corpus/"), debug=False, debug_patterns=False, debug_inception=None, output_file_name="ner")
# Out:
# 2024-05-13 10:13:19,514 - ERROR - root - Error finding word index for entity ['Adjectives/Qualities', 'μονοφυές', 'γὰρ ὡς', 'ἑκάτερον, καὶ']: Word 'μονοφυές' not found in sentence 'καὶ γὰρ ὡς μονοφυὲς ἑκάτερον, καὶ ὡς ἀνθʼ ἑνὸς δύο παραπλησίαν ἔχοντα τὴν φύσιν.'
# 2024-05-13 10:13:19,565 - ERROR - root - Error finding word index for entity ['Topography', 'πρός', 'καλούμεναι φρένες,', 'μέν τὰ']: Word 'πρός' not found in sentence 'Ὑπὸ δὲ τὸν πνεύμονά ἐστι τὸ διάζωμα τὸ τοῦ θώρακος, αἱ καλούμεναι φρένες, πρὸς μὲν τὰ πλευρὰ καὶ τὰ ὑποχόνδρια καὶ τὴν ῥάχιν συνηρτημέναι, ἐν μέσῳ δʼ ἔχει τὰ λεπτὰ καὶ ὑμενώδη'
# 2024-05-13 10:13:19,593 - ERROR - root - Error finding word index for entity ['Body Part', 'κοῖλον', 'συνήρτηται', 'ἐστίν']: Word 'κοῖλον' not found in sentence 'ᾗ δὲ συνήρτηται κοῖλόν ἐστιν'
# 2024-05-13 10:13:19,611 - ERROR - root - Error finding word index for entity ['Adjectives/Qualities', 'ξηρόν', 'οὔτε', 'οὔθʼ']: Word 'ξηρόν' not found in sentence 'Ἡ μὲν οὖν ἀρτηρία τοῦτον ἔχει τὸν τρόπον, καὶ δέχεται μόνον τὸ πνεῦμα καὶ ἀφίησιν ἄλλο δʼ οὐθὲν οὔτε ξηρὸν οὔθʼ ὑγρόν, ἢ πόνον παρέχει, ἕως ἂν ἐκβήξῃ τὸ κατελθόν'
# 2024-05-13 10:13:20,218 - INFO - root - Completed preparing training data from table. Total entries: 214. Entities found and registered: 1520. Entities not found: 4
# 2024-05-13 10:13:20,261 - DEBUG - root - Adjusted indices: 16-25 for token 'ὑστέραν' in normalized text.
# 2024-05-13 10:13:20,262 - DEBUG - root - Adjusted indices: 27-32 for token 'ὅσα' in normalized text.
# 2024-05-13 10:13:20,262 - DEBUG - root - Adjusted indices: 38-48 for token 'ζῳοτοκεῖ' in normalized text.
# 2024-05-13 10:13:20,263 - DEBUG - root - Adjusted indices: 54-57 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:20,264 - DEBUG - root - Adjusted indices: 58-66 for token 'αὑτοῖς' in normalized text.
# 2024-05-13 10:13:20,264 - DEBUG - root - Adjusted indices: 72-76 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,265 - DEBUG - root - Adjusted indices: 77-80 for token 'τὸ' in normalized text.
# 2024-05-13 10:13:20,265 - DEBUG - root - Adjusted indices: 81-90 for token 'ἐμφανές' in normalized text.
# 2024-05-13 10:13:20,266 - DEBUG - root - Adjusted indices: 92-100 for token 'ἄνωθεν' in normalized text.
# 2024-05-13 10:13:20,266 - DEBUG - root - Adjusted indices: 106-114 for token 'κοιλίας' in normalized text.
# 2024-05-13 10:13:20,267 - DEBUG - root - Adjusted indices: 116-121 for token 'ὅσα' in normalized text.
# 2024-05-13 10:13:20,267 - DEBUG - root - Adjusted indices: 125-135 for token 'ᾠοτοκεῖ' in normalized text.
# 2024-05-13 10:13:20,268 - DEBUG - root - Adjusted indices: 137-143 for token 'πάντα' in normalized text.
# 2024-05-13 10:13:20,268 - DEBUG - root - Adjusted indices: 144-152 for token 'κάτωθεν' in normalized text.
# 2024-05-13 10:13:20,269 - DEBUG - root - Adjusted indices: 153-158 for token 'πρὸς' in normalized text.
# 2024-05-13 10:13:20,270 - DEBUG - root - Adjusted indices: 164-172 for token 'ὀσφύϊ' in normalized text.
# 2024-05-13 10:13:20,270 - DEBUG - root - Adjusted indices: 0-5 for token 'ὅσα' in normalized text.
# 2024-05-13 10:13:20,271 - DEBUG - root - Adjusted indices: 9-13 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,271 - DEBUG - root - Adjusted indices: 14-17 for token 'τὸ' in normalized text.
# 2024-05-13 10:13:20,272 - DEBUG - root - Adjusted indices: 18-26 for token 'φανερὸν' in normalized text.
# 2024-05-13 10:13:20,272 - DEBUG - root - Adjusted indices: 32-42 for token 'ζῳοτοκεῖ' in normalized text.
# 2024-05-13 10:13:20,273 - DEBUG - root - Adjusted indices: 43-46 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:20,273 - DEBUG - root - Adjusted indices: 47-55 for token 'αὑτοῖς' in normalized text.
# 2024-05-13 10:13:20,274 - DEBUG - root - Adjusted indices: 59-69 for token 'ᾠοτοκεῖ' in normalized text.
# 2024-05-13 10:13:20,275 - DEBUG - root - Adjusted indices: 71-86 for token 'ἐπαμφοτερίζει' in normalized text.
# 2024-05-13 10:13:20,275 - DEBUG - root - Adjusted indices: 14-22 for token 'κάτωθεν' in normalized text.
# 2024-05-13 10:13:20,276 - DEBUG - root - Adjusted indices: 23-28 for token 'πρὸς' in normalized text.
# 2024-05-13 10:13:20,276 - DEBUG - root - Adjusted indices: 34-41 for token 'ὀσφὺν' in normalized text.
# 2024-05-13 10:13:20,277 - DEBUG - root - Adjusted indices: 50-56 for token 'μέρος' in normalized text.
# 2024-05-13 10:13:20,278 - DEBUG - root - Adjusted indices: 66-69 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:20,278 - DEBUG - root - Adjusted indices: 79-87 for token 'περιττὰ' in normalized text.
# 2024-05-13 10:13:20,279 - DEBUG - root - Adjusted indices: 103-108 for token 'περὶ' in normalized text.
# 2024-05-13 10:13:20,279 - DEBUG - root - Adjusted indices: 114-122 for token 'ἔξοδον' in normalized text.
# 2024-05-13 10:13:20,280 - DEBUG - root - Adjusted indices: 123-130 for token 'ἐπάνω' in normalized text.
# 2024-05-13 10:13:20,280 - DEBUG - root - Adjusted indices: 136-145 for token 'ἐντέρων' in normalized text.
# 2024-05-13 10:13:20,281 - DEBUG - root - Adjusted indices: 58-67 for token 'ὑστερῶν' in normalized text.
# 2024-05-13 10:13:20,281 - DEBUG - root - Adjusted indices: 14-25 for token 'κερατοφόρα' in normalized text.
# 2024-05-13 10:13:20,282 - DEBUG - root - Adjusted indices: 35-46 for token 'ἀμφώδοντα' in normalized text.
# 2024-05-13 10:13:20,283 - DEBUG - root - Adjusted indices: 54-66 for token 'κοτυληδόνας' in normalized text.
# 2024-05-13 10:13:20,283 - DEBUG - root - Adjusted indices: 67-70 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:20,284 - DEBUG - root - Adjusted indices: 76-85 for token 'ὑστέρᾳ' in normalized text.
# 2024-05-13 10:13:20,284 - DEBUG - root - Adjusted indices: 126-138 for token 'ἀμφωδόντων' in normalized text.
# 2024-05-13 10:13:20,285 - DEBUG - root - Adjusted indices: 7-13 for token 'ἄλλα' in normalized text.
# 2024-05-13 10:13:20,285 - DEBUG - root - Adjusted indices: 18-29 for token 'ἀμφώδοντα' in normalized text.
# 2024-05-13 10:13:20,286 - DEBUG - root - Adjusted indices: 35-44 for token 'ζῳοτόκα' in normalized text.
# 2024-05-13 10:13:20,286 - DEBUG - root - Adjusted indices: 50-59 for token 'ὑπόποδα' in normalized text.
# 2024-05-13 10:13:20,287 - DEBUG - root - Adjusted indices: 60-66 for token 'πάντα' in normalized text.
# 2024-05-13 10:13:20,288 - DEBUG - root - Adjusted indices: 67-73 for token 'λείαν' in normalized text.
# 2024-05-13 10:13:20,289 - DEBUG - root - Adjusted indices: 86-95 for token 'ὑστέραν' in normalized text.
# 2024-05-13 10:13:20,289 - DEBUG - root - Adjusted indices: 120-131 for token 'ἐξάρτησις' in normalized text.
# 2024-05-13 10:13:20,290 - DEBUG - root - Adjusted indices: 120-123 for token 'ἐξ' in normalized text.
# 2024-05-13 10:13:20,290 - DEBUG - root - Adjusted indices: 136-143 for token 'αὐτῆς' in normalized text.
# 2024-05-13 10:13:20,291 - DEBUG - root - Adjusted indices: 155-164 for token 'ὑστέρας' in normalized text.
# 2024-05-13 10:13:20,292 - DEBUG - root - Adjusted indices: 177-180 for token 'ἐκ' in normalized text.
# 2024-05-13 10:13:20,292 - DEBUG - root - Adjusted indices: 181-193 for token 'κοτυληδόνος' in normalized text.
# 2024-05-13 10:13:20,349 - DEBUG - root - Adjusted indices: 21-28 for token 'νεφροὶ' in normalized text.
# 2024-05-13 10:13:20,350 - DEBUG - root - Adjusted indices: 29-34 for token 'πρὸς' in normalized text.
# 2024-05-13 10:13:20,351 - DEBUG - root - Adjusted indices: 48-55 for token 'ῥάχει' in normalized text.
# 2024-05-13 10:13:20,351 - DEBUG - root - Adjusted indices: 56-64 for token 'κεῖνται' in normalized text.
# 2024-05-13 10:13:20,352 - DEBUG - root - Adjusted indices: 66-74 for token 'ὅμοιοι' in normalized text.
# 2024-05-13 10:13:20,352 - DEBUG - root - Adjusted indices: 101-109 for token 'βοείοις' in normalized text.
# 2024-05-13 10:13:20,353 - DEBUG - root - Adjusted indices: 0-10 for token 'ἀνώτερος' in normalized text.
# 2024-05-13 10:13:20,353 - DEBUG - root - Adjusted indices: 18-25 for token 'δεξιός' in normalized text.
# 2024-05-13 10:13:20,354 - DEBUG - root - Adjusted indices: 49-56 for token 'ζῴοις' in normalized text.
# 2024-05-13 10:13:20,354 - DEBUG - root - Adjusted indices: 72-80 for token 'νεφρούς' in normalized text.
# 2024-05-13 10:13:20,355 - DEBUG - root - Adjusted indices: 5-13 for token 'ἐλάττω' in normalized text.
# 2024-05-13 10:13:20,356 - DEBUG - root - Adjusted indices: 18-26 for token 'πιμελὴν' in normalized text.
# 2024-05-13 10:13:20,356 - DEBUG - root - Adjusted indices: 39-50 for token 'ἀριστεροῦ' in normalized text.
# 2024-05-13 10:13:20,357 - DEBUG - root - Adjusted indices: 56-70 for token 'αὐχμηρότερος' in normalized text.
# 2024-05-13 10:13:20,357 - DEBUG - root - Adjusted indices: 74-81 for token 'δεξιός' in normalized text.
# 2024-05-13 10:13:20,358 - DEBUG - root - Adjusted indices: 20-28 for token 'ὁμοίως' in normalized text.
# 2024-05-13 10:13:20,359 - DEBUG - root - Adjusted indices: 0-8 for token 'φέρουσι' in normalized text.
# 2024-05-13 10:13:20,360 - DEBUG - root - Adjusted indices: 13-17 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,360 - DEBUG - root - Adjusted indices: 27-33 for token 'πόροι' in normalized text.
# 2024-05-13 10:13:20,363 - DEBUG - root - Adjusted indices: 34-38 for token 'ἔκ' in normalized text.
# 2024-05-13 10:13:20,363 - DEBUG - root - Adjusted indices: 47-55 for token 'μεγάλης' in normalized text.
# 2024-05-13 10:13:20,364 - DEBUG - root - Adjusted indices: 56-63 for token 'φλεβὸς' in normalized text.
# 2024-05-13 10:13:20,364 - DEBUG - root - Adjusted indices: 74-82 for token 'ἀορτῆς' in normalized text.
# 2024-05-13 10:13:20,365 - DEBUG - root - Adjusted indices: 95-99 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,365 - DEBUG - root - Adjusted indices: 104-111 for token 'κοῖλον' in normalized text.
# 2024-05-13 10:13:20,366 - DEBUG - root - Adjusted indices: 18-25 for token 'νεφροὶ' in normalized text.
# 2024-05-13 10:13:20,366 - DEBUG - root - Adjusted indices: 26-29 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:20,367 - DEBUG - root - Adjusted indices: 30-36 for token 'μέσῳ' in normalized text.
# 2024-05-13 10:13:20,367 - DEBUG - root - Adjusted indices: 37-44 for token 'κοῖλον' in normalized text.
# 2024-05-13 10:13:20,368 - DEBUG - root - Adjusted indices: 55-62 for token 'μεῖζον' in normalized text.
# 2024-05-13 10:13:20,369 - DEBUG - root - Adjusted indices: 70-79 for token 'ἔλαττον' in normalized text.
# 2024-05-13 10:13:20,369 - DEBUG - root - Adjusted indices: 11-19 for token 'ὅμοιοι' in normalized text.
# 2024-05-13 10:13:20,370 - DEBUG - root - Adjusted indices: 43-55 for token 'στερεώτατοι' in normalized text.
# 2024-05-13 10:13:20,371 - DEBUG - root - Adjusted indices: 8-14 for token 'πόροι' in normalized text.
# 2024-05-13 10:13:20,371 - DEBUG - root - Adjusted indices: 19-29 for token 'τείνοντες' in normalized text.
# 2024-05-13 10:13:20,372 - DEBUG - root - Adjusted indices: 30-34 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,372 - DEBUG - root - Adjusted indices: 30-34 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,373 - DEBUG - root - Adjusted indices: 59-75 for token 'καταναλίσκονται' in normalized text.
# 2024-05-13 10:13:20,373 - DEBUG - root - Adjusted indices: 81-88 for token 'νεφρῶν' in normalized text.
# 2024-05-13 10:13:20,374 - DEBUG - root - Adjusted indices: 22-33 for token 'περαίνουσι' in normalized text.
# 2024-05-13 10:13:20,375 - DEBUG - root - Adjusted indices: 50-56 for token 'αἷμα' in normalized text.
# 2024-05-13 10:13:20,375 - DEBUG - root - Adjusted indices: 74-77 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:20,376 - DEBUG - root - Adjusted indices: 13-21 for token 'κοιλίαν' in normalized text.
# 2024-05-13 10:13:20,376 - DEBUG - root - Adjusted indices: 42-49 for token 'μικράν' in normalized text.
# 2024-05-13 10:13:20,377 - DEBUG - root - Adjusted indices: 0-3 for token 'ἐκ' in normalized text.
# 2024-05-13 10:13:20,377 - DEBUG - root - Adjusted indices: 13-20 for token 'κοίλου' in normalized text.
# 2024-05-13 10:13:20,378 - DEBUG - root - Adjusted indices: 26-33 for token 'νεφρῶν' in normalized text.
# 2024-05-13 10:13:20,378 - DEBUG - root - Adjusted indices: 44-48 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,379 - DEBUG - root - Adjusted indices: 54-61 for token 'κύστιν' in normalized text.
# 2024-05-13 10:13:20,379 - DEBUG - root - Adjusted indices: 62-68 for token 'πόροι' in normalized text.
# 2024-05-13 10:13:20,380 - DEBUG - root - Adjusted indices: 69-73 for token 'δύο' in normalized text.
# 2024-05-13 10:13:20,381 - DEBUG - root - Adjusted indices: 74-83 for token 'νεανικοί' in normalized text.
# 2024-05-13 10:13:20,381 - DEBUG - root - Adjusted indices: 98-101 for token 'ἐκ' in normalized text.
# 2024-05-13 10:13:20,382 - DEBUG - root - Adjusted indices: 107-115 for token 'ἀορτῆς' in normalized text.
# 2024-05-13 10:13:20,382 - DEBUG - root - Adjusted indices: 116-125 for token 'ἰσχυροὶ' in normalized text.
# 2024-05-13 10:13:20,383 - DEBUG - root - Adjusted indices: 131-141 for token 'συνεχεῖς.' in normalized text.
# 2024-05-13 10:13:20,384 - DEBUG - root - Adjusted indices: 0-3 for token 'ἐκ' in normalized text.
# 2024-05-13 10:13:20,384 - DEBUG - root - Adjusted indices: 4-10 for token 'μέσου' in normalized text.
# 2024-05-13 10:13:20,385 - DEBUG - root - Adjusted indices: 20-27 for token 'νεφρῶν' in normalized text.
# 2024-05-13 10:13:20,385 - DEBUG - root - Adjusted indices: 39-44 for token 'φλὲψ' in normalized text.
# 2024-05-13 10:13:20,386 - DEBUG - root - Adjusted indices: 45-51 for token 'κοίλη' in normalized text.
# 2024-05-13 10:13:20,386 - DEBUG - root - Adjusted indices: 57-66 for token 'νευρώδης' in normalized text.
# 2024-05-13 10:13:20,387 - DEBUG - root - Adjusted indices: 67-78 for token 'ἐξήρτηται' in normalized text.
# 2024-05-13 10:13:20,387 - DEBUG - root - Adjusted indices: 80-89 for token 'τείνουσα' in normalized text.
# 2024-05-13 10:13:20,388 - DEBUG - root - Adjusted indices: 90-93 for token 'παρ' in normalized text.
# 2024-05-13 10:13:20,388 - DEBUG - root - Adjusted indices: 108-115 for token 'ῥάχιν' in normalized text.
# 2024-05-13 10:13:20,389 - DEBUG - root - Adjusted indices: 116-120 for token 'διὰ' in normalized text.
# 2024-05-13 10:13:20,390 - DEBUG - root - Adjusted indices: 126-133 for token 'στενῶν' in normalized text.
# 2024-05-13 10:13:20,390 - DEBUG - root - Adjusted indices: 7-11 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,391 - DEBUG - root - Adjusted indices: 27-35 for token 'ἰσχίον' in normalized text.
# 2024-05-13 10:13:20,391 - DEBUG - root - Adjusted indices: 36-49 for token 'ἀφανίζονται' in normalized text.
# 2024-05-13 10:13:20,392 - DEBUG - root - Adjusted indices: 63-69 for token 'δῆλαι' in normalized text.
# 2024-05-13 10:13:20,392 - DEBUG - root - Adjusted indices: 70-79 for token 'γίνονται' in normalized text.
# 2024-05-13 10:13:20,393 - DEBUG - root - Adjusted indices: 80-90 for token 'τεταμέναι' in normalized text.
# 2024-05-13 10:13:20,393 - DEBUG - root - Adjusted indices: 91-96 for token 'πρὸς' in normalized text.
# 2024-05-13 10:13:20,394 - DEBUG - root - Adjusted indices: 101-109 for token 'ἰσχίον' in normalized text.
# 2024-05-13 10:13:20,394 - DEBUG - root - Adjusted indices: 15-25 for token 'ἀποτομαὶ' in normalized text.
# 2024-05-13 10:13:20,395 - DEBUG - root - Adjusted indices: 31-39 for token 'φλεβίων' in normalized text.
# 2024-05-13 10:13:20,395 - DEBUG - root - Adjusted indices: 40-44 for token 'εἰς' in normalized text.
# 2024-05-13 10:13:20,396 - DEBUG - root - Adjusted indices: 50-57 for token 'κύστιν' in normalized text.
# 2024-05-13 10:13:20,396 - DEBUG - root - Adjusted indices: 58-69 for token 'καθήκουσιν' in normalized text.
# file name:  Aristotle_Historia_Animalium_511a22-34.zip
# file name:  Aristotle_Historia_Animalium_496b34-497a18.zip
# file name:  hippocrates places in man 4.2-5.1.zip
# 2024-05-13 10:13:20,447 - DEBUG - root - Adjusted indices: 119-127 for token 'ὀστέου' in normalized text.
# 2024-05-13 10:13:20,448 - DEBUG - root - Adjusted indices: 179-186 for token 'σάρκες' in normalized text.
# 2024-05-13 10:13:20,448 - DEBUG - root - Adjusted indices: 8-14 for token 'νεῦρα' in normalized text.
# 2024-05-13 10:13:20,449 - DEBUG - root - Adjusted indices: 29-36 for token 'ἄρθρα' in normalized text.
# 2024-05-13 10:13:20,449 - DEBUG - root - Adjusted indices: 62-65 for token 'παρ' in normalized text.
# 2024-05-13 10:13:20,450 - DEBUG - root - Adjusted indices: 114-121 for token 'σάρκες' in normalized text.
# 2024-05-13 10:13:20,450 - DEBUG - root - Adjusted indices: 35-42 for token 'νεύρων' in normalized text.
# 2024-05-13 10:13:20,451 - DEBUG - root - Adjusted indices: 0-5 for token 'περὶ' in normalized text.
# 2024-05-13 10:13:20,451 - DEBUG - root - Adjusted indices: 14-23 for token 'πρόσωπον' in normalized text.
# 2024-05-13 10:13:20,452 - DEBUG - root - Adjusted indices: 34-42 for token 'κεφαλὴν' in normalized text.
# 2024-05-13 10:13:20,453 - DEBUG - root - Adjusted indices: 55-61 for token 'νεύρα' in normalized text.
# 2024-05-13 10:13:20,453 - DEBUG - root - Adjusted indices: 70-76 for token 'ἴνες' in normalized text.
# 2024-05-13 10:13:20,454 - DEBUG - root - Adjusted indices: 88-97 for token 'νεύροισι' in normalized text.
# 2024-05-13 10:13:20,456 - DEBUG - root - Adjusted indices: 114-122 for token 'ὀστέου' in normalized text.
# 2024-05-13 10:13:20,456 - DEBUG - root - Adjusted indices: 133-140 for token 'σαρκός' in normalized text.
# 2024-05-13 10:13:20,457 - DEBUG - root - Adjusted indices: 141-152 for token 'λεπτότεροι' in normalized text.
# 2024-05-13 10:13:20,457 - DEBUG - root - Adjusted indices: 157-169 for token 'στερεώτεροι' in normalized text.
# 2024-05-13 10:13:20,458 - DEBUG - root - Adjusted indices: 179-192 for token 'νευροκοίλιοι' in normalized text.
# 2024-05-13 10:13:20,502 - DEBUG - root - Adjusted indices: 13-20 for token 'φλέβες' in normalized text.
# 2024-05-13 10:13:20,503 - DEBUG - root - Adjusted indices: 33-43 for token 'κροτάφους' in normalized text.
# 2024-05-13 10:13:20,503 - DEBUG - root - Adjusted indices: 44-53 for token 'φέρονται' in normalized text.
# 2024-05-13 10:13:20,504 - DEBUG - root - Adjusted indices: 54-64 for token 'ἐν μέσῳ' in normalized text.
# 2024-05-13 10:13:20,504 - DEBUG - root - Adjusted indices: 70-79 for token 'κροτάφων' in normalized text.
# 2024-05-13 10:13:20,505 - DEBUG - root - Adjusted indices: 90-96 for token 'ὤτων' in normalized text.
# 2024-05-13 10:13:20,505 - DEBUG - root - Adjusted indices: 117-124 for token 'ὄψιας' in normalized text.
# 2024-05-13 10:13:20,506 - DEBUG - root - Adjusted indices: 41-48 for token 'φλεβῶν' in normalized text.
# 2024-05-13 10:13:20,506 - DEBUG - root - Adjusted indices: 42-47 for token 'ἄνω' in normalized text.
# 2024-05-13 10:13:20,507 - DEBUG - root - Adjusted indices: 212-223 for token 'φλεβίοισιν' in normalized text.
# 2024-05-13 10:13:20,508 - DEBUG - root - Adjusted indices: 232-238 for token 'ὄψις' in normalized text.
# 2024-05-13 10:13:20,508 - DEBUG - root - Adjusted indices: 255-266 for token 'ἐγκεφάλου' in normalized text.
# 2024-05-13 10:13:20,510 - DEBUG - root - Adjusted indices: 316-323 for token 'φλεβών' in normalized text.
# 2024-05-13 10:13:20,553 - DEBUG - root - Adjusted indices: 7-16 for token 'ὑστέραι' in normalized text.
# 2024-05-13 10:13:20,554 - DEBUG - root - Adjusted indices: 22-31 for token 'ἐχόντων' in normalized text.
# 2024-05-13 10:13:20,554 - DEBUG - root - Adjusted indices: 32-41 for token 'ὑστέρας' in normalized text.
# 2024-05-13 10:13:20,555 - DEBUG - root - Adjusted indices: 94-102 for token 'ὅμοιαι' in normalized text.
# 2024-05-13 10:13:20,555 - DEBUG - root - Adjusted indices: 103-110 for token 'πάντων' in normalized text.
# 2024-05-13 10:13:20,556 - DEBUG - root - Adjusted indices: 127-138 for token 'διαφέρουσι' in normalized text.
# 2024-05-13 10:13:20,556 - DEBUG - root - Adjusted indices: 149-163 for token 'ζῳοτοκούντων' in normalized text.
# 2024-05-13 10:13:20,556 - DEBUG - root - Adjusted indices: 189-203 for token 'ᾠοτοκούντων' in normalized text.
# 2024-05-13 10:13:20,557 - DEBUG - root - Adjusted indices: 0-8 for token 'δίκροαι' in normalized text.
# 2024-05-13 10:13:20,557 - DEBUG - root - Adjusted indices: 26-33 for token 'πάντων' in normalized text.
# 2024-05-13 10:13:20,558 - DEBUG - root - Adjusted indices: 39-44 for token 'πρὸς' in normalized text.
# 2024-05-13 10:13:20,558 - DEBUG - root - Adjusted indices: 51-60 for token 'ἄρθροις' in normalized text.
# 2024-05-13 10:13:20,559 - DEBUG - root - Adjusted indices: 61-70 for token 'ἐχόντων' in normalized text.
# 2024-05-13 10:13:20,559 - DEBUG - root - Adjusted indices: 76-85 for token 'ὑστέρας' in normalized text.
# 2024-05-13 10:13:20,560 - DEBUG - root - Adjusted indices: 109-112 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:20,560 - DEBUG - root - Adjusted indices: 113-118 for token 'τοῖς' in normalized text.
# 2024-05-13 10:13:20,561 - DEBUG - root - Adjusted indices: 119-127 for token 'δεξιοῖς' in normalized text.
# 2024-05-13 10:13:20,561 - DEBUG - root - Adjusted indices: 128-135 for token 'μέρεσι' in normalized text.
# 2024-05-13 10:13:20,561 - DEBUG - root - Adjusted indices: 109-112 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:20,562 - DEBUG - root - Adjusted indices: 113-118 for token 'τοῖς' in normalized text.
# 2024-05-13 10:13:20,562 - DEBUG - root - Adjusted indices: 163-175 for token 'ἀριστεροῖς' in normalized text.
# 2024-05-13 10:13:20,563 - DEBUG - root - Adjusted indices: 6-12 for token 'ἀρχὴ' in normalized text.
# 2024-05-13 10:13:20,563 - DEBUG - root - Adjusted indices: 13-17 for token 'μία' in normalized text.
# 2024-05-13 10:13:20,564 - DEBUG - root - Adjusted indices: 27-33 for token 'στόμα' in normalized text.
# 2024-05-13 10:13:20,564 - DEBUG - root - Adjusted indices: 34-38 for token 'ἕν' in normalized text.
# 2024-05-13 10:13:20,565 - DEBUG - root - Adjusted indices: 40-46 for token 'οἷον' in normalized text.
# 2024-05-13 10:13:20,566 - DEBUG - root - Adjusted indices: 55-64 for token 'σαρκώδης' in normalized text.
# 2024-05-13 10:13:20,566 - DEBUG - root - Adjusted indices: 65-72 for token 'σφόδρα' in normalized text.
# 2024-05-13 10:13:20,567 - DEBUG - root - Adjusted indices: 78-88 for token 'χονδρώδης' in normalized text.
# 2024-05-13 10:13:20,567 - DEBUG - root - Adjusted indices: 95-105 for token 'πλείστοις' in normalized text.
# 2024-05-13 10:13:20,568 - DEBUG - root - Adjusted indices: 111-121 for token 'μεγίστοις' in normalized text.
# 2024-05-13 10:13:20,568 - DEBUG - root - Adjusted indices: 31-39 for token 'ὑστέρα' in normalized text.
# 2024-05-13 10:13:20,569 - DEBUG - root - Adjusted indices: 45-52 for token 'δελφύς' in normalized text.
# 2024-05-13 10:13:20,569 - DEBUG - root - Adjusted indices: 95-101 for token 'μήτρα' in normalized text.
# 2024-05-13 10:13:20,570 - DEBUG - root - Adjusted indices: 108-115 for token 'καυλὸς' in normalized text.
# 2024-05-13 10:13:20,570 - DEBUG - root - Adjusted indices: 125-131 for token 'στόμα' in normalized text.
# 2024-05-13 10:13:20,571 - DEBUG - root - Adjusted indices: 137-146 for token 'ὑστέρας' in normalized text.
# 2024-05-13 10:13:20,571 - DEBUG - root - Adjusted indices: 0-5 for token 'ὅσα' in normalized text.
# 2024-05-13 10:13:20,572 - DEBUG - root - Adjusted indices: 23-32 for token 'ζῳοτόκα' in normalized text.
# 2024-05-13 10:13:20,572 - DEBUG - root - Adjusted indices: 38-45 for token 'δίποδα' in normalized text.
# 2024-05-13 10:13:20,572 - DEBUG - root - Adjusted indices: 50-60 for token 'τετράποδα' in normalized text.
# 2024-05-13 10:13:20,573 - DEBUG - root - Adjusted indices: 78-86 for token 'ὑστέρα' in normalized text.
# 2024-05-13 10:13:20,573 - DEBUG - root - Adjusted indices: 87-94 for token 'πάντων' in normalized text.
# 2024-05-13 10:13:20,574 - DEBUG - root - Adjusted indices: 102-107 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:20,574 - DEBUG - root - Adjusted indices: 113-125 for token 'ὑποζώματος' in normalized text.
# 2024-05-13 10:13:20,575 - DEBUG - root - Adjusted indices: 127-133 for token 'οἷον' in normalized text.
# 2024-05-13 10:13:20,575 - DEBUG - root - Adjusted indices: 11-24 for token 'κερατοφόροις' in normalized text.
# 2024-05-13 10:13:20,576 - DEBUG - root - Adjusted indices: 25-33 for token 'ὁμοίως' in normalized text.
# 2024-05-13 10:13:20,576 - DEBUG - root - Adjusted indices: 48-54 for token 'πᾶσιν' in normalized text.
# 2024-05-13 10:13:20,577 - DEBUG - root - Adjusted indices: 0-3 for token 'ἐπ' in normalized text.
# 2024-05-13 10:13:20,586 - DEBUG - root - Adjusted indices: 5-12 for token 'ἄκρων' in normalized text.
# 2024-05-13 10:13:20,586 - DEBUG - root - Adjusted indices: 20-29 for token 'ὑστέραι' in normalized text.
# 2024-05-13 10:13:20,587 - DEBUG - root - Adjusted indices: 47-55 for token 'κεράτων' in normalized text.
# 2024-05-13 10:13:20,588 - DEBUG - root - Adjusted indices: 56-66 for token 'εἱλιγμὸν' in normalized text.
# 2024-05-13 10:13:20,632 - DEBUG - root - Adjusted indices: 0-5 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:20,633 - DEBUG - root - Adjusted indices: 9-21 for token 'ἐκτείνοντι' in normalized text.
# 2024-05-13 10:13:20,633 - DEBUG - root - Adjusted indices: 67-103 for token 'ἡ συμβολὴ τῶν τῆς ἥβης ὀστῶν' in normalized text.
# 2024-05-13 10:13:20,634 - DEBUG - root - Adjusted indices: 89-103 for token 'ἥβης ὀστῶν' in normalized text.
# 2024-05-13 10:13:20,634 - DEBUG - root - Adjusted indices: 104-135 for token 'ἐν δὲ τῷ μεταξὺ τὸ μέσον' in normalized text.
# 2024-05-13 10:13:20,635 - DEBUG - root - Adjusted indices: 141-146 for token 'κατὰ' in normalized text.
# 2024-05-13 10:13:20,635 - DEBUG - root - Adjusted indices: 152-161 for token 'ὀμφαλόν' in normalized text.
# 2024-05-13 10:13:20,636 - DEBUG - root - Adjusted indices: 53-63 for token 'τὸ μέσον' in normalized text.
# 2024-05-13 10:13:20,636 - DEBUG - root - Adjusted indices: 83-90 for token 'κορυφή' in normalized text.
# 2024-05-13 10:13:20,637 - DEBUG - root - Adjusted indices: 91-116 for token 'τοῦ ξιφοειδούς χόνδρου' in normalized text.
# 2024-05-13 10:13:20,637 - DEBUG - root - Adjusted indices: 117-155 for token 'τῆς συμβολῆς τῶν τῆς ἥβης ὀτῶν' in normalized text.
# 2024-05-13 10:13:20,638 - DEBUG - root - Adjusted indices: 142-155 for token 'ἥβης ὀτῶν' in normalized text.
# 2024-05-13 10:13:20,638 - DEBUG - root - Adjusted indices: 26-38 for token 'ἀνατέμνειν' in normalized text.
# 2024-05-13 10:13:20,640 - DEBUG - root - Adjusted indices: 50-63 for token 'ἐπιγάστριον' in normalized text.
# 2024-05-13 10:13:20,640 - DEBUG - root - Adjusted indices: 64-68 for token 'μῦς' in normalized text.
# 2024-05-13 10:13:20,641 - DEBUG - root - Adjusted indices: 89-102 for token 'ἀφῃρημένου' in normalized text.
# 2024-05-13 10:13:20,642 - DEBUG - root - Adjusted indices: 108-117 for token 'δέρματος' in normalized text.
# 2024-05-13 10:13:20,642 - DEBUG - root - Adjusted indices: 119-143 for token 'ἄρξαι μὲν τῆς τομῆς' in normalized text.
# 2024-05-13 10:13:20,643 - DEBUG - root - Adjusted indices: 144-159 for token 'ἀπὸ τελευτῆς' in normalized text.
# 2024-05-13 10:13:20,643 - DEBUG - root - Adjusted indices: 165-185 for token 'ξιφοειδούς χόνδρου' in normalized text.
# 2024-05-13 10:13:20,644 - DEBUG - root - Adjusted indices: 187-196 for token 'προχώρει' in normalized text.
# 2024-05-13 10:13:20,644 - DEBUG - root - Adjusted indices: 200-249 for token 'ἐντεῦθεν περὶ μέσον τὸν ὀμφαλὸν ἐπιπολῆς' in normalized text.
# 2024-05-13 10:13:20,645 - DEBUG - root - Adjusted indices: 250-257 for token 'τέμνων' in normalized text.
# 2024-05-13 10:13:20,645 - DEBUG - root - Adjusted indices: 304-315 for token 'λευκοτέραν' in normalized text.
# 2024-05-13 10:13:20,646 - DEBUG - root - Adjusted indices: 321-335 for token 'ὑποτεταμένην' in normalized text.
# 2024-05-13 10:13:20,646 - DEBUG - root - Adjusted indices: 49-59 for token 'τετμῆσθαι' in normalized text.
# 2024-05-13 10:13:20,647 - DEBUG - root - Adjusted indices: 12-17 for token 'μύες' in normalized text.
# 2024-05-13 10:13:20,648 - DEBUG - root - Adjusted indices: 22-32 for token 'σαρκώδεις' in normalized text.
# 2024-05-13 10:13:20,649 - DEBUG - root - Adjusted indices: 40-48 for token 'ὀρθοὺς' in normalized text.
# 2024-05-13 10:13:20,649 - DEBUG - root - Adjusted indices: 152-162 for token 'λευκοτέρα' in normalized text.
# 2024-05-13 10:13:20,650 - DEBUG - root - Adjusted indices: 168-174 for token 'πέριξ' in normalized text.
# 2024-05-13 10:13:20,650 - DEBUG - root - Adjusted indices: 187-200 for token 'ὑποκειμένης' in normalized text.
# 2024-05-13 10:13:20,651 - DEBUG - root - Adjusted indices: 209-216 for token 'σαρκός' in normalized text.
# 2024-05-13 10:13:20,651 - DEBUG - root - Adjusted indices: 13-22 for token 'τένοντες' in normalized text.
# 2024-05-13 10:13:20,652 - DEBUG - root - Adjusted indices: 27-38 for token 'ὑμενώδεις' in normalized text.
# 2024-05-13 10:13:20,652 - DEBUG - root - Adjusted indices: 43-59 for token 'περιλαμβάνοντες' in normalized text.
# 2024-05-13 10:13:20,653 - DEBUG - root - Adjusted indices: 66-79 for token 'ὀρθίους μυς' in normalized text.
# 2024-05-13 10:13:20,653 - DEBUG - root - Adjusted indices: 98-110 for token 'λοξῶν μυῶν' in normalized text.
# 2024-05-13 10:13:20,654 - DEBUG - root - Adjusted indices: 147-163 for token 'λευκὴν γραμμὴν' in normalized text.
# 2024-05-13 10:13:20,654 - DEBUG - root - Adjusted indices: 0-8 for token 'τέμνειν' in normalized text.
# 2024-05-13 10:13:20,654 - DEBUG - root - Adjusted indices: 71-82 for token 'συντέμνειν' in normalized text.
# 2024-05-13 10:13:20,655 - DEBUG - root - Adjusted indices: 113-121 for token 'χωρίσαι' in normalized text.
# 2024-05-13 10:13:20,655 - DEBUG - root - Adjusted indices: 128-137 for token 'τένοντας' in normalized text.
# file name:  hippocrates places in man 3.2-3.zip
# file name:  Aristotle_Historia_Animalium_510b5-20.zip
# file name:  Gal. AA. 5, 7, 313, 28 - 315, 19.zip
# 2024-05-13 10:13:20,701 - DEBUG - root - Adjusted indices: 0-14 for token 'ἀνατέμνεσθαι' in normalized text.
# 2024-05-13 10:13:20,702 - DEBUG - root - Adjusted indices: 62-83 for token 'τῆς ἄνωθεν ἀρχῆς' in normalized text.
# 2024-05-13 10:13:20,702 - DEBUG - root - Adjusted indices: 151-162 for token 'ἐγχειρεῖν' in normalized text.
# 2024-05-13 10:13:20,703 - DEBUG - root - Adjusted indices: 171-183 for token 'γυμνάζεσθαι' in normalized text.
# 2024-05-13 10:13:20,703 - DEBUG - root - Adjusted indices: 9-17 for token 'κάτωθεν' in normalized text.
# 2024-05-13 10:13:20,704 - DEBUG - root - Adjusted indices: 70-94 for token 'διὰ τῶν ὀπίσω μερῶν' in normalized text.
# 2024-05-13 10:13:20,705 - DEBUG - root - Adjusted indices: 100-106 for token 'μηροῦ' in normalized text.
# 2024-05-13 10:13:20,705 - DEBUG - root - Adjusted indices: 119-140 for token 'κατʼ ἰσχίον ὀστοῦ' in normalized text.
# 2024-05-13 10:13:20,706 - DEBUG - root - Adjusted indices: 124-132 for token 'ἰσχίον' in normalized text.
# 2024-05-13 10:13:20,706 - DEBUG - root - Adjusted indices: 133-140 for token 'ὀστοῦ' in normalized text.
# 2024-05-13 10:13:20,707 - DEBUG - root - Adjusted indices: 211-216 for token 'μυὸς' in normalized text.
# 2024-05-13 10:13:20,707 - DEBUG - root - Adjusted indices: 8-16 for token 'ἄνωθεν' in normalized text.
# 2024-05-13 10:13:20,708 - DEBUG - root - Adjusted indices: 73-90 for token 'προανατετμημένου' in normalized text.
# 2024-05-13 10:13:20,708 - DEBUG - root - Adjusted indices: 91-96 for token 'μυός' in normalized text.
# 2024-05-13 10:13:20,709 - DEBUG - root - Adjusted indices: 24-32 for token 'κεφαλαὶ' in normalized text.
# 2024-05-13 10:13:20,709 - DEBUG - root - Adjusted indices: 33-38 for token 'μυῶν' in normalized text.
# 2024-05-13 10:13:20,709 - DEBUG - root - Adjusted indices: 48-52 for token 'κατʼ' in normalized text.
# 2024-05-13 10:13:20,710 - DEBUG - root - Adjusted indices: 53-61 for token 'ἰσχίον' in normalized text.
# 2024-05-13 10:13:20,710 - DEBUG - root - Adjusted indices: 62-69 for token 'ὀστοῦ' in normalized text.
# 2024-05-13 10:13:20,711 - DEBUG - root - Adjusted indices: 0-9 for token 'ἐξωτάτω' in normalized text.
# 2024-05-13 10:13:20,711 - DEBUG - root - Adjusted indices: 32-40 for token 'πλατέος' in normalized text.
# 2024-05-13 10:13:20,712 - DEBUG - root - Adjusted indices: 26-33 for token 'κνήμην' in normalized text.
# 2024-05-13 10:13:20,712 - DEBUG - root - Adjusted indices: 49-64 for token 'πρὸς τοὐκτός' in normalized text.
# 2024-05-13 10:13:20,834 - DEBUG - root - Adjusted indices: 50-55 for token 'ἔξω' in normalized text.
# 2024-05-13 10:13:20,860 - DEBUG - root - Adjusted indices: 99-106 for token 'κνήμην' in normalized text.
# file name:  Gal. AA, 2, 4, 91, 15-28.zip
# 2024-05-13 10:13:20,900 - DEBUG - root - Adjusted indices: 0-10 for token 'ἡπατῖτις' in normalized text.
# 2024-05-13 10:13:20,901 - DEBUG - root - Adjusted indices: 15-23 for token 'ὀσφύϊ' in normalized text.
# 2024-05-13 10:13:20,902 - DEBUG - root - Adjusted indices: 36-44 for token 'μεγάλου' in normalized text.
# 2024-05-13 10:13:20,902 - DEBUG - root - Adjusted indices: 45-55 for token 'σπονδύλου' in normalized text.
# 2024-05-13 10:13:20,903 - DEBUG - root - Adjusted indices: 56-64 for token 'κάτωθεν' in normalized text.
# 2024-05-13 10:13:20,903 - DEBUG - root - Adjusted indices: 70-82 for token 'σπονδύλοισι' in normalized text.
# 2024-05-13 10:13:20,904 - DEBUG - root - Adjusted indices: 83-93 for token 'προσδιδοῖ' in normalized text.
# 2024-05-13 10:13:20,904 - DEBUG - root - Adjusted indices: 95-105 for token 'ἐντεῦθεν' in normalized text.
# 2024-05-13 10:13:20,905 - DEBUG - root - Adjusted indices: 106-115 for token 'μετέωρος' in normalized text.
# 2024-05-13 10:13:20,905 - DEBUG - root - Adjusted indices: 87-89 for token 'δι' in normalized text.
# 2024-05-13 10:13:20,906 - DEBUG - root - Adjusted indices: 120-128 for token 'ἥπατος' in normalized text.
# 2024-05-13 10:13:20,906 - DEBUG - root - Adjusted indices: 134-138 for token 'διὰ' in normalized text.
# 2024-05-13 10:13:20,907 - DEBUG - root - Adjusted indices: 139-146 for token 'φρενῶν' in normalized text.
# 2024-05-13 10:13:20,907 - DEBUG - root - Adjusted indices: 147-150 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:20,908 - DEBUG - root - Adjusted indices: 151-159 for token 'καρδίην' in normalized text.
# 2024-05-13 10:13:20,910 - DEBUG - root - Adjusted indices: 5-11 for token 'ᾔει' in normalized text.
# 2024-05-13 10:13:20,911 - DEBUG - root - Adjusted indices: 17-25 for token 'εὐθεῖα' in normalized text.
# 2024-05-13 10:13:20,911 - DEBUG - root - Adjusted indices: 26-29 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:20,912 - DEBUG - root - Adjusted indices: 30-38 for token 'κληῖδας' in normalized text.
# 2024-05-13 10:13:20,913 - DEBUG - root - Adjusted indices: 0-10 for token 'ἐντεῦθεν' in normalized text.
# 2024-05-13 10:13:20,913 - DEBUG - root - Adjusted indices: 24-27 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:20,914 - DEBUG - root - Adjusted indices: 28-37 for token 'τράχηλον' in normalized text.
# 2024-05-13 10:13:20,915 - DEBUG - root - Adjusted indices: 46-49 for token 'ἐπ' in normalized text.
# 2024-05-13 10:13:20,915 - DEBUG - root - Adjusted indices: 51-62 for token 'ὠμοπλάτας' in normalized text.
# 2024-05-13 10:13:20,916 - DEBUG - root - Adjusted indices: 71-86 for token 'ἀποκαμφθεῖσαι' in normalized text.
# 2024-05-13 10:13:20,916 - DEBUG - root - Adjusted indices: 87-92 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:20,917 - DEBUG - root - Adjusted indices: 93-98 for token 'παρὰ' in normalized text.
# 2024-05-13 10:13:20,917 - DEBUG - root - Adjusted indices: 99-110 for token 'σπονδύλους' in normalized text.
# 2024-05-13 10:13:20,918 - DEBUG - root - Adjusted indices: 116-124 for token 'πλευρὰς' in normalized text.
# 2024-05-13 10:13:20,918 - DEBUG - root - Adjusted indices: 125-139 for token 'ἀποκλίνουσιν' in normalized text.
# 2024-05-13 10:13:20,920 - DEBUG - root - Adjusted indices: 144-155 for token 'ἀριστερῶν' in normalized text.
# 2024-05-13 10:13:20,921 - DEBUG - root - Adjusted indices: 168-175 for token 'ἐγγὺς' in normalized text.
# 2024-05-13 10:13:20,921 - DEBUG - root - Adjusted indices: 176-185 for token 'κληΐδων' in normalized text.
# 2024-05-13 10:13:20,922 - DEBUG - root - Adjusted indices: 191-198 for token 'δεξιῶν' in normalized text.
# 2024-05-13 10:13:20,922 - DEBUG - root - Adjusted indices: 254-263 for token 'κατωτέρω' in normalized text.
# 2024-05-13 10:13:20,923 - DEBUG - root - Adjusted indices: 264-278 for token 'ἀποκαμφθεῖσα' in normalized text.
# 2024-05-13 10:13:20,923 - DEBUG - root - Adjusted indices: 300-309 for token 'ἀπέλιπε' in normalized text.
# 2024-05-13 10:13:20,924 - DEBUG - root - Adjusted indices: 310-320 for token 'προσέδωκε' in normalized text.
# 2024-05-13 10:13:20,924 - DEBUG - root - Adjusted indices: 328-339 for token 'πλευρῇσιν' in normalized text.
# 2024-05-13 10:13:20,925 - DEBUG - root - Adjusted indices: 375-383 for token 'καρδίης' in normalized text.
# 2024-05-13 10:13:20,925 - DEBUG - root - Adjusted indices: 384-394 for token 'προστύχῃ' in normalized text.
# 2024-05-13 10:13:20,926 - DEBUG - root - Adjusted indices: 395-411 for token 'ἀποκαμπτομένῃ' in normalized text.
# 2024-05-13 10:13:20,926 - DEBUG - root - Adjusted indices: 412-415 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:20,927 - DEBUG - root - Adjusted indices: 420-430 for token 'ἀριστερά' in normalized text.
# 2024-05-13 10:13:20,927 - DEBUG - root - Adjusted indices: 0-14 for token 'ἀποκαμφθεῖσα' in normalized text.
# 2024-05-13 10:13:20,928 - DEBUG - root - Adjusted indices: 19-24 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:20,928 - DEBUG - root - Adjusted indices: 25-30 for token 'ἐπὶ' in normalized text.
# 2024-05-13 10:13:20,931 - DEBUG - root - Adjusted indices: 31-42 for token 'σπονδύλους' in normalized text.
# 2024-05-13 10:13:20,932 - DEBUG - root - Adjusted indices: 43-54 for token 'καταβαίνει' in normalized text.
# 2024-05-13 10:13:20,932 - DEBUG - root - Adjusted indices: 55-60 for token 'ἔστ' in normalized text.
# 2024-05-13 10:13:20,933 - DEBUG - root - Adjusted indices: 67-77 for token 'ἀφίκηται' in normalized text.
# 2024-05-13 10:13:20,933 - DEBUG - root - Adjusted indices: 109-121 for token 'ἀποδιδοῦσα' in normalized text.
# 2024-05-13 10:13:20,934 - DEBUG - root - Adjusted indices: 129-139 for token 'πλευρῇσι' in normalized text.
# 2024-05-13 10:13:20,934 - DEBUG - root - Adjusted indices: 181-188 for token 'ἔνθεν' in normalized text.
# 2024-05-13 10:13:20,935 - DEBUG - root - Adjusted indices: 181-188 for token 'ἔνθεν' in normalized text.
# 2024-05-13 10:13:20,935 - DEBUG - root - Adjusted indices: 202-213 for token 'ἀποσχίδας' in normalized text.
# 2024-05-13 10:13:20,975 - DEBUG - root - Adjusted indices: 0-8 for token 'εὐθεῖα' in normalized text.
# 2024-05-13 10:13:20,976 - DEBUG - root - Adjusted indices: 19-27 for token 'καρδίης' in normalized text.
# 2024-05-13 10:13:20,977 - DEBUG - root - Adjusted indices: 28-33 for token 'πρὸς' in normalized text.
# 2024-05-13 10:13:20,977 - DEBUG - root - Adjusted indices: 34-42 for token 'κληῖδας' in normalized text.
# 2024-05-13 10:13:20,978 - DEBUG - root - Adjusted indices: 43-52 for token 'τείνουσα' in normalized text.
# 2024-05-13 10:13:20,978 - DEBUG - root - Adjusted indices: 53-61 for token 'ἄνωθεν' in normalized text.
# 2024-05-13 10:13:20,979 - DEBUG - root - Adjusted indices: 67-77 for token 'ἀρτηρίης' in normalized text.
# 2024-05-13 10:13:20,979 - DEBUG - root - Adjusted indices: 91-96 for token 'ἀπὸ' in normalized text.
# 2024-05-13 10:13:20,980 - DEBUG - root - Adjusted indices: 118-121 for token 'παρ' in normalized text.
# 2024-05-13 10:13:20,980 - DEBUG - root - Adjusted indices: 123-130 for token 'ὀσφῦν' in normalized text.
# 2024-05-13 10:13:20,981 - DEBUG - root - Adjusted indices: 131-139 for token 'κάτωθεν' in normalized text.
# 2024-05-13 10:13:20,982 - DEBUG - root - Adjusted indices: 145-155 for token 'ἀρτηρίης' in normalized text.
# 2024-05-13 10:13:20,982 - DEBUG - root - Adjusted indices: 0-8 for token 'ἀίσσει' in normalized text.
# 2024-05-13 10:13:20,983 - DEBUG - root - Adjusted indices: 9-12 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:20,983 - DEBUG - root - Adjusted indices: 17-23 for token 'ἧπαρ' in normalized text.
# 2024-05-13 10:13:20,984 - DEBUG - root - Adjusted indices: 32-37 for token 'ἐπὶ' in normalized text.
# 2024-05-13 10:13:20,984 - DEBUG - root - Adjusted indices: 38-44 for token 'πύλας' in normalized text.
# 2024-05-13 10:13:20,985 - DEBUG - root - Adjusted indices: 50-56 for token 'λοβὸν' in normalized text.
# 2024-05-13 10:13:20,985 - DEBUG - root - Adjusted indices: 64-67 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:20,988 - DEBUG - root - Adjusted indices: 88-99 for token 'ἀφωρμήκει' in normalized text.
# 2024-05-13 10:13:20,988 - DEBUG - root - Adjusted indices: 100-117 for token 'σμικρὸν κάτωθεν' in normalized text.
# 2024-05-13 10:13:20,989 - DEBUG - root - Adjusted indices: 118-125 for token 'φρενῶν' in normalized text.
# 2024-05-13 10:13:20,989 - DEBUG - root - Adjusted indices: 0-7 for token 'φρένες' in normalized text.
# 2024-05-13 10:13:20,990 - DEBUG - root - Adjusted indices: 12-25 for token 'προσπεφύκασι' in normalized text.
# 2024-05-13 10:13:20,990 - DEBUG - root - Adjusted indices: 31-38 for token 'ἥπατι' in normalized text.
# 2024-05-13 10:13:20,991 - DEBUG - root - Adjusted indices: 81-86 for token 'ἀπὸ' in normalized text.
# 2024-05-13 10:13:20,991 - DEBUG - root - Adjusted indices: 89-98 for token 'κληΐδων' in normalized text.
# 2024-05-13 10:13:20,991 - DEBUG - root - Adjusted indices: 108-115 for token 'ἔνθεν' in normalized text.
# 2024-05-13 10:13:20,992 - DEBUG - root - Adjusted indices: 108-115 for token 'ἔνθεν' in normalized text.
# 2024-05-13 10:13:20,992 - DEBUG - root - Adjusted indices: 132-137 for token 'ὑπὸ' in normalized text.
# 2024-05-13 10:13:20,993 - DEBUG - root - Adjusted indices: 138-145 for token 'στῆθος' in normalized text.
# 2024-05-13 10:13:20,993 - DEBUG - root - Adjusted indices: 146-149 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:20,994 - DEBUG - root - Adjusted indices: 150-157 for token 'ἦτρον' in normalized text.
# 2024-05-13 10:13:20,995 - DEBUG - root - Adjusted indices: 10-20 for token 'ἐντεῦθεν' in normalized text.
# 2024-05-13 10:13:20,995 - DEBUG - root - Adjusted indices: 0-7 for token 'φρένες' in normalized text.
# 2024-05-13 10:13:20,996 - DEBUG - root - Adjusted indices: 13-18 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:20,996 - DEBUG - root - Adjusted indices: 20-25 for token 'κατὰ' in normalized text.
# 2024-05-13 10:13:20,997 - DEBUG - root - Adjusted indices: 31-41 for token 'σπόνδυλον' in normalized text.
# 2024-05-13 10:13:20,998 - DEBUG - root - Adjusted indices: 47-52 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:20,998 - DEBUG - root - Adjusted indices: 58-67 for token 'πλευρέων' in normalized text.
# 2024-05-13 10:13:20,999 - DEBUG - root - Adjusted indices: 74-81 for token 'νεφρὸς' in normalized text.
# 2024-05-13 10:13:21,001 - DEBUG - root - Adjusted indices: 86-96 for token 'ἀρτηρίης' in normalized text.
# 2024-05-13 10:13:21,002 - DEBUG - root - Adjusted indices: 106-121 for token 'ἀμφιβεβηκυῖαι' in normalized text.
# 2024-05-13 10:13:21,003 - DEBUG - root - Adjusted indices: 0-10 for token 'ἀρτηρίαι' in normalized text.
# 2024-05-13 10:13:21,003 - DEBUG - root - Adjusted indices: 15-18 for token 'ἐκ' in normalized text.
# 2024-05-13 10:13:21,003 - DEBUG - root - Adjusted indices: 27-37 for token 'πεφύκασιν' in normalized text.
# 2024-05-13 10:13:21,004 - DEBUG - root - Adjusted indices: 59-68 for token 'ἀρτηρίη' in normalized text.
# 2024-05-13 10:13:21,005 - DEBUG - root - Adjusted indices: 69-75 for token 'τόνον' in normalized text.
# 2024-05-13 10:13:21,005 - DEBUG - root - Adjusted indices: 15-30 for token 'παλινδρομήσασα' in normalized text.
# 2024-05-13 10:13:21,006 - DEBUG - root - Adjusted indices: 31-36 for token 'ἀπὸ' in normalized text.
# 2024-05-13 10:13:21,006 - DEBUG - root - Adjusted indices: 37-45 for token 'καρδίης' in normalized text.
# 2024-05-13 10:13:21,007 - DEBUG - root - Adjusted indices: 49-59 for token 'ἡπατῖτις' in normalized text.
# 2024-05-13 10:13:21,007 - DEBUG - root - Adjusted indices: 60-68 for token 'ἔληγεν' in normalized text.
# 2024-05-13 10:13:21,008 - DEBUG - root - Adjusted indices: 0-5 for token 'ἀπὸ' in normalized text.
# 2024-05-13 10:13:21,008 - DEBUG - root - Adjusted indices: 15-27 for token 'ἡπατίτιδος' in normalized text.
# 2024-05-13 10:13:21,009 - DEBUG - root - Adjusted indices: 28-32 for token 'διὰ' in normalized text.
# 2024-05-13 10:13:21,009 - DEBUG - root - Adjusted indices: 38-45 for token 'φρενῶν' in normalized text.
# 2024-05-13 10:13:21,052 - DEBUG - root - Adjusted indices: 0-5 for token 'παρὰ' in normalized text.
# 2024-05-13 10:13:21,052 - DEBUG - root - Adjusted indices: 14-22 for token 'ὀστέον' in normalized text.
# 2024-05-13 10:13:21,053 - DEBUG - root - Adjusted indices: 23-31 for token 'περόναι' in normalized text.
# 2024-05-13 10:13:21,053 - DEBUG - root - Adjusted indices: 37-48 for token 'παρήκουσιν' in normalized text.
# 2024-05-13 10:13:21,054 - DEBUG - root - Adjusted indices: 58-67 for token 'ἔνδοθεν' in normalized text.
# 2024-05-13 10:13:21,055 - DEBUG - root - Adjusted indices: 75-82 for token 'ἐκτός' in normalized text.
# 2024-05-13 10:13:21,055 - DEBUG - root - Adjusted indices: 89-94 for token 'πρὸς' in normalized text.
# 2024-05-13 10:13:21,056 - DEBUG - root - Adjusted indices: 113-121 for token 'ὀστέῳ' in normalized text.
# 2024-05-13 10:13:21,057 - DEBUG - root - Adjusted indices: 137-148 for token 'ἤρθρωνται' in normalized text.
# 2024-05-13 10:13:21,057 - DEBUG - root - Adjusted indices: 150-155 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:21,057 - DEBUG - root - Adjusted indices: 159-162 for token 'ἐν' in normalized text.
# 2024-05-13 10:13:21,058 - DEBUG - root - Adjusted indices: 168-176 for token 'ἀγκῶνι' in normalized text.
# 2024-05-13 10:13:21,059 - DEBUG - root - Adjusted indices: 150-155 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:21,059 - DEBUG - root - Adjusted indices: 189-196 for token 'περόνη' in normalized text.
# 2024-05-13 10:13:21,059 - DEBUG - root - Adjusted indices: 197-206 for token 'ήρθρωται' in normalized text.
# 2024-05-13 10:13:21,061 - DEBUG - root - Adjusted indices: 178-183 for token 'κάτω' in normalized text.
# 2024-05-13 10:13:21,062 - DEBUG - root - Adjusted indices: 224-229 for token 'ἄνω' in normalized text.
# 2024-05-13 10:13:21,062 - DEBUG - root - Adjusted indices: 248-256 for token 'περόνης' in normalized text.
# 2024-05-13 10:13:21,063 - DEBUG - root - Adjusted indices: 257-260 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:21,064 - DEBUG - root - Adjusted indices: 266-274 for token 'ἀγκώνα' in normalized text.
# file name:  Hippocrates epidemics 2.4.1 pt.1.zip
# file name:  Hippocrates epidemics 2.4.1 pt.3.zip
# file name:  hippocrates places in man 6.3-4.zip
# 2024-05-13 10:13:21,065 - DEBUG - root - Adjusted indices: 282-290 for token 'ὀστέον' in normalized text.
# 2024-05-13 10:13:21,065 - DEBUG - root - Adjusted indices: 248-255 for token 'περόνη' in normalized text.
# 2024-05-13 10:13:21,066 - DEBUG - root - Adjusted indices: 257-260 for token 'ἐς' in normalized text.
# 2024-05-13 10:13:21,066 - DEBUG - root - Adjusted indices: 322-334 for token 'συμβάλλοντα' in normalized text.
# 2024-05-13 10:13:21,067 - DEBUG - root - Adjusted indices: 335-343 for token 'ἄρθρον' in normalized text.
# 2024-05-13 10:13:21,067 - DEBUG - root - Adjusted indices: 353-361 for token 'κυβίτῳ' in normalized text.
# 2024-05-13 10:13:21,111 - DEBUG - root - Adjusted indices: 12-20 for token 'συνεχής' in normalized text.
# 2024-05-13 10:13:21,111 - DEBUG - root - Adjusted indices: 21-27 for token 'ὑμὴν' in normalized text.
# ...
#  ('οὔκουν ἀπιστητέον ἡμῖν περὶ τοῦ ποτοῦ εἰ εὐτρεπίζει τὴν σύριγγα τῷ ἀνθρώπῳ.',
#   {'entities': [(69, 77, 'Body Part')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ἀλλὰ πῶς ὕδωρ ἀναιδὲς ἐνοροῦον ὄχλον καὶ βῆχα παρέχει πολλήν; οὕνεκα, φημί, ἀπάντικρυ τῆς ἀναπνοῆς φέρεται.',
#   {'entities': [(19, 28, 'Adjectives/Qualities'),
#     (68, 75, 'Adjectives/Qualities'),
#     (94, 105, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('τὸ γὰρ διὰ τῆς ὁρμης ἐσρέον, ἅτε παρὰ τοῖχον ἰόν, οὐκ ἐνίσταται τῇ ἀναφορῇ τοῦ ἠέρος, ἀλλά τινα καὶλείην ὁδόν οἱ παρέχει ἡ ἐπίτεγξις·',
#   {'entities': [(9, 13, 'Topography'),
#     (42, 47, 'Topography'),
#     (48, 55, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('τοῦτο δὲ τὸ ὑγρὸν ἀπάγει τοῦ πνεύμονος ἅμα τῷ ἠέρι.',
#   {'entities': [(23, 31, 'Topography'), (37, 47, 'Body Part')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('τὸν μὲν οὖν ἠέρα χρή, γενόμενον θεραπείην, ὀπίσω τὴν αὐτὴν ὁδὸν ἐκβάλλειν ἔνθεν ἤγαγε·',
#   {'entities': [(52, 59, 'Topography'),
#     (60, 64, 'Topography'),
#     (65, 72, 'Topography'),
#     (73, 79, 'Topography'),
#     (92, 99, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('τὸ δὲ ὑγρόν, τὸ μὲν εἰς τὸν κουλεὸν αὐτῆς ἀποπτύει, τὸ δʼ αὖ σὺν τῷ ἠέρι θύραζε χωρέειν ἐᾷ.',
#   {'entities': [(26, 30, 'Topography'),
#     (36, 44, 'Body Part'),
#     (94, 101, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ταύτῃ καὶ διαίρει τὸν οὐραχὸν ὁκόταν παλινδρομῇ τὸ πνεῦμα·',
#   {'entities': [(27, 36, 'Body Part'),
#     (46, 58, 'Physiology'),
#     (63, 70, 'Body Part')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('παλινδρομεῖ δὲ κατὰ δίκην·',
#   {'entities': [(0, 12, 'Physiology')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('κῶς γὰρ ἀνθρώπου τροφὴ ἄνεμος καὶ ὕδωρ τὰ ὠμά; ἀλλὰ μᾶλλον τιμωρίη ξυγγενέος πάθης.',
#   {'entities': [(53, 58, 'Adjectives/Qualities')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('περὶ δὲ οὗ λόγος, ἡ καρδίη μῦς ἐστι κάρτα ἰσχυρός, οὒ τῳ νεύρῳ, ἀλλὰ πιλήματι σαρκός.',
#   {'entities': [(26, 33, 'Body Part'),
#     (34, 38, 'Body Part'),
#     (45, 51, 'Adjectives/Qualities'),
#     (52, 61, 'Adjectives/Qualities'),
#     (72, 79, 'Adjectives/Qualities'),
#     (88, 97, 'Adjectives/Qualities'),
#     (98, 105, 'Body Part')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('καὶ δύο γαστέρας ἔχει διακεκριμένας ἐν ἑνὶ περιβόλῳ, τὴν μὲν ἔνθα, τὴν δὲ ἔνθα·',
#   {'entities': [(5, 9, 'Adjectives/Qualities'),
#     (10, 19, 'Body Part'),
#     (27, 41, 'Topography'),
#     (42, 45, 'Topography'),
#     (46, 51, 'Adjectives/Qualities'),
#     (52, 62, 'Body Part'),
#     (74, 80, 'Topography'),
#     (74, 80, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('οὐδὲν δʼ ἐοίκασιν ἀλλήλῃσιν·',
#   {'entities': [(11, 21, 'Adjectives/Qualities')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ἡ μὲν γὰρ ἐν τοῖσι δεξιοῖσιν ἐπὶ στόμα κεῖται ὁμιλέουσα τῇ ἑτέρῃ φλεβί, ἡ δὲ δεξιή φημι τῶν ἐν λαιοῖσι·',
#   {'entities': [(13, 16, 'Topography'),
#     (24, 34, 'Topography'),
#     (35, 40, 'Topography'),
#     (41, 47, 'Body Part'),
#     (48, 55, 'Topography'),
#     (56, 67, 'Topography'),
#     (73, 81, 'Adjectives/Qualities'),
#     (82, 88, 'Body Part'),
#     (97, 103, 'Body Part'),
#     (114, 117, 'Topography'),
#     (118, 126, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ἡ γὰρ πᾶσα καρδίη τούτοισι τὴν ἕδρην ἐμπεποίηται·',
#   {'entities': [(8, 13, 'Adjectives/Qualities'),
#     (14, 21, 'Body Part'),
#     (32, 36, 'Topography'),
#     (37, 44, 'Topography'),
#     (45, 58, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('ἀτὰρ ἥδε καὶ πάμπαν εὐρυκοίλιος καὶ λαγαρωτέρη πολλῷ τῆς ἑτέρης, οὐδὲ τῆς καρδίης νέμεται τὴν ἐσχατιήν, ἀλλʼ ἐγκαταλέιπει τὸν οὐραχὸν στερεὸν καί ἔστιν ὥσπερ ἔξωθεν προσερραμμένη.',
#   {'entities': [(7, 12, 'Body Part'),
#     (18, 25, 'Adjectives/Qualities'),
#     (26, 39, 'Adjectives/Qualities'),
#     (45, 56, 'Adjectives/Qualities'),
#     (57, 64, 'Adjectives/Qualities'),
#     (70, 78, 'Body Part'),
#     (92, 100, 'Body Part'),
#     (101, 109, 'Topography'),
#     (115, 125, 'Body Part'),
#     (133, 147, 'Topography'),
#     (153, 162, 'Body Part'),
#     (163, 171, 'Adjectives/Qualities'),
#     (193, 201, 'Topography'),
#     (202, 216, 'Topography')]},
#   'Hippocratic_De corde Part A chs 1-4'),
#  ('παρὰ τὸν πήχυν δὲ περόναι παρήκουσι λεπταί πάνυ τέσσερις, οἱ το μὲν δύο ἄνω, αἱ δὲ δύο κάτω·',
#   {'entities': [(0, 5, 'Topography'),
#     (11, 17, 'Body Part'),
#     (22, 30, 'Body Part'),
#     (31, 41, 'Topography'),
#     (42, 49, 'Adjectives/Qualities'),
#     (84, 89, 'Topography'),
#     (104, 109, 'Topography')]},
#   'hippocrates places in man 6.5-6'),
#  ('καὶ πρὸς μὲν τὸν ἀγκῶνα δύο περόναι πεφυκυῖαι ἄνω ἐκ τοῦ ὀστέου αὗται σὺν τῷ ὀστέῳ πεφυκυίαι παρὰ τὸ τοῦ ὀστέου ἄρθρον ἤρθρωνται ἐς τὸ κύβιτον·',
#   {'entities': [(5, 10, 'Topography'),
#     (21, 29, 'Body Part'),
#     (35, 43, 'Body Part'),
#     (44, 54, 'Topography'),
#     (55, 60, 'Topography'),
#     (61, 64, 'Topography'),
#     (70, 78, 'Body Part'),
#     (97, 105, 'Body Part'),
#     (106, 116, 'Topography'),
#     (117, 122, 'Topography'),
#     (132, 140, 'Body Part'),
#     (141, 149, 'Body Part'),
#     (150, 161, 'Topography'),
#     (170, 178, 'Body Part')]},
#   'hippocrates places in man 6.5-6'),
#  ('αἱ δὲ κάτω κείμενοι καὶ ἐντὸς κεκλιμέναι, αὗται ἀμφότεραι συμβάλλουσαι πρὸς τὴν περόνην τὴν ἄνωθεν ἀπὸ τοῦ γυίου φερομένην, ἐντὸς τοῦ γυίου ἤρθρωνται, και περόνην καλουμένην ποιέουσιν, αυται ἑωυτῇσι συμβάλλουσαι ἐν τῷ κυβίτῳ ἐντός.',
#   {'entities': [(8, 13, 'Topography'),
#     (14, 23, 'Topography'),
#     (29, 36, 'Topography'),
#     (37, 48, 'Topography'),
#     (70, 83, 'Topography'),
#     (95, 103, 'Body Part'),
#     (109, 117, 'Topography'),
#     (118, 123, 'Topography'),
#     (129, 135, 'Body Part'),
#     (136, 146, 'Topography'),
#     (148, 155, 'Topography'),
#     (129, 135, 'Body Part'),
#     (168, 179, 'Topography'),
#     (185, 193, 'Technical Appellation'),
#     (235, 248, 'Topography'),
#     (249, 252, 'Topography'),
#     (258, 266, 'Body Part'),
#     (267, 274, 'Topography')]},
#   'hippocrates places in man 6.5-6'),
#  ('κάτω δὲ πρὸς τὴν χεῖρα τὸ ὀστέον ἄρθρον ἔχει·',
#   {'entities': [(0, 5, 'Topography'),
#     (10, 15, 'Topography'),
#     (21, 27, 'Body Part'),
#     (32, 40, 'Body Part'),
#     (41, 49, 'Body Part')]},
#   'hippocrates places in man 6.5-6'),
 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('τραχήλου ἐς τὸν μέγαν ἑπτά·',
#   {'entities': [(0, 9, 'Body Part'), (10, 13, 'Topography')]},
#   'On Nature of Bones 1'),
#  ('ὀσφύος πέντε·',
#   {'entities': [(0, 8, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ῥάχιος εἴκοσι·',
#   {'entities': [(0, 8, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('κεφαλῆς ξύν ὀπωπίοισιν ὀκτὼ ·',
#   {'entities': [(0, 8, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ξύμπαντα ὀγδοήκοντα ὀκτώ, σὺν ὄνυξιν ἑκατὸν ὀκτώ.',
#   {'entities': [(36, 44, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ἅ δʼ ἡμεῖς αὐτοὶ ἐξ ἀνθρώπου ὀστέων κατεμάθομεν, σφόνδυλοι οἱ ἄνω τῆς κληῖδος ξὺν τῷ μεγάλῳ ἑπτά·',
#   {'entities': [(38, 46, 'Body Part'),
#     (61, 71, 'Body Part'),
#     (76, 81, 'Topography'),
#     (87, 95, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('οἱ δὲ κατὰ τὰς πλευράς ὅσαιπερ αἱ πλευραὶ δώδεκα·',
#   {'entities': [(8, 13, 'Topography'),
#     (19, 27, 'Body Part'),
#     (42, 50, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('οἱ δὲ κατὰ κενεῶνας ἐκτός, ἐν ᾧ τὰ ἰσχία, ἐν τῇ ὀσφύι πέντε·',
#   {'entities': [(8, 13, 'Topography'),
#     (14, 23, 'Body Part'),
#     (33, 36, 'Topography'),
#     (46, 53, 'Body Part'),
#     (33, 36, 'Topography'),
#     (64, 71, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('τὸ δὲ σπέρμα οἷον κηρίον ἑκατέρωθεν τῆς κύστιος·',
#   {'entities': [(8, 15, 'Body Part'),
#     (31, 43, 'Topography'),
#     (49, 57, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ἐκ δʼ αὐτῶν φλέβες ἑκατέρωθεν τοῦ οὐρητῆρος ἐς τὸ αἰδοῖον τείνουσι.',
#   {'entities': [(0, 3, 'Topography'),
#     (15, 22, 'Body Part'),
#     (23, 35, 'Topography'),
#     (41, 52, 'Body Part'),
#     (53, 56, 'Topography'),
#     (61, 70, 'Body Part'),
#     (71, 80, 'Topography')]},
#   'On Nature of Bones 1'),
#  ('ποτὸν διὰ φάρυγγος καὶ διὰ στομάχου (λάρυγξ ἐς πλεύμονα καὶ ἀρτηρίην)·',
#   {'entities': [(7, 11, 'Topography'),
#     (12, 21, 'Body Part'),
#     (27, 31, 'Topography'),
#     (32, 41, 'Body Part'),
#     (43, 50, 'Body Part'),
#     (51, 54, 'Topography'),
#     (55, 64, 'Body Part'),
#     (70, 80, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ἀπὸ δὲ τούτων ἐς ἄκρην κύστιν.',
#   {'entities': [(0, 5, 'Topography'),
#     (18, 21, 'Topography'),
#     (30, 37, 'Body Part')]},
#   'On Nature of Bones 1'),
#  ('ταύτῃ δʼ ἐφεξῆς τῇ κεφαλῇ τετάρτην ἄλλην εὑρήσεις, ὡς εἶπον·',
#   {'entities': [(52, 63, 'Action Verbs')]},
#   'Gal. AA, 2, 4, 91, 28 - 93, 16'),
#  ('ἐφʼ ἑνὸς γὰρ στίχου τεταγμέναι πᾶσαι τοῦ κατʼ ἰσχίον ἐκπεφύκασιν ὀστοῦ.',
#   {'entities': [(54, 62, 'Body Part'), (77, 84, 'Body Part')]},
#   'Gal. AA, 2, 4, 91, 28 - 93, 16'),
#  
# %%
import seaborn as sns
import matplotlib.pyplot as plt
from spacy.tokens import DocBin
import pandas as pd

if nlp is None:
    nlp = spacy.load("../training/SageMaker/transformer/PROIEL/Assembled/pos-trf-11-may-2024/model-best/")  # Example with a blank English model. Replace according to your model.
    
def visualize_label_distribution(nlp=nlp, form='NFKD'):
    # Load the train, test and dev data
    FORMAT = form
    train_docbin = DocBin().from_disk("../corpus/train/ner_train/ner_train_{0}.spacy".format(FORMAT))
    train_docs = list(train_docbin.get_docs(nlp.vocab))
    dev_docbin = DocBin().from_disk("../corpus/dev/ner_dev/ner_dev_{0}.spacy".format(FORMAT))
    dev_docs = list(dev_docbin.get_docs(nlp.vocab))
    test_docbin = DocBin().from_disk("../corpus/test/ner_test/ner_test_{0}.spacy".format(FORMAT))
    test_docs = list(test_docbin.get_docs(nlp.vocab))

    # Print the number of sentences in train, test and dev data
    print ("train:", len(train_docs), "dev:", len(dev_docs), "test:", len(test_docs))

    sns.set(style="darkgrid")

    # Extract labels from each dataset
    train_data_labels = pd.DataFrame([ent.label_ for doc in train_docs for ent in doc.ents], columns=['labels'])
    dev_data_labels = pd.DataFrame([ent.label_ for doc in dev_docs for ent in doc.ents], columns=['labels'])
    test_data_labels = pd.DataFrame([ent.label_ for doc in test_docs for ent in doc.ents], columns=['labels'])

    # Add a 'dataset' column to each dataframe
    train_data_labels['dataset'] = 'train'
    dev_data_labels['dataset'] = 'dev'
    test_data_labels['dataset'] = 'test'

    # Concatenate all dataframes
    all_data_labels = pd.concat([train_data_labels, dev_data_labels, test_data_labels], ignore_index=True)

    # Plot the distribution of labels in each dataset
    plt.figure(figsize=(20,10))
    sns.countplot(data=all_data_labels, x='labels', hue='dataset')
    plt.title("Distribution of labels in the train, test, and dev data")

    # Plot the frequency of labels in the train data
    train_data_labels = train_data_labels['labels'].value_counts().reset_index()
    plt.figure(figsize=(20,10))
    sns.barplot(data=train_data_labels, x='labels', y='count')
    plt.title("Frequency of labels in the train data")
    plt.xticks(rotation=90)

    plt.show()
    
    return train_docs, dev_docs, test_docs
# Out:
# 2024-05-13 10:13:27,386 - DEBUG - matplotlib - matplotlib data path: /root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data
# 2024-05-13 10:13:27,390 - DEBUG - matplotlib - CONFIGDIR=/root/.config/matplotlib
# 2024-05-13 10:13:27,391 - DEBUG - matplotlib - interactive is False
# 2024-05-13 10:13:27,392 - DEBUG - matplotlib - platform is linux
# 2024-05-13 10:13:27,390 - DEBUG - matplotlib - CONFIGDIR=/root/.config/matplotlib
# 2024-05-13 10:13:27,391 - DEBUG - matplotlib - interactive is False
# 2024-05-13 10:13:27,392 - DEBUG - matplotlib - platform is linux
# 2024-05-13 10:13:27,429 - DEBUG - matplotlib - CACHEDIR=/root/.cache/matplotlib
# 2024-05-13 10:13:27,431 - DEBUG - matplotlib.font_manager - Using fontManager instance from /root/.cache/matplotlib/fontlist-v330.json

# %%
train_docs, dev_docs, test_docs = visualize_label_distribution(nlp, form='NFKD')
# Out:
# 2024-05-13 10:13:27,814 - DEBUG - matplotlib.pyplot - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2024-05-13 10:13:27,815 - DEBUG - matplotlib.pyplot - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2024-05-13 10:13:27,832 - DEBUG - matplotlib.font_manager - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# 2024-05-13 10:13:27,833 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-05-13 10:13:27,834 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-05-13 10:13:27,834 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-05-13 10:13:27,835 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-05-13 10:13:27,835 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2024-05-13 10:13:27,836 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-05-13 10:13:27,836 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-05-13 10:13:27,837 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-05-13 10:13:27,838 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2024-05-13 10:13:27,838 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2024-05-13 10:13:27,839 - DEBUG - matplotlib.font_manager - findfont: score(FontEntry(fname='/root/anaconda3/envs/atlomy_nlp/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2024-05-13 10:13:27
lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 2.050000.
# train: 406 dev: 51 test: 51

# %%
from spacy.tokens import DocBin

# load a docbin
test_doc_bin_nfkc = DocBin().from_disk("../corpus/train/ner_train/ner_train_NFKC.spacy")
test_doc_bin_nfkd = DocBin().from_disk("../corpus/train/ner_train/ner_train_NFKD.spacy")
test_docs_nfkc = list(test_doc_bin_nfkc.get_docs(nlp.vocab))
test_docs_nfkd = list(test_doc_bin_nfkd.get_docs(nlp.vocab))

def print_user_data_for_label(docs, label):
    for doc in docs:
        # Check if the doc contains an entity with the specified label
        if any(ent.label_ == label for ent in doc.ents):
            print("doc user data: ", doc.user_data)

# %%
print_user_data_for_label(test_docs_nfkc, "Action verb")

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Extract labels from the training data
train_data_labels = [ent.label_ for docs in train_docs for ent in docs.ents]

# Convert the list of labels into a DataFrame
train_data_labels = pd.DataFrame(train_data_labels, columns=['labels'])

# Count the frequency of each label
train_data_labels = train_data_labels['labels'].value_counts()

# Convert the Series object into a DataFrame and reset the index
train_data_labels = pd.DataFrame(train_data_labels).reset_index()

# Rename the columns for better understanding
train_data_labels.columns = ['Label', 'Count']

# Print the DataFrame
print(train_data_labels)

# Plot the frequency of each label
plt.figure(figsize=(20,10))
sns.barplot(data=train_data_labels, x='Label', y='Count')
plt.title("Frequency of labels in the train data")
plt.xticks(rotation=90)
plt.show()
# Out:
#                    Label  Count
# 0              Body Part    984
# 1             Topography    914
# 2   Adjectives/Qualities    414
# 3             Physiology     74
# 4                Medical     65
# 5           Action Verbs     64
# 6               Division     43
# 7  Technical Appellation     23
# 8    Symmetry/Opposition     13
# 9              Pathology      7

# %%
# load the train, test and dev data
#import spacy
#from spacy.tokens import DocBin
#nlp = spacy.load("grc_proiel_trf")
FORMAT = 'NFKD'
train_docbin = DocBin().from_disk("../corpus/train/ner_train/ner_train_{0}.spacy".format(FORMAT))
# get docs from new_docbin
train_docs = list(train_docbin.get_docs(nlp.vocab))
dev_docbin = DocBin().from_disk("../corpus/dev/ner_dev/ner_dev_{0}.spacy".format(FORMAT))
# get docs from new_docbin
dev_docs = list(dev_docbin.get_docs(nlp.vocab))
test_docbin = DocBin().from_disk("../corpus/test/ner_test/ner_test_{0}.spacy".format(FORMAT))
# get docs from new_docbin
test_docs = list(test_docbin.get_docs(nlp.vocab))
# count sentences in train, test and dev data
print ("train:", len(train_docs), "dev:", len(dev_docs), "test:", len(test_docs))
# Out:
# train: 406 dev: 51 test: 51

# %%
# load the train, test and dev data
#import spacy
#from spacy.tokens import DocBin
#nlp = spacy.load("grc_proiel_trf")
FORMAT = 'NFKC'
train_docbin = DocBin().from_disk("../corpus/train/ner_train/ner_train_{0}.spacy".format(FORMAT))
# get docs from new_docbin
train_docs = list(train_docbin.get_docs(nlp.vocab))
dev_docbin = DocBin().from_disk("../corpus/dev/ner_dev/ner_dev_{0}.spacy".format(FORMAT))
# get docs from new_docbin
dev_docs = list(dev_docbin.get_docs(nlp.vocab))
test_docbin = DocBin().from_disk("../corpus/test/ner_test/ner_test_{0}.spacy".format(FORMAT))
# get docs from new_docbin
test_docs = list(test_docbin.get_docs(nlp.vocab))
# count sentences in train, test and dev data
print ("train:", len(train_docs), "dev:", len(dev_docs), "test:", len(test_docs))
# find sentence "διακοπεῖσα δὲ οὐδʼ ἡ κύστις συμφύεται ἀλλʼ ἢ παρʼ αὐτὴν τὴν ἀρχὴν τοῦ οὐρητῆρος, εἰ μή τι πάμπαν σπάνιον" and print ents for tokens
for doc in train_docs:
    if doc.text == "τὴν μὲν γὰρ καρδίην ἴδοις ἂν ῥιπταζομένην οὐλομελῆ, τὰ δὲ οὔατα κατʼ ἰδίην ἀναφυσώμενά τε καὶ ξυμπίπτοντα.":
        print("doc user data: ", doc.user_data)
        for ent in doc.ents:
            print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# train: 406 dev: 51 test: 51
# doc user data:  {'source_info': 'Hippocratic_De corde Part B chs 5-9'}
# καρδίην 12 19 Body Part
# ῥιπταζομένην 29 41 Physiology
# οὐλομελῆ 42 50 Physiology
# οὔατα 58 63 Body Part
# κατʼ 64 68 Topography
# ἰδίην 69 74 Physiology
# ἀναφυσώμενά 75 86 Physiology
# ξυμπίπτοντα 94 105 Physiology

# %%
# debug ner data in spacy
import random
# sample random from train_docs
doc = random.choice(train_docs)
print (doc.text)
for ent in doc.ents:
    print (ent.text, ent.label_)
print ("Spacy entities, for line:")
print (doc.text)
print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# προχωρῶν δʼ ἐπὶ τὰ πλάγια παρὰ τὰς νόθας πλευράς, εἰ μὴ προσέχοις τὸν νοῦν, διασπάσεις [οἷον] τὴν κεφαλὴν τοῦ μικροῦ μυός, ὃν εἰς τὴν μασχάλην ἔλεγον ἀναφέρεσθαι λαθόντα τοὺς ἀνατομικούς.
# πλάγια Topography
# τὰς νόθας πλευράς Medical
# διασπάσεις Action Verbs
# μικροῦ Adjectives/Qualities
# μυός Body Part
# μασχάλην Body Part
# Spacy entities, for line:
# προχωρῶν δʼ ἐπὶ τὰ πλάγια παρὰ τὰς νόθας πλευράς, εἰ μὴ προσέχοις τὸν νοῦν, διασπάσεις [οἷον] τὴν κεφαλὴν τοῦ μικροῦ μυός, ὃν εἰς τὴν μασχάλην ἔλεγον ἀναφέρεσθαι λαθόντα τοὺς ἀνατομικούς.
# [('πλάγια', 'Topography'), ('τὰς νόθας πλευράς', 'Medical'), ('διασπάσεις', 'Action Verbs'), ('μικροῦ', 'Adjectives/Qualities'), ('μυός', 'Body Part'), ('μασχάλην', 'Body Part')]

# %%
from IPython.display import Markdown, display

def print_words_at_indices(sentence, entities, source):
    for start, end, label in entities:
        word = sentence[start:end]
        display(Markdown(sentence[:start] + f"**[{word}]**" + sentence[end:]))
        print(f"Word: {word}, Label: {label}, Source: {source}")

# Example usage:
# Assuming TRAIN_DATA2 is already defined and is not empty.
#sentence, entities_dict = TRAIN_DATA[207]  # Get the first sentence and its entities.
#entities = entities_dict['entities']  # Get the list of entity tuples.
#print_words_at_indices(sentence, entities)
sentence, entities_dict, source = MERGED_TRAIN_DATA[252]  # Get the first sentence and its entities.
entities = entities_dict['entities']  # Get the list of entity tuples.
print_words_at_indices(sentence, entities, source)
# Out:
# καί σοι τοῦτʼ ἔσται μέγιστον γνώρισμα τοῦ **[τετμῆσθαι]** καλώς.
# Word: τετμῆσθαι, Label: Action Verbs, Source: Gal. AA. 5, 7, 313, 28 - 315, 19
