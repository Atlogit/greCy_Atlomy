# %% [markdown]
# # Train Lemmatizer

# %%
# !python -m spacy debug data ../configs/lemmatizer_trf_wantuta.cfg --paths.train ../corpus/train/lemma_train/ --paths.dev ../corpus/dev/lemma_dev/ --nlp.lang=grc
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
#
# ============================ Data file validation ============================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
# !python -m spacy debug data ../configs/lemmatizer_trf_wantuta.cfg --paths.train ../corpus/train/lemma_train/ --paths.dev ../corpus/dev/lemma_dev/ --nlp.lang=grc
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
#
# ============================ Data file validation ============================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
# !python -m spacy debug data ../configs/lemmatizer_trf_wantuta.cfg --paths.train ../corpus/dataset_info_lemma/train/ --paths.dev ../corpus/dataset_info_lemma/dev/ --nlp.lang=grc
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
#
# ============================ Data file validation ============================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
# !python -m spacy train ../configs/lemmatizer_trf_wantuta.cfg  --output ../training/lemmatizer/trf_26_jan_2025_wantuta_NFC_epoch_0 --paths.train ../corpus/train/lemma_train/ --paths.dev ../corpus/dev/lemma_dev/ --gpu-id 0 --nlp.lang=grc
# Out:
# ✔ Created output directory:
# ../training/lemmatizer/trf_26_jan_2025_wantuta_NFC_epoch_0
# ℹ Saving to output directory:
# ../training/lemmatizer/trf_26_jan_2025_wantuta_NFC_epoch_0
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %%
# !python -m spacy train ../configs/lemmatizer_trf_wantuta.cfg  --output ../training/lemmatizer/trf_18_dec_2024_wantuta --paths.train ../corpus/train/lemma_train/ --paths.dev ../corpus/dev/lemma_dev/ --gpu-id 0 --nlp.lang=grc
# Out:
# ℹ Saving to output directory:
# ../training/lemmatizer/trf_18_dec_2024_wantuta
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %%
# !python -m spacy train ../configs/lemmatizer_trf_aristoberto.cfg  --output ../training/lemmatizer/trf_18_dec_2024_aristoBERTo --paths.train ../corpus/train/lemma_train/ --paths.dev ../corpus/dev/lemma_dev/ --gpu-id 0 --nlp.lang=grc
# Out:
# ℹ Saving to output directory:
# ../training/lemmatizer/trf_18_dec_2024_aristoBERTo
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %%
#  train large vectors lemmatizer with grecy+atlomy texts db 20 dec 2024
# !python -m spacy train ../configs/lemmatizer_vec.cfg  --output ../training/lemmatizer/vec_large_20_dec_2024 --paths.train ../corpus/train/lemma_train_Copy_18-12-24/ --paths.dev ../corpus/dev/lemma_dev_Copy_18-12-24/ --paths.vectors ../vectors/large --gpu-id 0 --nlp.lang=grc
# Out:
# ℹ Saving to output directory:
# ../training/lemmatizer/vec_large_20_dec_2024
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %% [markdown]
# # train transformer-based pipeline for POS and morphology

# %%
# 9/25/24: Debug PoS data for transformer with lemmatizer (full texts db) 8th November 2023
# !python -m spacy debug data ../configs/transformer_proiel_SageMaker_trf_Sep_25.cfg --paths.train ../corpus/train/pos_train/ --paths.dev ../corpus/dev/pos_dev/ --paths.lemmatizer_model ../training/SageMaker/lemmatizer/lemma-trf-26-jan-25-NFC/model-best --nlp.lang=grc
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'grc_pipeline' (0.0.0) was trained with spaCy v3.7.4 and may not be 100% compatible with the current version (3.8.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
# ...

# %%
# 3/25/25: Training the transformer pipline with lemmatizer (full texts db) 25th September 2024 - 2nd try with lmmatizer annotating
# !python -m spacy train ../configs/transformer_proiel_SageMaker_trf_Sep_25.cfg --output ../training/transformer/proiel/assembled/trf_25_mar_25 --paths.train ../corpus/train/pos_train/ --paths.dev ../corpus/dev/pos_dev/ --paths.lemmatizer_model ../training/SageMaker/lemmatizer/lemma_trf_26_jan_25_NFC/model-best --training.logger.run_name "greCy_pos_trf_25_mar_25" --gpu-id 0 --nlp.lang=grc

# %%
# 3/25/25: Training the transformer pipline with lemmatizer (full texts db) 25th September 2024 - 2nd try with lmmatizer annotating AND WITH TRANSFORMER name = "wantuta/roberta_ancient_greek_mlm"
# !python -m spacy train ../configs/transformer_proiel_SageMaker_trf_Sep_25_WITH_WANTUTA_TRF.cfg --output ../training/transformer/proiel/assembled/trf_25_mar_25_wantuta --paths.train ../corpus/train/pos_train/ --paths.dev ../corpus/dev/pos_dev/ --paths.lemmatizer_model ../training/SageMaker/lemmatizer/lemma_trf_26_jan_25_NFC/model-best --training.logger.run_name "greCy_pos_trf_25_mar_25_wantuta" --gpu-id 0 --nlp.lang=grc --paths.source_path ../training/SageMaker/lemmatizer/lemma_trf_26_jan_25_NFC/model-best
# Out:
# ℹ Saving to output directory:
# ../training/transformer/proiel/assembled/trf_25_mar_25_wantuta
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %%
# 2/27/25: Training the transformer pipline with lemmatizer (full texts db) 25th September 2024
# !python -m spacy train ../configs/transformer_proiel_SageMaker_trf_Sep_25.cfg --output ../training/transformer/proiel/assembled/trf_27_feb_25 --paths.train ../corpus/train/pos_train/ --paths.dev ../corpus/dev/pos_dev/ --paths.lemmatizer_model ../training/SageMaker/lemmatizer/lemma-trf-26-jan-25-NFC/model-best --training.logger.run_name "greCy_pos_trf_27_feb_25" --gpu-id 0 --nlp.lang=grc
# Out:
# ✔ Created output directory:
# ../training/transformer/proiel/assembled/trf_27_feb_25
# ℹ Saving to output directory:
# ../training/transformer/proiel/assembled/trf_27_feb_25
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %% [markdown]
# # train the SpanCat model

# %%
# train spancat with wantuta 25.3.25
# !python -m spacy train ../configs/SpanCat_full_pipeline_annotating_transformer_lemmatizer.cfg --output ../training/ATLOMY_G_NER_pipeline/atlomy_full_pipeline_annotation_wantuta_032325 --paths.train ../corpus/train/spancat_train/spancat_train_NFC.spacy --paths.dev ../corpus/dev/spancat_dev/spancat_dev_NFC.spacy --paths.source_path ../training/transformer/proiel/assembled/trf_25_mar_25_wantuta/model-best/  --gpu-id 0 --nlp.lang=grc
# Out:
# ✔ Created output directory:
# ../training/ATLOMY_G_NER_pipeline/atlomy_full_pipeline_annotation_wantuta_032325
# ℹ Saving to output directory:
# ../training/ATLOMY_G_NER_pipeline/atlomy_full_pipeline_annotation_wantuta_032325
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %%
# Debug spancat data for transformer with lemmatizer (full texts db) 
# !python -m spacy debug data ../configs/SpanCat_full_pipeline_annotating_transformer_lemmatizer.cfg --paths.train ../corpus/train/spancat_train/spancat_train_NFC.spacy --paths.dev ../corpus/dev/spancat_dev/spancat_dev_NFC.spacy --paths.source_path ../training/transformer/proiel/assembled/trf_27_feb_25/model-best/ --nlp.lang=grc
# Out:
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %%
# !python -m spacy train ../configs/SpanCat_full_pipeline_annotating_transformer_lemmatizer.cfg --output ../training/ATLOMY_G_NER_pipeline/atlomy_full_pipeline_annotation_032325 --paths.train ../corpus/train/spancat_train/spancat_train_NFC.spacy --paths.dev ../corpus/dev/spancat_dev/spancat_dev_NFC.spacy --paths.source_path ../training/transformer/proiel/assembled/trf_27_feb_25/model-best/  --gpu-id 0 --nlp.lang=grc
# Out:
# ✔ Created output directory:
# ../training/ATLOMY_G_NER_pipeline/atlomy_full_pipeline_annotation_032325
# ℹ Saving to output directory:
# ../training/ATLOMY_G_NER_pipeline/atlomy_full_pipeline_annotation_032325
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /root/anaconda3/envs/atlomy_nlp/lib/python3.12/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %% [markdown]
# # Model Package

# %%
# !python -m spacy package '../model_folder/model-best' '../packages/model_folder/' --name "model_name" --version 0.1
